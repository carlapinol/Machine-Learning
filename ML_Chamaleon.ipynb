# %% [markdown]
# # Node classification practice

# %%
#Libraries we are going to use
# Install required packages.
import os
import torch #Library for deep learning
os.environ['TORCH'] = torch.__version__
print(torch.__version__)

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git
COLLAB_ENV = True
if COLLAB_ENV:
    # !pip install 'scipy>=1.8'
    # !pip install mycolorpy
import numpy as np #Library for linear algebra
import matplotlib.pyplot as plt #Library for plotting
import networkx as nx #Library for graph
from torch_geometric.datasets import Planetoid,WebKB, Actor #Library for graph dataset and deep learning on graphs
from torch_geometric.utils import to_dense_adj
import warnings
warnings.filterwarnings("ignore") # Get rid of warnings
# Out:
# 2.2.1+cu121
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.10/dist-packages (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy>=1.8) (1.25.2)
# Requirement already satisfied: mycolorpy in /usr/local/lib/python3.10/dist-packages (1.5.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mycolorpy) (1.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mycolorpy) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mycolorpy) (1.16.0)

# %% [markdown]
# ### 1. Load data and visualize it

# %%
'''
    Load the dataset:
        * root: The root directory where the dataset should be saved.
        * name: The name of the dataset (cora, citeseer or pubmed).
        * transform: A function/transform that takes in an Data object of the dataset and returns a transformed version. The data object will be transformed before every access.
    Returns:
        * Dataset object
'''
data_Cora = Planetoid(root='/tmp/Cora', name='Cora') # Load the Cora dataset (homogeneous)
data_Citeseer = Planetoid(root='/tmp/CiteSeer', name='CiteSeer') # Load the CiteSeer dataset (homogeneous)
data_Actor = Actor(root='/tmp/Actor') # Load the Actor dataset (heterogeneous)
#data_Chamaleon = Planetoid(root='/tmp/Cora', name='Cora') # Load the Cora dataset (homogeneous)
#data_Squirrel = Planetoid(root='/tmp/Cora', name='Cora') # Load the Cora dataset (homogeneous)
data_Wisconsin = WebKB(root='/tmp/Wisconsin', name='Wisconsin') # Load the Wisconsin dataset (homogeneous)
data_Cornell = WebKB(root='/tmp/Cornell', name='Cornell') # Load the Cornell dataset (homogeneous)
data_Texas = WebKB(root='/tmp/Texas', name='Texas') # Load the Wisconsin dataset (homogeneous)

# !pip install dgl
import dgl.data
from dgl.data import ChameleonDataset
data_Chamaleon = ChameleonDataset()

dataset = data_Chamaleon
data = dataset[0] # Get the first graph object (in this case is only one graph, while in Graph classification there are multiple graphs)
print()
print(f'Dataset: {dataset}:')
print('======================')
print(f'Number of graphs: {len(dataset)}')
node_features = data.ndata['feat']

# Obtener el número de características de los nodos
num_features = node_features.shape[1]

print("Número de características de los nodos:", num_features)
#print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.num_classes}')
print()
print(data) # Note that the adjacency matrix is not stored explicitly but in the edge_index attribute.
            # The edge_index attribute is a 2 x E tensor, with each column denoting an edge.
            # The first row denotes the source nodes and the second row the destination nodes of the edges.
            # The nodes are numbered consecutively starting from zero.
            # The features are stored in the x attribute, which is a N x F tensor, with N being the number of nodes and F the number of features per node.
            # The labels are stored in the y attribute, which is a vector of length N, with each entry denoting the class of the corresponding node.
print('===========================================================================================================')
#adj = to_dense_adj(data.edge_index)[0] # Convert the sparse adjacency matrix to a dense adjacency matrix
adj_sp = data.adjacency_matrix()  # Transponemos para obtener la orientación correcta

# Convierte la matriz de adyacencia dispersa a una matriz densa
adj = adj_sp.to_dense()

print("Shape of the new adjacency matrix: ",adj.shape)
#Let's get statistics about the graph adjacency matrix
print("Number of nodes: ",adj.shape[0])
print("Number of edges: ",round(adj.sum().item()))
print("Density: ",round((adj.sum()/(adj.shape[0]*adj.shape[0])).item(),4))
print("Maximum node degree: ",round(adj.sum(axis=1).max().item()))
print("Minimum node degree: ",round(adj.sum(axis=1).min().item()))
print("Average node degree: ",round(adj.sum(axis=1).mean().item()))
num_isolated_nodes = torch.sum((adj.sum(axis=0) == 0) & (adj.sum(axis=1) == 0))

if num_isolated_nodes == 0:
    print("No hay nodos aislados en el grafo.")
else:
    print(f"Hay {num_isolated_nodes} nodos aislados en el grafo.")

# Verificar si hay bucles en el grafo
has_self_loops = (data.edges()[0] == data.edges()[1]).any()

if has_self_loops:
    print("El grafo tiene bucles.")
else:
    print("El grafo no tiene bucles.")

# Verificar si el grafo es no dirigido
is_undirected = (data.in_degrees() == data.out_degrees()).all().item()

if is_undirected:
    print("El grafo es no dirigido.")
else:
    print("El grafo es dirigido.")
print('===========================================================================================================')
# Out:
# Requirement already satisfied: dgl in /usr/local/lib/python3.10/dist-packages (2.1.0)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from dgl) (1.25.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from dgl) (1.11.4)
# Requirement already satisfied: networkx>=2.1 in /usr/local/lib/python3.10/dist-packages (from dgl) (3.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from dgl) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from dgl) (4.66.4)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from dgl) (5.9.5)
# Requirement already satisfied: torchdata>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from dgl) (0.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl) (2024.2.2)
# Requirement already satisfied: torch>=2 in /usr/local/lib/python3.10/dist-packages (from torchdata>=0.5.0->dgl) (2.2.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2->torchdata>=0.5.0->dgl) (12.4.127)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2->torchdata>=0.5.0->dgl) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2->torchdata>=0.5.0->dgl) (1.3.0)
# Done loading data from cached files.
#
# Dataset: Dataset("chameleon", num_graphs=1, save_path=/root/.dgl/chameleon_03d661d3):
# ======================
# Number of graphs: 1
# Número de características de los nodos: 2325
# Number of classes: 5
#
# Graph(num_nodes=2277, num_edges=36101,
#       ndata_schemes={'feat': Scheme(shape=(2325,), dtype=torch.float32), 'label': Scheme(shape=(), dtype=torch.int64), 'train_mask': Scheme(shape=(10,), dtype=torch.bool), 'val_mask': Scheme(shape=(10,), dtype=torch.bool), 'test_mask': Scheme(shape=(10,), dtype=torch.bool)}
#       edata_schemes={})
# ===========================================================================================================
# Shape of the new adjacency matrix:  torch.Size([2277, 2277])
# Number of nodes:  2277
# Number of edges:  36101
# Density:  0.007
# Maximum node degree:  728
# Minimum node degree:  0
# Average node degree:  16
# No hay nodos aislados en el grafo.
# El grafo tiene bucles.
# El grafo es dirigido.
# ===========================================================================================================

# %%
def calculate_homophily(graph):
    src, dst = graph.edges()
    labels = graph.ndata['label']

    num_edges = len(src)
    same_label_edges = torch.sum(labels[src] == labels[dst]).item()

    homophily = same_label_edges / num_edges
    return homophily

homophily = calculate_homophily(data)
print(f'Grado de homofilia: {homophily:.4f}')
# Out:
# Grado de homofilia: 0.2350

# %% [markdown]
# ### 1.1 Visualize the graph

# %%
# To visualize the graph we are going to use networkx library, but first we need to convert the graph to networkx format
from torch_geometric.utils import to_networkx
#A = to_networkx(data, to_undirected=True) # Convert the graph to networkx format
A = dgl.to_networkx(data, node_attrs=None, edge_attrs=None).to_undirected()
# Now we are going to get the largest connected component of the graph, because the graph is not connected!
Gcc = sorted(nx.connected_components(A), key=len, reverse=True) # Get the sorted list of connected components
A = A.subgraph(Gcc[0]) # Get the largest connected component
G = nx.adjacency_matrix(A)
# All the following code is just for plotting the graph, so you can ignore it
# This how we can get the edge_index attribute for the largest connected component
g_tensor = torch.tensor(G.todense())
new_edge_index = g_tensor.nonzero().t().contiguous()
# This is how we create the new data object for the largest connected component
#data.x = data.x[list(A.nodes())]
data.x = data.ndata['feat'][list(A.nodes())]
#data.y = data.y[list(A.nodes())]
data.y = data.ndata['label'][list(A.nodes())]
data.edge_index = new_edge_index
data.num_nodes = len(A.nodes())
data.num_edges = len(A.edges())
#print(data)
# Now we can plot the graph
#A = to_networkx(data, to_undirected=True) # Convert the graph to networkx format
#A = dgl.to_networkx(data)

# Si deseas un grafo no dirigido, puedes usar:
#A = A.to_undirected()
plt.figure(figsize=(20,15))
plt.title('Largest connected component',fontsize=20)
pos = nx.spring_layout(A,seed=12)
#Let's drow the graph, adding borders to the nodes
'''
    Arguments of nx.draw:
        * G: The graph to draw.
        * node_color: The color of the nodes.
        * pos: A dictionary with nodes as keys and positions as values.
        * cmap: A colormap or registered colormap name.
        * node_size: The size of the nodes.
        * edge_color: The color of the edges.
        * width: The width of the edges.
        * with_labels: Whether to draw the node labels.
        * node_shape: The shape of the nodes.
        * alpha: The node transparency.
    Returns:
        * None
'''
nx.draw(A,node_color=data.y,pos= pos, cmap=plt.cm.viridis, node_size=100, edge_color='black',width=1,with_labels=False,node_shape='o',alpha=0.8)
plt.show()

# %% [markdown]
# ### 1.3 Visualize full graph [Optional]

# %%
# The same as above but with the whole graph
data = dataset[0]
#G = to_networkx(data, to_undirected=True)
G = dgl.to_networkx(data).to_undirected()
plt.figure(figsize=(20,15))
plt.title('Whole graph',fontsize=20)
#color = data.y
color = data.ndata['label']
pos = nx.spring_layout(G,seed=12)
nx.draw(G,node_color=color,pos= pos, cmap=plt.cm.viridis, node_size=100, edge_color='black',width=1,with_labels=False,node_shape='o',alpha=0.8)
plt.show()

# %% [markdown]
# ### 2. Train a GCN model

# %% [markdown]
# #### Utility functions

# %%
'''
    Arguments of train:
        * model: The model to train.
        * data: The data object.
        * optimizer: The optimizer to use.
        * train_mask: The mask of the training nodes.
        * criterion: The loss function to use.
    Returns:
        * loss: The loss of the model.
        * acc: The accuracy of the model.
'''
def train(model, data, optimizer,train_mask,device,criterion = torch.nn.CrossEntropyLoss()):
    model.train()
    optimizer.zero_grad() # Clear gradients.
    #Make sure that we only use the features of the training nodes
    #features = torch.zeros(data.x.shape[0],data.x.shape[1]).to(device)
    features = torch.zeros(data.ndata['feat'].shape[0],data.ndata['feat'].shape[1]).to(device)
    #features[train_mask] = data.x[train_mask]
    features[train_mask] = data.ndata['feat'][train_mask]
    # Put the features in the same device as the model
    features = features.to(device)
    # al modelo se le pasan las características y las conexiones
    src_nodes, dst_nodes = data.edges()
    edge_index = torch.stack([src_nodes, dst_nodes], dim=0)
    #out = model(features, data.edge_index) # Perform a single forward pass.
    out = model(features, edge_index) # Perform a single forward pass.
    # Lo que me equivoco, solo en entrenamiento
    #loss = criterion(out[train_mask], data.y[train_mask]) # Compute the loss solely based on the training nodes.
    loss = criterion(out[train_mask], data.ndata['label'][train_mask]) # Compute the loss solely based on the training nodes.
    pred = out.argmax(dim=1) # Use the class with highest probability.
    #acc = pred[train_mask].eq(data.y[train_mask]).sum().item() / train_mask.sum().item() # Derive ratio of correct predictions.
    acc = pred[train_mask].eq(data.ndata['label'][train_mask]).sum().item() / train_mask.sum().item() # Derive ratio of correct predictions.
    # Actualizar la loss, cambiar las matrices W de cada neurona
    loss.backward() # Derive gradients.
    optimizer.step() # Update parameters based on gradients.
    return loss,acc
'''
    Arguments of validation:
        * model: The model to train.
        * data: The data object.
        * val_mask: The mask of the validation nodes.
    Returns:
        * acc: The accuracy of the model.
'''
@torch.no_grad()
def validation(model,data,val_mask,device):
    model.eval() # Set model to evaluation mode (e.g. disable dropout)
    #Make sure that we only use the features of the validation nodes
    #features = torch.zeros(data.x.shape[0],data.x.shape[1]).to(device)
    features = torch.zeros(data.ndata['feat'].shape[0],data.ndata['feat'].shape[1]).to(device)
    #features[val_mask] = data.x[val_mask]
    features[val_mask] = data.ndata['feat'][val_mask]
    # Put the features in the same device as the model
    features = features.to(device)
    #out = model(features, data.edge_index)
    src_nodes, dst_nodes = data.edges()
    edge_index = torch.stack([src_nodes, dst_nodes], dim=0)
    out = model(features, edge_index)
    pred = out.argmax(dim=1) # Use the class with highest probability.
    #acc = pred[val_mask].eq(data.y[val_mask]).sum().item() / val_mask.sum().item() # Derive ratio of correct predictions.
    acc = pred[val_mask].eq(data.ndata['label'][val_mask]).sum().item() / val_mask.sum().item() # Derive ratio of correct predictions.
    return acc
'''
    Arguments of test:
        * model: The model to train.
        * data: The data object.
        * test_mask: The mask of the test nodes.
    Returns:
        * acc: The accuracy of the model.
'''
@torch.no_grad()
def test(model,data,test_mask,device):
    model.eval() # Set model to evaluation mode (e.g. disable dropout)
    #Make sure that we only use the features of the testing nodes
    #features = torch.zeros(data.x.shape[0],data.x.shape[1]).to(device)
    features = torch.zeros(data.ndata['feat'].shape[0],data.ndata['feat'].shape[1]).to(device)
    #features[test_mask] = data.x[test_mask]
    features[test_mask] = data.ndata['feat'][test_mask]
    # Put the features in the same device as the model
    features = features.to(device)
    #out = model(features, data.edge_index)
    src_nodes, dst_nodes = data.edges()
    edge_index = torch.stack([src_nodes, dst_nodes], dim=0)
    out = model(features, edge_index)
    pred = out.argmax(dim=1) # Use the class with highest probability.
    #acc = pred[test_mask].eq(data.y[test_mask]).sum().item() / test_mask.sum().item() # Derive ratio of correct predictions.
    acc = pred[test_mask].eq(data.ndata['label'][test_mask]).sum().item() / test_mask.sum().item() # Derive ratio of correct predictions.
    return acc

# %% [markdown]
# #### Split dataset

# %% [markdown]
# In this section we will split the dataset into training, validation and test sets. We will use the training set to train the model, the validation set to tune the hyperparameters and the test set to evaluate the model. We will use two functions for the splits. One function will give as a semi-supervised split where we will have a small number of labeled nodes in the training set and the rest of the nodes will be unlabeled. The other function will give us a fully supervised split where all the nodes in the training set will be labeled.

# %%
from sklearn.model_selection import train_test_split
'''
    Arguments of get_semi_supervised_split:
        * data: The data object.
        * seed: The seed to use for the random split.
    Returns: the train, test and validation masks with an 48%/32%/20%.
        * train_mask: The mask of the training nodes.
        * test_mask: The mask of the test nodes.
        * val_mask: The mask of the validation nodes.
'''
def get_semi_supervised_split(data,seed):
    #We are going to use 48% of the nodes for training, 32% for testing and 20% for validation
    #First we split the nodes in 80% for training and 20% for testing
    #Then we split the training nodes in 48% for training and 32% for validation over the 80% of the nodes
    #train_split, test_split = train_test_split(list(range(len(data.y))), test_size=0.20,random_state=seed, shuffle=True)
    train_split, test_split = train_test_split(list(range(len(data.ndata['label']))), test_size=0.20,random_state=seed, shuffle=True)
    train_split, val_split = train_test_split(train_split, test_size=0.40,random_state=seed, shuffle=True)



    #train_mask = torch.full_like(data.y, False, dtype=bool)
    train_mask = torch.full_like(data.ndata['label'], False, dtype=bool)
    train_mask[train_split] = True

    #test_mask = torch.full_like(data.y, False, dtype=bool)
    test_mask = torch.full_like(data.ndata['label'], False, dtype=bool)
    test_mask[test_split] = True

    #val_mask = torch.full_like(data.y, False, dtype=bool)
    val_mask = torch.full_like(data.ndata['label'], False, dtype=bool)
    val_mask[val_split] = True

    return train_mask,test_mask,val_mask
'''
    Arguments of get_supervised_split:
        * data: The data object.
        * seed: The seed to use for the random split.
    Returns: the train, test and validation masks with an 60%/20%/20%.
        * train_mask: The mask of the training nodes.
        * test_mask: The mask of the test nodes.
        * val_mask: The mask of the validation nodes.
'''
def get_supervised_split(data,seed):
    train_split, test_split = train_test_split(list(range(len(data.y))), test_size=0.40,random_state=seed, shuffle=True)
    test_split, val_split = train_test_split(test_split, test_size=0.50,random_state=seed, shuffle=True)

    train_mask = torch.full_like(data.y, False, dtype=bool)
    train_mask[train_split] = True

    test_mask = torch.full_like(data.y, False, dtype=bool)
    test_mask[test_split] = True

    val_mask = torch.full_like(data.y, False, dtype=bool)
    val_mask[val_split] = True

    return train_mask, test_mask, val_mask

# %% [markdown]
# #### Create the model

# %% [markdown]
# In this section we will create our model for node classification. We will use a GCN model with 2 hidden layers. The input to the model will be the node features and the output will be the logits for each node in the graph. We will use the cross entropy loss function and the Adam optimizer.

# %% [markdown]
# Using the above models as templates, **create as many cells as models**.

# %% [markdown]
# ##### GCN

# %%
from torch_geometric.nn import GCNConv
from torch.functional import F
'''
    In PyTorch, you define a model by subclassing torch.nn.Module and defining a forward() method which receives input data and returns output data.
    The forward() method can use other modules defined in the constructor as submodules, and it can use arbitrary operators on Tensors, including loops and conditional statements.
    This approach is very flexible, and you can use it to define models of arbitrary complexity.
'''
class GCN(torch.nn.Module):
    '''
        Arguments of __init__:
            * hidden_channels: The number of hidden units.
            * dataset.num_features: The number of input features.
            * dataset.num_classes: The number of output classes.
        Returns:
            * self.conv1: The first GCN layer.
            * self.conv2: The second GCN layer.
    '''
    # hidden channels: capa intermedia
    def __init__(self,hidden_channels = 16):
        super(GCN, self).__init__()
        # 2-layer GCN
        # GCConv(tamaño entrada, tamaño salida)
        #self.conv1 = GCNConv(dataset.num_features, hidden_channels) # 16 hidden units
        self.conv1 = GCNConv(num_features, hidden_channels) # 16 hidden units
        self.conv2 = GCNConv(hidden_channels, dataset.num_classes) # dataset.num_classes output units
    '''
        Arguments of forward:
            * x: The input features.
            * edge_index: The edge indices.
        Returns:
            * F.softmax(x, dim=1): The output of the model.
    '''
    # lo que aplica el modelo
    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index)) # ReLU activation
        x = F.dropout(x,p=0.5, training=self.training) # Dropout: 50% of the nodes are randomly dropped out during training
        x = self.conv2(x, edge_index)
        return x.softmax(dim=1) # Log softmax activation
print(GCN())
# Out:
# GCN(
#   (conv1): GCNConv(2325, 16)
#   (conv2): GCNConv(16, 5)
# )

# %% [markdown]
# ##### SAGE

# %%
from torch_geometric.nn import SAGEConv
from torch.functional import F
'''
    In PyTorch, you define a model by subclassing torch.nn.Module and defining a forward() method which receives input data and returns output data.
    The forward() method can use other modules defined in the constructor as submodules, and it can use arbitrary operators on Tensors, including loops and conditional statements.
    This approach is very flexible, and you can use it to define models of arbitrary complexity.
'''
class SAGE(torch.nn.Module):
    '''
        Arguments of __init__:
            * hidden_channels: The number of hidden units.
            * dataset.num_features: The number of input features.
            * dataset.num_classes: The number of output classes.
        Returns:
            * self.conv1: The first GCN layer.
            * self.conv2: The second GCN layer.
    '''
    # hidden channels: capa intermedia
    def __init__(self,hidden_channels = 16):
        super(SAGE, self).__init__()
        # 2-layer GCN
        # GCConv(tamaño entrada, tamaño salida)
        self.conv1 = SAGEConv(num_features, hidden_channels, aggr='max') # 16 hidden units
        self.conv2 = SAGEConv(hidden_channels, dataset.num_classes) # dataset.num_classes output units
    '''
        Arguments of forward:
            * x: The input features.
            * edge_index: The edge indices.
        Returns:
            * F.softmax(x, dim=1): The output of the model.
    '''
    # lo que aplica el modelo
    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index)) # ReLU activation
        x = F.dropout(x,p=0.5, training=self.training) # Dropout: 50% of the nodes are randomly dropped out during training
        x = self.conv2(x, edge_index)
        return x.softmax(dim=1) # Log softmax activation
print(SAGE())
# Out:
# SAGE(
#   (conv1): SAGEConv(2325, 16, aggr=max)
#   (conv2): SAGEConv(16, 5, aggr=mean)
# )

# %% [markdown]
# ##### Cheb

# %%
from torch_geometric.nn import ChebConv
from torch.functional import F
'''
    In PyTorch, you define a model by subclassing torch.nn.Module and defining a forward() method which receives input data and returns output data.
    The forward() method can use other modules defined in the constructor as submodules, and it can use arbitrary operators on Tensors, including loops and conditional statements.
    This approach is very flexible, and you can use it to define models of arbitrary complexity.
'''
class Cheb(torch.nn.Module):
    '''
        Arguments of __init__:
            * hidden_channels: The number of hidden units.
            * dataset.num_features: The number of input features.
            * dataset.num_classes: The number of output classes.
        Returns:
            * self.conv1: The first GCN layer.
            * self.conv2: The second GCN layer.
    '''
    # hidden channels: capa intermedia
    def __init__(self,hidden_channels = 16):
        super(Cheb, self).__init__()
        # 2-layer GCN
        # GCConv(tamaño entrada, tamaño salida)
        self.conv1 = ChebConv(num_features, hidden_channels, K=10, normalization='sym') # 16 hidden units
        self.conv2 = ChebConv(hidden_channels, dataset.num_classes, K=10, normalization='sym') # dataset.num_classes output units
    '''
        Arguments of forward:
            * x: The input features.
            * edge_index: The edge indices.
        Returns:
            * F.softmax(x, dim=1): The output of the model.
    '''
    # lo que aplica el modelo
    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index)) # ReLU activation
        x = F.dropout(x,p=0.5, training=self.training) # Dropout: 50% of the nodes are randomly dropped out during training
        x = self.conv2(x, edge_index)
        return x.softmax(dim=1) # Log softmax activation
print(Cheb())
# Out:
# Cheb(
#   (conv1): ChebConv(2325, 16, K=10, normalization=sym)
#   (conv2): ChebConv(16, 5, K=10, normalization=sym)
# )

# %% [markdown]
# ##### GAT

# %%
from torch_geometric.nn import GATConv
from torch.functional import F
'''
    In PyTorch, you define a model by subclassing torch.nn.Module and defining a forward() method which receives input data and returns output data.
    The forward() method can use other modules defined in the constructor as submodules, and it can use arbitrary operators on Tensors, including loops and conditional statements.
    This approach is very flexible, and you can use it to define models of arbitrary complexity.
'''
class GAT(torch.nn.Module):
    '''
        Arguments of __init__:
            * hidden_channels: The number of hidden units.
            * dataset.num_features: The number of input features.
            * dataset.num_classes: The number of output classes.
        Returns:
            * self.conv1: The first GCN layer.
            * self.conv2: The second GCN layer.
    '''
    # hidden channels: capa intermedia
    def __init__(self,hidden_channels = 16):
        super(GAT, self).__init__()
        # 2-layer GCN
        # GCConv(tamaño entrada, tamaño salida)
        self.conv1 = GATConv(num_features, hidden_channels, heads=1) # 16 hidden units
        self.conv2 = GATConv(hidden_channels, dataset.num_classes, heads=1) # dataset.num_classes output units
    '''
        Arguments of forward:
            * x: The input features.
            * edge_index: The edge indices.
        Returns:
            * F.softmax(x, dim=1): The output of the model.
    '''
    # lo que aplica el modelo
    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index)) # ReLU activation
        x = F.dropout(x,p=0.5, training=self.training) # Dropout: 50% of the nodes are randomly dropped out during training
        x = self.conv2(x, edge_index)
        return x.softmax(dim=1) # Log softmax activation
print(GAT())
# Out:
# GAT(
#   (conv1): GATConv(2325, 16, heads=1)
#   (conv2): GATConv(16, 5, heads=1)
# )

# %% [markdown]
# ##### MLP

# %%
from torch.nn import Linear
# Same as GCN but with Linear layers instead of GCNConv layers. If we use MLP as a model, we can't take into account the graph STRUCTURE.
class MLP(torch.nn.Module):
    def __init__(self,hidden_channels = 16):
        super(MLP, self).__init__()
        # 2-layer GCN
        #self.lin1 = Linear(dataset.num_features, hidden_channels)
        self.lin1 = Linear(num_features, hidden_channels)
        self.lin2 = Linear(hidden_channels, dataset.num_classes)

    def forward(self, x, edge_index):
        # edge_index is not used
        x = self.lin1(x)
        x = x.relu()
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin2(x)
        return x.softmax(dim=1)
print(MLP())
# Out:
# MLP(
#   (lin1): Linear(in_features=2325, out_features=16, bias=True)
#   (lin2): Linear(in_features=16, out_features=5, bias=True)
# )

# %% [markdown]
# #### Train the models

# %%
# Seeds for the random split. This allows us to reproduce the results.
RandList = [12345, 423456, 643451, 543452, 743456, 4734510, 654321, 124321, 945321, 784328]
# This allows us to run the code on the GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Here you can add models to train and test (include your own models)
models = [GCN(), MLP(), SAGE(), Cheb(), GAT()]
#models = [SAGE(), Cheb(), GAT()]
global_results = []
global_best_models = []
for j in range(len(models)):
    ExperimentResult = []
    best_model = None

    for i in range(10):
        print("Random State", RandList[i]," in the iteration",i)
        train_mask,test_mask,val_mask = get_semi_supervised_split(data.cpu(), RandList[i])
        #train_mask,test_mask,val_mask = get_supervised_split(data.cpu(), RandList[i])
        data = data.to(device)
        model = models[j].to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
        for epoch in range(1, 101):
            loss, acc_train = train(model,data,optimizer,train_mask.to(device),device=device)
            acc_validation = validation(model,data,val_mask.to(device),device=device)
            print('Epoch: {:03d}, Loss: {:.5f}, Train Acc: {:.5f}, Val Acc: {:.5f}'.format(epoch, loss, acc_train, acc_validation))
        acc = test(model,data,test_mask.to(device),device=device)
        print('Test Accuracy: {:.5f}'.format(acc))
        # Save the best model over the 10 runs
        if best_model is None or acc > best_model[1]:
            best_model = [model, acc]
        ExperimentResult.append(acc)
        del model
    print(models[j].__class__.__name__) # Name of the model
    print('{} +- {}'.format(np.mean(ExperimentResult)*100, np.std(ExperimentResult)*100))
    global_results.append(ExperimentResult.copy())
    global_best_models.append(best_model.copy())
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Epoch: 008, Loss: 1.40077, Train Acc: 0.55495, Val Acc: 0.50892
# Epoch: 009, Loss: 1.38507, Train Acc: 0.56044, Val Acc: 0.51578
# Epoch: 010, Loss: 1.38301, Train Acc: 0.57326, Val Acc: 0.51303
# Epoch: 011, Loss: 1.39512, Train Acc: 0.51832, Val Acc: 0.49520
# Epoch: 012, Loss: 1.38942, Train Acc: 0.55769, Val Acc: 0.50069
# Epoch: 013, Loss: 1.37851, Train Acc: 0.55678, Val Acc: 0.51029
# Epoch: 014, Loss: 1.36997, Train Acc: 0.57234, Val Acc: 0.50069
# Epoch: 015, Loss: 1.37976, Train Acc: 0.57601, Val Acc: 0.50069
# Epoch: 016, Loss: 1.37584, Train Acc: 0.57784, Val Acc: 0.49657
# Epoch: 017, Loss: 1.37087, Train Acc: 0.57784, Val Acc: 0.49383
# Epoch: 018, Loss: 1.38562, Train Acc: 0.55311, Val Acc: 0.48148
# Epoch: 019, Loss: 1.37709, Train Acc: 0.55861, Val Acc: 0.48422
# Epoch: 020, Loss: 1.36132, Train Acc: 0.59890, Val Acc: 0.48285
# Epoch: 021, Loss: 1.35442, Train Acc: 0.60256, Val Acc: 0.48285
# Epoch: 022, Loss: 1.37452, Train Acc: 0.57784, Val Acc: 0.47462
# Epoch: 023, Loss: 1.35573, Train Acc: 0.61172, Val Acc: 0.47325
# Epoch: 024, Loss: 1.36220, Train Acc: 0.58700, Val Acc: 0.46091
# Epoch: 025, Loss: 1.34641, Train Acc: 0.60440, Val Acc: 0.45405
# Epoch: 026, Loss: 1.35458, Train Acc: 0.59158, Val Acc: 0.45267
# Epoch: 027, Loss: 1.36546, Train Acc: 0.57875, Val Acc: 0.45130
# Epoch: 028, Loss: 1.37349, Train Acc: 0.56777, Val Acc: 0.45130
# Epoch: 029, Loss: 1.36221, Train Acc: 0.60348, Val Acc: 0.44170
# Epoch: 030, Loss: 1.34839, Train Acc: 0.59707, Val Acc: 0.45130
# Epoch: 031, Loss: 1.35290, Train Acc: 0.60073, Val Acc: 0.44444
# Epoch: 032, Loss: 1.35430, Train Acc: 0.58516, Val Acc: 0.44033
# Epoch: 033, Loss: 1.34307, Train Acc: 0.61630, Val Acc: 0.46091
# Epoch: 034, Loss: 1.36421, Train Acc: 0.56593, Val Acc: 0.46365
# Epoch: 035, Loss: 1.33960, Train Acc: 0.61355, Val Acc: 0.45816
# Epoch: 036, Loss: 1.34901, Train Acc: 0.60714, Val Acc: 0.45130
# Epoch: 037, Loss: 1.35499, Train Acc: 0.60348, Val Acc: 0.42661
# Epoch: 038, Loss: 1.34035, Train Acc: 0.61996, Val Acc: 0.38546
# Epoch: 039, Loss: 1.34678, Train Acc: 0.61355, Val Acc: 0.38134
# Epoch: 040, Loss: 1.35536, Train Acc: 0.60531, Val Acc: 0.38272
# Epoch: 041, Loss: 1.35488, Train Acc: 0.59707, Val Acc: 0.42661
# Epoch: 042, Loss: 1.34011, Train Acc: 0.61264, Val Acc: 0.43347
# Epoch: 043, Loss: 1.35270, Train Acc: 0.60348, Val Acc: 0.42936
# Epoch: 044, Loss: 1.34926, Train Acc: 0.58608, Val Acc: 0.42936
# Epoch: 045, Loss: 1.33615, Train Acc: 0.62179, Val Acc: 0.43210
# Epoch: 046, Loss: 1.34505, Train Acc: 0.59890, Val Acc: 0.42936
# Epoch: 047, Loss: 1.35057, Train Acc: 0.62637, Val Acc: 0.38683
# Epoch: 048, Loss: 1.34634, Train Acc: 0.61355, Val Acc: 0.37174
# Epoch: 049, Loss: 1.35021, Train Acc: 0.60256, Val Acc: 0.37449
# Epoch: 050, Loss: 1.33963, Train Acc: 0.60348, Val Acc: 0.37449
# Epoch: 051, Loss: 1.34679, Train Acc: 0.60989, Val Acc: 0.36488
# Epoch: 052, Loss: 1.33901, Train Acc: 0.62179, Val Acc: 0.41564
# Epoch: 053, Loss: 1.35147, Train Acc: 0.60623, Val Acc: 0.42936
# Epoch: 054, Loss: 1.34169, Train Acc: 0.60348, Val Acc: 0.37449
# Epoch: 055, Loss: 1.34840, Train Acc: 0.59890, Val Acc: 0.37723
# Epoch: 056, Loss: 1.33613, Train Acc: 0.63004, Val Acc: 0.37586
# Epoch: 057, Loss: 1.34344, Train Acc: 0.61081, Val Acc: 0.37449
# Epoch: 058, Loss: 1.33494, Train Acc: 0.62821, Val Acc: 0.37586
# Epoch: 059, Loss: 1.33528, Train Acc: 0.61447, Val Acc: 0.37449
# Epoch: 060, Loss: 1.33907, Train Acc: 0.61172, Val Acc: 0.37586
# Epoch: 061, Loss: 1.34358, Train Acc: 0.61722, Val Acc: 0.37723
# Epoch: 062, Loss: 1.33193, Train Acc: 0.60897, Val Acc: 0.38134
# Epoch: 063, Loss: 1.33859, Train Acc: 0.61722, Val Acc: 0.38134
# Epoch: 064, Loss: 1.33815, Train Acc: 0.61447, Val Acc: 0.37174
# Epoch: 065, Loss: 1.32960, Train Acc: 0.61813, Val Acc: 0.36488
# Epoch: 066, Loss: 1.33395, Train Acc: 0.60806, Val Acc: 0.36351
# Epoch: 067, Loss: 1.34175, Train Acc: 0.60531, Val Acc: 0.37449
# Epoch: 068, Loss: 1.33380, Train Acc: 0.61813, Val Acc: 0.37997
# Epoch: 069, Loss: 1.33133, Train Acc: 0.62637, Val Acc: 0.40466
# Epoch: 070, Loss: 1.35451, Train Acc: 0.60073, Val Acc: 0.41838
# Epoch: 071, Loss: 1.33750, Train Acc: 0.61447, Val Acc: 0.41564
# Epoch: 072, Loss: 1.33328, Train Acc: 0.61355, Val Acc: 0.37037
# Epoch: 073, Loss: 1.33283, Train Acc: 0.62729, Val Acc: 0.36763
# Epoch: 074, Loss: 1.32953, Train Acc: 0.61081, Val Acc: 0.35665
# Epoch: 075, Loss: 1.32488, Train Acc: 0.61813, Val Acc: 0.35391
# Epoch: 076, Loss: 1.33608, Train Acc: 0.61630, Val Acc: 0.34705
# Epoch: 077, Loss: 1.34055, Train Acc: 0.61630, Val Acc: 0.34705
# Epoch: 078, Loss: 1.33700, Train Acc: 0.61264, Val Acc: 0.35254
# Epoch: 079, Loss: 1.33850, Train Acc: 0.61813, Val Acc: 0.36077
# Epoch: 080, Loss: 1.33490, Train Acc: 0.60806, Val Acc: 0.36214
# Epoch: 081, Loss: 1.33845, Train Acc: 0.59982, Val Acc: 0.36488
# Epoch: 082, Loss: 1.32445, Train Acc: 0.63004, Val Acc: 0.40604
# Epoch: 083, Loss: 1.32238, Train Acc: 0.62729, Val Acc: 0.39918
# Epoch: 084, Loss: 1.32040, Train Acc: 0.64103, Val Acc: 0.39232
# Epoch: 085, Loss: 1.32882, Train Acc: 0.62912, Val Acc: 0.40878
# Epoch: 086, Loss: 1.33730, Train Acc: 0.61996, Val Acc: 0.36763
# Epoch: 087, Loss: 1.31745, Train Acc: 0.63370, Val Acc: 0.35391
# Epoch: 088, Loss: 1.32638, Train Acc: 0.62729, Val Acc: 0.35665
# Epoch: 089, Loss: 1.32735, Train Acc: 0.62363, Val Acc: 0.34979
# Epoch: 090, Loss: 1.34952, Train Acc: 0.60897, Val Acc: 0.35665
# Epoch: 091, Loss: 1.32236, Train Acc: 0.62912, Val Acc: 0.35665
# Epoch: 092, Loss: 1.33125, Train Acc: 0.62454, Val Acc: 0.35802
# Epoch: 093, Loss: 1.33535, Train Acc: 0.61172, Val Acc: 0.35528
# Epoch: 094, Loss: 1.33465, Train Acc: 0.60256, Val Acc: 0.35391
# Epoch: 095, Loss: 1.33328, Train Acc: 0.63278, Val Acc: 0.35665
# Epoch: 096, Loss: 1.32061, Train Acc: 0.62821, Val Acc: 0.35528
# Epoch: 097, Loss: 1.33115, Train Acc: 0.61905, Val Acc: 0.35117
# Epoch: 098, Loss: 1.33832, Train Acc: 0.60531, Val Acc: 0.38134
# Epoch: 099, Loss: 1.34297, Train Acc: 0.59890, Val Acc: 0.38683
# Epoch: 100, Loss: 1.32953, Train Acc: 0.61081, Val Acc: 0.36077
# Test Accuracy: 0.30263
# Random State 643451  in the iteration 2
# Epoch: 001, Loss: 1.44550, Train Acc: 0.50458, Val Acc: 0.47462
# Epoch: 002, Loss: 1.44316, Train Acc: 0.47161, Val Acc: 0.47325
# Epoch: 003, Loss: 1.41496, Train Acc: 0.55495, Val Acc: 0.51440
# Epoch: 004, Loss: 1.41147, Train Acc: 0.55861, Val Acc: 0.49383
# Epoch: 005, Loss: 1.39393, Train Acc: 0.57967, Val Acc: 0.47325
# Epoch: 006, Loss: 1.37836, Train Acc: 0.57418, Val Acc: 0.43073
# Epoch: 007, Loss: 1.38654, Train Acc: 0.58791, Val Acc: 0.42387
# Epoch: 008, Loss: 1.37741, Train Acc: 0.56960, Val Acc: 0.41838
# Epoch: 009, Loss: 1.36539, Train Acc: 0.57051, Val Acc: 0.42250
# Epoch: 010, Loss: 1.36181, Train Acc: 0.57051, Val Acc: 0.42798
# Epoch: 011, Loss: 1.35703, Train Acc: 0.58608, Val Acc: 0.42524
# Epoch: 012, Loss: 1.35008, Train Acc: 0.58608, Val Acc: 0.42936
# Epoch: 013, Loss: 1.35381, Train Acc: 0.58608, Val Acc: 0.43073
# Epoch: 014, Loss: 1.34391, Train Acc: 0.58883, Val Acc: 0.43073
# Epoch: 015, Loss: 1.35409, Train Acc: 0.59158, Val Acc: 0.43073
# Epoch: 016, Loss: 1.34256, Train Acc: 0.59524, Val Acc: 0.43073
# Epoch: 017, Loss: 1.33750, Train Acc: 0.60348, Val Acc: 0.44856
# Epoch: 018, Loss: 1.31830, Train Acc: 0.61996, Val Acc: 0.47462
# Epoch: 019, Loss: 1.32989, Train Acc: 0.60714, Val Acc: 0.47462
# Epoch: 020, Loss: 1.33606, Train Acc: 0.60806, Val Acc: 0.46914
# Epoch: 021, Loss: 1.32986, Train Acc: 0.60348, Val Acc: 0.46502
# Epoch: 022, Loss: 1.32718, Train Acc: 0.62454, Val Acc: 0.45267
# Epoch: 023, Loss: 1.32542, Train Acc: 0.61081, Val Acc: 0.46091
# Epoch: 024, Loss: 1.33364, Train Acc: 0.62179, Val Acc: 0.46365
# Epoch: 025, Loss: 1.33206, Train Acc: 0.62912, Val Acc: 0.42250
# Epoch: 026, Loss: 1.33740, Train Acc: 0.61355, Val Acc: 0.41838
# Epoch: 027, Loss: 1.32323, Train Acc: 0.61905, Val Acc: 0.41152
# Epoch: 028, Loss: 1.32493, Train Acc: 0.61538, Val Acc: 0.38546
# Epoch: 029, Loss: 1.32132, Train Acc: 0.62912, Val Acc: 0.37449
# Epoch: 030, Loss: 1.32410, Train Acc: 0.62271, Val Acc: 0.37174
# Epoch: 031, Loss: 1.32409, Train Acc: 0.61996, Val Acc: 0.35802
# Epoch: 032, Loss: 1.31683, Train Acc: 0.62088, Val Acc: 0.36626
# Epoch: 033, Loss: 1.31891, Train Acc: 0.61905, Val Acc: 0.37586
# Epoch: 034, Loss: 1.31559, Train Acc: 0.61355, Val Acc: 0.37860
# Epoch: 035, Loss: 1.31951, Train Acc: 0.61538, Val Acc: 0.37586
# Epoch: 036, Loss: 1.32067, Train Acc: 0.62546, Val Acc: 0.37586
# Epoch: 037, Loss: 1.31668, Train Acc: 0.62088, Val Acc: 0.37311
# Epoch: 038, Loss: 1.32005, Train Acc: 0.61538, Val Acc: 0.38272
# Epoch: 039, Loss: 1.31646, Train Acc: 0.61355, Val Acc: 0.38409
# Epoch: 040, Loss: 1.31771, Train Acc: 0.62912, Val Acc: 0.37997
# Epoch: 041, Loss: 1.31928, Train Acc: 0.64744, Val Acc: 0.37723
# Epoch: 042, Loss: 1.31689, Train Acc: 0.62179, Val Acc: 0.37311
# Epoch: 043, Loss: 1.31394, Train Acc: 0.64927, Val Acc: 0.37311
# Epoch: 044, Loss: 1.31667, Train Acc: 0.64652, Val Acc: 0.37037
# Epoch: 045, Loss: 1.31558, Train Acc: 0.63553, Val Acc: 0.37586
# Epoch: 046, Loss: 1.31279, Train Acc: 0.62271, Val Acc: 0.38272
# Epoch: 047, Loss: 1.30264, Train Acc: 0.64103, Val Acc: 0.37997
# Epoch: 048, Loss: 1.30971, Train Acc: 0.63004, Val Acc: 0.37586
# Epoch: 049, Loss: 1.32165, Train Acc: 0.63004, Val Acc: 0.36900
# Epoch: 050, Loss: 1.31455, Train Acc: 0.61905, Val Acc: 0.35528
# Epoch: 051, Loss: 1.32450, Train Acc: 0.63004, Val Acc: 0.35117
# Epoch: 052, Loss: 1.30566, Train Acc: 0.63095, Val Acc: 0.34705
# Epoch: 053, Loss: 1.31255, Train Acc: 0.63919, Val Acc: 0.34568
# Epoch: 054, Loss: 1.31204, Train Acc: 0.63462, Val Acc: 0.35391
# Epoch: 055, Loss: 1.30440, Train Acc: 0.64377, Val Acc: 0.35528
# Epoch: 056, Loss: 1.30331, Train Acc: 0.64560, Val Acc: 0.36488
# Epoch: 057, Loss: 1.31571, Train Acc: 0.64469, Val Acc: 0.37037
# Epoch: 058, Loss: 1.30357, Train Acc: 0.63370, Val Acc: 0.36900
# Epoch: 059, Loss: 1.32221, Train Acc: 0.63278, Val Acc: 0.36626
# Epoch: 060, Loss: 1.30058, Train Acc: 0.64927, Val Acc: 0.36351
# Epoch: 061, Loss: 1.31399, Train Acc: 0.60623, Val Acc: 0.35802
# Epoch: 062, Loss: 1.31246, Train Acc: 0.63828, Val Acc: 0.34979
# Epoch: 063, Loss: 1.29815, Train Acc: 0.64377, Val Acc: 0.36077
# Epoch: 064, Loss: 1.31644, Train Acc: 0.63645, Val Acc: 0.35254
# Epoch: 065, Loss: 1.31636, Train Acc: 0.63095, Val Acc: 0.34979
# Epoch: 066, Loss: 1.31309, Train Acc: 0.64286, Val Acc: 0.35254
# Epoch: 067, Loss: 1.30027, Train Acc: 0.64103, Val Acc: 0.34568
# Epoch: 068, Loss: 1.30863, Train Acc: 0.64103, Val Acc: 0.34431
# Epoch: 069, Loss: 1.30548, Train Acc: 0.64011, Val Acc: 0.33745
# Epoch: 070, Loss: 1.31731, Train Acc: 0.60623, Val Acc: 0.33608
# Epoch: 071, Loss: 1.31331, Train Acc: 0.63095, Val Acc: 0.33608
# Epoch: 072, Loss: 1.30873, Train Acc: 0.64377, Val Acc: 0.33882
# Epoch: 073, Loss: 1.30785, Train Acc: 0.63828, Val Acc: 0.33882
# Epoch: 074, Loss: 1.29844, Train Acc: 0.64377, Val Acc: 0.33745
# Epoch: 075, Loss: 1.30506, Train Acc: 0.64011, Val Acc: 0.34842
# Epoch: 076, Loss: 1.30491, Train Acc: 0.65659, Val Acc: 0.35117
# Epoch: 077, Loss: 1.30515, Train Acc: 0.63278, Val Acc: 0.35665
# Epoch: 078, Loss: 1.30295, Train Acc: 0.63645, Val Acc: 0.34842
# Epoch: 079, Loss: 1.30490, Train Acc: 0.63462, Val Acc: 0.34705
# Epoch: 080, Loss: 1.31074, Train Acc: 0.64469, Val Acc: 0.34019
# Epoch: 081, Loss: 1.31229, Train Acc: 0.62912, Val Acc: 0.34294
# Epoch: 082, Loss: 1.31213, Train Acc: 0.62088, Val Acc: 0.33882
# Epoch: 083, Loss: 1.30188, Train Acc: 0.63828, Val Acc: 0.33608
# Epoch: 084, Loss: 1.29632, Train Acc: 0.63370, Val Acc: 0.35665
# Epoch: 085, Loss: 1.31388, Train Acc: 0.62912, Val Acc: 0.36077
# Epoch: 086, Loss: 1.29663, Train Acc: 0.63645, Val Acc: 0.37586
# Epoch: 087, Loss: 1.30479, Train Acc: 0.63370, Val Acc: 0.37723
# Epoch: 088, Loss: 1.30444, Train Acc: 0.62179, Val Acc: 0.38272
# Epoch: 089, Loss: 1.29635, Train Acc: 0.64652, Val Acc: 0.37449
# Epoch: 090, Loss: 1.30182, Train Acc: 0.63095, Val Acc: 0.36488
# Epoch: 091, Loss: 1.29842, Train Acc: 0.63278, Val Acc: 0.36626
# Epoch: 092, Loss: 1.30094, Train Acc: 0.63645, Val Acc: 0.36214
# Epoch: 093, Loss: 1.30093, Train Acc: 0.65201, Val Acc: 0.34568
# Epoch: 094, Loss: 1.30664, Train Acc: 0.63004, Val Acc: 0.34568
# Epoch: 095, Loss: 1.30429, Train Acc: 0.63370, Val Acc: 0.33196
# Epoch: 096, Loss: 1.31190, Train Acc: 0.64560, Val Acc: 0.33471
# Epoch: 097, Loss: 1.30681, Train Acc: 0.63187, Val Acc: 0.34431
# Epoch: 098, Loss: 1.28722, Train Acc: 0.66300, Val Acc: 0.34294
# Epoch: 099, Loss: 1.30119, Train Acc: 0.65018, Val Acc: 0.33745
# Epoch: 100, Loss: 1.29474, Train Acc: 0.65201, Val Acc: 0.33882
# Test Accuracy: 0.31360
# Random State 543452  in the iteration 3
# Epoch: 001, Loss: 1.38170, Train Acc: 0.55403, Val Acc: 0.40192
# Epoch: 002, Loss: 1.35372, Train Acc: 0.58608, Val Acc: 0.37860
# Epoch: 003, Loss: 1.34690, Train Acc: 0.57234, Val Acc: 0.37860
# Epoch: 004, Loss: 1.34523, Train Acc: 0.60073, Val Acc: 0.38272
# Epoch: 005, Loss: 1.33807, Train Acc: 0.59890, Val Acc: 0.40878
# Epoch: 006, Loss: 1.34093, Train Acc: 0.61172, Val Acc: 0.39643
# Epoch: 007, Loss: 1.33255, Train Acc: 0.59890, Val Acc: 0.40192
# Epoch: 008, Loss: 1.31589, Train Acc: 0.60989, Val Acc: 0.43210
# Epoch: 009, Loss: 1.32760, Train Acc: 0.60440, Val Acc: 0.42112
# Epoch: 010, Loss: 1.31904, Train Acc: 0.60623, Val Acc: 0.40055
# Epoch: 011, Loss: 1.32497, Train Acc: 0.60897, Val Acc: 0.38957
# Epoch: 012, Loss: 1.30312, Train Acc: 0.63553, Val Acc: 0.37997
# Epoch: 013, Loss: 1.30679, Train Acc: 0.63553, Val Acc: 0.37174
# Epoch: 014, Loss: 1.30910, Train Acc: 0.63736, Val Acc: 0.35528
# Epoch: 015, Loss: 1.30895, Train Acc: 0.62637, Val Acc: 0.36488
# Epoch: 016, Loss: 1.32335, Train Acc: 0.63004, Val Acc: 0.37449
# Epoch: 017, Loss: 1.30832, Train Acc: 0.61905, Val Acc: 0.38409
# Epoch: 018, Loss: 1.29909, Train Acc: 0.63278, Val Acc: 0.38683
# Epoch: 019, Loss: 1.30379, Train Acc: 0.62729, Val Acc: 0.37997
# Epoch: 020, Loss: 1.30229, Train Acc: 0.62546, Val Acc: 0.38683
# Epoch: 021, Loss: 1.31511, Train Acc: 0.60531, Val Acc: 0.38272
# Epoch: 022, Loss: 1.29511, Train Acc: 0.63462, Val Acc: 0.37997
# Epoch: 023, Loss: 1.29862, Train Acc: 0.64103, Val Acc: 0.37723
# Epoch: 024, Loss: 1.30381, Train Acc: 0.63278, Val Acc: 0.40055
# Epoch: 025, Loss: 1.29660, Train Acc: 0.64927, Val Acc: 0.38683
# Epoch: 026, Loss: 1.29932, Train Acc: 0.64194, Val Acc: 0.37997
# Epoch: 027, Loss: 1.30987, Train Acc: 0.62363, Val Acc: 0.36351
# Epoch: 028, Loss: 1.29964, Train Acc: 0.65018, Val Acc: 0.35940
# Epoch: 029, Loss: 1.29993, Train Acc: 0.65385, Val Acc: 0.36626
# Epoch: 030, Loss: 1.29161, Train Acc: 0.64011, Val Acc: 0.36488
# Epoch: 031, Loss: 1.29087, Train Acc: 0.64652, Val Acc: 0.36488
# Epoch: 032, Loss: 1.29235, Train Acc: 0.65659, Val Acc: 0.37449
# Epoch: 033, Loss: 1.28427, Train Acc: 0.65751, Val Acc: 0.38409
# Epoch: 034, Loss: 1.29446, Train Acc: 0.65568, Val Acc: 0.38134
# Epoch: 035, Loss: 1.29999, Train Acc: 0.63736, Val Acc: 0.37723
# Epoch: 036, Loss: 1.29153, Train Acc: 0.64744, Val Acc: 0.38957
# Epoch: 037, Loss: 1.29724, Train Acc: 0.62821, Val Acc: 0.37997
# Epoch: 038, Loss: 1.29307, Train Acc: 0.65385, Val Acc: 0.38272
# Epoch: 039, Loss: 1.29380, Train Acc: 0.64927, Val Acc: 0.36077
# Epoch: 040, Loss: 1.29234, Train Acc: 0.64560, Val Acc: 0.35254
# Epoch: 041, Loss: 1.29179, Train Acc: 0.67216, Val Acc: 0.35117
# Epoch: 042, Loss: 1.29119, Train Acc: 0.65842, Val Acc: 0.35391
# Epoch: 043, Loss: 1.29584, Train Acc: 0.64835, Val Acc: 0.38272
# Epoch: 044, Loss: 1.30885, Train Acc: 0.64194, Val Acc: 0.37449
# Epoch: 045, Loss: 1.30668, Train Acc: 0.62179, Val Acc: 0.36763
# Epoch: 046, Loss: 1.29369, Train Acc: 0.62729, Val Acc: 0.37174
# Epoch: 047, Loss: 1.28951, Train Acc: 0.64652, Val Acc: 0.37037
# Epoch: 048, Loss: 1.30925, Train Acc: 0.63187, Val Acc: 0.37311
# Epoch: 049, Loss: 1.28591, Train Acc: 0.65751, Val Acc: 0.37723
# Epoch: 050, Loss: 1.29236, Train Acc: 0.64652, Val Acc: 0.37174
# Epoch: 051, Loss: 1.28510, Train Acc: 0.66758, Val Acc: 0.34705
# Epoch: 052, Loss: 1.30075, Train Acc: 0.64835, Val Acc: 0.35254
# Epoch: 053, Loss: 1.29960, Train Acc: 0.65659, Val Acc: 0.37037
# Epoch: 054, Loss: 1.28232, Train Acc: 0.65934, Val Acc: 0.38409
# Epoch: 055, Loss: 1.27902, Train Acc: 0.66300, Val Acc: 0.36900
# Epoch: 056, Loss: 1.30125, Train Acc: 0.64652, Val Acc: 0.36214
# Epoch: 057, Loss: 1.28800, Train Acc: 0.66575, Val Acc: 0.37311
# Epoch: 058, Loss: 1.28450, Train Acc: 0.66850, Val Acc: 0.38134
# Epoch: 059, Loss: 1.28905, Train Acc: 0.65934, Val Acc: 0.36900
# Epoch: 060, Loss: 1.28812, Train Acc: 0.65934, Val Acc: 0.35802
# Epoch: 061, Loss: 1.29248, Train Acc: 0.64011, Val Acc: 0.35802
# Epoch: 062, Loss: 1.28267, Train Acc: 0.67674, Val Acc: 0.35117
# Epoch: 063, Loss: 1.28544, Train Acc: 0.66758, Val Acc: 0.34842
# Epoch: 064, Loss: 1.28986, Train Acc: 0.65842, Val Acc: 0.36626
# Epoch: 065, Loss: 1.27799, Train Acc: 0.66392, Val Acc: 0.37586
# Epoch: 066, Loss: 1.29742, Train Acc: 0.64835, Val Acc: 0.36763
# Epoch: 067, Loss: 1.28225, Train Acc: 0.66941, Val Acc: 0.35391
# Epoch: 068, Loss: 1.29293, Train Acc: 0.65751, Val Acc: 0.36626
# Epoch: 069, Loss: 1.29017, Train Acc: 0.65110, Val Acc: 0.36214
# Epoch: 070, Loss: 1.28602, Train Acc: 0.66209, Val Acc: 0.34705
# Epoch: 071, Loss: 1.28754, Train Acc: 0.66209, Val Acc: 0.34842
# Epoch: 072, Loss: 1.28453, Train Acc: 0.66026, Val Acc: 0.35254
# Epoch: 073, Loss: 1.27309, Train Acc: 0.66300, Val Acc: 0.34842
# Epoch: 074, Loss: 1.30133, Train Acc: 0.64469, Val Acc: 0.33608
# Epoch: 075, Loss: 1.28501, Train Acc: 0.67766, Val Acc: 0.34156
# Epoch: 076, Loss: 1.28170, Train Acc: 0.67033, Val Acc: 0.34156
# Epoch: 077, Loss: 1.28200, Train Acc: 0.66575, Val Acc: 0.34294
# Epoch: 078, Loss: 1.28367, Train Acc: 0.66300, Val Acc: 0.34979
# Epoch: 079, Loss: 1.29644, Train Acc: 0.65751, Val Acc: 0.37037
# Epoch: 080, Loss: 1.28652, Train Acc: 0.66209, Val Acc: 0.37311
# Epoch: 081, Loss: 1.27994, Train Acc: 0.66850, Val Acc: 0.36763
# Epoch: 082, Loss: 1.27765, Train Acc: 0.66850, Val Acc: 0.38409
# Epoch: 083, Loss: 1.28553, Train Acc: 0.66117, Val Acc: 0.38272
# Epoch: 084, Loss: 1.28964, Train Acc: 0.66209, Val Acc: 0.36488
# Epoch: 085, Loss: 1.27485, Train Acc: 0.67125, Val Acc: 0.35528
# Epoch: 086, Loss: 1.28466, Train Acc: 0.66117, Val Acc: 0.35254
# Epoch: 087, Loss: 1.28471, Train Acc: 0.66117, Val Acc: 0.35802
# Epoch: 088, Loss: 1.29455, Train Acc: 0.65476, Val Acc: 0.35528
# Epoch: 089, Loss: 1.28689, Train Acc: 0.64560, Val Acc: 0.36351
# Epoch: 090, Loss: 1.28263, Train Acc: 0.64560, Val Acc: 0.35391
# Epoch: 091, Loss: 1.28200, Train Acc: 0.64835, Val Acc: 0.34294
# Epoch: 092, Loss: 1.27452, Train Acc: 0.67582, Val Acc: 0.33745
# Epoch: 093, Loss: 1.28195, Train Acc: 0.66392, Val Acc: 0.34019
# Epoch: 094, Loss: 1.27144, Train Acc: 0.66026, Val Acc: 0.33882
# Epoch: 095, Loss: 1.28000, Train Acc: 0.67033, Val Acc: 0.34156
# Epoch: 096, Loss: 1.27148, Train Acc: 0.67125, Val Acc: 0.34431
# Epoch: 097, Loss: 1.29178, Train Acc: 0.65293, Val Acc: 0.34431
# Epoch: 098, Loss: 1.27188, Train Acc: 0.67582, Val Acc: 0.32785
# Epoch: 099, Loss: 1.28388, Train Acc: 0.65568, Val Acc: 0.32236
# Epoch: 100, Loss: 1.27867, Train Acc: 0.66209, Val Acc: 0.30727
# Test Accuracy: 0.36184
# Random State 743456  in the iteration 4
# Epoch: 001, Loss: 1.41589, Train Acc: 0.52198, Val Acc: 0.46091
# Epoch: 002, Loss: 1.39265, Train Acc: 0.52656, Val Acc: 0.44993
# Epoch: 003, Loss: 1.40596, Train Acc: 0.50549, Val Acc: 0.43759
# Epoch: 004, Loss: 1.39242, Train Acc: 0.51832, Val Acc: 0.44719
# Epoch: 005, Loss: 1.38782, Train Acc: 0.52564, Val Acc: 0.44993
# Epoch: 006, Loss: 1.38258, Train Acc: 0.53663, Val Acc: 0.44993
# Epoch: 007, Loss: 1.38404, Train Acc: 0.52381, Val Acc: 0.45130
# Epoch: 008, Loss: 1.35959, Train Acc: 0.60256, Val Acc: 0.44856
# Epoch: 009, Loss: 1.34382, Train Acc: 0.58974, Val Acc: 0.44582
# Epoch: 010, Loss: 1.35010, Train Acc: 0.59066, Val Acc: 0.44170
# Epoch: 011, Loss: 1.33608, Train Acc: 0.60531, Val Acc: 0.42798
# Epoch: 012, Loss: 1.34902, Train Acc: 0.60806, Val Acc: 0.41838
# Epoch: 013, Loss: 1.34352, Train Acc: 0.62179, Val Acc: 0.40741
# Epoch: 014, Loss: 1.34272, Train Acc: 0.59524, Val Acc: 0.40878
# Epoch: 015, Loss: 1.34522, Train Acc: 0.59341, Val Acc: 0.40604
# Epoch: 016, Loss: 1.34577, Train Acc: 0.59982, Val Acc: 0.40878
# Epoch: 017, Loss: 1.33344, Train Acc: 0.61447, Val Acc: 0.40604
# Epoch: 018, Loss: 1.33299, Train Acc: 0.59890, Val Acc: 0.39918
# Epoch: 019, Loss: 1.32693, Train Acc: 0.59890, Val Acc: 0.40466
# Epoch: 020, Loss: 1.34075, Train Acc: 0.59249, Val Acc: 0.40466
# Epoch: 021, Loss: 1.33895, Train Acc: 0.59524, Val Acc: 0.39369
# Epoch: 022, Loss: 1.32050, Train Acc: 0.60531, Val Acc: 0.38957
# Epoch: 023, Loss: 1.32566, Train Acc: 0.62546, Val Acc: 0.38134
# Epoch: 024, Loss: 1.31982, Train Acc: 0.62088, Val Acc: 0.36077
# Epoch: 025, Loss: 1.32474, Train Acc: 0.61264, Val Acc: 0.35528
# Epoch: 026, Loss: 1.31511, Train Acc: 0.61447, Val Acc: 0.34431
# Epoch: 027, Loss: 1.31718, Train Acc: 0.62271, Val Acc: 0.34842
# Epoch: 028, Loss: 1.33049, Train Acc: 0.63187, Val Acc: 0.34705
# Epoch: 029, Loss: 1.31287, Train Acc: 0.62637, Val Acc: 0.36077
# Epoch: 030, Loss: 1.32241, Train Acc: 0.60440, Val Acc: 0.36214
# Epoch: 031, Loss: 1.31616, Train Acc: 0.63095, Val Acc: 0.35802
# Epoch: 032, Loss: 1.30179, Train Acc: 0.64286, Val Acc: 0.35391
# Epoch: 033, Loss: 1.30996, Train Acc: 0.61905, Val Acc: 0.34979
# Epoch: 034, Loss: 1.32517, Train Acc: 0.60531, Val Acc: 0.35117
# Epoch: 035, Loss: 1.31031, Train Acc: 0.62546, Val Acc: 0.35391
# Epoch: 036, Loss: 1.30750, Train Acc: 0.62637, Val Acc: 0.34705
# Epoch: 037, Loss: 1.30431, Train Acc: 0.64103, Val Acc: 0.32922
# Epoch: 038, Loss: 1.31316, Train Acc: 0.62179, Val Acc: 0.32373
# Epoch: 039, Loss: 1.31196, Train Acc: 0.63736, Val Acc: 0.31139
# Epoch: 040, Loss: 1.31036, Train Acc: 0.63187, Val Acc: 0.30590
# Epoch: 041, Loss: 1.30223, Train Acc: 0.64469, Val Acc: 0.30727
# Epoch: 042, Loss: 1.31791, Train Acc: 0.62821, Val Acc: 0.32099
# Epoch: 043, Loss: 1.32025, Train Acc: 0.60256, Val Acc: 0.32785
# Epoch: 044, Loss: 1.31867, Train Acc: 0.60714, Val Acc: 0.33745
# Epoch: 045, Loss: 1.31270, Train Acc: 0.62546, Val Acc: 0.34842
# Epoch: 046, Loss: 1.31573, Train Acc: 0.61996, Val Acc: 0.35254
# Epoch: 047, Loss: 1.30519, Train Acc: 0.62637, Val Acc: 0.34842
# Epoch: 048, Loss: 1.31504, Train Acc: 0.62271, Val Acc: 0.32647
# Epoch: 049, Loss: 1.31108, Train Acc: 0.62546, Val Acc: 0.32236
# Epoch: 050, Loss: 1.30750, Train Acc: 0.65110, Val Acc: 0.31824
# Epoch: 051, Loss: 1.30360, Train Acc: 0.62088, Val Acc: 0.31687
# Epoch: 052, Loss: 1.30843, Train Acc: 0.63095, Val Acc: 0.31962
# Epoch: 053, Loss: 1.32104, Train Acc: 0.60897, Val Acc: 0.32785
# Epoch: 054, Loss: 1.30620, Train Acc: 0.64560, Val Acc: 0.34019
# Epoch: 055, Loss: 1.30887, Train Acc: 0.62546, Val Acc: 0.34842
# Epoch: 056, Loss: 1.30231, Train Acc: 0.63278, Val Acc: 0.35117
# Epoch: 057, Loss: 1.31227, Train Acc: 0.62179, Val Acc: 0.34705
# Epoch: 058, Loss: 1.31522, Train Acc: 0.61264, Val Acc: 0.34294
# Epoch: 059, Loss: 1.30706, Train Acc: 0.62821, Val Acc: 0.32922
# Epoch: 060, Loss: 1.30778, Train Acc: 0.62912, Val Acc: 0.32922
# Epoch: 061, Loss: 1.30741, Train Acc: 0.63004, Val Acc: 0.32785
# Epoch: 062, Loss: 1.30960, Train Acc: 0.62363, Val Acc: 0.31962
# Epoch: 063, Loss: 1.31564, Train Acc: 0.63187, Val Acc: 0.31962
# Epoch: 064, Loss: 1.30626, Train Acc: 0.62821, Val Acc: 0.31824
# Epoch: 065, Loss: 1.29870, Train Acc: 0.62546, Val Acc: 0.33882
# Epoch: 066, Loss: 1.29588, Train Acc: 0.63736, Val Acc: 0.34568
# Epoch: 067, Loss: 1.30519, Train Acc: 0.61264, Val Acc: 0.34019
# Epoch: 068, Loss: 1.31064, Train Acc: 0.64103, Val Acc: 0.35254
# Epoch: 069, Loss: 1.28647, Train Acc: 0.64652, Val Acc: 0.33745
# Epoch: 070, Loss: 1.31253, Train Acc: 0.64377, Val Acc: 0.32922
# Epoch: 071, Loss: 1.29587, Train Acc: 0.63187, Val Acc: 0.31550
# Epoch: 072, Loss: 1.29729, Train Acc: 0.66392, Val Acc: 0.31824
# Epoch: 073, Loss: 1.29653, Train Acc: 0.65018, Val Acc: 0.31824
# Epoch: 074, Loss: 1.30620, Train Acc: 0.63828, Val Acc: 0.30727
# Epoch: 075, Loss: 1.31350, Train Acc: 0.62363, Val Acc: 0.32647
# Epoch: 076, Loss: 1.30336, Train Acc: 0.62546, Val Acc: 0.33059
# Epoch: 077, Loss: 1.29784, Train Acc: 0.64103, Val Acc: 0.34431
# Epoch: 078, Loss: 1.29458, Train Acc: 0.64377, Val Acc: 0.34294
# Epoch: 079, Loss: 1.30414, Train Acc: 0.63645, Val Acc: 0.34568
# Epoch: 080, Loss: 1.31215, Train Acc: 0.63828, Val Acc: 0.34431
# Epoch: 081, Loss: 1.29703, Train Acc: 0.65385, Val Acc: 0.33745
# Epoch: 082, Loss: 1.30228, Train Acc: 0.64011, Val Acc: 0.33333
# Epoch: 083, Loss: 1.30064, Train Acc: 0.64194, Val Acc: 0.33059
# Epoch: 084, Loss: 1.28753, Train Acc: 0.65934, Val Acc: 0.31687
# Epoch: 085, Loss: 1.30681, Train Acc: 0.63828, Val Acc: 0.31550
# Epoch: 086, Loss: 1.30431, Train Acc: 0.63370, Val Acc: 0.32373
# Epoch: 087, Loss: 1.29289, Train Acc: 0.65476, Val Acc: 0.33333
# Epoch: 088, Loss: 1.29676, Train Acc: 0.64560, Val Acc: 0.34019
# Epoch: 089, Loss: 1.29636, Train Acc: 0.65018, Val Acc: 0.33745
# Epoch: 090, Loss: 1.29996, Train Acc: 0.64286, Val Acc: 0.33745
# Epoch: 091, Loss: 1.29583, Train Acc: 0.64103, Val Acc: 0.33608
# Epoch: 092, Loss: 1.29351, Train Acc: 0.63095, Val Acc: 0.33882
# Epoch: 093, Loss: 1.29289, Train Acc: 0.64103, Val Acc: 0.33333
# Epoch: 094, Loss: 1.29251, Train Acc: 0.64011, Val Acc: 0.31413
# Epoch: 095, Loss: 1.30478, Train Acc: 0.62454, Val Acc: 0.30590
# Epoch: 096, Loss: 1.29018, Train Acc: 0.64652, Val Acc: 0.30590
# Epoch: 097, Loss: 1.31038, Train Acc: 0.63553, Val Acc: 0.30453
# Epoch: 098, Loss: 1.29824, Train Acc: 0.64652, Val Acc: 0.30727
# Epoch: 099, Loss: 1.30174, Train Acc: 0.63095, Val Acc: 0.31687
# Epoch: 100, Loss: 1.29262, Train Acc: 0.64927, Val Acc: 0.32647
# Test Accuracy: 0.36623
# Random State 4734510  in the iteration 5
# Epoch: 001, Loss: 1.42256, Train Acc: 0.50733, Val Acc: 0.41975
# Epoch: 002, Loss: 1.39819, Train Acc: 0.51740, Val Acc: 0.39506
# Epoch: 003, Loss: 1.38286, Train Acc: 0.53205, Val Acc: 0.39506
# Epoch: 004, Loss: 1.36562, Train Acc: 0.56960, Val Acc: 0.38820
# Epoch: 005, Loss: 1.39049, Train Acc: 0.53571, Val Acc: 0.39918
# Epoch: 006, Loss: 1.35018, Train Acc: 0.59615, Val Acc: 0.39369
# Epoch: 007, Loss: 1.33521, Train Acc: 0.62088, Val Acc: 0.41152
# Epoch: 008, Loss: 1.34528, Train Acc: 0.58974, Val Acc: 0.43347
# Epoch: 009, Loss: 1.33301, Train Acc: 0.60165, Val Acc: 0.43484
# Epoch: 010, Loss: 1.32087, Train Acc: 0.61630, Val Acc: 0.43484
# Epoch: 011, Loss: 1.32559, Train Acc: 0.61905, Val Acc: 0.41289
# Epoch: 012, Loss: 1.31203, Train Acc: 0.61813, Val Acc: 0.42112
# Epoch: 013, Loss: 1.33158, Train Acc: 0.60989, Val Acc: 0.42387
# Epoch: 014, Loss: 1.30681, Train Acc: 0.62821, Val Acc: 0.42112
# Epoch: 015, Loss: 1.30507, Train Acc: 0.64560, Val Acc: 0.42387
# Epoch: 016, Loss: 1.30024, Train Acc: 0.65018, Val Acc: 0.42112
# Epoch: 017, Loss: 1.31071, Train Acc: 0.64011, Val Acc: 0.43073
# Epoch: 018, Loss: 1.30559, Train Acc: 0.63187, Val Acc: 0.44170
# Epoch: 019, Loss: 1.29499, Train Acc: 0.64835, Val Acc: 0.44444
# Epoch: 020, Loss: 1.29813, Train Acc: 0.64011, Val Acc: 0.44993
# Epoch: 021, Loss: 1.30245, Train Acc: 0.64835, Val Acc: 0.45130
# Epoch: 022, Loss: 1.30512, Train Acc: 0.62637, Val Acc: 0.44444
# Epoch: 023, Loss: 1.29612, Train Acc: 0.64652, Val Acc: 0.39506
# Epoch: 024, Loss: 1.28827, Train Acc: 0.63919, Val Acc: 0.39095
# Epoch: 025, Loss: 1.30590, Train Acc: 0.62363, Val Acc: 0.39095
# Epoch: 026, Loss: 1.29153, Train Acc: 0.64652, Val Acc: 0.38957
# Epoch: 027, Loss: 1.29892, Train Acc: 0.64469, Val Acc: 0.38683
# Epoch: 028, Loss: 1.29555, Train Acc: 0.63278, Val Acc: 0.38683
# Epoch: 029, Loss: 1.28372, Train Acc: 0.65293, Val Acc: 0.38272
# Epoch: 030, Loss: 1.28473, Train Acc: 0.64286, Val Acc: 0.37449
# Epoch: 031, Loss: 1.28754, Train Acc: 0.64469, Val Acc: 0.36900
# Epoch: 032, Loss: 1.29046, Train Acc: 0.64286, Val Acc: 0.38272
# Epoch: 033, Loss: 1.28415, Train Acc: 0.65568, Val Acc: 0.38683
# Epoch: 034, Loss: 1.28993, Train Acc: 0.65293, Val Acc: 0.39095
# Epoch: 035, Loss: 1.28339, Train Acc: 0.64927, Val Acc: 0.36763
# Epoch: 036, Loss: 1.28166, Train Acc: 0.65476, Val Acc: 0.37449
# Epoch: 037, Loss: 1.27877, Train Acc: 0.66026, Val Acc: 0.37174
# Epoch: 038, Loss: 1.27085, Train Acc: 0.67582, Val Acc: 0.38272
# Epoch: 039, Loss: 1.28587, Train Acc: 0.66392, Val Acc: 0.38820
# Epoch: 040, Loss: 1.27737, Train Acc: 0.67766, Val Acc: 0.38820
# Epoch: 041, Loss: 1.27731, Train Acc: 0.67399, Val Acc: 0.38683
# Epoch: 042, Loss: 1.29213, Train Acc: 0.65476, Val Acc: 0.38546
# Epoch: 043, Loss: 1.28692, Train Acc: 0.64744, Val Acc: 0.38546
# Epoch: 044, Loss: 1.27128, Train Acc: 0.67491, Val Acc: 0.38957
# Epoch: 045, Loss: 1.27766, Train Acc: 0.65842, Val Acc: 0.38957
# Epoch: 046, Loss: 1.28100, Train Acc: 0.64103, Val Acc: 0.38820
# Epoch: 047, Loss: 1.28156, Train Acc: 0.64744, Val Acc: 0.37037
# Epoch: 048, Loss: 1.27337, Train Acc: 0.66850, Val Acc: 0.36214
# Epoch: 049, Loss: 1.27517, Train Acc: 0.64652, Val Acc: 0.35802
# Epoch: 050, Loss: 1.27064, Train Acc: 0.68407, Val Acc: 0.34979
# Epoch: 051, Loss: 1.27481, Train Acc: 0.66667, Val Acc: 0.33745
# Epoch: 052, Loss: 1.28432, Train Acc: 0.66758, Val Acc: 0.34294
# Epoch: 053, Loss: 1.26575, Train Acc: 0.68315, Val Acc: 0.34842
# Epoch: 054, Loss: 1.27504, Train Acc: 0.65842, Val Acc: 0.34979
# Epoch: 055, Loss: 1.27900, Train Acc: 0.66575, Val Acc: 0.34294
# Epoch: 056, Loss: 1.26885, Train Acc: 0.67582, Val Acc: 0.34979
# Epoch: 057, Loss: 1.29299, Train Acc: 0.64835, Val Acc: 0.34842
# Epoch: 058, Loss: 1.28602, Train Acc: 0.65385, Val Acc: 0.34431
# Epoch: 059, Loss: 1.27566, Train Acc: 0.68864, Val Acc: 0.34568
# Epoch: 060, Loss: 1.28009, Train Acc: 0.65934, Val Acc: 0.34431
# Epoch: 061, Loss: 1.29012, Train Acc: 0.64103, Val Acc: 0.33745
# Epoch: 062, Loss: 1.27979, Train Acc: 0.67399, Val Acc: 0.33882
# Epoch: 063, Loss: 1.29124, Train Acc: 0.65385, Val Acc: 0.33745
# Epoch: 064, Loss: 1.28643, Train Acc: 0.68132, Val Acc: 0.34431
# Epoch: 065, Loss: 1.29018, Train Acc: 0.65476, Val Acc: 0.34431
# Epoch: 066, Loss: 1.29435, Train Acc: 0.64194, Val Acc: 0.34842
# Epoch: 067, Loss: 1.27739, Train Acc: 0.65110, Val Acc: 0.35665
# Epoch: 068, Loss: 1.28542, Train Acc: 0.65201, Val Acc: 0.34979
# Epoch: 069, Loss: 1.27445, Train Acc: 0.66300, Val Acc: 0.35528
# Epoch: 070, Loss: 1.27869, Train Acc: 0.65201, Val Acc: 0.33745
# Epoch: 071, Loss: 1.27767, Train Acc: 0.67491, Val Acc: 0.33471
# Epoch: 072, Loss: 1.27989, Train Acc: 0.66026, Val Acc: 0.33196
# Epoch: 073, Loss: 1.26432, Train Acc: 0.68498, Val Acc: 0.33059
# Epoch: 074, Loss: 1.28106, Train Acc: 0.67216, Val Acc: 0.33471
# Epoch: 075, Loss: 1.27735, Train Acc: 0.67216, Val Acc: 0.33745
# Epoch: 076, Loss: 1.27960, Train Acc: 0.66209, Val Acc: 0.33471
# Epoch: 077, Loss: 1.28321, Train Acc: 0.66026, Val Acc: 0.33608
# Epoch: 078, Loss: 1.27704, Train Acc: 0.66117, Val Acc: 0.34294
# Epoch: 079, Loss: 1.28495, Train Acc: 0.66575, Val Acc: 0.34156
# Epoch: 080, Loss: 1.28749, Train Acc: 0.65476, Val Acc: 0.33333
# Epoch: 081, Loss: 1.27476, Train Acc: 0.67766, Val Acc: 0.33471
# Epoch: 082, Loss: 1.26959, Train Acc: 0.66209, Val Acc: 0.33059
# Epoch: 083, Loss: 1.28057, Train Acc: 0.66667, Val Acc: 0.32099
# Epoch: 084, Loss: 1.27342, Train Acc: 0.66667, Val Acc: 0.32236
# Epoch: 085, Loss: 1.26727, Train Acc: 0.67033, Val Acc: 0.35528
# Epoch: 086, Loss: 1.27422, Train Acc: 0.66026, Val Acc: 0.35117
# Epoch: 087, Loss: 1.29007, Train Acc: 0.65751, Val Acc: 0.33608
# Epoch: 088, Loss: 1.28346, Train Acc: 0.66117, Val Acc: 0.33471
# Epoch: 089, Loss: 1.27802, Train Acc: 0.66209, Val Acc: 0.34431
# Epoch: 090, Loss: 1.27422, Train Acc: 0.66850, Val Acc: 0.33882
# Epoch: 091, Loss: 1.26983, Train Acc: 0.66392, Val Acc: 0.33196
# Epoch: 092, Loss: 1.28313, Train Acc: 0.66484, Val Acc: 0.33471
# Epoch: 093, Loss: 1.27008, Train Acc: 0.69597, Val Acc: 0.33471
# Epoch: 094, Loss: 1.29192, Train Acc: 0.65751, Val Acc: 0.33333
# Epoch: 095, Loss: 1.26800, Train Acc: 0.69231, Val Acc: 0.36763
# Epoch: 096, Loss: 1.26419, Train Acc: 0.67308, Val Acc: 0.37037
# Epoch: 097, Loss: 1.26663, Train Acc: 0.68956, Val Acc: 0.36351
# Epoch: 098, Loss: 1.27968, Train Acc: 0.67216, Val Acc: 0.34568
# Epoch: 099, Loss: 1.26953, Train Acc: 0.66575, Val Acc: 0.35528
# Epoch: 100, Loss: 1.27087, Train Acc: 0.66667, Val Acc: 0.33882
# Test Accuracy: 0.27851
# Random State 654321  in the iteration 6
# Epoch: 001, Loss: 1.41833, Train Acc: 0.50000, Val Acc: 0.47325
# Epoch: 002, Loss: 1.40274, Train Acc: 0.52930, Val Acc: 0.47874
# Epoch: 003, Loss: 1.39141, Train Acc: 0.52839, Val Acc: 0.47737
# Epoch: 004, Loss: 1.37378, Train Acc: 0.55586, Val Acc: 0.51166
# Epoch: 005, Loss: 1.37252, Train Acc: 0.56044, Val Acc: 0.50617
# Epoch: 006, Loss: 1.36795, Train Acc: 0.56136, Val Acc: 0.49246
# Epoch: 007, Loss: 1.36211, Train Acc: 0.56685, Val Acc: 0.49108
# Epoch: 008, Loss: 1.37261, Train Acc: 0.55128, Val Acc: 0.49931
# Epoch: 009, Loss: 1.36121, Train Acc: 0.57509, Val Acc: 0.46502
# Epoch: 010, Loss: 1.35196, Train Acc: 0.57784, Val Acc: 0.47325
# Epoch: 011, Loss: 1.34960, Train Acc: 0.56044, Val Acc: 0.46365
# Epoch: 012, Loss: 1.35090, Train Acc: 0.56685, Val Acc: 0.45679
# Epoch: 013, Loss: 1.34496, Train Acc: 0.56868, Val Acc: 0.45405
# Epoch: 014, Loss: 1.34221, Train Acc: 0.58425, Val Acc: 0.46091
# Epoch: 015, Loss: 1.33842, Train Acc: 0.57509, Val Acc: 0.47462
# Epoch: 016, Loss: 1.33255, Train Acc: 0.63370, Val Acc: 0.47462
# Epoch: 017, Loss: 1.35053, Train Acc: 0.60623, Val Acc: 0.46639
# Epoch: 018, Loss: 1.33122, Train Acc: 0.63278, Val Acc: 0.45816
# Epoch: 019, Loss: 1.33117, Train Acc: 0.60897, Val Acc: 0.46914
# Epoch: 020, Loss: 1.32723, Train Acc: 0.63095, Val Acc: 0.46091
# Epoch: 021, Loss: 1.32135, Train Acc: 0.64652, Val Acc: 0.44444
# Epoch: 022, Loss: 1.30961, Train Acc: 0.63004, Val Acc: 0.44033
# Epoch: 023, Loss: 1.32079, Train Acc: 0.60623, Val Acc: 0.44033
# Epoch: 024, Loss: 1.32724, Train Acc: 0.59249, Val Acc: 0.44033
# Epoch: 025, Loss: 1.29678, Train Acc: 0.64011, Val Acc: 0.43896
# Epoch: 026, Loss: 1.30518, Train Acc: 0.62637, Val Acc: 0.43347
# Epoch: 027, Loss: 1.30675, Train Acc: 0.63004, Val Acc: 0.43484
# Epoch: 028, Loss: 1.30031, Train Acc: 0.63462, Val Acc: 0.44307
# Epoch: 029, Loss: 1.31089, Train Acc: 0.61813, Val Acc: 0.44444
# Epoch: 030, Loss: 1.29840, Train Acc: 0.64652, Val Acc: 0.44856
# Epoch: 031, Loss: 1.29258, Train Acc: 0.64927, Val Acc: 0.43759
# Epoch: 032, Loss: 1.30579, Train Acc: 0.65659, Val Acc: 0.43759
# Epoch: 033, Loss: 1.29195, Train Acc: 0.65476, Val Acc: 0.44033
# Epoch: 034, Loss: 1.29992, Train Acc: 0.66850, Val Acc: 0.43073
# Epoch: 035, Loss: 1.30786, Train Acc: 0.65201, Val Acc: 0.38546
# Epoch: 036, Loss: 1.30128, Train Acc: 0.63919, Val Acc: 0.38546
# Epoch: 037, Loss: 1.29585, Train Acc: 0.65568, Val Acc: 0.38683
# Epoch: 038, Loss: 1.29431, Train Acc: 0.65751, Val Acc: 0.38272
# Epoch: 039, Loss: 1.30131, Train Acc: 0.65659, Val Acc: 0.38409
# Epoch: 040, Loss: 1.29458, Train Acc: 0.66026, Val Acc: 0.38134
# Epoch: 041, Loss: 1.30742, Train Acc: 0.63919, Val Acc: 0.38134
# Epoch: 042, Loss: 1.29918, Train Acc: 0.64652, Val Acc: 0.38272
# Epoch: 043, Loss: 1.29278, Train Acc: 0.64927, Val Acc: 0.38546
# Epoch: 044, Loss: 1.28716, Train Acc: 0.66758, Val Acc: 0.38409
# Epoch: 045, Loss: 1.29708, Train Acc: 0.64835, Val Acc: 0.38409
# Epoch: 046, Loss: 1.30062, Train Acc: 0.64377, Val Acc: 0.38683
# Epoch: 047, Loss: 1.28952, Train Acc: 0.67033, Val Acc: 0.38134
# Epoch: 048, Loss: 1.29399, Train Acc: 0.66209, Val Acc: 0.38546
# Epoch: 049, Loss: 1.29228, Train Acc: 0.64927, Val Acc: 0.38820
# Epoch: 050, Loss: 1.29293, Train Acc: 0.64560, Val Acc: 0.37997
# Epoch: 051, Loss: 1.29448, Train Acc: 0.65568, Val Acc: 0.38272
# Epoch: 052, Loss: 1.29067, Train Acc: 0.66300, Val Acc: 0.37997
# Epoch: 053, Loss: 1.28988, Train Acc: 0.66117, Val Acc: 0.38409
# Epoch: 054, Loss: 1.28907, Train Acc: 0.67033, Val Acc: 0.37586
# Epoch: 055, Loss: 1.29777, Train Acc: 0.64469, Val Acc: 0.37174
# Epoch: 056, Loss: 1.29819, Train Acc: 0.63278, Val Acc: 0.37586
# Epoch: 057, Loss: 1.28971, Train Acc: 0.66667, Val Acc: 0.37860
# Epoch: 058, Loss: 1.28923, Train Acc: 0.65934, Val Acc: 0.37449
# Epoch: 059, Loss: 1.28536, Train Acc: 0.66484, Val Acc: 0.37586
# Epoch: 060, Loss: 1.29410, Train Acc: 0.65476, Val Acc: 0.37449
# Epoch: 061, Loss: 1.28514, Train Acc: 0.65110, Val Acc: 0.37997
# Epoch: 062, Loss: 1.28356, Train Acc: 0.65385, Val Acc: 0.38683
# Epoch: 063, Loss: 1.29196, Train Acc: 0.64927, Val Acc: 0.38957
# Epoch: 064, Loss: 1.27792, Train Acc: 0.66575, Val Acc: 0.38134
# Epoch: 065, Loss: 1.29539, Train Acc: 0.65110, Val Acc: 0.37311
# Epoch: 066, Loss: 1.28406, Train Acc: 0.65293, Val Acc: 0.37449
# Epoch: 067, Loss: 1.29183, Train Acc: 0.64560, Val Acc: 0.37586
# Epoch: 068, Loss: 1.28766, Train Acc: 0.67582, Val Acc: 0.37449
# Epoch: 069, Loss: 1.28487, Train Acc: 0.66300, Val Acc: 0.37174
# Epoch: 070, Loss: 1.28234, Train Acc: 0.65934, Val Acc: 0.37037
# Epoch: 071, Loss: 1.28303, Train Acc: 0.65842, Val Acc: 0.36077
# Epoch: 072, Loss: 1.29256, Train Acc: 0.66300, Val Acc: 0.35802
# Epoch: 073, Loss: 1.28317, Train Acc: 0.67399, Val Acc: 0.36488
# Epoch: 074, Loss: 1.28758, Train Acc: 0.67491, Val Acc: 0.36351
# Epoch: 075, Loss: 1.28517, Train Acc: 0.66758, Val Acc: 0.36488
# Epoch: 076, Loss: 1.28552, Train Acc: 0.66209, Val Acc: 0.36214
# Epoch: 077, Loss: 1.29932, Train Acc: 0.66026, Val Acc: 0.37037
# Epoch: 078, Loss: 1.29652, Train Acc: 0.66026, Val Acc: 0.37174
# Epoch: 079, Loss: 1.28850, Train Acc: 0.65568, Val Acc: 0.37586
# Epoch: 080, Loss: 1.28074, Train Acc: 0.66758, Val Acc: 0.36900
# Epoch: 081, Loss: 1.28668, Train Acc: 0.66484, Val Acc: 0.37311
# Epoch: 082, Loss: 1.27955, Train Acc: 0.65568, Val Acc: 0.37449
# Epoch: 083, Loss: 1.28906, Train Acc: 0.65751, Val Acc: 0.37037
# Epoch: 084, Loss: 1.29465, Train Acc: 0.64469, Val Acc: 0.36077
# Epoch: 085, Loss: 1.26879, Train Acc: 0.67949, Val Acc: 0.35940
# Epoch: 086, Loss: 1.27863, Train Acc: 0.67033, Val Acc: 0.36351
# Epoch: 087, Loss: 1.28299, Train Acc: 0.66300, Val Acc: 0.36488
# Epoch: 088, Loss: 1.28565, Train Acc: 0.66117, Val Acc: 0.35940
# Epoch: 089, Loss: 1.29366, Train Acc: 0.66209, Val Acc: 0.35940
# Epoch: 090, Loss: 1.28877, Train Acc: 0.67216, Val Acc: 0.36488
# Epoch: 091, Loss: 1.28955, Train Acc: 0.66117, Val Acc: 0.35665
# Epoch: 092, Loss: 1.27908, Train Acc: 0.66392, Val Acc: 0.34842
# Epoch: 093, Loss: 1.29220, Train Acc: 0.66392, Val Acc: 0.36077
# Epoch: 094, Loss: 1.29093, Train Acc: 0.65659, Val Acc: 0.36351
# Epoch: 095, Loss: 1.28359, Train Acc: 0.66850, Val Acc: 0.35940
# Epoch: 096, Loss: 1.28403, Train Acc: 0.66850, Val Acc: 0.35665
# Epoch: 097, Loss: 1.28860, Train Acc: 0.64927, Val Acc: 0.35528
# Epoch: 098, Loss: 1.28176, Train Acc: 0.67949, Val Acc: 0.35802
# Epoch: 099, Loss: 1.28090, Train Acc: 0.65476, Val Acc: 0.35391
# Epoch: 100, Loss: 1.28113, Train Acc: 0.66026, Val Acc: 0.35117
# Test Accuracy: 0.32237
# Random State 124321  in the iteration 7
# Epoch: 001, Loss: 1.41124, Train Acc: 0.47070, Val Acc: 0.49108
# Epoch: 002, Loss: 1.35691, Train Acc: 0.58700, Val Acc: 0.49108
# Epoch: 003, Loss: 1.34600, Train Acc: 0.59615, Val Acc: 0.48285
# Epoch: 004, Loss: 1.35017, Train Acc: 0.59341, Val Acc: 0.49246
# Epoch: 005, Loss: 1.34628, Train Acc: 0.57418, Val Acc: 0.49794
# Epoch: 006, Loss: 1.33112, Train Acc: 0.61081, Val Acc: 0.49794
# Epoch: 007, Loss: 1.32992, Train Acc: 0.60531, Val Acc: 0.48148
# Epoch: 008, Loss: 1.31985, Train Acc: 0.61081, Val Acc: 0.43896
# Epoch: 009, Loss: 1.31305, Train Acc: 0.62088, Val Acc: 0.43210
# Epoch: 010, Loss: 1.31454, Train Acc: 0.61905, Val Acc: 0.41838
# Epoch: 011, Loss: 1.32520, Train Acc: 0.62271, Val Acc: 0.40878
# Epoch: 012, Loss: 1.30715, Train Acc: 0.62821, Val Acc: 0.40466
# Epoch: 013, Loss: 1.30716, Train Acc: 0.62454, Val Acc: 0.40466
# Epoch: 014, Loss: 1.30303, Train Acc: 0.63736, Val Acc: 0.40192
# Epoch: 015, Loss: 1.31274, Train Acc: 0.64103, Val Acc: 0.40466
# Epoch: 016, Loss: 1.30799, Train Acc: 0.62821, Val Acc: 0.41289
# Epoch: 017, Loss: 1.29762, Train Acc: 0.64377, Val Acc: 0.40329
# Epoch: 018, Loss: 1.30067, Train Acc: 0.64377, Val Acc: 0.39232
# Epoch: 019, Loss: 1.29109, Train Acc: 0.65385, Val Acc: 0.38820
# Epoch: 020, Loss: 1.30650, Train Acc: 0.64835, Val Acc: 0.37997
# Epoch: 021, Loss: 1.29114, Train Acc: 0.64103, Val Acc: 0.38409
# Epoch: 022, Loss: 1.29390, Train Acc: 0.64103, Val Acc: 0.38546
# Epoch: 023, Loss: 1.28925, Train Acc: 0.64835, Val Acc: 0.38134
# Epoch: 024, Loss: 1.28579, Train Acc: 0.66026, Val Acc: 0.37449
# Epoch: 025, Loss: 1.29876, Train Acc: 0.64103, Val Acc: 0.37997
# Epoch: 026, Loss: 1.29269, Train Acc: 0.65385, Val Acc: 0.38546
# Epoch: 027, Loss: 1.29339, Train Acc: 0.64652, Val Acc: 0.38683
# Epoch: 028, Loss: 1.28337, Train Acc: 0.65201, Val Acc: 0.38683
# Epoch: 029, Loss: 1.29066, Train Acc: 0.64744, Val Acc: 0.37860
# Epoch: 030, Loss: 1.28855, Train Acc: 0.65201, Val Acc: 0.38272
# Epoch: 031, Loss: 1.28378, Train Acc: 0.65293, Val Acc: 0.37997
# Epoch: 032, Loss: 1.29951, Train Acc: 0.61905, Val Acc: 0.36077
# Epoch: 033, Loss: 1.28677, Train Acc: 0.64835, Val Acc: 0.34294
# Epoch: 034, Loss: 1.27981, Train Acc: 0.66575, Val Acc: 0.34431
# Epoch: 035, Loss: 1.27974, Train Acc: 0.65018, Val Acc: 0.34294
# Epoch: 036, Loss: 1.28627, Train Acc: 0.66300, Val Acc: 0.34842
# Epoch: 037, Loss: 1.28547, Train Acc: 0.64652, Val Acc: 0.34842
# Epoch: 038, Loss: 1.28390, Train Acc: 0.65751, Val Acc: 0.35528
# Epoch: 039, Loss: 1.28676, Train Acc: 0.65293, Val Acc: 0.37311
# Epoch: 040, Loss: 1.27993, Train Acc: 0.66392, Val Acc: 0.37723
# Epoch: 041, Loss: 1.28811, Train Acc: 0.65842, Val Acc: 0.38546
# Epoch: 042, Loss: 1.29128, Train Acc: 0.66575, Val Acc: 0.37449
# Epoch: 043, Loss: 1.28653, Train Acc: 0.65659, Val Acc: 0.36488
# Epoch: 044, Loss: 1.27960, Train Acc: 0.66300, Val Acc: 0.34979
# Epoch: 045, Loss: 1.29009, Train Acc: 0.64744, Val Acc: 0.34019
# Epoch: 046, Loss: 1.28175, Train Acc: 0.65293, Val Acc: 0.32922
# Epoch: 047, Loss: 1.28320, Train Acc: 0.65568, Val Acc: 0.32647
# Epoch: 048, Loss: 1.28412, Train Acc: 0.65476, Val Acc: 0.32785
# Epoch: 049, Loss: 1.28555, Train Acc: 0.63645, Val Acc: 0.32647
# Epoch: 050, Loss: 1.28578, Train Acc: 0.65476, Val Acc: 0.33333
# Epoch: 051, Loss: 1.26832, Train Acc: 0.68498, Val Acc: 0.33608
# Epoch: 052, Loss: 1.28396, Train Acc: 0.65201, Val Acc: 0.33471
# Epoch: 053, Loss: 1.26974, Train Acc: 0.67399, Val Acc: 0.33196
# Epoch: 054, Loss: 1.27634, Train Acc: 0.67216, Val Acc: 0.33333
# Epoch: 055, Loss: 1.26562, Train Acc: 0.68315, Val Acc: 0.33471
# Epoch: 056, Loss: 1.28061, Train Acc: 0.67308, Val Acc: 0.33471
# Epoch: 057, Loss: 1.27562, Train Acc: 0.66758, Val Acc: 0.33196
# Epoch: 058, Loss: 1.27871, Train Acc: 0.65751, Val Acc: 0.33471
# Epoch: 059, Loss: 1.27287, Train Acc: 0.67582, Val Acc: 0.34568
# Epoch: 060, Loss: 1.27839, Train Acc: 0.65293, Val Acc: 0.35254
# Epoch: 061, Loss: 1.27917, Train Acc: 0.65751, Val Acc: 0.35802
# Epoch: 062, Loss: 1.28159, Train Acc: 0.65934, Val Acc: 0.35940
# Epoch: 063, Loss: 1.26366, Train Acc: 0.68590, Val Acc: 0.34568
# Epoch: 064, Loss: 1.28418, Train Acc: 0.67125, Val Acc: 0.32922
# Epoch: 065, Loss: 1.27426, Train Acc: 0.66484, Val Acc: 0.32647
# Epoch: 066, Loss: 1.26832, Train Acc: 0.67766, Val Acc: 0.32099
# Epoch: 067, Loss: 1.28237, Train Acc: 0.67674, Val Acc: 0.32373
# Epoch: 068, Loss: 1.27413, Train Acc: 0.67766, Val Acc: 0.32373
# Epoch: 069, Loss: 1.27881, Train Acc: 0.65385, Val Acc: 0.32647
# Epoch: 070, Loss: 1.27152, Train Acc: 0.66392, Val Acc: 0.34156
# Epoch: 071, Loss: 1.27214, Train Acc: 0.65110, Val Acc: 0.35254
# Epoch: 072, Loss: 1.26822, Train Acc: 0.67674, Val Acc: 0.35254
# Epoch: 073, Loss: 1.27097, Train Acc: 0.67857, Val Acc: 0.34568
# Epoch: 074, Loss: 1.27792, Train Acc: 0.66300, Val Acc: 0.34156
# Epoch: 075, Loss: 1.27646, Train Acc: 0.69048, Val Acc: 0.34156
# Epoch: 076, Loss: 1.28090, Train Acc: 0.65293, Val Acc: 0.34156
# Epoch: 077, Loss: 1.26966, Train Acc: 0.66026, Val Acc: 0.33882
# Epoch: 078, Loss: 1.27544, Train Acc: 0.67033, Val Acc: 0.33471
# Epoch: 079, Loss: 1.27877, Train Acc: 0.67582, Val Acc: 0.33471
# Epoch: 080, Loss: 1.26578, Train Acc: 0.67491, Val Acc: 0.33882
# Epoch: 081, Loss: 1.27221, Train Acc: 0.66575, Val Acc: 0.34019
# Epoch: 082, Loss: 1.27049, Train Acc: 0.68040, Val Acc: 0.31687
# Epoch: 083, Loss: 1.26887, Train Acc: 0.68407, Val Acc: 0.30316
# Epoch: 084, Loss: 1.26819, Train Acc: 0.65842, Val Acc: 0.29630
# Epoch: 085, Loss: 1.27443, Train Acc: 0.67308, Val Acc: 0.29767
# Epoch: 086, Loss: 1.26725, Train Acc: 0.67399, Val Acc: 0.29767
# Epoch: 087, Loss: 1.27005, Train Acc: 0.67125, Val Acc: 0.30316
# Epoch: 088, Loss: 1.27083, Train Acc: 0.65842, Val Acc: 0.30041
# Epoch: 089, Loss: 1.25679, Train Acc: 0.69231, Val Acc: 0.30590
# Epoch: 090, Loss: 1.26330, Train Acc: 0.67857, Val Acc: 0.31962
# Epoch: 091, Loss: 1.26835, Train Acc: 0.68498, Val Acc: 0.33471
# Epoch: 092, Loss: 1.27093, Train Acc: 0.67308, Val Acc: 0.33608
# Epoch: 093, Loss: 1.26408, Train Acc: 0.68223, Val Acc: 0.32373
# Epoch: 094, Loss: 1.26671, Train Acc: 0.67216, Val Acc: 0.32373
# Epoch: 095, Loss: 1.26215, Train Acc: 0.70788, Val Acc: 0.31962
# Epoch: 096, Loss: 1.26354, Train Acc: 0.69231, Val Acc: 0.32510
# Epoch: 097, Loss: 1.26678, Train Acc: 0.68681, Val Acc: 0.32099
# Epoch: 098, Loss: 1.26588, Train Acc: 0.67857, Val Acc: 0.31550
# Epoch: 099, Loss: 1.27579, Train Acc: 0.67308, Val Acc: 0.31824
# Epoch: 100, Loss: 1.27823, Train Acc: 0.67308, Val Acc: 0.32236
# Test Accuracy: 0.37061
# Random State 945321  in the iteration 8
# Epoch: 001, Loss: 1.45008, Train Acc: 0.46154, Val Acc: 0.54595
# Epoch: 002, Loss: 1.40276, Train Acc: 0.55220, Val Acc: 0.53224
# Epoch: 003, Loss: 1.38257, Train Acc: 0.56044, Val Acc: 0.51989
# Epoch: 004, Loss: 1.36925, Train Acc: 0.57143, Val Acc: 0.51852
# Epoch: 005, Loss: 1.37293, Train Acc: 0.55311, Val Acc: 0.52401
# Epoch: 006, Loss: 1.36443, Train Acc: 0.57509, Val Acc: 0.52812
# Epoch: 007, Loss: 1.36881, Train Acc: 0.58242, Val Acc: 0.51852
# Epoch: 008, Loss: 1.36093, Train Acc: 0.58608, Val Acc: 0.52126
# Epoch: 009, Loss: 1.35414, Train Acc: 0.58333, Val Acc: 0.51852
# Epoch: 010, Loss: 1.35775, Train Acc: 0.58974, Val Acc: 0.52949
# Epoch: 011, Loss: 1.33464, Train Acc: 0.61905, Val Acc: 0.52812
# Epoch: 012, Loss: 1.33409, Train Acc: 0.60989, Val Acc: 0.50892
# Epoch: 013, Loss: 1.32747, Train Acc: 0.60806, Val Acc: 0.51029
# Epoch: 014, Loss: 1.32554, Train Acc: 0.61447, Val Acc: 0.50069
# Epoch: 015, Loss: 1.32682, Train Acc: 0.61081, Val Acc: 0.51029
# Epoch: 016, Loss: 1.32246, Train Acc: 0.61447, Val Acc: 0.52126
# Epoch: 017, Loss: 1.30813, Train Acc: 0.63736, Val Acc: 0.53498
# Epoch: 018, Loss: 1.31085, Train Acc: 0.63187, Val Acc: 0.51989
# Epoch: 019, Loss: 1.32576, Train Acc: 0.61905, Val Acc: 0.51166
# Epoch: 020, Loss: 1.31021, Train Acc: 0.63187, Val Acc: 0.48285
# Epoch: 021, Loss: 1.31843, Train Acc: 0.60806, Val Acc: 0.50069
# Epoch: 022, Loss: 1.30997, Train Acc: 0.62271, Val Acc: 0.47462
# Epoch: 023, Loss: 1.31291, Train Acc: 0.61630, Val Acc: 0.45405
# Epoch: 024, Loss: 1.30988, Train Acc: 0.61905, Val Acc: 0.45542
# Epoch: 025, Loss: 1.30613, Train Acc: 0.63462, Val Acc: 0.46365
# Epoch: 026, Loss: 1.31723, Train Acc: 0.61996, Val Acc: 0.46639
# Epoch: 027, Loss: 1.31115, Train Acc: 0.62912, Val Acc: 0.46091
# Epoch: 028, Loss: 1.30782, Train Acc: 0.64469, Val Acc: 0.46365
# Epoch: 029, Loss: 1.30734, Train Acc: 0.62363, Val Acc: 0.46091
# Epoch: 030, Loss: 1.30325, Train Acc: 0.63370, Val Acc: 0.45816
# Epoch: 031, Loss: 1.29863, Train Acc: 0.63553, Val Acc: 0.48011
# Epoch: 032, Loss: 1.30130, Train Acc: 0.64469, Val Acc: 0.49383
# Epoch: 033, Loss: 1.29990, Train Acc: 0.63736, Val Acc: 0.49108
# Epoch: 034, Loss: 1.30327, Train Acc: 0.63828, Val Acc: 0.49108
# Epoch: 035, Loss: 1.30152, Train Acc: 0.64652, Val Acc: 0.48834
# Epoch: 036, Loss: 1.29463, Train Acc: 0.65842, Val Acc: 0.48560
# Epoch: 037, Loss: 1.30365, Train Acc: 0.63919, Val Acc: 0.47599
# Epoch: 038, Loss: 1.29779, Train Acc: 0.63370, Val Acc: 0.47874
# Epoch: 039, Loss: 1.30886, Train Acc: 0.64469, Val Acc: 0.47737
# Epoch: 040, Loss: 1.29493, Train Acc: 0.64835, Val Acc: 0.47737
# Epoch: 041, Loss: 1.30291, Train Acc: 0.64103, Val Acc: 0.47051
# Epoch: 042, Loss: 1.30628, Train Acc: 0.63004, Val Acc: 0.47051
# Epoch: 043, Loss: 1.30149, Train Acc: 0.63645, Val Acc: 0.45542
# Epoch: 044, Loss: 1.30076, Train Acc: 0.63553, Val Acc: 0.45405
# Epoch: 045, Loss: 1.31941, Train Acc: 0.61355, Val Acc: 0.45816
# Epoch: 046, Loss: 1.29621, Train Acc: 0.64652, Val Acc: 0.45679
# Epoch: 047, Loss: 1.31590, Train Acc: 0.63370, Val Acc: 0.46091
# Epoch: 048, Loss: 1.29918, Train Acc: 0.62637, Val Acc: 0.46365
# Epoch: 049, Loss: 1.30370, Train Acc: 0.65110, Val Acc: 0.46091
# ...
# Epoch: 055, Loss: 1.25866, Train Acc: 0.64927, Val Acc: 0.24417
# Epoch: 056, Loss: 1.24931, Train Acc: 0.66300, Val Acc: 0.24829
# Epoch: 057, Loss: 1.25123, Train Acc: 0.66392, Val Acc: 0.24554
# Epoch: 058, Loss: 1.24485, Train Acc: 0.67766, Val Acc: 0.24417
# Epoch: 059, Loss: 1.24291, Train Acc: 0.66941, Val Acc: 0.24280
# Epoch: 060, Loss: 1.27308, Train Acc: 0.63736, Val Acc: 0.24280
# Epoch: 061, Loss: 1.25570, Train Acc: 0.65934, Val Acc: 0.24280
# Epoch: 062, Loss: 1.26246, Train Acc: 0.66209, Val Acc: 0.24143
# Epoch: 063, Loss: 1.24253, Train Acc: 0.66484, Val Acc: 0.24143
# Epoch: 064, Loss: 1.25836, Train Acc: 0.65293, Val Acc: 0.24143
# Epoch: 065, Loss: 1.24506, Train Acc: 0.67033, Val Acc: 0.24005
# Epoch: 066, Loss: 1.26802, Train Acc: 0.64560, Val Acc: 0.24280
# Epoch: 067, Loss: 1.25202, Train Acc: 0.66392, Val Acc: 0.24280
# Epoch: 068, Loss: 1.24105, Train Acc: 0.67582, Val Acc: 0.24280
# Epoch: 069, Loss: 1.25321, Train Acc: 0.66758, Val Acc: 0.23868
# Epoch: 070, Loss: 1.24392, Train Acc: 0.66484, Val Acc: 0.24280
# Epoch: 071, Loss: 1.27057, Train Acc: 0.65110, Val Acc: 0.24143
# Epoch: 072, Loss: 1.25558, Train Acc: 0.66117, Val Acc: 0.24143
# Epoch: 073, Loss: 1.25277, Train Acc: 0.65568, Val Acc: 0.24143
# Epoch: 074, Loss: 1.25127, Train Acc: 0.67216, Val Acc: 0.24143
# Epoch: 075, Loss: 1.25845, Train Acc: 0.65842, Val Acc: 0.24005
# Epoch: 076, Loss: 1.26666, Train Acc: 0.64652, Val Acc: 0.24143
# Epoch: 077, Loss: 1.24040, Train Acc: 0.67582, Val Acc: 0.23868
# Epoch: 078, Loss: 1.23462, Train Acc: 0.67857, Val Acc: 0.23731
# Epoch: 079, Loss: 1.23320, Train Acc: 0.68223, Val Acc: 0.23320
# Epoch: 080, Loss: 1.25680, Train Acc: 0.65018, Val Acc: 0.23457
# Epoch: 081, Loss: 1.24456, Train Acc: 0.67491, Val Acc: 0.23594
# Epoch: 082, Loss: 1.24583, Train Acc: 0.66667, Val Acc: 0.23457
# Epoch: 083, Loss: 1.23396, Train Acc: 0.68040, Val Acc: 0.23594
# Epoch: 084, Loss: 1.24335, Train Acc: 0.67491, Val Acc: 0.23182
# Epoch: 085, Loss: 1.23377, Train Acc: 0.68590, Val Acc: 0.23182
# Epoch: 086, Loss: 1.26013, Train Acc: 0.66117, Val Acc: 0.23045
# Epoch: 087, Loss: 1.22952, Train Acc: 0.68407, Val Acc: 0.23320
# Epoch: 088, Loss: 1.23966, Train Acc: 0.67399, Val Acc: 0.23594
# Epoch: 089, Loss: 1.22686, Train Acc: 0.68681, Val Acc: 0.23731
# Epoch: 090, Loss: 1.25564, Train Acc: 0.65842, Val Acc: 0.23594
# Epoch: 091, Loss: 1.23034, Train Acc: 0.68407, Val Acc: 0.23594
# Epoch: 092, Loss: 1.23604, Train Acc: 0.66941, Val Acc: 0.23868
# Epoch: 093, Loss: 1.23014, Train Acc: 0.68498, Val Acc: 0.24143
# Epoch: 094, Loss: 1.23656, Train Acc: 0.67949, Val Acc: 0.24005
# Epoch: 095, Loss: 1.24332, Train Acc: 0.66941, Val Acc: 0.24143
# Epoch: 096, Loss: 1.21739, Train Acc: 0.69780, Val Acc: 0.24005
# Epoch: 097, Loss: 1.24696, Train Acc: 0.67125, Val Acc: 0.23594
# Epoch: 098, Loss: 1.25000, Train Acc: 0.67216, Val Acc: 0.23868
# Epoch: 099, Loss: 1.22332, Train Acc: 0.69048, Val Acc: 0.23457
# Epoch: 100, Loss: 1.23326, Train Acc: 0.68498, Val Acc: 0.23731
# Test Accuracy: 0.41447
# Random State 945321  in the iteration 8
# Epoch: 001, Loss: 1.46916, Train Acc: 0.41575, Val Acc: 0.29767
# Epoch: 002, Loss: 1.37681, Train Acc: 0.51740, Val Acc: 0.29630
# Epoch: 003, Loss: 1.37223, Train Acc: 0.52747, Val Acc: 0.29492
# Epoch: 004, Loss: 1.36527, Train Acc: 0.52289, Val Acc: 0.29492
# Epoch: 005, Loss: 1.36543, Train Acc: 0.53755, Val Acc: 0.29767
# Epoch: 006, Loss: 1.35475, Train Acc: 0.55678, Val Acc: 0.29492
# Epoch: 007, Loss: 1.34974, Train Acc: 0.57784, Val Acc: 0.29218
# Epoch: 008, Loss: 1.34640, Train Acc: 0.56319, Val Acc: 0.28669
# Epoch: 009, Loss: 1.32757, Train Acc: 0.57051, Val Acc: 0.28944
# Epoch: 010, Loss: 1.34656, Train Acc: 0.55220, Val Acc: 0.28669
# Epoch: 011, Loss: 1.33080, Train Acc: 0.57875, Val Acc: 0.28532
# Epoch: 012, Loss: 1.32737, Train Acc: 0.58150, Val Acc: 0.28258
# Epoch: 013, Loss: 1.33235, Train Acc: 0.59432, Val Acc: 0.28121
# Epoch: 014, Loss: 1.31144, Train Acc: 0.59432, Val Acc: 0.28121
# Epoch: 015, Loss: 1.31789, Train Acc: 0.58333, Val Acc: 0.27709
# Epoch: 016, Loss: 1.30714, Train Acc: 0.60897, Val Acc: 0.27572
# Epoch: 017, Loss: 1.31358, Train Acc: 0.60073, Val Acc: 0.27572
# Epoch: 018, Loss: 1.31232, Train Acc: 0.59707, Val Acc: 0.27709
# Epoch: 019, Loss: 1.29804, Train Acc: 0.61630, Val Acc: 0.27846
# Epoch: 020, Loss: 1.30144, Train Acc: 0.60806, Val Acc: 0.27709
# Epoch: 021, Loss: 1.30670, Train Acc: 0.60531, Val Acc: 0.27572
# Epoch: 022, Loss: 1.31764, Train Acc: 0.58883, Val Acc: 0.27846
# Epoch: 023, Loss: 1.28775, Train Acc: 0.62637, Val Acc: 0.27984
# Epoch: 024, Loss: 1.29565, Train Acc: 0.61081, Val Acc: 0.27435
# Epoch: 025, Loss: 1.28706, Train Acc: 0.62271, Val Acc: 0.26749
# Epoch: 026, Loss: 1.28683, Train Acc: 0.62088, Val Acc: 0.26749
# Epoch: 027, Loss: 1.29532, Train Acc: 0.60897, Val Acc: 0.26612
# Epoch: 028, Loss: 1.28736, Train Acc: 0.62363, Val Acc: 0.26749
# Epoch: 029, Loss: 1.27455, Train Acc: 0.64103, Val Acc: 0.26749
# Epoch: 030, Loss: 1.28477, Train Acc: 0.62546, Val Acc: 0.26749
# Epoch: 031, Loss: 1.27172, Train Acc: 0.64103, Val Acc: 0.26749
# Epoch: 032, Loss: 1.28608, Train Acc: 0.63919, Val Acc: 0.26886
# Epoch: 033, Loss: 1.28261, Train Acc: 0.63187, Val Acc: 0.26886
# Epoch: 034, Loss: 1.26972, Train Acc: 0.64286, Val Acc: 0.26886
# Epoch: 035, Loss: 1.26830, Train Acc: 0.64011, Val Acc: 0.26886
# Epoch: 036, Loss: 1.27562, Train Acc: 0.63736, Val Acc: 0.26749
# Epoch: 037, Loss: 1.27766, Train Acc: 0.63645, Val Acc: 0.26749
# Epoch: 038, Loss: 1.27756, Train Acc: 0.63370, Val Acc: 0.26749
# Epoch: 039, Loss: 1.26651, Train Acc: 0.64560, Val Acc: 0.26612
# Epoch: 040, Loss: 1.26557, Train Acc: 0.65476, Val Acc: 0.26337
# Epoch: 041, Loss: 1.27075, Train Acc: 0.64835, Val Acc: 0.26200
# Epoch: 042, Loss: 1.27914, Train Acc: 0.63187, Val Acc: 0.25652
# Epoch: 043, Loss: 1.25586, Train Acc: 0.65934, Val Acc: 0.25926
# Epoch: 044, Loss: 1.28810, Train Acc: 0.63004, Val Acc: 0.25789
# Epoch: 045, Loss: 1.27009, Train Acc: 0.64469, Val Acc: 0.25652
# Epoch: 046, Loss: 1.26337, Train Acc: 0.65018, Val Acc: 0.25789
# Epoch: 047, Loss: 1.26029, Train Acc: 0.64927, Val Acc: 0.25789
# Epoch: 048, Loss: 1.27015, Train Acc: 0.64744, Val Acc: 0.25240
# Epoch: 049, Loss: 1.28607, Train Acc: 0.63370, Val Acc: 0.25240
# Epoch: 050, Loss: 1.25398, Train Acc: 0.66300, Val Acc: 0.24829
# Epoch: 051, Loss: 1.25952, Train Acc: 0.66209, Val Acc: 0.24143
# Epoch: 052, Loss: 1.27598, Train Acc: 0.65018, Val Acc: 0.24143
# Epoch: 053, Loss: 1.25101, Train Acc: 0.66850, Val Acc: 0.24143
# Epoch: 054, Loss: 1.24977, Train Acc: 0.66758, Val Acc: 0.24417
# Epoch: 055, Loss: 1.26021, Train Acc: 0.65476, Val Acc: 0.24143
# Epoch: 056, Loss: 1.24857, Train Acc: 0.66941, Val Acc: 0.24143
# Epoch: 057, Loss: 1.24232, Train Acc: 0.66667, Val Acc: 0.24143
# Epoch: 058, Loss: 1.25617, Train Acc: 0.65842, Val Acc: 0.24143
# Epoch: 059, Loss: 1.26778, Train Acc: 0.65934, Val Acc: 0.24143
# Epoch: 060, Loss: 1.24359, Train Acc: 0.67582, Val Acc: 0.24143
# Epoch: 061, Loss: 1.25743, Train Acc: 0.65201, Val Acc: 0.24143
# Epoch: 062, Loss: 1.24083, Train Acc: 0.66941, Val Acc: 0.24143
# Epoch: 063, Loss: 1.24546, Train Acc: 0.67125, Val Acc: 0.24143
# Epoch: 064, Loss: 1.25106, Train Acc: 0.67125, Val Acc: 0.24280
# Epoch: 065, Loss: 1.23880, Train Acc: 0.67308, Val Acc: 0.24417
# Epoch: 066, Loss: 1.25635, Train Acc: 0.65385, Val Acc: 0.24829
# Epoch: 067, Loss: 1.24737, Train Acc: 0.66575, Val Acc: 0.25377
# Epoch: 068, Loss: 1.24914, Train Acc: 0.66758, Val Acc: 0.25652
# Epoch: 069, Loss: 1.26548, Train Acc: 0.65110, Val Acc: 0.25789
# Epoch: 070, Loss: 1.23607, Train Acc: 0.68040, Val Acc: 0.25652
# Epoch: 071, Loss: 1.24821, Train Acc: 0.67125, Val Acc: 0.24829
# Epoch: 072, Loss: 1.24744, Train Acc: 0.67033, Val Acc: 0.24829
# Epoch: 073, Loss: 1.24724, Train Acc: 0.66941, Val Acc: 0.25103
# Epoch: 074, Loss: 1.25507, Train Acc: 0.66575, Val Acc: 0.25377
# Epoch: 075, Loss: 1.25943, Train Acc: 0.65293, Val Acc: 0.26063
# Epoch: 076, Loss: 1.24145, Train Acc: 0.67399, Val Acc: 0.26063
# Epoch: 077, Loss: 1.25693, Train Acc: 0.66758, Val Acc: 0.25789
# Epoch: 078, Loss: 1.24244, Train Acc: 0.69048, Val Acc: 0.25926
# Epoch: 079, Loss: 1.25429, Train Acc: 0.64835, Val Acc: 0.25652
# Epoch: 080, Loss: 1.23380, Train Acc: 0.68315, Val Acc: 0.25926
# Epoch: 081, Loss: 1.23858, Train Acc: 0.67857, Val Acc: 0.26063
# Epoch: 082, Loss: 1.24171, Train Acc: 0.67308, Val Acc: 0.26063
# Epoch: 083, Loss: 1.24629, Train Acc: 0.65934, Val Acc: 0.25926
# Epoch: 084, Loss: 1.24471, Train Acc: 0.66758, Val Acc: 0.25377
# Epoch: 085, Loss: 1.25982, Train Acc: 0.64927, Val Acc: 0.25240
# Epoch: 086, Loss: 1.27349, Train Acc: 0.64377, Val Acc: 0.24966
# Epoch: 087, Loss: 1.27716, Train Acc: 0.64835, Val Acc: 0.25103
# Epoch: 088, Loss: 1.30158, Train Acc: 0.61722, Val Acc: 0.25240
# Epoch: 089, Loss: 1.30636, Train Acc: 0.61447, Val Acc: 0.25514
# Epoch: 090, Loss: 1.27978, Train Acc: 0.63278, Val Acc: 0.25377
# Epoch: 091, Loss: 1.23756, Train Acc: 0.67766, Val Acc: 0.25926
# Epoch: 092, Loss: 1.26529, Train Acc: 0.65293, Val Acc: 0.25926
# Epoch: 093, Loss: 1.23369, Train Acc: 0.68132, Val Acc: 0.25926
# Epoch: 094, Loss: 1.26720, Train Acc: 0.64103, Val Acc: 0.25926
# Epoch: 095, Loss: 1.24963, Train Acc: 0.68407, Val Acc: 0.25240
# Epoch: 096, Loss: 1.25265, Train Acc: 0.65659, Val Acc: 0.25789
# Epoch: 097, Loss: 1.26248, Train Acc: 0.65476, Val Acc: 0.25377
# Epoch: 098, Loss: 1.23270, Train Acc: 0.67399, Val Acc: 0.25240
# Epoch: 099, Loss: 1.23251, Train Acc: 0.68132, Val Acc: 0.25240
# Epoch: 100, Loss: 1.25444, Train Acc: 0.65476, Val Acc: 0.24966
# Test Accuracy: 0.30263
# Random State 784328  in the iteration 9
# Epoch: 001, Loss: 1.58123, Train Acc: 0.30037, Val Acc: 0.28669
# Epoch: 002, Loss: 1.55297, Train Acc: 0.31410, Val Acc: 0.28532
# Epoch: 003, Loss: 1.43325, Train Acc: 0.47711, Val Acc: 0.27435
# Epoch: 004, Loss: 1.46699, Train Acc: 0.43590, Val Acc: 0.26475
# Epoch: 005, Loss: 1.40610, Train Acc: 0.50733, Val Acc: 0.25926
# Epoch: 006, Loss: 1.37761, Train Acc: 0.53480, Val Acc: 0.24829
# Epoch: 007, Loss: 1.37489, Train Acc: 0.54212, Val Acc: 0.25514
# Epoch: 008, Loss: 1.39951, Train Acc: 0.51465, Val Acc: 0.25652
# Epoch: 009, Loss: 1.37282, Train Acc: 0.52656, Val Acc: 0.25926
# Epoch: 010, Loss: 1.36474, Train Acc: 0.54762, Val Acc: 0.25652
# Epoch: 011, Loss: 1.35932, Train Acc: 0.55311, Val Acc: 0.26200
# Epoch: 012, Loss: 1.38412, Train Acc: 0.53205, Val Acc: 0.26063
# Epoch: 013, Loss: 1.35333, Train Acc: 0.54853, Val Acc: 0.25789
# Epoch: 014, Loss: 1.36151, Train Acc: 0.53846, Val Acc: 0.25652
# Epoch: 015, Loss: 1.34280, Train Acc: 0.56777, Val Acc: 0.25514
# Epoch: 016, Loss: 1.35313, Train Acc: 0.55678, Val Acc: 0.24966
# Epoch: 017, Loss: 1.35050, Train Acc: 0.56136, Val Acc: 0.25240
# Epoch: 018, Loss: 1.34263, Train Acc: 0.56960, Val Acc: 0.25240
# Epoch: 019, Loss: 1.35033, Train Acc: 0.56685, Val Acc: 0.25377
# Epoch: 020, Loss: 1.32960, Train Acc: 0.58425, Val Acc: 0.24691
# Epoch: 021, Loss: 1.34896, Train Acc: 0.56319, Val Acc: 0.24554
# Epoch: 022, Loss: 1.34369, Train Acc: 0.56777, Val Acc: 0.24280
# Epoch: 023, Loss: 1.32824, Train Acc: 0.58791, Val Acc: 0.24143
# Epoch: 024, Loss: 1.32048, Train Acc: 0.59799, Val Acc: 0.24143
# Epoch: 025, Loss: 1.33165, Train Acc: 0.57784, Val Acc: 0.24829
# Epoch: 026, Loss: 1.33608, Train Acc: 0.58242, Val Acc: 0.24691
# Epoch: 027, Loss: 1.30862, Train Acc: 0.61813, Val Acc: 0.24829
# Epoch: 028, Loss: 1.30123, Train Acc: 0.61081, Val Acc: 0.24417
# Epoch: 029, Loss: 1.33532, Train Acc: 0.58242, Val Acc: 0.23868
# Epoch: 030, Loss: 1.27719, Train Acc: 0.64377, Val Acc: 0.23731
# Epoch: 031, Loss: 1.29839, Train Acc: 0.61538, Val Acc: 0.23320
# Epoch: 032, Loss: 1.29118, Train Acc: 0.62912, Val Acc: 0.23182
# Epoch: 033, Loss: 1.30173, Train Acc: 0.60531, Val Acc: 0.22908
# Epoch: 034, Loss: 1.30817, Train Acc: 0.61447, Val Acc: 0.22771
# Epoch: 035, Loss: 1.28476, Train Acc: 0.62912, Val Acc: 0.22497
# Epoch: 036, Loss: 1.29988, Train Acc: 0.61630, Val Acc: 0.22222
# Epoch: 037, Loss: 1.29439, Train Acc: 0.62546, Val Acc: 0.22222
# Epoch: 038, Loss: 1.29718, Train Acc: 0.62088, Val Acc: 0.22359
# Epoch: 039, Loss: 1.29248, Train Acc: 0.62637, Val Acc: 0.22359
# Epoch: 040, Loss: 1.29221, Train Acc: 0.62546, Val Acc: 0.22222
# Epoch: 041, Loss: 1.28766, Train Acc: 0.62363, Val Acc: 0.21948
# Epoch: 042, Loss: 1.27841, Train Acc: 0.64103, Val Acc: 0.21948
# Epoch: 043, Loss: 1.27690, Train Acc: 0.63553, Val Acc: 0.22359
# Epoch: 044, Loss: 1.29031, Train Acc: 0.62912, Val Acc: 0.22908
# Epoch: 045, Loss: 1.29501, Train Acc: 0.61722, Val Acc: 0.22908
# Epoch: 046, Loss: 1.29297, Train Acc: 0.61722, Val Acc: 0.22771
# Epoch: 047, Loss: 1.30198, Train Acc: 0.61081, Val Acc: 0.22771
# Epoch: 048, Loss: 1.27786, Train Acc: 0.63736, Val Acc: 0.23045
# Epoch: 049, Loss: 1.27539, Train Acc: 0.63645, Val Acc: 0.23182
# Epoch: 050, Loss: 1.27864, Train Acc: 0.63462, Val Acc: 0.23457
# Epoch: 051, Loss: 1.28303, Train Acc: 0.63462, Val Acc: 0.22771
# Epoch: 052, Loss: 1.26099, Train Acc: 0.65201, Val Acc: 0.22634
# Epoch: 053, Loss: 1.27260, Train Acc: 0.64744, Val Acc: 0.22771
# Epoch: 054, Loss: 1.28295, Train Acc: 0.63736, Val Acc: 0.22908
# Epoch: 055, Loss: 1.27189, Train Acc: 0.64103, Val Acc: 0.22634
# Epoch: 056, Loss: 1.27859, Train Acc: 0.63462, Val Acc: 0.22497
# Epoch: 057, Loss: 1.28326, Train Acc: 0.63278, Val Acc: 0.23045
# Epoch: 058, Loss: 1.26863, Train Acc: 0.64652, Val Acc: 0.23731
# Epoch: 059, Loss: 1.28447, Train Acc: 0.63553, Val Acc: 0.24280
# Epoch: 060, Loss: 1.27471, Train Acc: 0.64103, Val Acc: 0.24554
# Epoch: 061, Loss: 1.28959, Train Acc: 0.62546, Val Acc: 0.25377
# Epoch: 062, Loss: 1.25864, Train Acc: 0.66392, Val Acc: 0.25377
# Epoch: 063, Loss: 1.25636, Train Acc: 0.66209, Val Acc: 0.25514
# Epoch: 064, Loss: 1.28512, Train Acc: 0.62821, Val Acc: 0.25926
# Epoch: 065, Loss: 1.26186, Train Acc: 0.64652, Val Acc: 0.26337
# Epoch: 066, Loss: 1.27998, Train Acc: 0.63645, Val Acc: 0.26200
# Epoch: 067, Loss: 1.26008, Train Acc: 0.66026, Val Acc: 0.25926
# Epoch: 068, Loss: 1.26688, Train Acc: 0.65293, Val Acc: 0.26200
# Epoch: 069, Loss: 1.26432, Train Acc: 0.66758, Val Acc: 0.26886
# Epoch: 070, Loss: 1.26440, Train Acc: 0.66026, Val Acc: 0.26749
# Epoch: 071, Loss: 1.27369, Train Acc: 0.64835, Val Acc: 0.28258
# Epoch: 072, Loss: 1.27194, Train Acc: 0.63919, Val Acc: 0.31550
# Epoch: 073, Loss: 1.28244, Train Acc: 0.63004, Val Acc: 0.29355
# Epoch: 074, Loss: 1.26629, Train Acc: 0.65018, Val Acc: 0.31687
# Epoch: 075, Loss: 1.25544, Train Acc: 0.66026, Val Acc: 0.31824
# Epoch: 076, Loss: 1.27588, Train Acc: 0.64011, Val Acc: 0.31687
# Epoch: 077, Loss: 1.28246, Train Acc: 0.63828, Val Acc: 0.31687
# Epoch: 078, Loss: 1.25367, Train Acc: 0.66209, Val Acc: 0.31276
# Epoch: 079, Loss: 1.28123, Train Acc: 0.63828, Val Acc: 0.28532
# Epoch: 080, Loss: 1.27922, Train Acc: 0.63553, Val Acc: 0.28669
# Epoch: 081, Loss: 1.26829, Train Acc: 0.64011, Val Acc: 0.28669
# Epoch: 082, Loss: 1.26877, Train Acc: 0.64927, Val Acc: 0.28944
# Epoch: 083, Loss: 1.25826, Train Acc: 0.65751, Val Acc: 0.28944
# Epoch: 084, Loss: 1.26257, Train Acc: 0.66026, Val Acc: 0.29081
# Epoch: 085, Loss: 1.28504, Train Acc: 0.62821, Val Acc: 0.29081
# Epoch: 086, Loss: 1.25890, Train Acc: 0.65659, Val Acc: 0.28944
# Epoch: 087, Loss: 1.25601, Train Acc: 0.66117, Val Acc: 0.28258
# Epoch: 088, Loss: 1.26705, Train Acc: 0.65201, Val Acc: 0.27846
# Epoch: 089, Loss: 1.25919, Train Acc: 0.64927, Val Acc: 0.27435
# Epoch: 090, Loss: 1.27489, Train Acc: 0.64011, Val Acc: 0.27435
# Epoch: 091, Loss: 1.27248, Train Acc: 0.64560, Val Acc: 0.27298
# Epoch: 092, Loss: 1.25019, Train Acc: 0.67399, Val Acc: 0.27023
# Epoch: 093, Loss: 1.25170, Train Acc: 0.67216, Val Acc: 0.26612
# Epoch: 094, Loss: 1.24464, Train Acc: 0.67582, Val Acc: 0.26612
# Epoch: 095, Loss: 1.25385, Train Acc: 0.66484, Val Acc: 0.26337
# Epoch: 096, Loss: 1.25458, Train Acc: 0.66850, Val Acc: 0.26337
# Epoch: 097, Loss: 1.27103, Train Acc: 0.64194, Val Acc: 0.26475
# Epoch: 098, Loss: 1.25981, Train Acc: 0.66026, Val Acc: 0.26475
# Epoch: 099, Loss: 1.24828, Train Acc: 0.66667, Val Acc: 0.26200
# Epoch: 100, Loss: 1.27307, Train Acc: 0.63462, Val Acc: 0.26200
# Test Accuracy: 0.25658
# GAT
# 28.245614035087723 +- 6.3253764956431136

# %% [markdown]
# #### Visualize the results and the embedding

# %%
fig,axs = plt.subplots(1,2,figsize=(20,8))
axs[0].set_title('GCN boxplot of 10 runs')
axs[0].boxplot(global_results,labels=['GCN','MLP', 'SAGE', 'Cheb', 'GAT'])
axs[0].set_xlabel('Run')
axs[0].set_ylabel('Accuracy')

axs[1].set_title('Models lineplot of 10 runs')
axs[1].plot(range(1,11),global_results[0],'ro',color='red')
axs[1].plot(range(1,11),global_results[0],color='red',label='GCN')

axs[1].plot(range(1,11),global_results[1],'ro',color='blue')
axs[1].plot(range(1,11),global_results[1],color='blue',label='MLP')

axs[1].plot(range(1,11),global_results[2],'ro',color='green')
axs[1].plot(range(1,11),global_results[2],color='green',label='SAGE')

axs[1].plot(range(1,11),global_results[3],'ro',color='k')
axs[1].plot(range(1,11),global_results[3],color='k',label='Cheb')

axs[1].plot(range(1,11),global_results[4],'ro',color='violet')
axs[1].plot(range(1,11),global_results[4],color='violet',label='GAT')

axs[1].set_xticks(range(1,11))
axs[1].set_xlabel('Run')
axs[1].set_ylabel('Accuracy')
axs[1].legend()
fig.show()

# %%
from sklearn.manifold import TSNE
# Let's see the embedding of the best model over the 10 runs
# First model is GCN, second model is MLP
# GCN
#out_gcn = global_best_models[0][0](data.x, data.edge_index) # Get the output of the model with the entire dataset
src_nodes, dst_nodes = data.edges()
edge_index = torch.stack([src_nodes, dst_nodes], dim=0)
out_gcn = global_best_models[0][0](data.ndata['feat'], edge_index) # Get the output of the model with the entire dataset

'''
    Arguments of TSNE:
        * n_components: The dimension of the embedded space.
        * random_state: The seed to use for the t-SNE algorithm.
    Returns:
        * tsne_obj: The t-SNE embedding of the nodes.
'''
tsne = TSNE(n_components=2, random_state=12345)
tsne_gcn_results = tsne.fit_transform(out_gcn.detach().cpu().numpy())
# SAGE
out_sage = global_best_models[2][0](data.ndata['feat'], edge_index) # Get the output of the model with the entire dataset
tsne = TSNE(n_components=2, random_state=12345)
tsne_sage_results = tsne.fit_transform(out_sage.detach().cpu().numpy())
# Cheb
out_cheb = global_best_models[3][0](data.ndata['feat'], edge_index) # Get the output of the model with the entire dataset
tsne = TSNE(n_components=2, random_state=12345)
tsne_cheb_results = tsne.fit_transform(out_cheb.detach().cpu().numpy())
# GAT
out_gat = global_best_models[4][0](data.ndata['feat'], edge_index) # Get the output of the model with the entire dataset
tsne = TSNE(n_components=2, random_state=12345)
tsne_gat_results = tsne.fit_transform(out_gat.detach().cpu().numpy())
# MLP
#out_mlp = global_best_models[1][0](data.x, data.edge_index) # Get the output of the model with the entire dataset
out_mlp = global_best_models[1][0](data.ndata['feat'], edge_index) # Get the output of the model with the entire dataset
tsne = TSNE(n_components=2, random_state=12345)
tsne_mlp_results = tsne.fit_transform(out_mlp.detach().cpu().numpy())
# Plot the results
fig,axs = plt.subplots(3,2,figsize=(20,10))
axs[0,0].set_title('GCN t-SNE')
#axs[0].scatter(tsne_gcn_results[:,0],tsne_gcn_results[:,1],c=data.y.cpu(),cmap='viridis',s=60,alpha=0.85,edgecolors='black',linewidths=0.5)
axs[0,0].scatter(tsne_gcn_results[:,0],tsne_gcn_results[:,1],c=data.ndata['label'].cpu(),cmap='viridis',s=60,alpha=0.85,edgecolors='black',linewidths=0.5)

axs[0,1].set_title('MLP t-SNE')
#axs[1].scatter(tsne_mlp_results[:,0],tsne_mlp_results[:,1],c=data.y.cpu(),cmap='viridis',s=60,alpha=0.85,edgecolors='black',linewidths=0.5)
axs[0,1].scatter(tsne_mlp_results[:,0],tsne_mlp_results[:,1],c=data.ndata['label'].cpu(),cmap='viridis',s=60,alpha=0.85,edgecolors='black',linewidths=0.5)

axs[1,0].set_title('SAGE t-SNE')
#axs[0].scatter(tsne_gcn_results[:,0],tsne_gcn_results[:,1],c=data.y.cpu(),cmap='viridis',s=60,alpha=0.85,edgecolors='black',linewidths=0.5)
axs[1,0].scatter(tsne_sage_results[:,0],tsne_sage_results[:,1],c=data.ndata['label'].cpu(),cmap='viridis',s=60,alpha=0.85,edgecolors='black',linewidths=0.5)

axs[1,1].set_title('Cheb t-SNE')
#axs[0].scatter(tsne_gcn_results[:,0],tsne_gcn_results[:,1],c=data.y.cpu(),cmap='viridis',s=60,alpha=0.85,edgecolors='black',linewidths=0.5)
axs[1,1].scatter(tsne_cheb_results[:,0],tsne_cheb_results[:,1],c=data.ndata['label'].cpu(),cmap='viridis',s=60,alpha=0.85,edgecolors='black',linewidths=0.5)

axs[2,0].set_title('GAT t-SNE')
#axs[0].scatter(tsne_gcn_results[:,0],tsne_gcn_results[:,1],c=data.y.cpu(),cmap='viridis',s=60,alpha=0.85,edgecolors='black',linewidths=0.5)
axs[2,0].scatter(tsne_gat_results[:,0],tsne_gat_results[:,1],c=data.ndata['label'].cpu(),cmap='viridis',s=60,alpha=0.85,edgecolors='black',linewidths=0.5)

fig.suptitle('t-SNE of the best model over the 10 runs',fontsize=20)
fig.show()

# %% [markdown]
# ### 3.1 Report

# %% [markdown]
# In this section we will report the results of the model. We will report the accuracy, precision, recall and F1 score for the model. We will also visualize the confusion matrix for the model using the scikit-learn library to report the results. After all, we will put the results in a markdown cell.

# %% [markdown]
# #### Report the results

# %%
# Report the best model over the 10 runs using the test set and sklearn classification report
from sklearn.metrics import classification_report
print('GCN')
print(classification_report(data.ndata['label'][test_mask].cpu(), global_best_models[0][0](data.ndata['feat'], edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy()))
print('========================================================================')
print('MLP')
print(classification_report(data.ndata['label'][test_mask].cpu(), global_best_models[1][0](data.ndata['feat'], edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy()))
print('SAGE')
print(classification_report(data.ndata['label'][test_mask].cpu(), global_best_models[2][0](data.ndata['feat'], edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy()))
print('========================================================================')
print('Cheb')
print(classification_report(data.ndata['label'][test_mask].cpu(), global_best_models[3][0](data.ndata['feat'], edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy()))
print('========================================================================')
print('GAT')
print(classification_report(data.ndata['label'][test_mask].cpu(), global_best_models[4][0](data.ndata['feat'], edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy()))
print('========================================================================')
# Out:
# GCN
#               precision    recall  f1-score   support
#
#            0       0.68      0.61      0.65        88
#            1       0.78      0.57      0.66        83
#            2       0.51      0.28      0.36        87
#            3       0.48      0.82      0.60       109
#            4       0.67      0.63      0.65        89
#
#     accuracy                           0.59       456
#    macro avg       0.62      0.58      0.58       456
# weighted avg       0.62      0.59      0.58       456
#
# ========================================================================
# MLP
#               precision    recall  f1-score   support
#
#            0       0.46      0.67      0.55        88
#            1       0.41      0.30      0.35        83
#            2       0.44      0.39      0.41        87
#            3       0.57      0.57      0.57       109
#            4       0.59      0.53      0.56        89
#
#     accuracy                           0.50       456
#    macro avg       0.49      0.49      0.49       456
# weighted avg       0.50      0.50      0.49       456
#
# SAGE
#               precision    recall  f1-score   support
#
#            0       0.88      0.33      0.48        88
#            1       0.54      0.76      0.63        83
#            2       0.70      0.56      0.62        87
#            3       0.64      0.83      0.72       109
#            4       0.71      0.78      0.74        89
#
#     accuracy                           0.66       456
#    macro avg       0.70      0.65      0.64       456
# weighted avg       0.69      0.66      0.64       456
#
# ========================================================================
# Cheb
#               precision    recall  f1-score   support
#
#            0       0.52      0.61      0.56        88
#            1       0.42      0.33      0.36        83
#            2       0.42      0.40      0.41        87
#            3       0.57      0.63      0.60       109
#            4       0.56      0.51      0.53        89
#
#     accuracy                           0.50       456
#    macro avg       0.49      0.50      0.49       456
# weighted avg       0.50      0.50      0.50       456
#
# ========================================================================
# GAT
#               precision    recall  f1-score   support
#
#            0       1.00      0.14      0.24        88
#            1       0.14      0.01      0.02        83
#            2       0.32      0.32      0.32        87
#            3       0.33      0.66      0.44       109
#            4       0.40      0.58      0.47        89
#
#     accuracy                           0.36       456
#    macro avg       0.44      0.34      0.30       456
# weighted avg       0.44      0.36      0.31       456
#
# ========================================================================

# %% [markdown]
# #### Confusion matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Crear las matrices de confusión
conf_matrix_gcn = confusion_matrix(data.ndata['label'][test_mask].cpu(), global_best_models[0][0](data.ndata['feat'], edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy())
conf_matrix_mlp = confusion_matrix(data.ndata['label'][test_mask].cpu(), global_best_models[1][0](data.ndata['feat'], edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy())
conf_matrix_sage = confusion_matrix(data.ndata['label'][test_mask].cpu(), global_best_models[2][0](data.ndata['feat'], edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy())
conf_matrix_cheb = confusion_matrix(data.ndata['label'][test_mask].cpu(), global_best_models[3][0](data.ndata['feat'], edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy())
conf_matrix_gat = confusion_matrix(data.ndata['label'][test_mask].cpu(), global_best_models[4][0](data.ndata['feat'], edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy())

# Crear los displays de las matrices de confusión
disp_gcn = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_gcn, display_labels=data.ndata['label'].unique().cpu().numpy())
disp_mlp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_mlp, display_labels=data.ndata['label'].unique().cpu().numpy())
disp_sage = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_sage, display_labels=data.ndata['label'].unique().cpu().numpy())
disp_cheb = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_cheb, display_labels=data.ndata['label'].unique().cpu().numpy())
disp_gat = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_gat, display_labels=data.ndata['label'].unique().cpu().numpy())

# Crear la figura y los ejes
fig, axs = plt.subplots(3, 2, figsize=(20, 15))

# Plotear las matrices de confusión
disp_gcn.plot(ax=axs[0][0])
disp_gcn.ax_.set_title('GCN Confusion Matrix')
disp_gcn.im_.colorbar.remove()

disp_mlp.plot(ax=axs[0][1])
disp_mlp.ax_.set_title('MLP Confusion Matrix')
disp_mlp.im_.colorbar.remove()

disp_sage.plot(ax=axs[1][0])
disp_sage.ax_.set_title('SAGE Confusion Matrix')
disp_sage.im_.colorbar.remove()

disp_cheb.plot(ax=axs[1][1])
disp_cheb.ax_.set_title('Cheb Confusion Matrix')
disp_cheb.im_.colorbar.remove()

# Colocar la última matriz en la posición central de la tercera fila
disp_gat.plot(ax=axs[2][0])
disp_gat.ax_.set_title('GAT Confusion Matrix')
disp_gat.im_.colorbar.remove()

# Eliminar el subplot vacío
fig.delaxes(axs[2][1])

# Ajustar el diseño
fig.tight_layout(rect=[0, 0, 1, 0.95])
fig.suptitle('Confusion Matrix of the best model over the 10 runs', fontsize=20)

# Mostrar la figura
plt.show()
