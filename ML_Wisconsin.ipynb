# %% [markdown]
# # Node classification practice

# %%
#Libraries we are going to use
# Install required packages.
import os
import torch #Library for deep learning
os.environ['TORCH'] = torch.__version__
print(torch.__version__)

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git
COLLAB_ENV = True
if COLLAB_ENV:
    # !pip install 'scipy>=1.8'
    # !pip install mycolorpy
import numpy as np #Library for linear algebra
import matplotlib.pyplot as plt #Library for plotting
import networkx as nx #Library for graph
from torch_geometric.datasets import Planetoid,WebKB, Actor #Library for graph dataset and deep learning on graphs
from torch_geometric.utils import to_dense_adj
import warnings
warnings.filterwarnings("ignore") # Get rid of warnings
# Out:
# 2.2.1+cu121
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 20.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 28.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for torch-geometric (pyproject.toml) ... done
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.10/dist-packages (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy>=1.8) (1.25.2)
# Collecting mycolorpy
#   Downloading mycolorpy-1.5.1.tar.gz (2.5 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mycolorpy) (1.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mycolorpy) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mycolorpy) (1.16.0)
# Building wheels for collected packages: mycolorpy
#   Building wheel for mycolorpy (setup.py) ... done
#   Created wheel for mycolorpy: filename=mycolorpy-1.5.1-py3-none-any.whl size=3851 sha256=e2c932ce2a0a3e3b189023af4f1641d8e5f3a7ece26514269f3dcc5fed132eb3
#   Stored in directory: /root/.cache/pip/wheels/d6/1d/04/f8bfb8b04e3daba330b3f377c041b89304271ff98fb6704946
# Successfully built mycolorpy
# Installing collected packages: mycolorpy
# Successfully installed mycolorpy-1.5.1

# %% [markdown]
# ### 1. Load data and visualize it

# %%
'''
    Load the dataset:
        * root: The root directory where the dataset should be saved.
        * name: The name of the dataset (cora, citeseer or pubmed).
        * transform: A function/transform that takes in an Data object of the dataset and returns a transformed version. The data object will be transformed before every access.
    Returns:
        * Dataset object
'''

data_Wisconsin = WebKB(root='/tmp/Wisconsin', name='Wisconsin') # Load the Wisconsin dataset (homogeneous)
dataset = data_Wisconsin
data = dataset[0] # Get the first graph object (in this case is only one graph, while in Graph classification there are multiple graphs)
print()
print(f'Dataset: {dataset}:')
print('======================')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.num_classes}')
print()
print(data) # Note that the adjacency matrix is not stored explicitly but in the edge_index attribute.
            # The edge_index attribute is a 2 x E tensor, with each column denoting an edge.
            # The first row denotes the source nodes and the second row the destination nodes of the edges.
            # The nodes are numbered consecutively starting from zero.
            # The features are stored in the x attribute, which is a N x F tensor, with N being the number of nodes and F the number of features per node.
            # The labels are stored in the y attribute, which is a vector of length N, with each entry denoting the class of the corresponding node.
print('===========================================================================================================')
adj = to_dense_adj(data.edge_index)[0] # Convert the sparse adjacency matrix to a dense adjacency matrix
print("Shape of the new adjacency matrix: ",adj.shape)
#Let's get statistics about the graph adjacency matrix
print("Number of nodes: ",adj.shape[0])
print("Number of edges: ",round(adj.sum().item()))
print("Density: ",round((adj.sum()/(adj.shape[0]*adj.shape[0])).item(),4))
print("Maximum node degree: ",round(adj.sum(axis=1).max().item()))
print("Minimum node degree: ",round(adj.sum(axis=1).min().item()))
print("Average node degree: ",round(adj.sum(axis=1).mean().item()))
print(f'Has isolated nodes: {data.has_isolated_nodes()}')
print(f'Has self-loops: {data.has_self_loops()}')
print(f'Is undirected: {data.is_undirected()}')
print('===========================================================================================================')
# Out:
# Dataset: wisconsin():
# ======================
# Number of graphs: 1
# Number of features: 1703
# Number of classes: 5
#
# Data(x=[251, 1703], edge_index=[2, 515], y=[251], train_mask=[251, 10], val_mask=[251, 10], test_mask=[251, 10])
# ===========================================================================================================
# Shape of the new adjacency matrix:  torch.Size([251, 251])
# Number of nodes:  251
# Number of edges:  515
# Density:  0.0082
# Maximum node degree:  122
# Minimum node degree:  0
# Average node degree:  2
# Has isolated nodes: False
# Has self-loops: True
# Is undirected: False
# ===========================================================================================================

# %%
def calculate_homophily(edge_index, labels):
    num_edges = edge_index.size(1)
    same_label_edges = 0

    for i in range(num_edges):
        src, dst = edge_index[:, i]
        if labels[src] == labels[dst]:
            same_label_edges += 1

    homophily = same_label_edges / num_edges
    return homophily

homophily = calculate_homophily(data.edge_index, data.y)
print(f'Grado de homofilia: {homophily:.4f}')
# Out:
# Grado de homofilia: 0.1961

# %% [markdown]
# ### 1.1 Visualize the graph

# %%
# To visualize the graph we are going to use networkx library, but first we need to convert the graph to networkx format
from torch_geometric.utils import to_networkx
A = to_networkx(data, to_undirected=True) # Convert the graph to networkx format
# Now we are going to get the largest connected component of the graph, because the graph is not connected!
Gcc = sorted(nx.connected_components(A), key=len, reverse=True) # Get the sorted list of connected components
A = A.subgraph(Gcc[0]) # Get the largest connected component
G = nx.adjacency_matrix(A)
# All the following code is just for plotting the graph, so you can ignore it
# This how we can get the edge_index attribute for the largest connected component
g_tensor = torch.tensor(G.todense())
new_edge_index = g_tensor.nonzero().t().contiguous()
# This is how we create the new data object for the largest connected component
data.x = data.x[list(A.nodes())]
data.y = data.y[list(A.nodes())]
data.edge_index = new_edge_index
data.num_nodes = len(A.nodes())
data.num_edges = len(A.edges())
print(data)
# Now we can plot the graph
A = to_networkx(data, to_undirected=True) # Convert the graph to networkx format
plt.figure(figsize=(20,15))
plt.title('Largest connected component',fontsize=20)
pos = nx.spring_layout(A,seed=12)
#Let's drow the graph, adding borders to the nodes
'''
    Arguments of nx.draw:
        * G: The graph to draw.
        * node_color: The color of the nodes.
        * pos: A dictionary with nodes as keys and positions as values.
        * cmap: A colormap or registered colormap name.
        * node_size: The size of the nodes.
        * edge_color: The color of the edges.
        * width: The width of the edges.
        * with_labels: Whether to draw the node labels.
        * node_shape: The shape of the nodes.
        * alpha: The node transparency.
    Returns:
        * None
'''
nx.draw(A,node_color=data.y,pos= pos, cmap=plt.cm.viridis, node_size=100, edge_color='black',width=1,with_labels=False,node_shape='o',alpha=0.8)
plt.show()
# Out:
# Data(x=[251, 1703], edge_index=[2, 916], y=[251], train_mask=[251, 10], val_mask=[251, 10], test_mask=[251, 10], num_nodes=251, num_edges=466)

# %% [markdown]
# ### 1.3 Visualize full graph [Optional]

# %%
# The same as above but with the whole graph
data = dataset[0]
G = to_networkx(data, to_undirected=True)
plt.figure(figsize=(20,15))
plt.title('Whole graph',fontsize=20)
color = data.y
pos = nx.spring_layout(G,seed=12)
nx.draw(G,node_color=color,pos= pos, cmap=plt.cm.viridis, node_size=100, edge_color='black',width=1,with_labels=False,node_shape='o',alpha=0.8)
plt.show()

# %% [markdown]
# ### 2. Train a GCN model

# %% [markdown]
# #### Utility functions

# %%
'''
    Arguments of train:
        * model: The model to train.
        * data: The data object.
        * optimizer: The optimizer to use.
        * train_mask: The mask of the training nodes.
        * criterion: The loss function to use.
    Returns:
        * loss: The loss of the model.
        * acc: The accuracy of the model.
'''
def train(model, data, optimizer,train_mask,device,criterion = torch.nn.CrossEntropyLoss()):
    model.train()
    optimizer.zero_grad() # Clear gradients.
    #Make sure that we only use the features of the training nodes
    features = torch.zeros(data.x.shape[0],data.x.shape[1]).to(device)
    features[train_mask] = data.x[train_mask]
    # Put the features in the same device as the model
    features = features.to(device)
    # al modelo se le pasan las características y las conexiones
    out = model(features, data.edge_index) # Perform a single forward pass.
    # Lo que me equivoco, solo en entrenamiento
    loss = criterion(out[train_mask], data.y[train_mask]) # Compute the loss solely based on the training nodes.
    pred = out.argmax(dim=1) # Use the class with highest probability.
    acc = pred[train_mask].eq(data.y[train_mask]).sum().item() / train_mask.sum().item() # Derive ratio of correct predictions.
    # Actualizar la loss, cambiar las matrices W de cada neurona
    loss.backward() # Derive gradients.
    optimizer.step() # Update parameters based on gradients.
    return loss,acc
'''
    Arguments of validation:
        * model: The model to train.
        * data: The data object.
        * val_mask: The mask of the validation nodes.
    Returns:
        * acc: The accuracy of the model.
'''
@torch.no_grad()
def validation(model,data,val_mask,device):
    model.eval() # Set model to evaluation mode (e.g. disable dropout)
    #Make sure that we only use the features of the validation nodes
    features = torch.zeros(data.x.shape[0],data.x.shape[1]).to(device)
    features[val_mask] = data.x[val_mask]
    # Put the features in the same device as the model
    features = features.to(device)
    out = model(features, data.edge_index)
    pred = out.argmax(dim=1) # Use the class with highest probability.
    acc = pred[val_mask].eq(data.y[val_mask]).sum().item() / val_mask.sum().item() # Derive ratio of correct predictions.
    return acc
'''
    Arguments of test:
        * model: The model to train.
        * data: The data object.
        * test_mask: The mask of the test nodes.
    Returns:
        * acc: The accuracy of the model.
'''
@torch.no_grad()
def test(model,data,test_mask,device):
    model.eval() # Set model to evaluation mode (e.g. disable dropout)
    #Make sure that we only use the features of the testing nodes
    features = torch.zeros(data.x.shape[0],data.x.shape[1]).to(device)
    features[test_mask] = data.x[test_mask]
    # Put the features in the same device as the model
    features = features.to(device)
    out = model(features, data.edge_index)
    pred = out.argmax(dim=1) # Use the class with highest probability.
    acc = pred[test_mask].eq(data.y[test_mask]).sum().item() / test_mask.sum().item() # Derive ratio of correct predictions.
    return acc

# %% [markdown]
# #### Split dataset

# %% [markdown]
# In this section we will split the dataset into training, validation and test sets. We will use the training set to train the model, the validation set to tune the hyperparameters and the test set to evaluate the model. We will use two functions for the splits. One function will give as a semi-supervised split where we will have a small number of labeled nodes in the training set and the rest of the nodes will be unlabeled. The other function will give us a fully supervised split where all the nodes in the training set will be labeled.

# %%
from sklearn.model_selection import train_test_split
'''
    Arguments of get_semi_supervised_split:
        * data: The data object.
        * seed: The seed to use for the random split.
    Returns: the train, test and validation masks with an 48%/32%/20%.
        * train_mask: The mask of the training nodes.
        * test_mask: The mask of the test nodes.
        * val_mask: The mask of the validation nodes.
'''
def get_semi_supervised_split(data,seed):
    #We are going to use 48% of the nodes for training, 32% for testing and 20% for validation
    #First we split the nodes in 80% for training and 20% for testing
    #Then we split the training nodes in 48% for training and 32% for validation over the 80% of the nodes
    train_split, test_split = train_test_split(list(range(len(data.y))), test_size=0.20,random_state=seed, shuffle=True)
    train_split, val_split = train_test_split(train_split, test_size=0.40,random_state=seed, shuffle=True)

    train_mask = torch.full_like(data.y, False, dtype=bool)
    train_mask[train_split] = True

    test_mask = torch.full_like(data.y, False, dtype=bool)
    test_mask[test_split] = True

    val_mask = torch.full_like(data.y, False, dtype=bool)
    val_mask[val_split] = True

    return train_mask,test_mask,val_mask
'''
    Arguments of get_supervised_split:
        * data: The data object.
        * seed: The seed to use for the random split.
    Returns: the train, test and validation masks with an 60%/20%/20%.
        * train_mask: The mask of the training nodes.
        * test_mask: The mask of the test nodes.
        * val_mask: The mask of the validation nodes.
'''
def get_supervised_split(data,seed):
    train_split, test_split = train_test_split(list(range(len(data.y))), test_size=0.40,random_state=seed, shuffle=True)
    test_split, val_split = train_test_split(test_split, test_size=0.50,random_state=seed, shuffle=True)

    train_mask = torch.full_like(data.y, False, dtype=bool)
    train_mask[train_split] = True

    test_mask = torch.full_like(data.y, False, dtype=bool)
    test_mask[test_split] = True

    val_mask = torch.full_like(data.y, False, dtype=bool)
    val_mask[val_split] = True

    return train_mask, test_mask, val_mask

# %% [markdown]
# #### Create the model

# %% [markdown]
# In this section we will create our model for node classification. We will use a GCN model with 2 hidden layers. The input to the model will be the node features and the output will be the logits for each node in the graph. We will use the cross entropy loss function and the Adam optimizer.

# %% [markdown]
# Using the above models as templates, **create as many cells as models**.

# %% [markdown]
# ##### GCN

# %%
from torch_geometric.nn import GCNConv
from torch.functional import F
'''
    In PyTorch, you define a model by subclassing torch.nn.Module and defining a forward() method which receives input data and returns output data.
    The forward() method can use other modules defined in the constructor as submodules, and it can use arbitrary operators on Tensors, including loops and conditional statements.
    This approach is very flexible, and you can use it to define models of arbitrary complexity.
'''
class GCN(torch.nn.Module):
    '''
        Arguments of __init__:
            * hidden_channels: The number of hidden units.
            * dataset.num_features: The number of input features.
            * dataset.num_classes: The number of output classes.
        Returns:
            * self.conv1: The first GCN layer.
            * self.conv2: The second GCN layer.
    '''
    # hidden channels: capa intermedia
    def __init__(self,hidden_channels = 16):
        super(GCN, self).__init__()
        # 2-layer GCN
        # GCConv(tamaño entrada, tamaño salida)
        self.conv1 = GCNConv(dataset.num_features, hidden_channels) # 16 hidden units
        self.conv2 = GCNConv(hidden_channels, dataset.num_classes) # dataset.num_classes output units
    '''
        Arguments of forward:
            * x: The input features.
            * edge_index: The edge indices.
        Returns:
            * F.softmax(x, dim=1): The output of the model.
    '''
    # lo que aplica el modelo
    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index)) # ReLU activation
        x = F.dropout(x,p=0.5, training=self.training) # Dropout: 50% of the nodes are randomly dropped out during training
        x = self.conv2(x, edge_index)
        return x.softmax(dim=1) # Log softmax activation
print(GCN())
# Out:
# GCN(
#   (conv1): GCNConv(1703, 16)
#   (conv2): GCNConv(16, 5)
# )

# %% [markdown]
# ##### SAGE

# %%
from torch_geometric.nn import SAGEConv
from torch.functional import F
'''
    In PyTorch, you define a model by subclassing torch.nn.Module and defining a forward() method which receives input data and returns output data.
    The forward() method can use other modules defined in the constructor as submodules, and it can use arbitrary operators on Tensors, including loops and conditional statements.
    This approach is very flexible, and you can use it to define models of arbitrary complexity.
'''
class SAGE(torch.nn.Module):
    '''
        Arguments of __init__:
            * hidden_channels: The number of hidden units.
            * dataset.num_features: The number of input features.
            * dataset.num_classes: The number of output classes.
        Returns:
            * self.conv1: The first GCN layer.
            * self.conv2: The second GCN layer.
    '''
    # hidden channels: capa intermedia
    def __init__(self,hidden_channels = 16):
        super(SAGE, self).__init__()
        # 2-layer GCN
        # GCConv(tamaño entrada, tamaño salida)
        self.conv1 = SAGEConv(dataset.num_features, hidden_channels, aggr='max') # 16 hidden units
        self.conv2 = SAGEConv(hidden_channels, dataset.num_classes) # dataset.num_classes output units
    '''
        Arguments of forward:
            * x: The input features.
            * edge_index: The edge indices.
        Returns:
            * F.softmax(x, dim=1): The output of the model.
    '''
    # lo que aplica el modelo
    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index)) # ReLU activation
        x = F.dropout(x,p=0.5, training=self.training) # Dropout: 50% of the nodes are randomly dropped out during training
        x = self.conv2(x, edge_index)
        return x.softmax(dim=1) # Log softmax activation
print(SAGE())
# Out:
# SAGE(
#   (conv1): SAGEConv(1703, 16, aggr=max)
#   (conv2): SAGEConv(16, 5, aggr=mean)
# )

# %% [markdown]
# ##### Cheb

# %%
from torch_geometric.nn import ChebConv
from torch.functional import F
'''
    In PyTorch, you define a model by subclassing torch.nn.Module and defining a forward() method which receives input data and returns output data.
    The forward() method can use other modules defined in the constructor as submodules, and it can use arbitrary operators on Tensors, including loops and conditional statements.
    This approach is very flexible, and you can use it to define models of arbitrary complexity.
'''
class Cheb(torch.nn.Module):
    '''
        Arguments of __init__:
            * hidden_channels: The number of hidden units.
            * dataset.num_features: The number of input features.
            * dataset.num_classes: The number of output classes.
        Returns:
            * self.conv1: The first GCN layer.
            * self.conv2: The second GCN layer.
    '''
    # hidden channels: capa intermedia
    def __init__(self,hidden_channels = 16):
        super(Cheb, self).__init__()
        # 2-layer GCN
        # GCConv(tamaño entrada, tamaño salida)
        self.conv1 = ChebConv(dataset.num_features, hidden_channels, K=10, normalization='sym') # 16 hidden units
        self.conv2 = ChebConv(hidden_channels, dataset.num_classes, K=10, normalization='sym') # dataset.num_classes output units
    '''
        Arguments of forward:
            * x: The input features.
            * edge_index: The edge indices.
        Returns:
            * F.softmax(x, dim=1): The output of the model.
    '''
    # lo que aplica el modelo
    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index)) # ReLU activation
        x = F.dropout(x,p=0.5, training=self.training) # Dropout: 50% of the nodes are randomly dropped out during training
        x = self.conv2(x, edge_index)
        return x.softmax(dim=1) # Log softmax activation
print(Cheb())
# Out:
# Cheb(
#   (conv1): ChebConv(1703, 16, K=10, normalization=sym)
#   (conv2): ChebConv(16, 5, K=10, normalization=sym)
# )

# %% [markdown]
# ##### GAT

# %%
from torch_geometric.nn import GATConv
from torch.functional import F
'''
    In PyTorch, you define a model by subclassing torch.nn.Module and defining a forward() method which receives input data and returns output data.
    The forward() method can use other modules defined in the constructor as submodules, and it can use arbitrary operators on Tensors, including loops and conditional statements.
    This approach is very flexible, and you can use it to define models of arbitrary complexity.
'''
class GAT(torch.nn.Module):
    '''
        Arguments of __init__:
            * hidden_channels: The number of hidden units.
            * dataset.num_features: The number of input features.
            * dataset.num_classes: The number of output classes.
        Returns:
            * self.conv1: The first GCN layer.
            * self.conv2: The second GCN layer.
    '''
    # hidden channels: capa intermedia
    def __init__(self,hidden_channels = 16):
        super(GAT, self).__init__()
        # 2-layer GCN
        # GCConv(tamaño entrada, tamaño salida)
        self.conv1 = GATConv(dataset.num_features, hidden_channels, heads=1) # 16 hidden units
        self.conv2 = GATConv(hidden_channels, dataset.num_classes, heads=1) # dataset.num_classes output units
    '''
        Arguments of forward:
            * x: The input features.
            * edge_index: The edge indices.
        Returns:
            * F.softmax(x, dim=1): The output of the model.
    '''
    # lo que aplica el modelo
    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index)) # ReLU activation
        x = F.dropout(x,p=0.5, training=self.training) # Dropout: 50% of the nodes are randomly dropped out during training
        x = self.conv2(x, edge_index)
        return x.softmax(dim=1) # Log softmax activation
print(GAT())
# Out:
# GAT(
#   (conv1): GATConv(1703, 16, heads=1)
#   (conv2): GATConv(16, 5, heads=1)
# )

# %% [markdown]
# ##### MLP

# %%
from torch.nn import Linear
# Same as GCN but with Linear layers instead of GCNConv layers. If we use MLP as a model, we can't take into account the graph STRUCTURE.
class MLP(torch.nn.Module):
    def __init__(self,hidden_channels = 16):
        super(MLP, self).__init__()
        # 2-layer GCN
        self.lin1 = Linear(dataset.num_features, hidden_channels)
        self.lin2 = Linear(hidden_channels, dataset.num_classes)

    def forward(self, x, edge_index):
        # edge_index is not used
        x = self.lin1(x)
        x = x.relu()
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin2(x)
        return x.softmax(dim=1)
print(MLP())
# Out:
# MLP(
#   (lin1): Linear(in_features=1703, out_features=16, bias=True)
#   (lin2): Linear(in_features=16, out_features=5, bias=True)
# )

# %% [markdown]
# #### Train the models

# %%
# Seeds for the random split. This allows us to reproduce the results.
RandList = [12345, 423456, 643451, 543452, 743456, 4734510, 654321, 124321, 945321, 784328]
# This allows us to run the code on the GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Here you can add models to train and test (include your own models)
models = [GCN(), MLP(), SAGE(), Cheb(), GAT()]
global_results = []
global_best_models = []
for j in range(len(models)):
    ExperimentResult = []
    best_model = None
    print(data)
    for i in range(10):
        print("Random State", RandList[i]," in the iteration",i)
        train_mask,test_mask,val_mask = get_semi_supervised_split(data.cpu(), RandList[i])
        #train_mask,test_mask,val_mask = get_supervised_split(data.cpu(), RandList[i])
        data = data.to(device)
        model = models[j].to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
        for epoch in range(1, 101):
            loss, acc_train = train(model,data,optimizer,train_mask.to(device),device=device)
            acc_validation = validation(model,data,val_mask.to(device),device=device)
            print('Epoch: {:03d}, Loss: {:.5f}, Train Acc: {:.5f}, Val Acc: {:.5f}'.format(epoch, loss, acc_train, acc_validation))
        acc = test(model,data,test_mask.to(device),device=device)
        print('Test Accuracy: {:.5f}'.format(acc))
        # Save the best model over the 10 runs
        if best_model is None or acc > best_model[1]:
            best_model = [model, acc]
        ExperimentResult.append(acc)
        del model
    print(models[j].__class__.__name__) # Name of the model
    print('{} +- {}'.format(np.mean(ExperimentResult)*100, np.std(ExperimentResult)*100))
    global_results.append(ExperimentResult.copy())
    global_best_models.append(best_model.copy())
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Epoch: 012, Loss: 1.22079, Train Acc: 0.69167, Val Acc: 0.76250
# Epoch: 013, Loss: 1.21342, Train Acc: 0.70000, Val Acc: 0.72500
# Epoch: 014, Loss: 1.19048, Train Acc: 0.70833, Val Acc: 0.71250
# Epoch: 015, Loss: 1.20656, Train Acc: 0.70833, Val Acc: 0.71250
# Epoch: 016, Loss: 1.19875, Train Acc: 0.70833, Val Acc: 0.71250
# Epoch: 017, Loss: 1.16804, Train Acc: 0.73333, Val Acc: 0.70000
# Epoch: 018, Loss: 1.19319, Train Acc: 0.71667, Val Acc: 0.71250
# Epoch: 019, Loss: 1.19244, Train Acc: 0.71667, Val Acc: 0.70000
# Epoch: 020, Loss: 1.18815, Train Acc: 0.73333, Val Acc: 0.71250
# Epoch: 021, Loss: 1.17947, Train Acc: 0.72500, Val Acc: 0.71250
# Epoch: 022, Loss: 1.16651, Train Acc: 0.74167, Val Acc: 0.71250
# Epoch: 023, Loss: 1.17409, Train Acc: 0.73333, Val Acc: 0.70000
# Epoch: 024, Loss: 1.19033, Train Acc: 0.70833, Val Acc: 0.68750
# Epoch: 025, Loss: 1.19617, Train Acc: 0.70833, Val Acc: 0.68750
# Epoch: 026, Loss: 1.18602, Train Acc: 0.71667, Val Acc: 0.67500
# Epoch: 027, Loss: 1.15409, Train Acc: 0.74167, Val Acc: 0.68750
# Epoch: 028, Loss: 1.18277, Train Acc: 0.71667, Val Acc: 0.70000
# Epoch: 029, Loss: 1.14232, Train Acc: 0.76667, Val Acc: 0.70000
# Epoch: 030, Loss: 1.16721, Train Acc: 0.74167, Val Acc: 0.70000
# Epoch: 031, Loss: 1.15795, Train Acc: 0.74167, Val Acc: 0.70000
# Epoch: 032, Loss: 1.16952, Train Acc: 0.75000, Val Acc: 0.70000
# Epoch: 033, Loss: 1.15855, Train Acc: 0.75000, Val Acc: 0.70000
# Epoch: 034, Loss: 1.16638, Train Acc: 0.73333, Val Acc: 0.70000
# Epoch: 035, Loss: 1.14558, Train Acc: 0.77500, Val Acc: 0.70000
# Epoch: 036, Loss: 1.13614, Train Acc: 0.75833, Val Acc: 0.72500
# Epoch: 037, Loss: 1.17210, Train Acc: 0.73333, Val Acc: 0.70000
# Epoch: 038, Loss: 1.14936, Train Acc: 0.76667, Val Acc: 0.70000
# Epoch: 039, Loss: 1.25628, Train Acc: 0.67500, Val Acc: 0.71250
# Epoch: 040, Loss: 1.13639, Train Acc: 0.76667, Val Acc: 0.73750
# Epoch: 041, Loss: 1.16219, Train Acc: 0.75000, Val Acc: 0.73750
# Epoch: 042, Loss: 1.14852, Train Acc: 0.76667, Val Acc: 0.72500
# Epoch: 043, Loss: 1.13576, Train Acc: 0.77500, Val Acc: 0.72500
# Epoch: 044, Loss: 1.14624, Train Acc: 0.77500, Val Acc: 0.72500
# Epoch: 045, Loss: 1.11460, Train Acc: 0.80000, Val Acc: 0.71250
# Epoch: 046, Loss: 1.13304, Train Acc: 0.75833, Val Acc: 0.72500
# Epoch: 047, Loss: 1.13737, Train Acc: 0.78333, Val Acc: 0.70000
# Epoch: 048, Loss: 1.13106, Train Acc: 0.78333, Val Acc: 0.70000
# Epoch: 049, Loss: 1.14755, Train Acc: 0.76667, Val Acc: 0.71250
# Epoch: 050, Loss: 1.15540, Train Acc: 0.74167, Val Acc: 0.71250
# Epoch: 051, Loss: 1.14173, Train Acc: 0.77500, Val Acc: 0.71250
# Epoch: 052, Loss: 1.16566, Train Acc: 0.73333, Val Acc: 0.72500
# Epoch: 053, Loss: 1.11944, Train Acc: 0.80000, Val Acc: 0.71250
# Epoch: 054, Loss: 1.12943, Train Acc: 0.78333, Val Acc: 0.71250
# Epoch: 055, Loss: 1.13407, Train Acc: 0.77500, Val Acc: 0.73750
# Epoch: 056, Loss: 1.15839, Train Acc: 0.75833, Val Acc: 0.73750
# Epoch: 057, Loss: 1.11311, Train Acc: 0.80000, Val Acc: 0.73750
# Epoch: 058, Loss: 1.16348, Train Acc: 0.75833, Val Acc: 0.75000
# Epoch: 059, Loss: 1.11833, Train Acc: 0.79167, Val Acc: 0.73750
# Epoch: 060, Loss: 1.13085, Train Acc: 0.77500, Val Acc: 0.73750
# Epoch: 061, Loss: 1.13053, Train Acc: 0.78333, Val Acc: 0.73750
# Epoch: 062, Loss: 1.11483, Train Acc: 0.79167, Val Acc: 0.76250
# Epoch: 063, Loss: 1.13404, Train Acc: 0.75833, Val Acc: 0.76250
# Epoch: 064, Loss: 1.12044, Train Acc: 0.81667, Val Acc: 0.73750
# Epoch: 065, Loss: 1.11065, Train Acc: 0.81667, Val Acc: 0.73750
# Epoch: 066, Loss: 1.11369, Train Acc: 0.80000, Val Acc: 0.73750
# Epoch: 067, Loss: 1.12350, Train Acc: 0.78333, Val Acc: 0.72500
# Epoch: 068, Loss: 1.08789, Train Acc: 0.84167, Val Acc: 0.72500
# Epoch: 069, Loss: 1.18247, Train Acc: 0.71667, Val Acc: 0.71250
# Epoch: 070, Loss: 1.11466, Train Acc: 0.79167, Val Acc: 0.70000
# Epoch: 071, Loss: 1.12429, Train Acc: 0.80000, Val Acc: 0.71250
# Epoch: 072, Loss: 1.12291, Train Acc: 0.77500, Val Acc: 0.70000
# Epoch: 073, Loss: 1.10863, Train Acc: 0.81667, Val Acc: 0.70000
# Epoch: 074, Loss: 1.14089, Train Acc: 0.74167, Val Acc: 0.70000
# Epoch: 075, Loss: 1.13114, Train Acc: 0.78333, Val Acc: 0.68750
# Epoch: 076, Loss: 1.12465, Train Acc: 0.79167, Val Acc: 0.68750
# Epoch: 077, Loss: 1.13510, Train Acc: 0.78333, Val Acc: 0.70000
# Epoch: 078, Loss: 1.12129, Train Acc: 0.78333, Val Acc: 0.70000
# Epoch: 079, Loss: 1.11566, Train Acc: 0.80833, Val Acc: 0.70000
# Epoch: 080, Loss: 1.16236, Train Acc: 0.72500, Val Acc: 0.70000
# Epoch: 081, Loss: 1.17897, Train Acc: 0.73333, Val Acc: 0.70000
# Epoch: 082, Loss: 1.11659, Train Acc: 0.79167, Val Acc: 0.70000
# Epoch: 083, Loss: 1.15443, Train Acc: 0.75833, Val Acc: 0.70000
# Epoch: 084, Loss: 1.14055, Train Acc: 0.75833, Val Acc: 0.70000
# Epoch: 085, Loss: 1.11023, Train Acc: 0.80000, Val Acc: 0.71250
# Epoch: 086, Loss: 1.13555, Train Acc: 0.77500, Val Acc: 0.70000
# Epoch: 087, Loss: 1.12891, Train Acc: 0.79167, Val Acc: 0.68750
# Epoch: 088, Loss: 1.13197, Train Acc: 0.78333, Val Acc: 0.70000
# Epoch: 089, Loss: 1.13354, Train Acc: 0.79167, Val Acc: 0.70000
# Epoch: 090, Loss: 1.13106, Train Acc: 0.77500, Val Acc: 0.67500
# Epoch: 091, Loss: 1.12352, Train Acc: 0.80000, Val Acc: 0.67500
# Epoch: 092, Loss: 1.15728, Train Acc: 0.73333, Val Acc: 0.68750
# Epoch: 093, Loss: 1.15251, Train Acc: 0.76667, Val Acc: 0.72500
# Epoch: 094, Loss: 1.11206, Train Acc: 0.80000, Val Acc: 0.72500
# Epoch: 095, Loss: 1.11518, Train Acc: 0.80833, Val Acc: 0.71250
# Epoch: 096, Loss: 1.12745, Train Acc: 0.79167, Val Acc: 0.71250
# Epoch: 097, Loss: 1.11896, Train Acc: 0.78333, Val Acc: 0.71250
# Epoch: 098, Loss: 1.14646, Train Acc: 0.76667, Val Acc: 0.71250
# Epoch: 099, Loss: 1.08940, Train Acc: 0.83333, Val Acc: 0.70000
# Epoch: 100, Loss: 1.09845, Train Acc: 0.80833, Val Acc: 0.68750
# Test Accuracy: 0.66667
# Random State 643451  in the iteration 2
# Epoch: 001, Loss: 1.30933, Train Acc: 0.64167, Val Acc: 0.80000
# Epoch: 002, Loss: 1.28651, Train Acc: 0.63333, Val Acc: 0.81250
# Epoch: 003, Loss: 1.25850, Train Acc: 0.65000, Val Acc: 0.81250
# Epoch: 004, Loss: 1.28775, Train Acc: 0.61667, Val Acc: 0.81250
# Epoch: 005, Loss: 1.25292, Train Acc: 0.65833, Val Acc: 0.81250
# Epoch: 006, Loss: 1.20985, Train Acc: 0.72500, Val Acc: 0.81250
# Epoch: 007, Loss: 1.25058, Train Acc: 0.65833, Val Acc: 0.81250
# Epoch: 008, Loss: 1.20912, Train Acc: 0.70833, Val Acc: 0.81250
# Epoch: 009, Loss: 1.20759, Train Acc: 0.70000, Val Acc: 0.81250
# Epoch: 010, Loss: 1.22405, Train Acc: 0.68333, Val Acc: 0.82500
# Epoch: 011, Loss: 1.21845, Train Acc: 0.68333, Val Acc: 0.81250
# Epoch: 012, Loss: 1.19289, Train Acc: 0.72500, Val Acc: 0.80000
# Epoch: 013, Loss: 1.22576, Train Acc: 0.68333, Val Acc: 0.80000
# Epoch: 014, Loss: 1.20316, Train Acc: 0.71667, Val Acc: 0.80000
# Epoch: 015, Loss: 1.20401, Train Acc: 0.70833, Val Acc: 0.80000
# Epoch: 016, Loss: 1.18931, Train Acc: 0.73333, Val Acc: 0.80000
# Epoch: 017, Loss: 1.19007, Train Acc: 0.73333, Val Acc: 0.80000
# Epoch: 018, Loss: 1.20253, Train Acc: 0.71667, Val Acc: 0.80000
# Epoch: 019, Loss: 1.22506, Train Acc: 0.69167, Val Acc: 0.80000
# Epoch: 020, Loss: 1.20790, Train Acc: 0.70000, Val Acc: 0.81250
# Epoch: 021, Loss: 1.17489, Train Acc: 0.71667, Val Acc: 0.81250
# Epoch: 022, Loss: 1.18793, Train Acc: 0.74167, Val Acc: 0.81250
# Epoch: 023, Loss: 1.20134, Train Acc: 0.70833, Val Acc: 0.80000
# Epoch: 024, Loss: 1.16456, Train Acc: 0.73333, Val Acc: 0.81250
# Epoch: 025, Loss: 1.19113, Train Acc: 0.70833, Val Acc: 0.80000
# Epoch: 026, Loss: 1.20586, Train Acc: 0.71667, Val Acc: 0.80000
# Epoch: 027, Loss: 1.16927, Train Acc: 0.76667, Val Acc: 0.81250
# Epoch: 028, Loss: 1.15772, Train Acc: 0.76667, Val Acc: 0.81250
# Epoch: 029, Loss: 1.17486, Train Acc: 0.73333, Val Acc: 0.81250
# Epoch: 030, Loss: 1.17144, Train Acc: 0.75000, Val Acc: 0.80000
# Epoch: 031, Loss: 1.16127, Train Acc: 0.75833, Val Acc: 0.80000
# Epoch: 032, Loss: 1.16988, Train Acc: 0.74167, Val Acc: 0.80000
# Epoch: 033, Loss: 1.15871, Train Acc: 0.75833, Val Acc: 0.78750
# Epoch: 034, Loss: 1.18048, Train Acc: 0.73333, Val Acc: 0.80000
# Epoch: 035, Loss: 1.14951, Train Acc: 0.77500, Val Acc: 0.80000
# Epoch: 036, Loss: 1.16361, Train Acc: 0.75000, Val Acc: 0.78750
# Epoch: 037, Loss: 1.16585, Train Acc: 0.75833, Val Acc: 0.78750
# Epoch: 038, Loss: 1.16239, Train Acc: 0.75000, Val Acc: 0.80000
# Epoch: 039, Loss: 1.14942, Train Acc: 0.75833, Val Acc: 0.77500
# Epoch: 040, Loss: 1.16171, Train Acc: 0.75000, Val Acc: 0.77500
# Epoch: 041, Loss: 1.17698, Train Acc: 0.72500, Val Acc: 0.77500
# Epoch: 042, Loss: 1.16805, Train Acc: 0.74167, Val Acc: 0.76250
# Epoch: 043, Loss: 1.14754, Train Acc: 0.77500, Val Acc: 0.76250
# Epoch: 044, Loss: 1.17704, Train Acc: 0.73333, Val Acc: 0.76250
# Epoch: 045, Loss: 1.16253, Train Acc: 0.75833, Val Acc: 0.76250
# Epoch: 046, Loss: 1.15522, Train Acc: 0.77500, Val Acc: 0.77500
# Epoch: 047, Loss: 1.14148, Train Acc: 0.80000, Val Acc: 0.76250
# Epoch: 048, Loss: 1.15367, Train Acc: 0.76667, Val Acc: 0.76250
# Epoch: 049, Loss: 1.18068, Train Acc: 0.72500, Val Acc: 0.77500
# Epoch: 050, Loss: 1.16025, Train Acc: 0.75833, Val Acc: 0.77500
# Epoch: 051, Loss: 1.15824, Train Acc: 0.75000, Val Acc: 0.77500
# Epoch: 052, Loss: 1.15535, Train Acc: 0.75833, Val Acc: 0.77500
# Epoch: 053, Loss: 1.15843, Train Acc: 0.75833, Val Acc: 0.77500
# Epoch: 054, Loss: 1.11657, Train Acc: 0.79167, Val Acc: 0.77500
# Epoch: 055, Loss: 1.16115, Train Acc: 0.75833, Val Acc: 0.77500
# Epoch: 056, Loss: 1.18110, Train Acc: 0.74167, Val Acc: 0.76250
# Epoch: 057, Loss: 1.14513, Train Acc: 0.77500, Val Acc: 0.76250
# Epoch: 058, Loss: 1.16241, Train Acc: 0.75833, Val Acc: 0.76250
# Epoch: 059, Loss: 1.14867, Train Acc: 0.76667, Val Acc: 0.77500
# Epoch: 060, Loss: 1.15873, Train Acc: 0.74167, Val Acc: 0.77500
# Epoch: 061, Loss: 1.17692, Train Acc: 0.75000, Val Acc: 0.77500
# Epoch: 062, Loss: 1.13561, Train Acc: 0.77500, Val Acc: 0.78750
# Epoch: 063, Loss: 1.15198, Train Acc: 0.76667, Val Acc: 0.78750
# Epoch: 064, Loss: 1.13119, Train Acc: 0.79167, Val Acc: 0.77500
# Epoch: 065, Loss: 1.14162, Train Acc: 0.76667, Val Acc: 0.77500
# Epoch: 066, Loss: 1.15109, Train Acc: 0.77500, Val Acc: 0.77500
# Epoch: 067, Loss: 1.15289, Train Acc: 0.75833, Val Acc: 0.76250
# Epoch: 068, Loss: 1.16181, Train Acc: 0.74167, Val Acc: 0.77500
# Epoch: 069, Loss: 1.13265, Train Acc: 0.78333, Val Acc: 0.77500
# Epoch: 070, Loss: 1.14821, Train Acc: 0.76667, Val Acc: 0.77500
# Epoch: 071, Loss: 1.14014, Train Acc: 0.79167, Val Acc: 0.77500
# Epoch: 072, Loss: 1.15320, Train Acc: 0.75833, Val Acc: 0.77500
# Epoch: 073, Loss: 1.17894, Train Acc: 0.71667, Val Acc: 0.77500
# Epoch: 074, Loss: 1.15103, Train Acc: 0.74167, Val Acc: 0.77500
# Epoch: 075, Loss: 1.12173, Train Acc: 0.79167, Val Acc: 0.78750
# Epoch: 076, Loss: 1.12511, Train Acc: 0.79167, Val Acc: 0.78750
# Epoch: 077, Loss: 1.14319, Train Acc: 0.75833, Val Acc: 0.78750
# Epoch: 078, Loss: 1.15812, Train Acc: 0.75000, Val Acc: 0.78750
# Epoch: 079, Loss: 1.15500, Train Acc: 0.76667, Val Acc: 0.77500
# Epoch: 080, Loss: 1.13743, Train Acc: 0.78333, Val Acc: 0.76250
# Epoch: 081, Loss: 1.12392, Train Acc: 0.80000, Val Acc: 0.76250
# Epoch: 082, Loss: 1.13944, Train Acc: 0.79167, Val Acc: 0.76250
# Epoch: 083, Loss: 1.13639, Train Acc: 0.78333, Val Acc: 0.76250
# Epoch: 084, Loss: 1.14907, Train Acc: 0.76667, Val Acc: 0.76250
# Epoch: 085, Loss: 1.14030, Train Acc: 0.77500, Val Acc: 0.76250
# Epoch: 086, Loss: 1.16654, Train Acc: 0.75000, Val Acc: 0.76250
# Epoch: 087, Loss: 1.12109, Train Acc: 0.79167, Val Acc: 0.77500
# Epoch: 088, Loss: 1.14490, Train Acc: 0.77500, Val Acc: 0.77500
# Epoch: 089, Loss: 1.13584, Train Acc: 0.75833, Val Acc: 0.78750
# Epoch: 090, Loss: 1.12806, Train Acc: 0.79167, Val Acc: 0.78750
# Epoch: 091, Loss: 1.12528, Train Acc: 0.79167, Val Acc: 0.78750
# Epoch: 092, Loss: 1.14530, Train Acc: 0.76667, Val Acc: 0.78750
# Epoch: 093, Loss: 1.13771, Train Acc: 0.76667, Val Acc: 0.77500
# Epoch: 094, Loss: 1.13417, Train Acc: 0.79167, Val Acc: 0.77500
# Epoch: 095, Loss: 1.14272, Train Acc: 0.78333, Val Acc: 0.77500
# Epoch: 096, Loss: 1.16881, Train Acc: 0.74167, Val Acc: 0.77500
# Epoch: 097, Loss: 1.16707, Train Acc: 0.72500, Val Acc: 0.77500
# Epoch: 098, Loss: 1.12637, Train Acc: 0.77500, Val Acc: 0.77500
# Epoch: 099, Loss: 1.13569, Train Acc: 0.78333, Val Acc: 0.78750
# Epoch: 100, Loss: 1.12256, Train Acc: 0.80833, Val Acc: 0.78750
# Test Accuracy: 0.66667
# Random State 543452  in the iteration 3
# Epoch: 001, Loss: 1.22561, Train Acc: 0.68333, Val Acc: 0.70000
# Epoch: 002, Loss: 1.19023, Train Acc: 0.71667, Val Acc: 0.68750
# Epoch: 003, Loss: 1.26102, Train Acc: 0.65833, Val Acc: 0.70000
# Epoch: 004, Loss: 1.18772, Train Acc: 0.71667, Val Acc: 0.70000
# Epoch: 005, Loss: 1.21904, Train Acc: 0.70000, Val Acc: 0.68750
# Epoch: 006, Loss: 1.19729, Train Acc: 0.70000, Val Acc: 0.70000
# Epoch: 007, Loss: 1.25862, Train Acc: 0.62500, Val Acc: 0.71250
# Epoch: 008, Loss: 1.24048, Train Acc: 0.66667, Val Acc: 0.72500
# Epoch: 009, Loss: 1.17625, Train Acc: 0.72500, Val Acc: 0.70000
# Epoch: 010, Loss: 1.21134, Train Acc: 0.70000, Val Acc: 0.71250
# Epoch: 011, Loss: 1.22049, Train Acc: 0.70000, Val Acc: 0.71250
# Epoch: 012, Loss: 1.18350, Train Acc: 0.70000, Val Acc: 0.71250
# Epoch: 013, Loss: 1.16139, Train Acc: 0.75000, Val Acc: 0.72500
# Epoch: 014, Loss: 1.18480, Train Acc: 0.72500, Val Acc: 0.72500
# Epoch: 015, Loss: 1.20770, Train Acc: 0.69167, Val Acc: 0.72500
# Epoch: 016, Loss: 1.20386, Train Acc: 0.70833, Val Acc: 0.72500
# Epoch: 017, Loss: 1.17100, Train Acc: 0.75000, Val Acc: 0.73750
# Epoch: 018, Loss: 1.20770, Train Acc: 0.69167, Val Acc: 0.73750
# Epoch: 019, Loss: 1.21185, Train Acc: 0.70000, Val Acc: 0.72500
# Epoch: 020, Loss: 1.12114, Train Acc: 0.79167, Val Acc: 0.72500
# Epoch: 021, Loss: 1.18330, Train Acc: 0.71667, Val Acc: 0.72500
# Epoch: 022, Loss: 1.18181, Train Acc: 0.74167, Val Acc: 0.71250
# Epoch: 023, Loss: 1.31924, Train Acc: 0.55000, Val Acc: 0.68750
# Epoch: 024, Loss: 1.17532, Train Acc: 0.74167, Val Acc: 0.70000
# Epoch: 025, Loss: 1.17393, Train Acc: 0.72500, Val Acc: 0.70000
# Epoch: 026, Loss: 1.19874, Train Acc: 0.70000, Val Acc: 0.70000
# Epoch: 027, Loss: 1.17384, Train Acc: 0.74167, Val Acc: 0.70000
# Epoch: 028, Loss: 1.17211, Train Acc: 0.72500, Val Acc: 0.70000
# Epoch: 029, Loss: 1.14724, Train Acc: 0.75000, Val Acc: 0.71250
# Epoch: 030, Loss: 1.16688, Train Acc: 0.73333, Val Acc: 0.71250
# Epoch: 031, Loss: 1.16424, Train Acc: 0.73333, Val Acc: 0.70000
# Epoch: 032, Loss: 1.18363, Train Acc: 0.70000, Val Acc: 0.68750
# Epoch: 033, Loss: 1.18081, Train Acc: 0.71667, Val Acc: 0.71250
# Epoch: 034, Loss: 1.16360, Train Acc: 0.74167, Val Acc: 0.72500
# Epoch: 035, Loss: 1.16372, Train Acc: 0.73333, Val Acc: 0.71250
# Epoch: 036, Loss: 1.17461, Train Acc: 0.72500, Val Acc: 0.72500
# Epoch: 037, Loss: 1.16114, Train Acc: 0.75000, Val Acc: 0.72500
# Epoch: 038, Loss: 1.15590, Train Acc: 0.75833, Val Acc: 0.72500
# Epoch: 039, Loss: 1.17638, Train Acc: 0.73333, Val Acc: 0.71250
# Epoch: 040, Loss: 1.12321, Train Acc: 0.80000, Val Acc: 0.71250
# Epoch: 041, Loss: 1.17303, Train Acc: 0.74167, Val Acc: 0.71250
# Epoch: 042, Loss: 1.14419, Train Acc: 0.76667, Val Acc: 0.71250
# Epoch: 043, Loss: 1.23365, Train Acc: 0.67500, Val Acc: 0.71250
# Epoch: 044, Loss: 1.13647, Train Acc: 0.76667, Val Acc: 0.72500
# Epoch: 045, Loss: 1.16694, Train Acc: 0.73333, Val Acc: 0.72500
# Epoch: 046, Loss: 1.13467, Train Acc: 0.79167, Val Acc: 0.71250
# Epoch: 047, Loss: 1.15498, Train Acc: 0.76667, Val Acc: 0.71250
# Epoch: 048, Loss: 1.14447, Train Acc: 0.76667, Val Acc: 0.71250
# Epoch: 049, Loss: 1.14475, Train Acc: 0.75833, Val Acc: 0.71250
# Epoch: 050, Loss: 1.14020, Train Acc: 0.75000, Val Acc: 0.71250
# Epoch: 051, Loss: 1.13952, Train Acc: 0.76667, Val Acc: 0.71250
# Epoch: 052, Loss: 1.10512, Train Acc: 0.81667, Val Acc: 0.71250
# Epoch: 053, Loss: 1.11694, Train Acc: 0.78333, Val Acc: 0.70000
# Epoch: 054, Loss: 1.18319, Train Acc: 0.70833, Val Acc: 0.70000
# Epoch: 055, Loss: 1.14098, Train Acc: 0.78333, Val Acc: 0.70000
# Epoch: 056, Loss: 1.13607, Train Acc: 0.79167, Val Acc: 0.70000
# Epoch: 057, Loss: 1.12624, Train Acc: 0.76667, Val Acc: 0.70000
# Epoch: 058, Loss: 1.12307, Train Acc: 0.77500, Val Acc: 0.70000
# Epoch: 059, Loss: 1.12823, Train Acc: 0.75833, Val Acc: 0.70000
# Epoch: 060, Loss: 1.14465, Train Acc: 0.76667, Val Acc: 0.70000
# Epoch: 061, Loss: 1.15014, Train Acc: 0.76667, Val Acc: 0.70000
# Epoch: 062, Loss: 1.11379, Train Acc: 0.80000, Val Acc: 0.71250
# Epoch: 063, Loss: 1.12652, Train Acc: 0.79167, Val Acc: 0.71250
# Epoch: 064, Loss: 1.13113, Train Acc: 0.76667, Val Acc: 0.71250
# Epoch: 065, Loss: 1.13196, Train Acc: 0.76667, Val Acc: 0.71250
# Epoch: 066, Loss: 1.13846, Train Acc: 0.78333, Val Acc: 0.71250
# Epoch: 067, Loss: 1.14950, Train Acc: 0.75000, Val Acc: 0.70000
# Epoch: 068, Loss: 1.11386, Train Acc: 0.80000, Val Acc: 0.70000
# Epoch: 069, Loss: 1.09556, Train Acc: 0.82500, Val Acc: 0.68750
# Epoch: 070, Loss: 1.12492, Train Acc: 0.79167, Val Acc: 0.68750
# Epoch: 071, Loss: 1.08874, Train Acc: 0.83333, Val Acc: 0.68750
# Epoch: 072, Loss: 1.10377, Train Acc: 0.79167, Val Acc: 0.70000
# Epoch: 073, Loss: 1.09855, Train Acc: 0.81667, Val Acc: 0.68750
# Epoch: 074, Loss: 1.12676, Train Acc: 0.77500, Val Acc: 0.68750
# Epoch: 075, Loss: 1.12555, Train Acc: 0.77500, Val Acc: 0.68750
# Epoch: 076, Loss: 1.11594, Train Acc: 0.80000, Val Acc: 0.70000
# Epoch: 077, Loss: 1.11970, Train Acc: 0.79167, Val Acc: 0.68750
# Epoch: 078, Loss: 1.12270, Train Acc: 0.79167, Val Acc: 0.70000
# Epoch: 079, Loss: 1.09693, Train Acc: 0.82500, Val Acc: 0.70000
# Epoch: 080, Loss: 1.11438, Train Acc: 0.80000, Val Acc: 0.70000
# Epoch: 081, Loss: 1.12203, Train Acc: 0.79167, Val Acc: 0.70000
# Epoch: 082, Loss: 1.09318, Train Acc: 0.82500, Val Acc: 0.68750
# Epoch: 083, Loss: 1.13585, Train Acc: 0.78333, Val Acc: 0.68750
# Epoch: 084, Loss: 1.10283, Train Acc: 0.80833, Val Acc: 0.68750
# Epoch: 085, Loss: 1.12936, Train Acc: 0.78333, Val Acc: 0.68750
# Epoch: 086, Loss: 1.10325, Train Acc: 0.80833, Val Acc: 0.68750
# Epoch: 087, Loss: 1.08032, Train Acc: 0.85000, Val Acc: 0.68750
# Epoch: 088, Loss: 1.11632, Train Acc: 0.78333, Val Acc: 0.70000
# Epoch: 089, Loss: 1.10313, Train Acc: 0.82500, Val Acc: 0.71250
# Epoch: 090, Loss: 1.12158, Train Acc: 0.76667, Val Acc: 0.71250
# Epoch: 091, Loss: 1.11620, Train Acc: 0.79167, Val Acc: 0.70000
# Epoch: 092, Loss: 1.12036, Train Acc: 0.79167, Val Acc: 0.70000
# Epoch: 093, Loss: 1.10837, Train Acc: 0.80000, Val Acc: 0.70000
# Epoch: 094, Loss: 1.15480, Train Acc: 0.76667, Val Acc: 0.68750
# Epoch: 095, Loss: 1.10292, Train Acc: 0.80833, Val Acc: 0.68750
# Epoch: 096, Loss: 1.13699, Train Acc: 0.78333, Val Acc: 0.68750
# Epoch: 097, Loss: 1.11488, Train Acc: 0.80833, Val Acc: 0.70000
# Epoch: 098, Loss: 1.08599, Train Acc: 0.82500, Val Acc: 0.70000
# Epoch: 099, Loss: 1.11840, Train Acc: 0.79167, Val Acc: 0.70000
# Epoch: 100, Loss: 1.09938, Train Acc: 0.80833, Val Acc: 0.70000
# Test Accuracy: 0.76471
# Random State 743456  in the iteration 4
# Epoch: 001, Loss: 1.17622, Train Acc: 0.73333, Val Acc: 0.63750
# Epoch: 002, Loss: 1.20847, Train Acc: 0.69167, Val Acc: 0.61250
# Epoch: 003, Loss: 1.18541, Train Acc: 0.72500, Val Acc: 0.58750
# Epoch: 004, Loss: 1.18362, Train Acc: 0.72500, Val Acc: 0.60000
# Epoch: 005, Loss: 1.17946, Train Acc: 0.71667, Val Acc: 0.60000
# Epoch: 006, Loss: 1.17308, Train Acc: 0.73333, Val Acc: 0.58750
# Epoch: 007, Loss: 1.16224, Train Acc: 0.73333, Val Acc: 0.58750
# Epoch: 008, Loss: 1.14733, Train Acc: 0.75000, Val Acc: 0.57500
# Epoch: 009, Loss: 1.16647, Train Acc: 0.72500, Val Acc: 0.56250
# Epoch: 010, Loss: 1.13979, Train Acc: 0.78333, Val Acc: 0.57500
# Epoch: 011, Loss: 1.15483, Train Acc: 0.75000, Val Acc: 0.56250
# Epoch: 012, Loss: 1.13875, Train Acc: 0.79167, Val Acc: 0.56250
# Epoch: 013, Loss: 1.13004, Train Acc: 0.76667, Val Acc: 0.55000
# Epoch: 014, Loss: 1.15068, Train Acc: 0.75833, Val Acc: 0.57500
# Epoch: 015, Loss: 1.13968, Train Acc: 0.76667, Val Acc: 0.57500
# Epoch: 016, Loss: 1.13001, Train Acc: 0.78333, Val Acc: 0.57500
# Epoch: 017, Loss: 1.14027, Train Acc: 0.76667, Val Acc: 0.57500
# Epoch: 018, Loss: 1.14031, Train Acc: 0.75833, Val Acc: 0.57500
# Epoch: 019, Loss: 1.11587, Train Acc: 0.79167, Val Acc: 0.57500
# Epoch: 020, Loss: 1.11867, Train Acc: 0.80000, Val Acc: 0.57500
# Epoch: 021, Loss: 1.13165, Train Acc: 0.77500, Val Acc: 0.57500
# Epoch: 022, Loss: 1.11592, Train Acc: 0.80833, Val Acc: 0.57500
# Epoch: 023, Loss: 1.15122, Train Acc: 0.74167, Val Acc: 0.58750
# Epoch: 024, Loss: 1.11956, Train Acc: 0.80000, Val Acc: 0.61250
# Epoch: 025, Loss: 1.12658, Train Acc: 0.78333, Val Acc: 0.60000
# Epoch: 026, Loss: 1.10910, Train Acc: 0.80000, Val Acc: 0.60000
# Epoch: 027, Loss: 1.12746, Train Acc: 0.77500, Val Acc: 0.60000
# Epoch: 028, Loss: 1.10935, Train Acc: 0.79167, Val Acc: 0.60000
# Epoch: 029, Loss: 1.11640, Train Acc: 0.79167, Val Acc: 0.61250
# Epoch: 030, Loss: 1.11881, Train Acc: 0.80833, Val Acc: 0.57500
# Epoch: 031, Loss: 1.10682, Train Acc: 0.80000, Val Acc: 0.56250
# Epoch: 032, Loss: 1.12640, Train Acc: 0.77500, Val Acc: 0.56250
# Epoch: 033, Loss: 1.10739, Train Acc: 0.80833, Val Acc: 0.57500
# Epoch: 034, Loss: 1.11037, Train Acc: 0.80000, Val Acc: 0.57500
# Epoch: 035, Loss: 1.11052, Train Acc: 0.80000, Val Acc: 0.57500
# Epoch: 036, Loss: 1.11633, Train Acc: 0.77500, Val Acc: 0.57500
# Epoch: 037, Loss: 1.11571, Train Acc: 0.80000, Val Acc: 0.57500
# Epoch: 038, Loss: 1.10430, Train Acc: 0.80833, Val Acc: 0.57500
# Epoch: 039, Loss: 1.11256, Train Acc: 0.79167, Val Acc: 0.60000
# Epoch: 040, Loss: 1.10999, Train Acc: 0.80833, Val Acc: 0.61250
# Epoch: 041, Loss: 1.11124, Train Acc: 0.80000, Val Acc: 0.61250
# Epoch: 042, Loss: 1.10545, Train Acc: 0.80000, Val Acc: 0.62500
# Epoch: 043, Loss: 1.10502, Train Acc: 0.79167, Val Acc: 0.62500
# Epoch: 044, Loss: 1.09864, Train Acc: 0.80833, Val Acc: 0.61250
# Epoch: 045, Loss: 1.12925, Train Acc: 0.78333, Val Acc: 0.61250
# Epoch: 046, Loss: 1.09890, Train Acc: 0.80833, Val Acc: 0.62500
# Epoch: 047, Loss: 1.11582, Train Acc: 0.80833, Val Acc: 0.60000
# Epoch: 048, Loss: 1.09616, Train Acc: 0.81667, Val Acc: 0.57500
# Epoch: 049, Loss: 1.11787, Train Acc: 0.80000, Val Acc: 0.57500
# Epoch: 050, Loss: 1.09127, Train Acc: 0.82500, Val Acc: 0.58750
# Epoch: 051, Loss: 1.09432, Train Acc: 0.81667, Val Acc: 0.58750
# Epoch: 052, Loss: 1.11156, Train Acc: 0.77500, Val Acc: 0.58750
# Epoch: 053, Loss: 1.11091, Train Acc: 0.77500, Val Acc: 0.57500
# Epoch: 054, Loss: 1.12277, Train Acc: 0.79167, Val Acc: 0.58750
# Epoch: 055, Loss: 1.13304, Train Acc: 0.79167, Val Acc: 0.58750
# Epoch: 056, Loss: 1.11139, Train Acc: 0.80000, Val Acc: 0.57500
# Epoch: 057, Loss: 1.12575, Train Acc: 0.76667, Val Acc: 0.57500
# Epoch: 058, Loss: 1.09134, Train Acc: 0.82500, Val Acc: 0.57500
# Epoch: 059, Loss: 1.11092, Train Acc: 0.79167, Val Acc: 0.57500
# Epoch: 060, Loss: 1.09846, Train Acc: 0.80833, Val Acc: 0.57500
# Epoch: 061, Loss: 1.12815, Train Acc: 0.79167, Val Acc: 0.57500
# Epoch: 062, Loss: 1.08512, Train Acc: 0.81667, Val Acc: 0.57500
# Epoch: 063, Loss: 1.10369, Train Acc: 0.81667, Val Acc: 0.58750
# Epoch: 064, Loss: 1.10126, Train Acc: 0.81667, Val Acc: 0.61250
# Epoch: 065, Loss: 1.08584, Train Acc: 0.84167, Val Acc: 0.61250
# Epoch: 066, Loss: 1.08891, Train Acc: 0.81667, Val Acc: 0.61250
# Epoch: 067, Loss: 1.06202, Train Acc: 0.84167, Val Acc: 0.61250
# Epoch: 068, Loss: 1.10667, Train Acc: 0.79167, Val Acc: 0.60000
# Epoch: 069, Loss: 1.10481, Train Acc: 0.80833, Val Acc: 0.61250
# Epoch: 070, Loss: 1.09516, Train Acc: 0.81667, Val Acc: 0.61250
# Epoch: 071, Loss: 1.11079, Train Acc: 0.80833, Val Acc: 0.60000
# Epoch: 072, Loss: 1.09231, Train Acc: 0.82500, Val Acc: 0.61250
# Epoch: 073, Loss: 1.08723, Train Acc: 0.80833, Val Acc: 0.61250
# Epoch: 074, Loss: 1.08998, Train Acc: 0.80833, Val Acc: 0.60000
# Epoch: 075, Loss: 1.07694, Train Acc: 0.82500, Val Acc: 0.60000
# Epoch: 076, Loss: 1.06493, Train Acc: 0.85833, Val Acc: 0.58750
# Epoch: 077, Loss: 1.10554, Train Acc: 0.80000, Val Acc: 0.58750
# Epoch: 078, Loss: 1.09473, Train Acc: 0.80833, Val Acc: 0.57500
# Epoch: 079, Loss: 1.07910, Train Acc: 0.83333, Val Acc: 0.58750
# Epoch: 080, Loss: 1.07951, Train Acc: 0.83333, Val Acc: 0.57500
# Epoch: 081, Loss: 1.08124, Train Acc: 0.82500, Val Acc: 0.57500
# Epoch: 082, Loss: 1.10011, Train Acc: 0.81667, Val Acc: 0.56250
# Epoch: 083, Loss: 1.08403, Train Acc: 0.81667, Val Acc: 0.56250
# Epoch: 084, Loss: 1.07702, Train Acc: 0.83333, Val Acc: 0.55000
# Epoch: 085, Loss: 1.10270, Train Acc: 0.80833, Val Acc: 0.55000
# Epoch: 086, Loss: 1.10019, Train Acc: 0.80833, Val Acc: 0.53750
# Epoch: 087, Loss: 1.11402, Train Acc: 0.80833, Val Acc: 0.53750
# Epoch: 088, Loss: 1.08143, Train Acc: 0.83333, Val Acc: 0.55000
# Epoch: 089, Loss: 1.07657, Train Acc: 0.84167, Val Acc: 0.57500
# Epoch: 090, Loss: 1.09020, Train Acc: 0.82500, Val Acc: 0.57500
# Epoch: 091, Loss: 1.06805, Train Acc: 0.85000, Val Acc: 0.57500
# Epoch: 092, Loss: 1.07926, Train Acc: 0.81667, Val Acc: 0.57500
# Epoch: 093, Loss: 1.07629, Train Acc: 0.84167, Val Acc: 0.57500
# Epoch: 094, Loss: 1.07609, Train Acc: 0.85000, Val Acc: 0.57500
# Epoch: 095, Loss: 1.09335, Train Acc: 0.81667, Val Acc: 0.58750
# Epoch: 096, Loss: 1.07784, Train Acc: 0.83333, Val Acc: 0.57500
# Epoch: 097, Loss: 1.06683, Train Acc: 0.85000, Val Acc: 0.58750
# Epoch: 098, Loss: 1.06885, Train Acc: 0.85833, Val Acc: 0.58750
# Epoch: 099, Loss: 1.08589, Train Acc: 0.82500, Val Acc: 0.60000
# Epoch: 100, Loss: 1.08851, Train Acc: 0.81667, Val Acc: 0.60000
# Test Accuracy: 0.62745
# Random State 4734510  in the iteration 5
# Epoch: 001, Loss: 1.27610, Train Acc: 0.64167, Val Acc: 0.73750
# Epoch: 002, Loss: 1.25141, Train Acc: 0.65833, Val Acc: 0.71250
# Epoch: 003, Loss: 1.23900, Train Acc: 0.65833, Val Acc: 0.70000
# Epoch: 004, Loss: 1.25541, Train Acc: 0.63333, Val Acc: 0.70000
# Epoch: 005, Loss: 1.24661, Train Acc: 0.65833, Val Acc: 0.71250
# Epoch: 006, Loss: 1.21627, Train Acc: 0.69167, Val Acc: 0.72500
# Epoch: 007, Loss: 1.21492, Train Acc: 0.69167, Val Acc: 0.72500
# Epoch: 008, Loss: 1.24483, Train Acc: 0.65000, Val Acc: 0.72500
# Epoch: 009, Loss: 1.23002, Train Acc: 0.65833, Val Acc: 0.72500
# Epoch: 010, Loss: 1.23470, Train Acc: 0.66667, Val Acc: 0.72500
# Epoch: 011, Loss: 1.20259, Train Acc: 0.70000, Val Acc: 0.73750
# Epoch: 012, Loss: 1.25006, Train Acc: 0.65000, Val Acc: 0.73750
# Epoch: 013, Loss: 1.21797, Train Acc: 0.67500, Val Acc: 0.73750
# Epoch: 014, Loss: 1.23662, Train Acc: 0.65833, Val Acc: 0.73750
# Epoch: 015, Loss: 1.20130, Train Acc: 0.69167, Val Acc: 0.73750
# Epoch: 016, Loss: 1.20366, Train Acc: 0.70833, Val Acc: 0.73750
# Epoch: 017, Loss: 1.19277, Train Acc: 0.71667, Val Acc: 0.73750
# Epoch: 018, Loss: 1.20900, Train Acc: 0.69167, Val Acc: 0.75000
# Epoch: 019, Loss: 1.18528, Train Acc: 0.71667, Val Acc: 0.75000
# Epoch: 020, Loss: 1.20200, Train Acc: 0.70000, Val Acc: 0.75000
# Epoch: 021, Loss: 1.17103, Train Acc: 0.73333, Val Acc: 0.75000
# Epoch: 022, Loss: 1.17088, Train Acc: 0.72500, Val Acc: 0.75000
# Epoch: 023, Loss: 1.19660, Train Acc: 0.70000, Val Acc: 0.75000
# Epoch: 024, Loss: 1.17916, Train Acc: 0.71667, Val Acc: 0.75000
# Epoch: 025, Loss: 1.15870, Train Acc: 0.75833, Val Acc: 0.75000
# Epoch: 026, Loss: 1.16880, Train Acc: 0.73333, Val Acc: 0.75000
# Epoch: 027, Loss: 1.17259, Train Acc: 0.72500, Val Acc: 0.75000
# Epoch: 028, Loss: 1.17780, Train Acc: 0.70000, Val Acc: 0.76250
# Epoch: 029, Loss: 1.15988, Train Acc: 0.75000, Val Acc: 0.76250
# Epoch: 030, Loss: 1.17187, Train Acc: 0.73333, Val Acc: 0.75000
# Epoch: 031, Loss: 1.15251, Train Acc: 0.76667, Val Acc: 0.75000
# Epoch: 032, Loss: 1.19201, Train Acc: 0.70833, Val Acc: 0.73750
# Epoch: 033, Loss: 1.20831, Train Acc: 0.71667, Val Acc: 0.73750
# Epoch: 034, Loss: 1.15955, Train Acc: 0.75000, Val Acc: 0.75000
# Epoch: 035, Loss: 1.14084, Train Acc: 0.78333, Val Acc: 0.75000
# Epoch: 036, Loss: 1.14841, Train Acc: 0.75833, Val Acc: 0.73750
# Epoch: 037, Loss: 1.16639, Train Acc: 0.72500, Val Acc: 0.73750
# Epoch: 038, Loss: 1.16591, Train Acc: 0.75000, Val Acc: 0.73750
# Epoch: 039, Loss: 1.16637, Train Acc: 0.75000, Val Acc: 0.73750
# Epoch: 040, Loss: 1.18952, Train Acc: 0.70833, Val Acc: 0.73750
# Epoch: 041, Loss: 1.17400, Train Acc: 0.74167, Val Acc: 0.73750
# Epoch: 042, Loss: 1.15032, Train Acc: 0.75000, Val Acc: 0.72500
# Epoch: 043, Loss: 1.14555, Train Acc: 0.78333, Val Acc: 0.72500
# Epoch: 044, Loss: 1.12932, Train Acc: 0.79167, Val Acc: 0.71250
# Epoch: 045, Loss: 1.19656, Train Acc: 0.70000, Val Acc: 0.71250
# Epoch: 046, Loss: 1.12274, Train Acc: 0.80000, Val Acc: 0.71250
# Epoch: 047, Loss: 1.15610, Train Acc: 0.75000, Val Acc: 0.71250
# Epoch: 048, Loss: 1.13430, Train Acc: 0.77500, Val Acc: 0.72500
# Epoch: 049, Loss: 1.16143, Train Acc: 0.75000, Val Acc: 0.75000
# Epoch: 050, Loss: 1.16176, Train Acc: 0.75000, Val Acc: 0.75000
# Epoch: 051, Loss: 1.14148, Train Acc: 0.78333, Val Acc: 0.75000
# Epoch: 052, Loss: 1.15831, Train Acc: 0.75000, Val Acc: 0.75000
# Epoch: 053, Loss: 1.14886, Train Acc: 0.76667, Val Acc: 0.75000
# Epoch: 054, Loss: 1.10887, Train Acc: 0.80833, Val Acc: 0.73750
# Epoch: 055, Loss: 1.16002, Train Acc: 0.75000, Val Acc: 0.75000
# Epoch: 056, Loss: 1.11309, Train Acc: 0.80000, Val Acc: 0.75000
# Epoch: 057, Loss: 1.15428, Train Acc: 0.75000, Val Acc: 0.75000
# Epoch: 058, Loss: 1.14247, Train Acc: 0.75833, Val Acc: 0.75000
# Epoch: 059, Loss: 1.13170, Train Acc: 0.78333, Val Acc: 0.76250
# Epoch: 060, Loss: 1.17106, Train Acc: 0.71667, Val Acc: 0.76250
# Epoch: 061, Loss: 1.11951, Train Acc: 0.79167, Val Acc: 0.76250
# Epoch: 062, Loss: 1.14620, Train Acc: 0.76667, Val Acc: 0.76250
# Epoch: 063, Loss: 1.14208, Train Acc: 0.75833, Val Acc: 0.76250
# Epoch: 064, Loss: 1.15024, Train Acc: 0.75833, Val Acc: 0.76250
# Epoch: 065, Loss: 1.11532, Train Acc: 0.80000, Val Acc: 0.77500
# Epoch: 066, Loss: 1.09876, Train Acc: 0.82500, Val Acc: 0.76250
# Epoch: 067, Loss: 1.11834, Train Acc: 0.80000, Val Acc: 0.76250
# Epoch: 068, Loss: 1.16960, Train Acc: 0.71667, Val Acc: 0.76250
# Epoch: 069, Loss: 1.11809, Train Acc: 0.79167, Val Acc: 0.76250
# Epoch: 070, Loss: 1.11810, Train Acc: 0.79167, Val Acc: 0.76250
# Epoch: 071, Loss: 1.12998, Train Acc: 0.78333, Val Acc: 0.76250
# Epoch: 072, Loss: 1.11847, Train Acc: 0.80000, Val Acc: 0.76250
# Epoch: 073, Loss: 1.12355, Train Acc: 0.78333, Val Acc: 0.76250
# Epoch: 074, Loss: 1.11810, Train Acc: 0.79167, Val Acc: 0.76250
# Epoch: 075, Loss: 1.12734, Train Acc: 0.79167, Val Acc: 0.75000
# Epoch: 076, Loss: 1.11169, Train Acc: 0.80833, Val Acc: 0.75000
# Epoch: 077, Loss: 1.11700, Train Acc: 0.79167, Val Acc: 0.75000
# Epoch: 078, Loss: 1.11232, Train Acc: 0.79167, Val Acc: 0.75000
# Epoch: 079, Loss: 1.10476, Train Acc: 0.80833, Val Acc: 0.75000
# Epoch: 080, Loss: 1.08916, Train Acc: 0.81667, Val Acc: 0.75000
# Epoch: 081, Loss: 1.13941, Train Acc: 0.79167, Val Acc: 0.75000
# Epoch: 082, Loss: 1.07755, Train Acc: 0.85833, Val Acc: 0.75000
# Epoch: 083, Loss: 1.08929, Train Acc: 0.83333, Val Acc: 0.75000
# Epoch: 084, Loss: 1.09750, Train Acc: 0.83333, Val Acc: 0.75000
# Epoch: 085, Loss: 1.08366, Train Acc: 0.84167, Val Acc: 0.75000
# Epoch: 086, Loss: 1.08292, Train Acc: 0.84167, Val Acc: 0.75000
# Epoch: 087, Loss: 1.09442, Train Acc: 0.80833, Val Acc: 0.75000
# Epoch: 088, Loss: 1.10418, Train Acc: 0.80000, Val Acc: 0.75000
# Epoch: 089, Loss: 1.11307, Train Acc: 0.82500, Val Acc: 0.75000
# Epoch: 090, Loss: 1.09735, Train Acc: 0.82500, Val Acc: 0.75000
# Epoch: 091, Loss: 1.11670, Train Acc: 0.80833, Val Acc: 0.75000
# Epoch: 092, Loss: 1.08819, Train Acc: 0.82500, Val Acc: 0.75000
# Epoch: 093, Loss: 1.09342, Train Acc: 0.82500, Val Acc: 0.75000
# Epoch: 094, Loss: 1.09203, Train Acc: 0.82500, Val Acc: 0.75000
# Epoch: 095, Loss: 1.07636, Train Acc: 0.82500, Val Acc: 0.75000
# Epoch: 096, Loss: 1.07692, Train Acc: 0.83333, Val Acc: 0.76250
# Epoch: 097, Loss: 1.09255, Train Acc: 0.81667, Val Acc: 0.76250
# Epoch: 098, Loss: 1.09935, Train Acc: 0.80833, Val Acc: 0.76250
# Epoch: 099, Loss: 1.10964, Train Acc: 0.80000, Val Acc: 0.76250
# Epoch: 100, Loss: 1.08907, Train Acc: 0.83333, Val Acc: 0.75000
# Test Accuracy: 0.76471
# Random State 654321  in the iteration 6
# Epoch: 001, Loss: 1.22942, Train Acc: 0.68333, Val Acc: 0.72500
# Epoch: 002, Loss: 1.23310, Train Acc: 0.66667, Val Acc: 0.67500
# Epoch: 003, Loss: 1.22364, Train Acc: 0.67500, Val Acc: 0.67500
# Epoch: 004, Loss: 1.22808, Train Acc: 0.68333, Val Acc: 0.72500
# Epoch: 005, Loss: 1.18684, Train Acc: 0.72500, Val Acc: 0.71250
# Epoch: 006, Loss: 1.21904, Train Acc: 0.68333, Val Acc: 0.72500
# Epoch: 007, Loss: 1.16000, Train Acc: 0.76667, Val Acc: 0.72500
# Epoch: 008, Loss: 1.19278, Train Acc: 0.70833, Val Acc: 0.70000
# Epoch: 009, Loss: 1.18410, Train Acc: 0.73333, Val Acc: 0.70000
# Epoch: 010, Loss: 1.16055, Train Acc: 0.75833, Val Acc: 0.71250
# Epoch: 011, Loss: 1.18057, Train Acc: 0.74167, Val Acc: 0.68750
# Epoch: 012, Loss: 1.16750, Train Acc: 0.74167, Val Acc: 0.67500
# Epoch: 013, Loss: 1.18901, Train Acc: 0.70000, Val Acc: 0.67500
# Epoch: 014, Loss: 1.17151, Train Acc: 0.74167, Val Acc: 0.68750
# Epoch: 015, Loss: 1.15258, Train Acc: 0.75833, Val Acc: 0.68750
# Epoch: 016, Loss: 1.16127, Train Acc: 0.76667, Val Acc: 0.68750
# Epoch: 017, Loss: 1.14872, Train Acc: 0.74167, Val Acc: 0.68750
# Epoch: 018, Loss: 1.16246, Train Acc: 0.75000, Val Acc: 0.68750
# Epoch: 019, Loss: 1.14307, Train Acc: 0.76667, Val Acc: 0.67500
# Epoch: 020, Loss: 1.16065, Train Acc: 0.74167, Val Acc: 0.67500
# Epoch: 021, Loss: 1.12877, Train Acc: 0.79167, Val Acc: 0.67500
# Epoch: 022, Loss: 1.14697, Train Acc: 0.76667, Val Acc: 0.67500
# Epoch: 023, Loss: 1.17509, Train Acc: 0.72500, Val Acc: 0.66250
# Epoch: 024, Loss: 1.15249, Train Acc: 0.75000, Val Acc: 0.66250
# Epoch: 025, Loss: 1.12986, Train Acc: 0.78333, Val Acc: 0.67500
# Epoch: 026, Loss: 1.12219, Train Acc: 0.80000, Val Acc: 0.67500
# Epoch: 027, Loss: 1.16758, Train Acc: 0.71667, Val Acc: 0.67500
# Epoch: 028, Loss: 1.11895, Train Acc: 0.80000, Val Acc: 0.67500
# Epoch: 029, Loss: 1.16068, Train Acc: 0.74167, Val Acc: 0.67500
# Epoch: 030, Loss: 1.11788, Train Acc: 0.79167, Val Acc: 0.68750
# Epoch: 031, Loss: 1.14191, Train Acc: 0.78333, Val Acc: 0.68750
# Epoch: 032, Loss: 1.13365, Train Acc: 0.77500, Val Acc: 0.68750
# Epoch: 033, Loss: 1.12184, Train Acc: 0.77500, Val Acc: 0.68750
# Epoch: 034, Loss: 1.14966, Train Acc: 0.73333, Val Acc: 0.68750
# Epoch: 035, Loss: 1.12722, Train Acc: 0.78333, Val Acc: 0.68750
# Epoch: 036, Loss: 1.13553, Train Acc: 0.76667, Val Acc: 0.68750
# Epoch: 037, Loss: 1.13158, Train Acc: 0.80000, Val Acc: 0.68750
# Epoch: 038, Loss: 1.15513, Train Acc: 0.77500, Val Acc: 0.68750
# Epoch: 039, Loss: 1.14433, Train Acc: 0.77500, Val Acc: 0.68750
# Epoch: 040, Loss: 1.13035, Train Acc: 0.77500, Val Acc: 0.68750
# Epoch: 041, Loss: 1.11644, Train Acc: 0.79167, Val Acc: 0.67500
# Epoch: 042, Loss: 1.09895, Train Acc: 0.80000, Val Acc: 0.68750
# Epoch: 043, Loss: 1.12229, Train Acc: 0.80833, Val Acc: 0.68750
# Epoch: 044, Loss: 1.11669, Train Acc: 0.79167, Val Acc: 0.68750
# Epoch: 045, Loss: 1.13199, Train Acc: 0.79167, Val Acc: 0.70000
# Epoch: 046, Loss: 1.11889, Train Acc: 0.78333, Val Acc: 0.70000
# Epoch: 047, Loss: 1.12470, Train Acc: 0.78333, Val Acc: 0.70000
# Epoch: 048, Loss: 1.09138, Train Acc: 0.82500, Val Acc: 0.70000
# Epoch: 049, Loss: 1.09028, Train Acc: 0.84167, Val Acc: 0.70000
# Epoch: 050, Loss: 1.15093, Train Acc: 0.79167, Val Acc: 0.68750
# Epoch: 051, Loss: 1.11301, Train Acc: 0.80833, Val Acc: 0.68750
# Epoch: 052, Loss: 1.09755, Train Acc: 0.83333, Val Acc: 0.68750
# Epoch: 053, Loss: 1.12518, Train Acc: 0.79167, Val Acc: 0.68750
# Epoch: 054, Loss: 1.11291, Train Acc: 0.81667, Val Acc: 0.70000
# Epoch: 055, Loss: 1.11433, Train Acc: 0.78333, Val Acc: 0.70000
# Epoch: 056, Loss: 1.12546, Train Acc: 0.78333, Val Acc: 0.70000
# Epoch: 057, Loss: 1.11967, Train Acc: 0.79167, Val Acc: 0.68750
# Epoch: 058, Loss: 1.12685, Train Acc: 0.80000, Val Acc: 0.67500
# Epoch: 059, Loss: 1.13407, Train Acc: 0.80833, Val Acc: 0.68750
# Epoch: 060, Loss: 1.12661, Train Acc: 0.80000, Val Acc: 0.67500
# Epoch: 061, Loss: 1.08980, Train Acc: 0.83333, Val Acc: 0.68750
# Epoch: 062, Loss: 1.13192, Train Acc: 0.78333, Val Acc: 0.68750
# Epoch: 063, Loss: 1.13588, Train Acc: 0.78333, Val Acc: 0.68750
# Epoch: 064, Loss: 1.10173, Train Acc: 0.80833, Val Acc: 0.67500
# Epoch: 065, Loss: 1.10703, Train Acc: 0.82500, Val Acc: 0.66250
# Epoch: 066, Loss: 1.10886, Train Acc: 0.80833, Val Acc: 0.67500
# Epoch: 067, Loss: 1.06890, Train Acc: 0.85833, Val Acc: 0.67500
# Epoch: 068, Loss: 1.08351, Train Acc: 0.84167, Val Acc: 0.67500
# Epoch: 069, Loss: 1.10950, Train Acc: 0.80000, Val Acc: 0.67500
# Epoch: 070, Loss: 1.09753, Train Acc: 0.80000, Val Acc: 0.66250
# Epoch: 071, Loss: 1.11074, Train Acc: 0.80833, Val Acc: 0.66250
# Epoch: 072, Loss: 1.08002, Train Acc: 0.83333, Val Acc: 0.66250
# Epoch: 073, Loss: 1.11809, Train Acc: 0.80833, Val Acc: 0.67500
# Epoch: 074, Loss: 1.08146, Train Acc: 0.85000, Val Acc: 0.67500
# Epoch: 075, Loss: 1.10894, Train Acc: 0.80833, Val Acc: 0.66250
# Epoch: 076, Loss: 1.11139, Train Acc: 0.79167, Val Acc: 0.66250
# Epoch: 077, Loss: 1.10011, Train Acc: 0.80000, Val Acc: 0.65000
# Epoch: 078, Loss: 1.09933, Train Acc: 0.80000, Val Acc: 0.65000
# Epoch: 079, Loss: 1.09941, Train Acc: 0.80833, Val Acc: 0.65000
# Epoch: 080, Loss: 1.08607, Train Acc: 0.84167, Val Acc: 0.66250
# Epoch: 081, Loss: 1.11120, Train Acc: 0.81667, Val Acc: 0.66250
# Epoch: 082, Loss: 1.14175, Train Acc: 0.76667, Val Acc: 0.67500
# Epoch: 083, Loss: 1.08068, Train Acc: 0.84167, Val Acc: 0.67500
# Epoch: 084, Loss: 1.13113, Train Acc: 0.80000, Val Acc: 0.66250
# Epoch: 085, Loss: 1.11818, Train Acc: 0.78333, Val Acc: 0.66250
# Epoch: 086, Loss: 1.13151, Train Acc: 0.77500, Val Acc: 0.66250
# Epoch: 087, Loss: 1.10020, Train Acc: 0.81667, Val Acc: 0.66250
# Epoch: 088, Loss: 1.09896, Train Acc: 0.82500, Val Acc: 0.65000
# Epoch: 089, Loss: 1.10286, Train Acc: 0.80833, Val Acc: 0.63750
# Epoch: 090, Loss: 1.09946, Train Acc: 0.80833, Val Acc: 0.63750
# Epoch: 091, Loss: 1.10540, Train Acc: 0.80000, Val Acc: 0.63750
# Epoch: 092, Loss: 1.09229, Train Acc: 0.83333, Val Acc: 0.63750
# Epoch: 093, Loss: 1.12511, Train Acc: 0.76667, Val Acc: 0.65000
# Epoch: 094, Loss: 1.12630, Train Acc: 0.79167, Val Acc: 0.65000
# Epoch: 095, Loss: 1.08252, Train Acc: 0.83333, Val Acc: 0.66250
# Epoch: 096, Loss: 1.09118, Train Acc: 0.83333, Val Acc: 0.67500
# Epoch: 097, Loss: 1.08457, Train Acc: 0.83333, Val Acc: 0.67500
# Epoch: 098, Loss: 1.09788, Train Acc: 0.80000, Val Acc: 0.67500
# Epoch: 099, Loss: 1.13171, Train Acc: 0.79167, Val Acc: 0.68750
# Epoch: 100, Loss: 1.09486, Train Acc: 0.86667, Val Acc: 0.68750
# Test Accuracy: 0.82353
# Random State 124321  in the iteration 7
# Epoch: 001, Loss: 1.27627, Train Acc: 0.62500, Val Acc: 0.77500
# Epoch: 002, Loss: 1.23091, Train Acc: 0.67500, Val Acc: 0.77500
# Epoch: 003, Loss: 1.24017, Train Acc: 0.65833, Val Acc: 0.77500
# Epoch: 004, Loss: 1.18793, Train Acc: 0.71667, Val Acc: 0.77500
# Epoch: 005, Loss: 1.22248, Train Acc: 0.67500, Val Acc: 0.76250
# Epoch: 006, Loss: 1.19336, Train Acc: 0.71667, Val Acc: 0.76250
# Epoch: 007, Loss: 1.21297, Train Acc: 0.70833, Val Acc: 0.77500
# Epoch: 008, Loss: 1.28481, Train Acc: 0.63333, Val Acc: 0.77500
# Epoch: 009, Loss: 1.21457, Train Acc: 0.69167, Val Acc: 0.77500
# Epoch: 010, Loss: 1.24031, Train Acc: 0.65833, Val Acc: 0.78750
# Epoch: 011, Loss: 1.20495, Train Acc: 0.69167, Val Acc: 0.77500
# Epoch: 012, Loss: 1.23567, Train Acc: 0.67500, Val Acc: 0.77500
# Epoch: 013, Loss: 1.22777, Train Acc: 0.66667, Val Acc: 0.77500
# Epoch: 014, Loss: 1.20522, Train Acc: 0.69167, Val Acc: 0.77500
# Epoch: 015, Loss: 1.20998, Train Acc: 0.67500, Val Acc: 0.77500
# Epoch: 016, Loss: 1.20289, Train Acc: 0.69167, Val Acc: 0.77500
# Epoch: 017, Loss: 1.26853, Train Acc: 0.62500, Val Acc: 0.77500
# Epoch: 018, Loss: 1.21063, Train Acc: 0.71667, Val Acc: 0.77500
# Epoch: 019, Loss: 1.18879, Train Acc: 0.73333, Val Acc: 0.77500
# Epoch: 020, Loss: 1.17453, Train Acc: 0.71667, Val Acc: 0.77500
# Epoch: 021, Loss: 1.17172, Train Acc: 0.74167, Val Acc: 0.77500
# Epoch: 022, Loss: 1.17387, Train Acc: 0.75000, Val Acc: 0.76250
# Epoch: 023, Loss: 1.18285, Train Acc: 0.72500, Val Acc: 0.76250
# Epoch: 024, Loss: 1.18184, Train Acc: 0.71667, Val Acc: 0.76250
# Epoch: 025, Loss: 1.17609, Train Acc: 0.74167, Val Acc: 0.76250
# Epoch: 026, Loss: 1.16697, Train Acc: 0.74167, Val Acc: 0.77500
# Epoch: 027, Loss: 1.19292, Train Acc: 0.70000, Val Acc: 0.77500
# Epoch: 028, Loss: 1.14939, Train Acc: 0.75000, Val Acc: 0.77500
# Epoch: 029, Loss: 1.13307, Train Acc: 0.78333, Val Acc: 0.78750
# Epoch: 030, Loss: 1.15774, Train Acc: 0.75000, Val Acc: 0.80000
# Epoch: 031, Loss: 1.17087, Train Acc: 0.73333, Val Acc: 0.80000
# Epoch: 032, Loss: 1.15573, Train Acc: 0.75000, Val Acc: 0.81250
# Epoch: 033, Loss: 1.15712, Train Acc: 0.75833, Val Acc: 0.81250
# Epoch: 034, Loss: 1.21265, Train Acc: 0.68333, Val Acc: 0.81250
# Epoch: 035, Loss: 1.15884, Train Acc: 0.75833, Val Acc: 0.81250
# Epoch: 036, Loss: 1.18030, Train Acc: 0.74167, Val Acc: 0.77500
# Epoch: 037, Loss: 1.17184, Train Acc: 0.73333, Val Acc: 0.77500
# Epoch: 038, Loss: 1.15938, Train Acc: 0.74167, Val Acc: 0.77500
# Epoch: 039, Loss: 1.17936, Train Acc: 0.72500, Val Acc: 0.76250
# Epoch: 040, Loss: 1.15000, Train Acc: 0.75833, Val Acc: 0.75000
# Epoch: 041, Loss: 1.20369, Train Acc: 0.69167, Val Acc: 0.75000
# Epoch: 042, Loss: 1.15179, Train Acc: 0.75833, Val Acc: 0.75000
# Epoch: 043, Loss: 1.14585, Train Acc: 0.75000, Val Acc: 0.76250
# Epoch: 044, Loss: 1.17461, Train Acc: 0.72500, Val Acc: 0.76250
# Epoch: 045, Loss: 1.15671, Train Acc: 0.75000, Val Acc: 0.77500
# Epoch: 046, Loss: 1.12314, Train Acc: 0.79167, Val Acc: 0.77500
# Epoch: 047, Loss: 1.12643, Train Acc: 0.77500, Val Acc: 0.77500
# Epoch: 048, Loss: 1.15270, Train Acc: 0.76667, Val Acc: 0.77500
# Epoch: 049, Loss: 1.13388, Train Acc: 0.77500, Val Acc: 0.77500
# Epoch: 050, Loss: 1.14933, Train Acc: 0.77500, Val Acc: 0.77500
# Epoch: 051, Loss: 1.12913, Train Acc: 0.78333, Val Acc: 0.76250
# Epoch: 052, Loss: 1.11574, Train Acc: 0.79167, Val Acc: 0.76250
# Epoch: 053, Loss: 1.13869, Train Acc: 0.77500, Val Acc: 0.77500
# Epoch: 054, Loss: 1.15477, Train Acc: 0.76667, Val Acc: 0.77500
# Epoch: 055, Loss: 1.13060, Train Acc: 0.77500, Val Acc: 0.77500
# Epoch: 056, Loss: 1.14159, Train Acc: 0.76667, Val Acc: 0.77500
# Epoch: 057, Loss: 1.16282, Train Acc: 0.74167, Val Acc: 0.77500
# Epoch: 058, Loss: 1.14372, Train Acc: 0.77500, Val Acc: 0.77500
# Epoch: 059, Loss: 1.14678, Train Acc: 0.75833, Val Acc: 0.77500
# Epoch: 060, Loss: 1.12469, Train Acc: 0.78333, Val Acc: 0.78750
# Epoch: 061, Loss: 1.14003, Train Acc: 0.77500, Val Acc: 0.78750
# Epoch: 062, Loss: 1.14973, Train Acc: 0.77500, Val Acc: 0.78750
# Epoch: 063, Loss: 1.15622, Train Acc: 0.76667, Val Acc: 0.78750
# Epoch: 064, Loss: 1.15139, Train Acc: 0.75833, Val Acc: 0.78750
# Epoch: 065, Loss: 1.14942, Train Acc: 0.76667, Val Acc: 0.78750
# Epoch: 066, Loss: 1.15751, Train Acc: 0.75833, Val Acc: 0.78750
# Epoch: 067, Loss: 1.15313, Train Acc: 0.75000, Val Acc: 0.77500
# Epoch: 068, Loss: 1.15420, Train Acc: 0.75000, Val Acc: 0.77500
# Epoch: 069, Loss: 1.12755, Train Acc: 0.79167, Val Acc: 0.77500
# Epoch: 070, Loss: 1.12777, Train Acc: 0.78333, Val Acc: 0.77500
# Epoch: 071, Loss: 1.13370, Train Acc: 0.78333, Val Acc: 0.77500
# Epoch: 072, Loss: 1.16172, Train Acc: 0.73333, Val Acc: 0.77500
# Epoch: 073, Loss: 1.11742, Train Acc: 0.80000, Val Acc: 0.77500
# Epoch: 074, Loss: 1.15916, Train Acc: 0.75000, Val Acc: 0.77500
# Epoch: 075, Loss: 1.11852, Train Acc: 0.80000, Val Acc: 0.77500
# Epoch: 076, Loss: 1.12759, Train Acc: 0.78333, Val Acc: 0.77500
# Epoch: 077, Loss: 1.14223, Train Acc: 0.76667, Val Acc: 0.77500
# Epoch: 078, Loss: 1.13607, Train Acc: 0.76667, Val Acc: 0.77500
# Epoch: 079, Loss: 1.14414, Train Acc: 0.78333, Val Acc: 0.77500
# Epoch: 080, Loss: 1.15023, Train Acc: 0.76667, Val Acc: 0.76250
# Epoch: 081, Loss: 1.14186, Train Acc: 0.75833, Val Acc: 0.76250
# Epoch: 082, Loss: 1.12111, Train Acc: 0.80000, Val Acc: 0.76250
# Epoch: 083, Loss: 1.11745, Train Acc: 0.79167, Val Acc: 0.76250
# Epoch: 084, Loss: 1.13034, Train Acc: 0.76667, Val Acc: 0.76250
# Epoch: 085, Loss: 1.12726, Train Acc: 0.80000, Val Acc: 0.76250
# Epoch: 086, Loss: 1.12163, Train Acc: 0.80000, Val Acc: 0.76250
# Epoch: 087, Loss: 1.11839, Train Acc: 0.80000, Val Acc: 0.76250
# Epoch: 088, Loss: 1.11464, Train Acc: 0.79167, Val Acc: 0.76250
# Epoch: 089, Loss: 1.13203, Train Acc: 0.79167, Val Acc: 0.76250
# Epoch: 090, Loss: 1.13215, Train Acc: 0.78333, Val Acc: 0.76250
# Epoch: 091, Loss: 1.12793, Train Acc: 0.78333, Val Acc: 0.76250
# Epoch: 092, Loss: 1.14576, Train Acc: 0.77500, Val Acc: 0.76250
# Epoch: 093, Loss: 1.13544, Train Acc: 0.76667, Val Acc: 0.76250
# Epoch: 094, Loss: 1.13750, Train Acc: 0.79167, Val Acc: 0.76250
# Epoch: 095, Loss: 1.14816, Train Acc: 0.76667, Val Acc: 0.76250
# Epoch: 096, Loss: 1.12361, Train Acc: 0.78333, Val Acc: 0.75000
# Epoch: 097, Loss: 1.11378, Train Acc: 0.80833, Val Acc: 0.75000
# Epoch: 098, Loss: 1.15663, Train Acc: 0.74167, Val Acc: 0.75000
# Epoch: 099, Loss: 1.13807, Train Acc: 0.78333, Val Acc: 0.75000
# Epoch: 100, Loss: 1.14830, Train Acc: 0.78333, Val Acc: 0.75000
# Test Accuracy: 0.68627
# Random State 945321  in the iteration 8
# Epoch: 001, Loss: 1.22976, Train Acc: 0.66667, Val Acc: 0.78750
# Epoch: 002, Loss: 1.18626, Train Acc: 0.72500, Val Acc: 0.77500
# Epoch: 003, Loss: 1.19116, Train Acc: 0.70833, Val Acc: 0.78750
# Epoch: 004, Loss: 1.20918, Train Acc: 0.69167, Val Acc: 0.78750
# Epoch: 005, Loss: 1.18557, Train Acc: 0.71667, Val Acc: 0.77500
# Epoch: 006, Loss: 1.15776, Train Acc: 0.75000, Val Acc: 0.78750
# Epoch: 007, Loss: 1.15276, Train Acc: 0.75833, Val Acc: 0.78750
# Epoch: 008, Loss: 1.15739, Train Acc: 0.76667, Val Acc: 0.77500
# Epoch: 009, Loss: 1.18120, Train Acc: 0.72500, Val Acc: 0.77500
# Epoch: 010, Loss: 1.15071, Train Acc: 0.76667, Val Acc: 0.78750
# Epoch: 011, Loss: 1.16675, Train Acc: 0.75833, Val Acc: 0.77500
# Epoch: 012, Loss: 1.17582, Train Acc: 0.72500, Val Acc: 0.78750
# Epoch: 013, Loss: 1.15115, Train Acc: 0.76667, Val Acc: 0.78750
# Epoch: 014, Loss: 1.16903, Train Acc: 0.75000, Val Acc: 0.78750
# Epoch: 015, Loss: 1.13436, Train Acc: 0.77500, Val Acc: 0.78750
# Epoch: 016, Loss: 1.11961, Train Acc: 0.79167, Val Acc: 0.77500
# Epoch: 017, Loss: 1.12089, Train Acc: 0.80000, Val Acc: 0.77500
# Epoch: 018, Loss: 1.10884, Train Acc: 0.81667, Val Acc: 0.77500
# Epoch: 019, Loss: 1.12069, Train Acc: 0.79167, Val Acc: 0.77500
# Epoch: 020, Loss: 1.13000, Train Acc: 0.79167, Val Acc: 0.77500
# Epoch: 021, Loss: 1.11367, Train Acc: 0.80833, Val Acc: 0.77500
# Epoch: 022, Loss: 1.11234, Train Acc: 0.78333, Val Acc: 0.77500
# Epoch: 023, Loss: 1.10959, Train Acc: 0.81667, Val Acc: 0.77500
# Epoch: 024, Loss: 1.10849, Train Acc: 0.79167, Val Acc: 0.77500
# Epoch: 025, Loss: 1.11127, Train Acc: 0.80000, Val Acc: 0.77500
# Epoch: 026, Loss: 1.10805, Train Acc: 0.81667, Val Acc: 0.77500
# Epoch: 027, Loss: 1.12291, Train Acc: 0.80000, Val Acc: 0.78750
# Epoch: 028, Loss: 1.11324, Train Acc: 0.79167, Val Acc: 0.77500
# Epoch: 029, Loss: 1.11538, Train Acc: 0.80833, Val Acc: 0.77500
# Epoch: 030, Loss: 1.12582, Train Acc: 0.77500, Val Acc: 0.78750
# Epoch: 031, Loss: 1.10115, Train Acc: 0.81667, Val Acc: 0.78750
# Epoch: 032, Loss: 1.10615, Train Acc: 0.82500, Val Acc: 0.78750
# Epoch: 033, Loss: 1.08595, Train Acc: 0.82500, Val Acc: 0.80000
# Epoch: 034, Loss: 1.12087, Train Acc: 0.77500, Val Acc: 0.77500
# Epoch: 035, Loss: 1.10402, Train Acc: 0.80000, Val Acc: 0.76250
# Epoch: 036, Loss: 1.08766, Train Acc: 0.82500, Val Acc: 0.75000
# Epoch: 037, Loss: 1.10449, Train Acc: 0.80833, Val Acc: 0.76250
# Epoch: 038, Loss: 1.10380, Train Acc: 0.81667, Val Acc: 0.76250
# Epoch: 039, Loss: 1.10945, Train Acc: 0.79167, Val Acc: 0.76250
# Epoch: 040, Loss: 1.12852, Train Acc: 0.78333, Val Acc: 0.76250
# Epoch: 041, Loss: 1.11308, Train Acc: 0.79167, Val Acc: 0.76250
# Epoch: 042, Loss: 1.11162, Train Acc: 0.80000, Val Acc: 0.76250
# Epoch: 043, Loss: 1.07912, Train Acc: 0.82500, Val Acc: 0.76250
# Epoch: 044, Loss: 1.08908, Train Acc: 0.82500, Val Acc: 0.77500
# Epoch: 045, Loss: 1.09114, Train Acc: 0.81667, Val Acc: 0.77500
# Epoch: 046, Loss: 1.09009, Train Acc: 0.82500, Val Acc: 0.77500
# Epoch: 047, Loss: 1.11221, Train Acc: 0.78333, Val Acc: 0.77500
# Epoch: 048, Loss: 1.07545, Train Acc: 0.85000, Val Acc: 0.77500
# Epoch: 049, Loss: 1.07674, Train Acc: 0.83333, Val Acc: 0.77500
# Epoch: 050, Loss: 1.07673, Train Acc: 0.84167, Val Acc: 0.78750
# Epoch: 051, Loss: 1.08858, Train Acc: 0.82500, Val Acc: 0.77500
# Epoch: 052, Loss: 1.09019, Train Acc: 0.81667, Val Acc: 0.78750
# Epoch: 053, Loss: 1.08932, Train Acc: 0.82500, Val Acc: 0.78750
# ...
# Epoch: 054, Loss: 1.11457, Train Acc: 0.79167, Val Acc: 0.81250
# Epoch: 055, Loss: 1.10392, Train Acc: 0.79167, Val Acc: 0.81250
# Epoch: 056, Loss: 1.10711, Train Acc: 0.79167, Val Acc: 0.81250
# Epoch: 057, Loss: 1.10587, Train Acc: 0.80833, Val Acc: 0.81250
# Epoch: 058, Loss: 1.07146, Train Acc: 0.83333, Val Acc: 0.81250
# Epoch: 059, Loss: 1.09565, Train Acc: 0.81667, Val Acc: 0.81250
# Epoch: 060, Loss: 1.08731, Train Acc: 0.82500, Val Acc: 0.78750
# Epoch: 061, Loss: 1.10646, Train Acc: 0.80000, Val Acc: 0.78750
# Epoch: 062, Loss: 1.10574, Train Acc: 0.80833, Val Acc: 0.78750
# Epoch: 063, Loss: 1.06312, Train Acc: 0.85000, Val Acc: 0.78750
# Epoch: 064, Loss: 1.10640, Train Acc: 0.80000, Val Acc: 0.80000
# Epoch: 065, Loss: 1.09899, Train Acc: 0.81667, Val Acc: 0.80000
# Epoch: 066, Loss: 1.11723, Train Acc: 0.79167, Val Acc: 0.80000
# Epoch: 067, Loss: 1.06680, Train Acc: 0.84167, Val Acc: 0.80000
# Epoch: 068, Loss: 1.09112, Train Acc: 0.80833, Val Acc: 0.80000
# Epoch: 069, Loss: 1.08729, Train Acc: 0.81667, Val Acc: 0.78750
# Epoch: 070, Loss: 1.12105, Train Acc: 0.78333, Val Acc: 0.80000
# Epoch: 071, Loss: 1.11104, Train Acc: 0.80000, Val Acc: 0.80000
# Epoch: 072, Loss: 1.08609, Train Acc: 0.82500, Val Acc: 0.80000
# Epoch: 073, Loss: 1.11322, Train Acc: 0.79167, Val Acc: 0.80000
# Epoch: 074, Loss: 1.10057, Train Acc: 0.80833, Val Acc: 0.80000
# Epoch: 075, Loss: 1.13318, Train Acc: 0.77500, Val Acc: 0.80000
# Epoch: 076, Loss: 1.05737, Train Acc: 0.85000, Val Acc: 0.80000
# Epoch: 077, Loss: 1.06675, Train Acc: 0.84167, Val Acc: 0.80000
# Epoch: 078, Loss: 1.08800, Train Acc: 0.80833, Val Acc: 0.80000
# Epoch: 079, Loss: 1.12050, Train Acc: 0.77500, Val Acc: 0.80000
# Epoch: 080, Loss: 1.10997, Train Acc: 0.79167, Val Acc: 0.81250
# Epoch: 081, Loss: 1.08482, Train Acc: 0.81667, Val Acc: 0.81250
# Epoch: 082, Loss: 1.09076, Train Acc: 0.81667, Val Acc: 0.80000
# Epoch: 083, Loss: 1.09352, Train Acc: 0.81667, Val Acc: 0.80000
# Epoch: 084, Loss: 1.06147, Train Acc: 0.84167, Val Acc: 0.81250
# Epoch: 085, Loss: 1.12974, Train Acc: 0.75833, Val Acc: 0.80000
# Epoch: 086, Loss: 1.09121, Train Acc: 0.80833, Val Acc: 0.80000
# Epoch: 087, Loss: 1.09851, Train Acc: 0.79167, Val Acc: 0.80000
# Epoch: 088, Loss: 1.07332, Train Acc: 0.84167, Val Acc: 0.80000
# Epoch: 089, Loss: 1.07665, Train Acc: 0.83333, Val Acc: 0.78750
# Epoch: 090, Loss: 1.07146, Train Acc: 0.83333, Val Acc: 0.77500
# Epoch: 091, Loss: 1.08127, Train Acc: 0.82500, Val Acc: 0.80000
# Epoch: 092, Loss: 1.09586, Train Acc: 0.80000, Val Acc: 0.80000
# Epoch: 093, Loss: 1.06854, Train Acc: 0.85000, Val Acc: 0.78750
# Epoch: 094, Loss: 1.09922, Train Acc: 0.80833, Val Acc: 0.78750
# Epoch: 095, Loss: 1.08551, Train Acc: 0.82500, Val Acc: 0.78750
# Epoch: 096, Loss: 1.05982, Train Acc: 0.85000, Val Acc: 0.78750
# Epoch: 097, Loss: 1.09238, Train Acc: 0.80833, Val Acc: 0.78750
# Epoch: 098, Loss: 1.07327, Train Acc: 0.82500, Val Acc: 0.78750
# Epoch: 099, Loss: 1.09112, Train Acc: 0.80833, Val Acc: 0.78750
# Epoch: 100, Loss: 1.09408, Train Acc: 0.82500, Val Acc: 0.76250
# Test Accuracy: 0.74510
# Random State 945321  in the iteration 8
# Epoch: 001, Loss: 1.14033, Train Acc: 0.76667, Val Acc: 0.83750
# Epoch: 002, Loss: 1.14433, Train Acc: 0.76667, Val Acc: 0.88750
# Epoch: 003, Loss: 1.13930, Train Acc: 0.75000, Val Acc: 0.87500
# Epoch: 004, Loss: 1.11143, Train Acc: 0.80000, Val Acc: 0.88750
# Epoch: 005, Loss: 1.09516, Train Acc: 0.80000, Val Acc: 0.88750
# Epoch: 006, Loss: 1.11386, Train Acc: 0.79167, Val Acc: 0.88750
# Epoch: 007, Loss: 1.12148, Train Acc: 0.78333, Val Acc: 0.86250
# Epoch: 008, Loss: 1.10612, Train Acc: 0.80000, Val Acc: 0.86250
# Epoch: 009, Loss: 1.09898, Train Acc: 0.81667, Val Acc: 0.86250
# Epoch: 010, Loss: 1.08448, Train Acc: 0.82500, Val Acc: 0.86250
# Epoch: 011, Loss: 1.07175, Train Acc: 0.84167, Val Acc: 0.86250
# Epoch: 012, Loss: 1.10485, Train Acc: 0.80000, Val Acc: 0.86250
# Epoch: 013, Loss: 1.08616, Train Acc: 0.82500, Val Acc: 0.86250
# Epoch: 014, Loss: 1.08228, Train Acc: 0.82500, Val Acc: 0.85000
# Epoch: 015, Loss: 1.07458, Train Acc: 0.84167, Val Acc: 0.85000
# Epoch: 016, Loss: 1.11612, Train Acc: 0.79167, Val Acc: 0.85000
# Epoch: 017, Loss: 1.06633, Train Acc: 0.84167, Val Acc: 0.85000
# Epoch: 018, Loss: 1.07975, Train Acc: 0.82500, Val Acc: 0.85000
# Epoch: 019, Loss: 1.10530, Train Acc: 0.80000, Val Acc: 0.83750
# Epoch: 020, Loss: 1.10514, Train Acc: 0.80833, Val Acc: 0.83750
# Epoch: 021, Loss: 1.11081, Train Acc: 0.77500, Val Acc: 0.83750
# Epoch: 022, Loss: 1.11166, Train Acc: 0.79167, Val Acc: 0.83750
# Epoch: 023, Loss: 1.07321, Train Acc: 0.81667, Val Acc: 0.85000
# Epoch: 024, Loss: 1.07314, Train Acc: 0.83333, Val Acc: 0.86250
# Epoch: 025, Loss: 1.09635, Train Acc: 0.81667, Val Acc: 0.86250
# Epoch: 026, Loss: 1.08991, Train Acc: 0.82500, Val Acc: 0.86250
# Epoch: 027, Loss: 1.07303, Train Acc: 0.82500, Val Acc: 0.87500
# Epoch: 028, Loss: 1.09413, Train Acc: 0.81667, Val Acc: 0.87500
# Epoch: 029, Loss: 1.04671, Train Acc: 0.86667, Val Acc: 0.86250
# Epoch: 030, Loss: 1.05726, Train Acc: 0.85833, Val Acc: 0.86250
# Epoch: 031, Loss: 1.08899, Train Acc: 0.83333, Val Acc: 0.85000
# Epoch: 032, Loss: 1.05238, Train Acc: 0.85000, Val Acc: 0.83750
# Epoch: 033, Loss: 1.05099, Train Acc: 0.85833, Val Acc: 0.83750
# Epoch: 034, Loss: 1.07020, Train Acc: 0.85000, Val Acc: 0.82500
# Epoch: 035, Loss: 1.07680, Train Acc: 0.81667, Val Acc: 0.82500
# Epoch: 036, Loss: 1.08722, Train Acc: 0.81667, Val Acc: 0.81250
# Epoch: 037, Loss: 1.10511, Train Acc: 0.78333, Val Acc: 0.81250
# Epoch: 038, Loss: 1.05380, Train Acc: 0.85000, Val Acc: 0.80000
# Epoch: 039, Loss: 1.06631, Train Acc: 0.84167, Val Acc: 0.80000
# Epoch: 040, Loss: 1.05498, Train Acc: 0.85833, Val Acc: 0.80000
# Epoch: 041, Loss: 1.08544, Train Acc: 0.81667, Val Acc: 0.78750
# Epoch: 042, Loss: 1.09284, Train Acc: 0.80000, Val Acc: 0.78750
# Epoch: 043, Loss: 1.07198, Train Acc: 0.83333, Val Acc: 0.78750
# Epoch: 044, Loss: 1.05688, Train Acc: 0.85000, Val Acc: 0.78750
# Epoch: 045, Loss: 1.07219, Train Acc: 0.84167, Val Acc: 0.78750
# Epoch: 046, Loss: 1.11228, Train Acc: 0.80000, Val Acc: 0.78750
# Epoch: 047, Loss: 1.07217, Train Acc: 0.84167, Val Acc: 0.78750
# Epoch: 048, Loss: 1.04834, Train Acc: 0.85833, Val Acc: 0.78750
# Epoch: 049, Loss: 1.09978, Train Acc: 0.80833, Val Acc: 0.78750
# Epoch: 050, Loss: 1.08353, Train Acc: 0.81667, Val Acc: 0.80000
# Epoch: 051, Loss: 1.07630, Train Acc: 0.83333, Val Acc: 0.80000
# Epoch: 052, Loss: 1.08254, Train Acc: 0.83333, Val Acc: 0.81250
# Epoch: 053, Loss: 1.08581, Train Acc: 0.81667, Val Acc: 0.81250
# Epoch: 054, Loss: 1.06528, Train Acc: 0.84167, Val Acc: 0.81250
# Epoch: 055, Loss: 1.03157, Train Acc: 0.87500, Val Acc: 0.81250
# Epoch: 056, Loss: 1.05858, Train Acc: 0.85000, Val Acc: 0.81250
# Epoch: 057, Loss: 1.09276, Train Acc: 0.80833, Val Acc: 0.81250
# Epoch: 058, Loss: 1.08068, Train Acc: 0.83333, Val Acc: 0.81250
# Epoch: 059, Loss: 1.10439, Train Acc: 0.78333, Val Acc: 0.82500
# Epoch: 060, Loss: 1.06062, Train Acc: 0.85000, Val Acc: 0.82500
# Epoch: 061, Loss: 1.03926, Train Acc: 0.86667, Val Acc: 0.81250
# Epoch: 062, Loss: 1.08783, Train Acc: 0.80833, Val Acc: 0.82500
# Epoch: 063, Loss: 1.05272, Train Acc: 0.85833, Val Acc: 0.82500
# Epoch: 064, Loss: 1.10433, Train Acc: 0.79167, Val Acc: 0.82500
# Epoch: 065, Loss: 1.07100, Train Acc: 0.83333, Val Acc: 0.82500
# Epoch: 066, Loss: 1.05079, Train Acc: 0.85000, Val Acc: 0.82500
# Epoch: 067, Loss: 1.07066, Train Acc: 0.84167, Val Acc: 0.82500
# Epoch: 068, Loss: 1.07846, Train Acc: 0.81667, Val Acc: 0.82500
# Epoch: 069, Loss: 1.09728, Train Acc: 0.80833, Val Acc: 0.82500
# Epoch: 070, Loss: 1.05457, Train Acc: 0.85833, Val Acc: 0.82500
# Epoch: 071, Loss: 1.07635, Train Acc: 0.82500, Val Acc: 0.83750
# Epoch: 072, Loss: 1.06395, Train Acc: 0.84167, Val Acc: 0.85000
# Epoch: 073, Loss: 1.08370, Train Acc: 0.81667, Val Acc: 0.85000
# Epoch: 074, Loss: 1.08919, Train Acc: 0.82500, Val Acc: 0.85000
# Epoch: 075, Loss: 1.07889, Train Acc: 0.82500, Val Acc: 0.85000
# Epoch: 076, Loss: 1.07275, Train Acc: 0.85000, Val Acc: 0.86250
# Epoch: 077, Loss: 1.06401, Train Acc: 0.84167, Val Acc: 0.85000
# Epoch: 078, Loss: 1.08273, Train Acc: 0.82500, Val Acc: 0.85000
# Epoch: 079, Loss: 1.04853, Train Acc: 0.85833, Val Acc: 0.85000
# Epoch: 080, Loss: 1.09185, Train Acc: 0.81667, Val Acc: 0.83750
# Epoch: 081, Loss: 1.07551, Train Acc: 0.83333, Val Acc: 0.83750
# Epoch: 082, Loss: 1.05857, Train Acc: 0.84167, Val Acc: 0.83750
# Epoch: 083, Loss: 1.09907, Train Acc: 0.80833, Val Acc: 0.83750
# Epoch: 084, Loss: 1.05482, Train Acc: 0.85000, Val Acc: 0.85000
# Epoch: 085, Loss: 1.06448, Train Acc: 0.84167, Val Acc: 0.86250
# Epoch: 086, Loss: 1.04292, Train Acc: 0.85833, Val Acc: 0.86250
# Epoch: 087, Loss: 1.09100, Train Acc: 0.80000, Val Acc: 0.86250
# Epoch: 088, Loss: 1.06363, Train Acc: 0.83333, Val Acc: 0.86250
# Epoch: 089, Loss: 1.03787, Train Acc: 0.87500, Val Acc: 0.87500
# Epoch: 090, Loss: 1.08493, Train Acc: 0.82500, Val Acc: 0.87500
# Epoch: 091, Loss: 1.05780, Train Acc: 0.85833, Val Acc: 0.87500
# Epoch: 092, Loss: 1.07122, Train Acc: 0.83333, Val Acc: 0.85000
# Epoch: 093, Loss: 1.08839, Train Acc: 0.81667, Val Acc: 0.83750
# Epoch: 094, Loss: 1.07699, Train Acc: 0.84167, Val Acc: 0.82500
# Epoch: 095, Loss: 1.08590, Train Acc: 0.83333, Val Acc: 0.82500
# Epoch: 096, Loss: 1.05377, Train Acc: 0.85000, Val Acc: 0.82500
# Epoch: 097, Loss: 1.04172, Train Acc: 0.86667, Val Acc: 0.83750
# Epoch: 098, Loss: 1.08718, Train Acc: 0.81667, Val Acc: 0.82500
# Epoch: 099, Loss: 1.07225, Train Acc: 0.84167, Val Acc: 0.82500
# Epoch: 100, Loss: 1.06591, Train Acc: 0.84167, Val Acc: 0.82500
# Test Accuracy: 0.80392
# Random State 784328  in the iteration 9
# Epoch: 001, Loss: 1.18862, Train Acc: 0.74167, Val Acc: 0.86250
# Epoch: 002, Loss: 1.17648, Train Acc: 0.73333, Val Acc: 0.87500
# Epoch: 003, Loss: 1.18081, Train Acc: 0.71667, Val Acc: 0.86250
# Epoch: 004, Loss: 1.16834, Train Acc: 0.75000, Val Acc: 0.86250
# Epoch: 005, Loss: 1.15587, Train Acc: 0.74167, Val Acc: 0.86250
# Epoch: 006, Loss: 1.15133, Train Acc: 0.75833, Val Acc: 0.86250
# Epoch: 007, Loss: 1.12243, Train Acc: 0.79167, Val Acc: 0.87500
# Epoch: 008, Loss: 1.12885, Train Acc: 0.77500, Val Acc: 0.87500
# Epoch: 009, Loss: 1.18053, Train Acc: 0.74167, Val Acc: 0.87500
# Epoch: 010, Loss: 1.12419, Train Acc: 0.77500, Val Acc: 0.85000
# Epoch: 011, Loss: 1.09642, Train Acc: 0.81667, Val Acc: 0.85000
# Epoch: 012, Loss: 1.13890, Train Acc: 0.77500, Val Acc: 0.85000
# Epoch: 013, Loss: 1.15433, Train Acc: 0.76667, Val Acc: 0.85000
# Epoch: 014, Loss: 1.10878, Train Acc: 0.81667, Val Acc: 0.83750
# Epoch: 015, Loss: 1.13672, Train Acc: 0.78333, Val Acc: 0.83750
# Epoch: 016, Loss: 1.16047, Train Acc: 0.75000, Val Acc: 0.83750
# Epoch: 017, Loss: 1.14337, Train Acc: 0.77500, Val Acc: 0.83750
# Epoch: 018, Loss: 1.12560, Train Acc: 0.80000, Val Acc: 0.85000
# Epoch: 019, Loss: 1.14064, Train Acc: 0.76667, Val Acc: 0.85000
# Epoch: 020, Loss: 1.13341, Train Acc: 0.78333, Val Acc: 0.85000
# Epoch: 021, Loss: 1.10663, Train Acc: 0.80000, Val Acc: 0.85000
# Epoch: 022, Loss: 1.13411, Train Acc: 0.79167, Val Acc: 0.85000
# Epoch: 023, Loss: 1.12407, Train Acc: 0.79167, Val Acc: 0.85000
# Epoch: 024, Loss: 1.16117, Train Acc: 0.73333, Val Acc: 0.83750
# Epoch: 025, Loss: 1.11630, Train Acc: 0.80833, Val Acc: 0.83750
# Epoch: 026, Loss: 1.15871, Train Acc: 0.76667, Val Acc: 0.83750
# Epoch: 027, Loss: 1.11060, Train Acc: 0.80833, Val Acc: 0.82500
# Epoch: 028, Loss: 1.12608, Train Acc: 0.79167, Val Acc: 0.82500
# Epoch: 029, Loss: 1.09387, Train Acc: 0.82500, Val Acc: 0.83750
# Epoch: 030, Loss: 1.13412, Train Acc: 0.78333, Val Acc: 0.83750
# Epoch: 031, Loss: 1.14414, Train Acc: 0.75833, Val Acc: 0.83750
# Epoch: 032, Loss: 1.15965, Train Acc: 0.74167, Val Acc: 0.83750
# Epoch: 033, Loss: 1.13512, Train Acc: 0.78333, Val Acc: 0.83750
# Epoch: 034, Loss: 1.08618, Train Acc: 0.83333, Val Acc: 0.85000
# Epoch: 035, Loss: 1.14431, Train Acc: 0.75833, Val Acc: 0.86250
# Epoch: 036, Loss: 1.11981, Train Acc: 0.80000, Val Acc: 0.85000
# Epoch: 037, Loss: 1.09557, Train Acc: 0.82500, Val Acc: 0.85000
# Epoch: 038, Loss: 1.15466, Train Acc: 0.75000, Val Acc: 0.85000
# Epoch: 039, Loss: 1.09693, Train Acc: 0.82500, Val Acc: 0.85000
# Epoch: 040, Loss: 1.13720, Train Acc: 0.75833, Val Acc: 0.85000
# Epoch: 041, Loss: 1.11782, Train Acc: 0.79167, Val Acc: 0.85000
# Epoch: 042, Loss: 1.08515, Train Acc: 0.82500, Val Acc: 0.85000
# Epoch: 043, Loss: 1.09557, Train Acc: 0.82500, Val Acc: 0.85000
# Epoch: 044, Loss: 1.12521, Train Acc: 0.78333, Val Acc: 0.85000
# Epoch: 045, Loss: 1.11433, Train Acc: 0.79167, Val Acc: 0.85000
# Epoch: 046, Loss: 1.09207, Train Acc: 0.81667, Val Acc: 0.85000
# Epoch: 047, Loss: 1.11556, Train Acc: 0.80000, Val Acc: 0.85000
# Epoch: 048, Loss: 1.11830, Train Acc: 0.78333, Val Acc: 0.86250
# Epoch: 049, Loss: 1.13868, Train Acc: 0.76667, Val Acc: 0.86250
# Epoch: 050, Loss: 1.12777, Train Acc: 0.78333, Val Acc: 0.85000
# Epoch: 051, Loss: 1.11171, Train Acc: 0.80000, Val Acc: 0.85000
# Epoch: 052, Loss: 1.08280, Train Acc: 0.82500, Val Acc: 0.83750
# Epoch: 053, Loss: 1.09101, Train Acc: 0.82500, Val Acc: 0.83750
# Epoch: 054, Loss: 1.10532, Train Acc: 0.80833, Val Acc: 0.83750
# Epoch: 055, Loss: 1.09685, Train Acc: 0.80833, Val Acc: 0.85000
# Epoch: 056, Loss: 1.12319, Train Acc: 0.77500, Val Acc: 0.83750
# Epoch: 057, Loss: 1.11802, Train Acc: 0.79167, Val Acc: 0.83750
# Epoch: 058, Loss: 1.12078, Train Acc: 0.79167, Val Acc: 0.83750
# Epoch: 059, Loss: 1.13820, Train Acc: 0.77500, Val Acc: 0.83750
# Epoch: 060, Loss: 1.10599, Train Acc: 0.80000, Val Acc: 0.83750
# Epoch: 061, Loss: 1.12793, Train Acc: 0.76667, Val Acc: 0.83750
# Epoch: 062, Loss: 1.10682, Train Acc: 0.80000, Val Acc: 0.83750
# Epoch: 063, Loss: 1.10328, Train Acc: 0.81667, Val Acc: 0.85000
# Epoch: 064, Loss: 1.11803, Train Acc: 0.79167, Val Acc: 0.85000
# Epoch: 065, Loss: 1.10184, Train Acc: 0.80000, Val Acc: 0.85000
# Epoch: 066, Loss: 1.10826, Train Acc: 0.80833, Val Acc: 0.85000
# Epoch: 067, Loss: 1.09833, Train Acc: 0.81667, Val Acc: 0.85000
# Epoch: 068, Loss: 1.09425, Train Acc: 0.83333, Val Acc: 0.83750
# Epoch: 069, Loss: 1.10141, Train Acc: 0.80833, Val Acc: 0.83750
# Epoch: 070, Loss: 1.12848, Train Acc: 0.77500, Val Acc: 0.83750
# Epoch: 071, Loss: 1.09774, Train Acc: 0.80833, Val Acc: 0.85000
# Epoch: 072, Loss: 1.09032, Train Acc: 0.82500, Val Acc: 0.85000
# Epoch: 073, Loss: 1.10508, Train Acc: 0.80000, Val Acc: 0.85000
# Epoch: 074, Loss: 1.12366, Train Acc: 0.78333, Val Acc: 0.85000
# Epoch: 075, Loss: 1.11797, Train Acc: 0.78333, Val Acc: 0.87500
# Epoch: 076, Loss: 1.08432, Train Acc: 0.81667, Val Acc: 0.87500
# Epoch: 077, Loss: 1.11930, Train Acc: 0.80833, Val Acc: 0.87500
# Epoch: 078, Loss: 1.13025, Train Acc: 0.76667, Val Acc: 0.87500
# Epoch: 079, Loss: 1.08697, Train Acc: 0.82500, Val Acc: 0.87500
# Epoch: 080, Loss: 1.09195, Train Acc: 0.82500, Val Acc: 0.87500
# Epoch: 081, Loss: 1.10753, Train Acc: 0.80833, Val Acc: 0.87500
# Epoch: 082, Loss: 1.10301, Train Acc: 0.81667, Val Acc: 0.86250
# Epoch: 083, Loss: 1.10625, Train Acc: 0.80833, Val Acc: 0.86250
# Epoch: 084, Loss: 1.11386, Train Acc: 0.79167, Val Acc: 0.86250
# Epoch: 085, Loss: 1.09404, Train Acc: 0.82500, Val Acc: 0.86250
# Epoch: 086, Loss: 1.14451, Train Acc: 0.76667, Val Acc: 0.85000
# Epoch: 087, Loss: 1.08151, Train Acc: 0.83333, Val Acc: 0.85000
# Epoch: 088, Loss: 1.11133, Train Acc: 0.80000, Val Acc: 0.83750
# Epoch: 089, Loss: 1.09322, Train Acc: 0.80833, Val Acc: 0.83750
# Epoch: 090, Loss: 1.10421, Train Acc: 0.79167, Val Acc: 0.83750
# Epoch: 091, Loss: 1.09097, Train Acc: 0.80833, Val Acc: 0.83750
# Epoch: 092, Loss: 1.07866, Train Acc: 0.82500, Val Acc: 0.83750
# Epoch: 093, Loss: 1.09897, Train Acc: 0.81667, Val Acc: 0.83750
# Epoch: 094, Loss: 1.10005, Train Acc: 0.80000, Val Acc: 0.82500
# Epoch: 095, Loss: 1.11170, Train Acc: 0.78333, Val Acc: 0.83750
# Epoch: 096, Loss: 1.08715, Train Acc: 0.82500, Val Acc: 0.81250
# Epoch: 097, Loss: 1.06808, Train Acc: 0.85000, Val Acc: 0.82500
# Epoch: 098, Loss: 1.12188, Train Acc: 0.78333, Val Acc: 0.81250
# Epoch: 099, Loss: 1.08169, Train Acc: 0.83333, Val Acc: 0.83750
# Epoch: 100, Loss: 1.08841, Train Acc: 0.80833, Val Acc: 0.83750
# Test Accuracy: 0.74510
# GAT
# 76.07843137254902 +- 7.481876089544673

# %% [markdown]
# #### Visualize the results and the embedding

# %%
fig,axs = plt.subplots(1,2,figsize=(20,8))
axs[0].set_title('GCN boxplot of 10 runs')
axs[0].boxplot(global_results,labels=['GCN','MLP', 'SAGE', 'Cheb', 'GAT'])
axs[0].set_xlabel('Run')
axs[0].set_ylabel('Accuracy')

axs[1].set_title('Models lineplot of 10 runs')
axs[1].plot(range(1,11),global_results[0],'ro',color='red')
axs[1].plot(range(1,11),global_results[0],color='red',label='GCN')

axs[1].plot(range(1,11),global_results[1],'ro',color='blue')
axs[1].plot(range(1,11),global_results[1],color='blue',label='MLP')

axs[1].plot(range(1,11),global_results[2],'ro',color='green')
axs[1].plot(range(1,11),global_results[2],color='green',label='SAGE')

axs[1].plot(range(1,11),global_results[3],'ro',color='k')
axs[1].plot(range(1,11),global_results[3],color='k',label='Cheb')

axs[1].plot(range(1,11),global_results[4],'ro',color='violet')
axs[1].plot(range(1,11),global_results[4],color='violet',label='GAT')

axs[1].set_xticks(range(1,11))
axs[1].set_xlabel('Run')
axs[1].set_ylabel('Accuracy')
axs[1].legend()
fig.show()

# %%
from sklearn.manifold import TSNE
# Let's see the embedding of the best model over the 10 runs

'''
    Arguments of TSNE:
        * n_components: The dimension of the embedded space.
        * random_state: The seed to use for the t-SNE algorithm.
    Returns:
        * tsne_obj: The t-SNE embedding of the nodes.
'''

# GCN
out_gcn = global_best_models[0][0](data.x, data.edge_index) # Get the output of the model with the entire dataset
tsne = TSNE(n_components=2, random_state=12345)
tsne_gcn_results = tsne.fit_transform(out_gcn.detach().cpu().numpy())
# SAGE
out_sage = global_best_models[2][0](data.x, data.edge_index) # Get the output of the model with the entire dataset
tsne = TSNE(n_components=2, random_state=12345)
tsne_sage_results = tsne.fit_transform(out_sage.detach().cpu().numpy())
# Cheb
out_cheb = global_best_models[3][0](data.x, data.edge_index) # Get the output of the model with the entire dataset
tsne = TSNE(n_components=2, random_state=12345)
tsne_cheb_results = tsne.fit_transform(out_cheb.detach().cpu().numpy())
# GAT
out_gat = global_best_models[4][0](data.x, data.edge_index) # Get the output of the model with the entire dataset
tsne = TSNE(n_components=2, random_state=12345)
tsne_gat_results = tsne.fit_transform(out_gat.detach().cpu().numpy())
# MLP
out_mlp = global_best_models[1][0](data.x, data.edge_index) # Get the output of the model with the entire dataset
tsne = TSNE(n_components=2, random_state=12345)
tsne_mlp_results = tsne.fit_transform(out_mlp.detach().cpu().numpy())
# Plot the results
fig,axs = plt.subplots(3,2,figsize=(20,10))
axs[0,0].set_title('GCN t-SNE')
axs[0,0].scatter(tsne_gcn_results[:,0],tsne_gcn_results[:,1],c=data.y.cpu(),cmap='viridis',s=60,alpha=0.85,edgecolors='black',linewidths=0.5)

axs[0,1].set_title('MLP t-SNE')
axs[0,1].scatter(tsne_mlp_results[:,0],tsne_mlp_results[:,1],c=data.y.cpu(),cmap='viridis',s=60,alpha=0.85,edgecolors='black',linewidths=0.5)

axs[1,0].set_title('SAGE t-SNE')
axs[1,0].scatter(tsne_sage_results[:,0],tsne_sage_results[:,1],c=data.y.cpu(),cmap='viridis',s=60,alpha=0.85,edgecolors='black',linewidths=0.5)

axs[1,1].set_title('Cheb t-SNE')
axs[1,1].scatter(tsne_cheb_results[:,0],tsne_cheb_results[:,1],c=data.y.cpu(),cmap='viridis',s=60,alpha=0.85,edgecolors='black',linewidths=0.5)

axs[2,0].set_title('GAT t-SNE')
axs[2,0].scatter(tsne_gat_results[:,0],tsne_gat_results[:,1],c=data.y.cpu(),cmap='viridis',s=60,alpha=0.85,edgecolors='black',linewidths=0.5)

fig.suptitle('t-SNE of the best model over the 10 runs',fontsize=20)
fig.show()

# %% [markdown]
# ### 3.1 Report

# %% [markdown]
# In this section we will report the results of the model. We will report the accuracy, precision, recall and F1 score for the model. We will also visualize the confusion matrix for the model using the scikit-learn library to report the results. After all, we will put the results in a markdown cell.

# %% [markdown]
# #### Report the results

# %%
# Report the best model over the 10 runs using the test set and sklearn classification report
from sklearn.metrics import classification_report
print('GCN')
print(classification_report(data.y[test_mask].cpu(), global_best_models[0][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy()))
print('========================================================================')
print('MLP')
print(classification_report(data.y[test_mask].cpu(), global_best_models[1][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy()))
print('SAGE')
print(classification_report(data.y[test_mask].cpu(), global_best_models[2][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy()))
print('========================================================================')
print('Cheb')
print(classification_report(data.y[test_mask].cpu(), global_best_models[3][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy()))
print('========================================================================')
print('GAT')
print(classification_report(data.y[test_mask].cpu(), global_best_models[4][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy()))
print('========================================================================')
# Out:
# GCN
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.45      0.88      0.60        16
#            2       0.83      0.40      0.54        25
#            3       0.33      0.12      0.18         8
#            4       0.33      0.50      0.40         2
#
#     accuracy                           0.51        51
#    macro avg       0.39      0.38      0.34        51
# weighted avg       0.62      0.51      0.50        51
#
# ========================================================================
# MLP
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        16
#            2       0.96      1.00      0.98        25
#            3       1.00      0.88      0.93         8
#            4       1.00      1.00      1.00         2
#
#     accuracy                           0.98        51
#    macro avg       0.99      0.97      0.98        51
# weighted avg       0.98      0.98      0.98        51
#
# SAGE
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        16
#            2       1.00      1.00      1.00        25
#            3       0.89      1.00      0.94         8
#            4       1.00      0.50      0.67         2
#
#     accuracy                           0.98        51
#    macro avg       0.97      0.88      0.90        51
# weighted avg       0.98      0.98      0.98        51
#
# ========================================================================
# Cheb
#               precision    recall  f1-score   support
#
#            1       0.82      0.88      0.85        16
#            2       0.85      0.88      0.86        25
#            3       0.71      0.62      0.67         8
#            4       1.00      0.50      0.67         2
#
#     accuracy                           0.82        51
#    macro avg       0.85      0.72      0.76        51
# weighted avg       0.82      0.82      0.82        51
#
# ========================================================================
# GAT
#               precision    recall  f1-score   support
#
#            1       0.45      0.31      0.37        16
#            2       0.66      0.84      0.74        25
#            3       0.62      0.62      0.62         8
#            4       0.00      0.00      0.00         2
#
#     accuracy                           0.61        51
#    macro avg       0.43      0.44      0.43        51
# weighted avg       0.56      0.61      0.58        51
#
# ========================================================================

# %% [markdown]
# #### Confusion matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Crear las matrices de confusión
conf_matrix_gcn = confusion_matrix(data.y[test_mask].cpu(), global_best_models[0][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy())
conf_matrix_mlp = confusion_matrix(data.y[test_mask].cpu(), global_best_models[1][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy())
conf_matrix_sage = confusion_matrix(data.y[test_mask].cpu(), global_best_models[2][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy())
conf_matrix_cheb = confusion_matrix(data.y[test_mask].cpu(), global_best_models[3][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy())
conf_matrix_gat = confusion_matrix(data.y[test_mask].cpu(), global_best_models[4][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy())

# Crear los displays de las matrices de confusión
disp_gcn = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_gcn, display_labels=data.y.unique().cpu().numpy())
disp_mlp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_mlp, display_labels=data.y.unique().cpu().numpy())
disp_sage = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_sage, display_labels=data.y.unique().cpu().numpy())
disp_cheb = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_cheb, display_labels=data.y.unique().cpu().numpy())
disp_gat = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_gat, display_labels=data.y.unique().cpu().numpy())

# Crear la figura y los ejes
fig, axs = plt.subplots(3, 2, figsize=(20, 15))

# Plotear las matrices de confusión
disp_gcn.plot(ax=axs[0][0])
disp_gcn.ax_.set_title('GCN Confusion Matrix')
disp_gcn.im_.colorbar.remove()

#disp_mlp.plot(ax=axs[0][1])
#disp_mlp.ax_.set_title('MLP Confusion Matrix')
#disp_mlp.im_.colorbar.remove()

disp_sage.plot(ax=axs[1][0])
disp_sage.ax_.set_title('SAGE Confusion Matrix')
disp_sage.im_.colorbar.remove()

disp_cheb.plot(ax=axs[1][1])
disp_cheb.ax_.set_title('Cheb Confusion Matrix')
disp_cheb.im_.colorbar.remove()

# Colocar la última matriz en la posición central de la tercera fila
disp_gat.plot(ax=axs[2][0])
disp_gat.ax_.set_title('GAT Confusion Matrix')
disp_gat.im_.colorbar.remove()

# Eliminar el subplot vacío
fig.delaxes(axs[2][1])

# Ajustar el diseño
fig.tight_layout(rect=[0, 0, 1, 0.95])
fig.suptitle('Confusion Matrix of the best model over the 10 runs', fontsize=20)

# Mostrar la figura
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-26b29f961195> in <cell line: 34>()
#      32 disp_sage.im_.colorbar.remove()
#      33
# ---> 34 disp_cheb.plot(ax=axs[1][1])
#      35 disp_cheb.ax_.set_title('Cheb Confusion Matrix')
#      36 disp_cheb.im_.colorbar.remove()
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_plot/confusion_matrix.py in plot(self, include_values, cmap, xticks_rotation, values_format, ax, colorbar, im_kw, text_kw)
#     179         if colorbar:
#     180             fig.colorbar(self.im_, ax=ax)
# --> 181         ax.set(
#     182             xticks=np.arange(n_classes),
#     183             yticks=np.arange(n_classes),
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in <lambda>(self, **kwargs)
#     145             return
#     146
# --> 147         cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     148         cls.set.__name__ = "set"
#     149         cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in set(self, **kwargs)
#    1229         # Artist._update_set_signature_and_docstring() at the end of the
#    1230         # module.
# -> 1231         return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#    1232
#    1233     @contextlib.contextmanager
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in _internal_update(self, kwargs)
#    1221         The lack of prenormalization is to maintain backcompatibility.
#    1222         """
# -> 1223         return self._update_props(
#    1224             kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1225             "{prop_name!r}")
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in _update_props(self, props, errfmt)
#    1197                         raise AttributeError(
#    1198                             errfmt.format(cls=type(self), prop_name=k))
# -> 1199                     ret.append(func(v))
#    1200         if ret:
#    1201             self.pchanged()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      72
#      73         def wrapper(self, *args, **kwargs):
# ---> 74             return get_method(self)(*args, **kwargs)
#      75
#      76         wrapper.__module__ = owner.__module__
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     295                 f"for the old name will be dropped %(removal)s.")
#     296             kwargs[new] = kwargs.pop(old)
# --> 297         return func(*args, **kwargs)
#     298
#     299     # wrapper() must keep the same documented signature as func(): if we
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    1967             # remove all tick labels, so only error for > 0 labels
#    1968             if len(locator.locs) != len(labels) and len(labels) != 0:
# -> 1969                 raise ValueError(
#    1970                     "The number of FixedLocator locations"
#    1971                     f" ({len(locator.locs)}), usually from a call to"
#
# ValueError: The number of FixedLocator locations (4), usually from a call to set_ticks, does not match the number of labels (5).
