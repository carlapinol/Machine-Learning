# %% [markdown]
# # Node classification practice

# %%
#Libraries we are going to use
# Install required packages.
import os
import torch #Library for deep learning
os.environ['TORCH'] = torch.__version__
print(torch.__version__)

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git
COLLAB_ENV = True
if COLLAB_ENV:
    # !pip install 'scipy>=1.8'
    # !pip install mycolorpy
import numpy as np #Library for linear algebra
import matplotlib.pyplot as plt #Library for plotting
import networkx as nx #Library for graph
from torch_geometric.datasets import Planetoid,WebKB, Actor #Library for graph dataset and deep learning on graphs
from torch_geometric.utils import to_dense_adj
import warnings
warnings.filterwarnings("ignore") # Get rid of warnings
# Out:
# 2.2.1+cu121
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 12.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 12.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for torch-geometric (pyproject.toml) ... done
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.10/dist-packages (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy>=1.8) (1.25.2)
# Collecting mycolorpy
#   Downloading mycolorpy-1.5.1.tar.gz (2.5 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mycolorpy) (1.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mycolorpy) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mycolorpy) (1.16.0)
# Building wheels for collected packages: mycolorpy
#   Building wheel for mycolorpy (setup.py) ... done
#   Created wheel for mycolorpy: filename=mycolorpy-1.5.1-py3-none-any.whl size=3851 sha256=2e547a8f847b5d91dca70affb0de2e7494145cd52779f83b6fa2e313252881da
#   Stored in directory: /root/.cache/pip/wheels/d6/1d/04/f8bfb8b04e3daba330b3f377c041b89304271ff98fb6704946
# Successfully built mycolorpy
# Installing collected packages: mycolorpy
# Successfully installed mycolorpy-1.5.1

# %% [markdown]
# ### 1. Load data and visualize it

# %%
'''
    Load the dataset:
        * root: The root directory where the dataset should be saved.
        * name: The name of the dataset (cora, citeseer or pubmed).
        * transform: A function/transform that takes in an Data object of the dataset and returns a transformed version. The data object will be transformed before every access.
    Returns:
        * Dataset object
'''
data_Cora = Planetoid(root='/tmp/Cora', name='Cora') # Load the Cora dataset (homogeneous)
dataset = data_Cora
data = dataset[0] # Get the first graph object (in this case is only one graph, while in Graph classification there are multiple graphs)
print()
print(f'Dataset: {dataset}:')
print('======================')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.num_classes}')
print()
print(data) # Note that the adjacency matrix is not stored explicitly but in the edge_index attribute.
            # The edge_index attribute is a 2 x E tensor, with each column denoting an edge.
            # The first row denotes the source nodes and the second row the destination nodes of the edges.
            # The nodes are numbered consecutively starting from zero.
            # The features are stored in the x attribute, which is a N x F tensor, with N being the number of nodes and F the number of features per node.
            # The labels are stored in the y attribute, which is a vector of length N, with each entry denoting the class of the corresponding node.
print('===========================================================================================================')
adj = to_dense_adj(data.edge_index)[0] # Convert the sparse adjacency matrix to a dense adjacency matrix
print("Shape of the new adjacency matrix: ",adj.shape)
#Let's get statistics about the graph adjacency matrix
print("Number of nodes: ",adj.shape[0])
print("Number of edges: ",round(adj.sum().item()))
print("Density: ",round((adj.sum()/(adj.shape[0]*adj.shape[0])).item(),4))
print("Maximum node degree: ",round(adj.sum(axis=1).max().item()))
print("Minimum node degree: ",round(adj.sum(axis=1).min().item()))
print("Average node degree: ",round(adj.sum(axis=1).mean().item()))
print(f'Has isolated nodes: {data.has_isolated_nodes()}')
print(f'Has self-loops: {data.has_self_loops()}')
print(f'Is undirected: {data.is_undirected()}')
print('===========================================================================================================')
# Out:
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.x
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.tx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.allx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.y
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ty
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ally
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.graph
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.test.index
# Processing...
# Dataset: Cora():
# ======================
# Number of graphs: 1
# Number of features: 1433
# Number of classes: 7
#
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708])
# ===========================================================================================================
# Shape of the new adjacency matrix:  torch.Size([2708, 2708])
# Number of nodes:  2708
# Number of edges:  10556
# Density:  0.0014
# Maximum node degree:  168
# Minimum node degree:  1
# Average node degree:  4
# Has isolated nodes: False
# Has self-loops: False
# Is undirected: True
# ===========================================================================================================
# Done!

# %%
def calculate_homophily(edge_index, labels):
    num_edges = edge_index.size(1)
    same_label_edges = 0

    for i in range(num_edges):
        src, dst = edge_index[:, i]
        if labels[src] == labels[dst]:
            same_label_edges += 1

    homophily = same_label_edges / num_edges
    return homophily

homophily = calculate_homophily(data.edge_index, data.y)
print(f'Grado de homofilia: {homophily:.4f}')
# Out:
# Grado de homofilia: 0.8100

# %% [markdown]
# ### 1.1 Visualize the graph

# %%
# To visualize the graph we are going to use networkx library, but first we need to convert the graph to networkx format
from torch_geometric.utils import to_networkx
A = to_networkx(data, to_undirected=True) # Convert the graph to networkx format
# Now we are going to get the largest connected component of the graph, because the graph is not connected!
Gcc = sorted(nx.connected_components(A), key=len, reverse=True) # Get the sorted list of connected components
A = A.subgraph(Gcc[0]) # Get the largest connected component
G = nx.adjacency_matrix(A)
# All the following code is just for plotting the graph, so you can ignore it
# This how we can get the edge_index attribute for the largest connected component
g_tensor = torch.tensor(G.todense())
new_edge_index = g_tensor.nonzero().t().contiguous()
# This is how we create the new data object for the largest connected component
data.x = data.x[list(A.nodes())]
data.y = data.y[list(A.nodes())]
data.edge_index = new_edge_index
data.num_nodes = len(A.nodes())
data.num_edges = len(A.edges())
print(data)
# Now we can plot the graph
A = to_networkx(data, to_undirected=True) # Convert the graph to networkx format
plt.figure(figsize=(20,15))
plt.title('Largest connected component',fontsize=20)
pos = nx.spring_layout(A,seed=12)
#Let's drow the graph, adding borders to the nodes
'''
    Arguments of nx.draw:
        * G: The graph to draw.
        * node_color: The color of the nodes.
        * pos: A dictionary with nodes as keys and positions as values.
        * cmap: A colormap or registered colormap name.
        * node_size: The size of the nodes.
        * edge_color: The color of the edges.
        * width: The width of the edges.
        * with_labels: Whether to draw the node labels.
        * node_shape: The shape of the nodes.
        * alpha: The node transparency.
    Returns:
        * None
'''
nx.draw(A,node_color=data.y,pos= pos, cmap=plt.cm.viridis, node_size=100, edge_color='black',width=1,with_labels=False,node_shape='o',alpha=0.8)
plt.show()
# Out:
# Data(x=[2485, 1433], edge_index=[2, 10138], y=[2485], train_mask=[2708], val_mask=[2708], test_mask=[2708], num_nodes=2485, num_edges=5069)

# %% [markdown]
# ### 1.3 Visualize full graph [Optional]

# %%
# The same as above but with the whole graph
data = dataset[0]
G = to_networkx(data, to_undirected=True)
plt.figure(figsize=(20,15))
plt.title('Whole graph',fontsize=20)
color = data.y
pos = nx.spring_layout(G,seed=12)
nx.draw(G,node_color=color,pos= pos, cmap=plt.cm.viridis, node_size=100, edge_color='black',width=1,with_labels=False,node_shape='o',alpha=0.8)
plt.show()

# %% [markdown]
# ### 2. Train a GCN model

# %% [markdown]
# In this section we will create our model for node classification. We will use a GCN model with 2 hidden layers. The input to the model will be the node features and the output will be the logits for each node in the graph. We will use the cross entropy loss function and the Adam optimizer.
#
# ### TASK 0
# Here you have to create different models with different Convolutional layers. After that, you have to train them and compare the results in the following section.

# %% [markdown]
# #### Utility functions

# %%
'''
    Arguments of train:
        * model: The model to train.
        * data: The data object.
        * optimizer: The optimizer to use.
        * train_mask: The mask of the training nodes.
        * criterion: The loss function to use.
    Returns:
        * loss: The loss of the model.
        * acc: The accuracy of the model.
'''
def train(model, data, optimizer,train_mask,device,criterion = torch.nn.CrossEntropyLoss()):
    model.train()
    optimizer.zero_grad() # Clear gradients.
    #Make sure that we only use the features of the training nodes
    features = torch.zeros(data.x.shape[0],data.x.shape[1]).to(device)
    features[train_mask] = data.x[train_mask]
    # Put the features in the same device as the model
    features = features.to(device)
    # al modelo se le pasan las características y las conexiones
    out = model(features, data.edge_index) # Perform a single forward pass.
    # Lo que me equivoco, solo en entrenamiento
    loss = criterion(out[train_mask], data.y[train_mask]) # Compute the loss solely based on the training nodes.
    pred = out.argmax(dim=1) # Use the class with highest probability.
    acc = pred[train_mask].eq(data.y[train_mask]).sum().item() / train_mask.sum().item() # Derive ratio of correct predictions.
    # Actualizar la loss, cambiar las matrices W de cada neurona
    loss.backward() # Derive gradients.
    optimizer.step() # Update parameters based on gradients.
    return loss,acc
'''
    Arguments of validation:
        * model: The model to train.
        * data: The data object.
        * val_mask: The mask of the validation nodes.
    Returns:
        * acc: The accuracy of the model.
'''
@torch.no_grad()
def validation(model,data,val_mask,device):
    model.eval() # Set model to evaluation mode (e.g. disable dropout)
    #Make sure that we only use the features of the validation nodes
    features = torch.zeros(data.x.shape[0],data.x.shape[1]).to(device)
    features[val_mask] = data.x[val_mask]
    # Put the features in the same device as the model
    features = features.to(device)
    out = model(features, data.edge_index)
    pred = out.argmax(dim=1) # Use the class with highest probability.
    acc = pred[val_mask].eq(data.y[val_mask]).sum().item() / val_mask.sum().item() # Derive ratio of correct predictions.
    return acc
'''
    Arguments of test:
        * model: The model to train.
        * data: The data object.
        * test_mask: The mask of the test nodes.
    Returns:
        * acc: The accuracy of the model.
'''
@torch.no_grad()
def test(model,data,test_mask,device):
    model.eval() # Set model to evaluation mode (e.g. disable dropout)
    #Make sure that we only use the features of the testing nodes
    features = torch.zeros(data.x.shape[0],data.x.shape[1]).to(device)
    features[test_mask] = data.x[test_mask]
    # Put the features in the same device as the model
    features = features.to(device)
    out = model(features, data.edge_index)
    pred = out.argmax(dim=1) # Use the class with highest probability.
    acc = pred[test_mask].eq(data.y[test_mask]).sum().item() / test_mask.sum().item() # Derive ratio of correct predictions.
    return acc

# %% [markdown]
# #### Split dataset

# %% [markdown]
# In this section we will split the dataset into training, validation and test sets. We will use the training set to train the model, the validation set to tune the hyperparameters and the test set to evaluate the model. We will use two functions for the splits. One function will give as a semi-supervised split where we will have a small number of labeled nodes in the training set and the rest of the nodes will be unlabeled. The other function will give us a fully supervised split where all the nodes in the training set will be labeled.

# %%
from sklearn.model_selection import train_test_split
'''
    Arguments of get_semi_supervised_split:
        * data: The data object.
        * seed: The seed to use for the random split.
    Returns: the train, test and validation masks with an 48%/32%/20%.
        * train_mask: The mask of the training nodes.
        * test_mask: The mask of the test nodes.
        * val_mask: The mask of the validation nodes.
'''
def get_semi_supervised_split(data,seed):
    #We are going to use 48% of the nodes for training, 32% for testing and 20% for validation
    #First we split the nodes in 80% for training and 20% for testing
    #Then we split the training nodes in 48% for training and 32% for validation over the 80% of the nodes
    train_split, test_split = train_test_split(list(range(len(data.y))), test_size=0.20,random_state=seed, shuffle=True)
    train_split, val_split = train_test_split(train_split, test_size=0.40,random_state=seed, shuffle=True)

    train_mask = torch.full_like(data.y, False, dtype=bool)
    train_mask[train_split] = True

    test_mask = torch.full_like(data.y, False, dtype=bool)
    test_mask[test_split] = True

    val_mask = torch.full_like(data.y, False, dtype=bool)
    val_mask[val_split] = True

    return train_mask,test_mask,val_mask
'''
    Arguments of get_supervised_split:
        * data: The data object.
        * seed: The seed to use for the random split.
    Returns: the train, test and validation masks with an 60%/20%/20%.
        * train_mask: The mask of the training nodes.
        * test_mask: The mask of the test nodes.
        * val_mask: The mask of the validation nodes.
'''
def get_supervised_split(data,seed):
    train_split, test_split = train_test_split(list(range(len(data.y))), test_size=0.40,random_state=seed, shuffle=True)
    test_split, val_split = train_test_split(test_split, test_size=0.50,random_state=seed, shuffle=True)

    train_mask = torch.full_like(data.y, False, dtype=bool)
    train_mask[train_split] = True

    test_mask = torch.full_like(data.y, False, dtype=bool)
    test_mask[test_split] = True

    val_mask = torch.full_like(data.y, False, dtype=bool)
    val_mask[val_split] = True

    return train_mask, test_mask, val_mask

# %% [markdown]
# #### Create the model

# %% [markdown]
# In this section we will create our model for node classification. We will use a GCN model with 2 hidden layers. The input to the model will be the node features and the output will be the logits for each node in the graph. We will use the cross entropy loss function and the Adam optimizer.

# %% [markdown]
# Using the above models as templates, **create as many cells as models**.

# %% [markdown]
# ##### GCN

# %%
from torch_geometric.nn import GCNConv
from torch.functional import F
'''
    In PyTorch, you define a model by subclassing torch.nn.Module and defining a forward() method which receives input data and returns output data.
    The forward() method can use other modules defined in the constructor as submodules, and it can use arbitrary operators on Tensors, including loops and conditional statements.
    This approach is very flexible, and you can use it to define models of arbitrary complexity.
'''
class GCN(torch.nn.Module):
    '''
        Arguments of __init__:
            * hidden_channels: The number of hidden units.
            * dataset.num_features: The number of input features.
            * dataset.num_classes: The number of output classes.
        Returns:
            * self.conv1: The first GCN layer.
            * self.conv2: The second GCN layer.
    '''
    # hidden channels: capa intermedia
    def __init__(self,hidden_channels = 16):
        super(GCN, self).__init__()
        # 2-layer GCN
        # GCConv(tamaño entrada, tamaño salida)
        self.conv1 = GCNConv(dataset.num_features, hidden_channels, improved=True, normalize=True) # 16 hidden units
        self.conv2 = GCNConv(hidden_channels, dataset.num_classes, improved=True, normalize=True) # dataset.num_classes output units
    '''
        Arguments of forward:
            * x: The input features.
            * edge_index: The edge indices.
        Returns:
            * F.softmax(x, dim=1): The output of the model.
    '''
    # lo que aplica el modelo
    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index)) # ReLU activation
        x = F.dropout(x,p=0.5, training=self.training) # Dropout: 50% of the nodes are randomly dropped out during training
        x = self.conv2(x, edge_index)
        return x.softmax(dim=1) # Log softmax activation
print(GCN())
# Out:
# GCN(
#   (conv1): GCNConv(1433, 16)
#   (conv2): GCNConv(16, 7)
# )

# %% [markdown]
# ##### SAGE

# %%
from torch_geometric.nn import SAGEConv
from torch.functional import F
'''
    In PyTorch, you define a model by subclassing torch.nn.Module and defining a forward() method which receives input data and returns output data.
    The forward() method can use other modules defined in the constructor as submodules, and it can use arbitrary operators on Tensors, including loops and conditional statements.
    This approach is very flexible, and you can use it to define models of arbitrary complexity.
'''
class SAGE(torch.nn.Module):
    '''
        Arguments of __init__:
            * hidden_channels: The number of hidden units.
            * dataset.num_features: The number of input features.
            * dataset.num_classes: The number of output classes.
        Returns:
            * self.conv1: The first GCN layer.
            * self.conv2: The second GCN layer.
    '''
    # hidden channels: capa intermedia
    def __init__(self,hidden_channels = 16):
        super(SAGE, self).__init__()
        # 2-layer GCN
        # GCConv(tamaño entrada, tamaño salida)
        self.conv1 = SAGEConv(dataset.num_features, hidden_channels, aggr='max') # 16 hidden units
        self.conv2 = SAGEConv(hidden_channels, dataset.num_classes) # dataset.num_classes output units
    '''
        Arguments of forward:
            * x: The input features.
            * edge_index: The edge indices.
        Returns:
            * F.softmax(x, dim=1): The output of the model.
    '''
    # lo que aplica el modelo
    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index)) # ReLU activation
        x = F.dropout(x,p=0.5, training=self.training) # Dropout: 50% of the nodes are randomly dropped out during training
        x = self.conv2(x, edge_index)
        return x.softmax(dim=1) # Log softmax activation
print(SAGE())
# Out:
# SAGE(
#   (conv1): SAGEConv(1433, 16, aggr=max)
#   (conv2): SAGEConv(16, 7, aggr=mean)
# )

# %% [markdown]
# ##### Cheb

# %%
from torch_geometric.nn import ChebConv
from torch.functional import F
'''
    In PyTorch, you define a model by subclassing torch.nn.Module and defining a forward() method which receives input data and returns output data.
    The forward() method can use other modules defined in the constructor as submodules, and it can use arbitrary operators on Tensors, including loops and conditional statements.
    This approach is very flexible, and you can use it to define models of arbitrary complexity.
'''
class Cheb(torch.nn.Module):
    '''
        Arguments of __init__:
            * hidden_channels: The number of hidden units.
            * dataset.num_features: The number of input features.
            * dataset.num_classes: The number of output classes.
        Returns:
            * self.conv1: The first GCN layer.
            * self.conv2: The second GCN layer.
    '''
    # hidden channels: capa intermedia
    def __init__(self,hidden_channels = 16):
        super(Cheb, self).__init__()
        # 2-layer GCN
        # GCConv(tamaño entrada, tamaño salida)
        self.conv1 = ChebConv(dataset.num_features, hidden_channels, K=10, normalization='sym') # 16 hidden units
        self.conv2 = ChebConv(hidden_channels, dataset.num_classes, K=10, normalization='sym') # dataset.num_classes output units
    '''
        Arguments of forward:
            * x: The input features.
            * edge_index: The edge indices.
        Returns:
            * F.softmax(x, dim=1): The output of the model.
    '''
    # lo que aplica el modelo
    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index)) # ReLU activation
        x = F.dropout(x,p=0.5, training=self.training) # Dropout: 50% of the nodes are randomly dropped out during training
        x = self.conv2(x, edge_index)
        return x.softmax(dim=1) # Log softmax activation
print(Cheb())
# Out:
# Cheb(
#   (conv1): ChebConv(1433, 16, K=10, normalization=sym)
#   (conv2): ChebConv(16, 7, K=10, normalization=sym)
# )

# %% [markdown]
# ##### GAT

# %%
from torch_geometric.nn import GATConv
from torch.functional import F
'''
    In PyTorch, you define a model by subclassing torch.nn.Module and defining a forward() method which receives input data and returns output data.
    The forward() method can use other modules defined in the constructor as submodules, and it can use arbitrary operators on Tensors, including loops and conditional statements.
    This approach is very flexible, and you can use it to define models of arbitrary complexity.
'''
class GAT(torch.nn.Module):
    '''
        Arguments of __init__:
            * hidden_channels: The number of hidden units.
            * dataset.num_features: The number of input features.
            * dataset.num_classes: The number of output classes.
        Returns:
            * self.conv1: The first GCN layer.
            * self.conv2: The second GCN layer.
    '''
    # hidden channels: capa intermedia
    def __init__(self,hidden_channels = 16):
        super(GAT, self).__init__()
        # 2-layer GCN
        # GCConv(tamaño entrada, tamaño salida)
        self.conv1 = GATConv(dataset.num_features, hidden_channels, heads=1) # 16 hidden units
        self.conv2 = GATConv(hidden_channels, dataset.num_classes, heads=1) # dataset.num_classes output units
    '''
        Arguments of forward:
            * x: The input features.
            * edge_index: The edge indices.
        Returns:
            * F.softmax(x, dim=1): The output of the model.
    '''
    # lo que aplica el modelo
    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index)) # ReLU activation
        x = F.dropout(x,p=0.5, training=self.training) # Dropout: 50% of the nodes are randomly dropped out during training
        x = self.conv2(x, edge_index)
        return x.softmax(dim=1) # Log softmax activation
print(GAT())
# Out:
# GAT(
#   (conv1): GATConv(1433, 16, heads=1)
#   (conv2): GATConv(16, 7, heads=1)
# )

# %% [markdown]
# ##### MLP

# %%
from torch.nn import Linear
# Same as GCN but with Linear layers instead of GCNConv layers. If we use MLP as a model, we can't take into account the graph STRUCTURE.
class MLP(torch.nn.Module):
    def __init__(self,hidden_channels = 16):
        super(MLP, self).__init__()
        # 2-layer GCN
        self.lin1 = Linear(dataset.num_features, hidden_channels)
        self.lin2 = Linear(hidden_channels, dataset.num_classes)

    def forward(self, x, edge_index):
        # edge_index is not used
        x = self.lin1(x)
        x = x.relu()
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin2(x)
        return x.softmax(dim=1)
print(MLP())
# Out:
# MLP(
#   (lin1): Linear(in_features=1433, out_features=16, bias=True)
#   (lin2): Linear(in_features=16, out_features=7, bias=True)
# )

# %% [markdown]
# #### Train the models

# %%
# Seeds for the random split. This allows us to reproduce the results.
RandList = [12345, 423456, 643451, 543452, 743456, 4734510, 654321, 124321, 945321, 784328]
# This allows us to run the code on the GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Here you can add models to train and test (include your own models)
models = [GCN(), MLP(), SAGE(), Cheb(), GAT()]
global_results = []
global_best_models = []
for j in range(len(models)):
    ExperimentResult = []
    best_model = None
    print(data)
    for i in range(10):
        print("Random State", RandList[i]," in the iteration",i)
        #train_mask,test_mask,val_mask = get_semi_supervised_split(data.cpu(), RandList[i])
        train_mask,test_mask,val_mask = get_supervised_split(data.cpu(), RandList[i])
        data = data.to(device)
        model = models[j].to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
        for epoch in range(1, 101):
            loss, acc_train = train(model,data,optimizer,train_mask.to(device),device=device)
            acc_validation = validation(model,data,val_mask.to(device),device=device)
            print('Epoch: {:03d}, Loss: {:.5f}, Train Acc: {:.5f}, Val Acc: {:.5f}'.format(epoch, loss, acc_train, acc_validation))
        acc = test(model,data,test_mask.to(device),device=device)
        print('Test Accuracy: {:.5f}'.format(acc))
        # Save the best model over the 10 runs
        if best_model is None or acc > best_model[1]:
            best_model = [model, acc]
        ExperimentResult.append(acc)
        del model
    print(models[j].__class__.__name__) # Name of the model
    print('{} +- {}'.format(np.mean(ExperimentResult)*100, np.std(ExperimentResult)*100))
    global_results.append(ExperimentResult.copy())
    global_best_models.append(best_model.copy())
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Epoch: 012, Loss: 1.31653, Train Acc: 0.89470, Val Acc: 0.85240
# Epoch: 013, Loss: 1.31470, Train Acc: 0.89532, Val Acc: 0.85240
# Epoch: 014, Loss: 1.30656, Train Acc: 0.90579, Val Acc: 0.85240
# Epoch: 015, Loss: 1.30629, Train Acc: 0.90887, Val Acc: 0.85055
# Epoch: 016, Loss: 1.30660, Train Acc: 0.90825, Val Acc: 0.84686
# Epoch: 017, Loss: 1.30133, Train Acc: 0.90640, Val Acc: 0.83210
# Epoch: 018, Loss: 1.29757, Train Acc: 0.91872, Val Acc: 0.83026
# Epoch: 019, Loss: 1.29384, Train Acc: 0.91626, Val Acc: 0.82103
# Epoch: 020, Loss: 1.30021, Train Acc: 0.91195, Val Acc: 0.82657
# Epoch: 021, Loss: 1.29050, Train Acc: 0.91564, Val Acc: 0.82841
# Epoch: 022, Loss: 1.29053, Train Acc: 0.92118, Val Acc: 0.83026
# Epoch: 023, Loss: 1.28982, Train Acc: 0.91379, Val Acc: 0.83210
# Epoch: 024, Loss: 1.29080, Train Acc: 0.92365, Val Acc: 0.83579
# Epoch: 025, Loss: 1.28631, Train Acc: 0.92365, Val Acc: 0.83210
# Epoch: 026, Loss: 1.29005, Train Acc: 0.92241, Val Acc: 0.83395
# Epoch: 027, Loss: 1.29105, Train Acc: 0.91502, Val Acc: 0.83026
# Epoch: 028, Loss: 1.28615, Train Acc: 0.92180, Val Acc: 0.83764
# Epoch: 029, Loss: 1.27722, Train Acc: 0.92796, Val Acc: 0.83210
# Epoch: 030, Loss: 1.28410, Train Acc: 0.92303, Val Acc: 0.82841
# Epoch: 031, Loss: 1.27720, Train Acc: 0.93103, Val Acc: 0.83026
# Epoch: 032, Loss: 1.27750, Train Acc: 0.92734, Val Acc: 0.83210
# Epoch: 033, Loss: 1.27518, Train Acc: 0.93288, Val Acc: 0.83210
# Epoch: 034, Loss: 1.28018, Train Acc: 0.92611, Val Acc: 0.82841
# Epoch: 035, Loss: 1.27613, Train Acc: 0.93719, Val Acc: 0.82657
# Epoch: 036, Loss: 1.27322, Train Acc: 0.92611, Val Acc: 0.82841
# Epoch: 037, Loss: 1.27456, Train Acc: 0.93227, Val Acc: 0.82657
# Epoch: 038, Loss: 1.26420, Train Acc: 0.94520, Val Acc: 0.82472
# Epoch: 039, Loss: 1.27423, Train Acc: 0.92488, Val Acc: 0.82657
# Epoch: 040, Loss: 1.27816, Train Acc: 0.93227, Val Acc: 0.82288
# Epoch: 041, Loss: 1.27462, Train Acc: 0.93103, Val Acc: 0.82657
# Epoch: 042, Loss: 1.27227, Train Acc: 0.92980, Val Acc: 0.82288
# Epoch: 043, Loss: 1.27318, Train Acc: 0.93473, Val Acc: 0.82288
# Epoch: 044, Loss: 1.27426, Train Acc: 0.93103, Val Acc: 0.82472
# Epoch: 045, Loss: 1.27626, Train Acc: 0.92734, Val Acc: 0.83026
# Epoch: 046, Loss: 1.26754, Train Acc: 0.93719, Val Acc: 0.82657
# Epoch: 047, Loss: 1.27500, Train Acc: 0.92857, Val Acc: 0.82472
# Epoch: 048, Loss: 1.26761, Train Acc: 0.93719, Val Acc: 0.82103
# Epoch: 049, Loss: 1.27091, Train Acc: 0.93103, Val Acc: 0.81919
# Epoch: 050, Loss: 1.27681, Train Acc: 0.92980, Val Acc: 0.82103
# Epoch: 051, Loss: 1.27535, Train Acc: 0.92980, Val Acc: 0.82288
# Epoch: 052, Loss: 1.27103, Train Acc: 0.93288, Val Acc: 0.82657
# Epoch: 053, Loss: 1.27198, Train Acc: 0.92611, Val Acc: 0.82841
# Epoch: 054, Loss: 1.26242, Train Acc: 0.93842, Val Acc: 0.83026
# Epoch: 055, Loss: 1.27165, Train Acc: 0.93350, Val Acc: 0.83210
# Epoch: 056, Loss: 1.27309, Train Acc: 0.93411, Val Acc: 0.83210
# Epoch: 057, Loss: 1.25925, Train Acc: 0.94273, Val Acc: 0.83026
# Epoch: 058, Loss: 1.26366, Train Acc: 0.93658, Val Acc: 0.82657
# Epoch: 059, Loss: 1.26810, Train Acc: 0.93842, Val Acc: 0.82288
# Epoch: 060, Loss: 1.26348, Train Acc: 0.93781, Val Acc: 0.82103
# Epoch: 061, Loss: 1.26405, Train Acc: 0.93658, Val Acc: 0.82103
# Epoch: 062, Loss: 1.26370, Train Acc: 0.93596, Val Acc: 0.82657
# Epoch: 063, Loss: 1.26895, Train Acc: 0.94335, Val Acc: 0.82472
# Epoch: 064, Loss: 1.26994, Train Acc: 0.93904, Val Acc: 0.82657
# Epoch: 065, Loss: 1.26684, Train Acc: 0.93473, Val Acc: 0.82472
# Epoch: 066, Loss: 1.26790, Train Acc: 0.93350, Val Acc: 0.82841
# Epoch: 067, Loss: 1.26858, Train Acc: 0.94273, Val Acc: 0.82841
# Epoch: 068, Loss: 1.26937, Train Acc: 0.94150, Val Acc: 0.82472
# Epoch: 069, Loss: 1.26284, Train Acc: 0.93411, Val Acc: 0.83026
# Epoch: 070, Loss: 1.26840, Train Acc: 0.93473, Val Acc: 0.83026
# Epoch: 071, Loss: 1.26467, Train Acc: 0.93719, Val Acc: 0.82472
# Epoch: 072, Loss: 1.26260, Train Acc: 0.93596, Val Acc: 0.82472
# Epoch: 073, Loss: 1.26419, Train Acc: 0.93842, Val Acc: 0.82472
# Epoch: 074, Loss: 1.26007, Train Acc: 0.94212, Val Acc: 0.82472
# Epoch: 075, Loss: 1.25886, Train Acc: 0.94581, Val Acc: 0.83210
# Epoch: 076, Loss: 1.26296, Train Acc: 0.94150, Val Acc: 0.83026
# Epoch: 077, Loss: 1.26376, Train Acc: 0.93966, Val Acc: 0.83026
# Epoch: 078, Loss: 1.26512, Train Acc: 0.94027, Val Acc: 0.83026
# Epoch: 079, Loss: 1.26248, Train Acc: 0.94027, Val Acc: 0.83395
# Epoch: 080, Loss: 1.26097, Train Acc: 0.94027, Val Acc: 0.82472
# Epoch: 081, Loss: 1.26792, Train Acc: 0.94027, Val Acc: 0.82103
# Epoch: 082, Loss: 1.26247, Train Acc: 0.94458, Val Acc: 0.81550
# Epoch: 083, Loss: 1.26341, Train Acc: 0.93658, Val Acc: 0.82288
# Epoch: 084, Loss: 1.26634, Train Acc: 0.93966, Val Acc: 0.82657
# Epoch: 085, Loss: 1.25853, Train Acc: 0.94212, Val Acc: 0.82841
# Epoch: 086, Loss: 1.26178, Train Acc: 0.93966, Val Acc: 0.81919
# Epoch: 087, Loss: 1.26266, Train Acc: 0.93473, Val Acc: 0.81919
# Epoch: 088, Loss: 1.26239, Train Acc: 0.93904, Val Acc: 0.82103
# Epoch: 089, Loss: 1.26498, Train Acc: 0.93534, Val Acc: 0.82657
# Epoch: 090, Loss: 1.26466, Train Acc: 0.93781, Val Acc: 0.82472
# Epoch: 091, Loss: 1.26107, Train Acc: 0.93842, Val Acc: 0.81734
# Epoch: 092, Loss: 1.25952, Train Acc: 0.94273, Val Acc: 0.81181
# Epoch: 093, Loss: 1.26296, Train Acc: 0.94335, Val Acc: 0.81365
# Epoch: 094, Loss: 1.25720, Train Acc: 0.94027, Val Acc: 0.81734
# Epoch: 095, Loss: 1.25987, Train Acc: 0.94273, Val Acc: 0.82288
# Epoch: 096, Loss: 1.25813, Train Acc: 0.93842, Val Acc: 0.81919
# Epoch: 097, Loss: 1.25428, Train Acc: 0.94397, Val Acc: 0.82288
# Epoch: 098, Loss: 1.25904, Train Acc: 0.94150, Val Acc: 0.82657
# Epoch: 099, Loss: 1.26049, Train Acc: 0.94766, Val Acc: 0.82657
# Epoch: 100, Loss: 1.25810, Train Acc: 0.94273, Val Acc: 0.82657
# Test Accuracy: 0.77675
# Random State 643451  in the iteration 2
# Epoch: 001, Loss: 1.30789, Train Acc: 0.88916, Val Acc: 0.88376
# Epoch: 002, Loss: 1.30137, Train Acc: 0.90702, Val Acc: 0.88007
# Epoch: 003, Loss: 1.29816, Train Acc: 0.90394, Val Acc: 0.86900
# Epoch: 004, Loss: 1.29145, Train Acc: 0.91133, Val Acc: 0.86347
# Epoch: 005, Loss: 1.29333, Train Acc: 0.91133, Val Acc: 0.86347
# Epoch: 006, Loss: 1.29139, Train Acc: 0.91318, Val Acc: 0.87085
# Epoch: 007, Loss: 1.28536, Train Acc: 0.92118, Val Acc: 0.87269
# Epoch: 008, Loss: 1.27778, Train Acc: 0.91810, Val Acc: 0.87085
# Epoch: 009, Loss: 1.27299, Train Acc: 0.92303, Val Acc: 0.86531
# Epoch: 010, Loss: 1.27287, Train Acc: 0.92980, Val Acc: 0.85978
# Epoch: 011, Loss: 1.27266, Train Acc: 0.92796, Val Acc: 0.85424
# Epoch: 012, Loss: 1.27225, Train Acc: 0.93165, Val Acc: 0.84133
# Epoch: 013, Loss: 1.27070, Train Acc: 0.93227, Val Acc: 0.83948
# Epoch: 014, Loss: 1.27392, Train Acc: 0.91995, Val Acc: 0.83764
# Epoch: 015, Loss: 1.26810, Train Acc: 0.92857, Val Acc: 0.83948
# Epoch: 016, Loss: 1.26958, Train Acc: 0.92796, Val Acc: 0.84317
# Epoch: 017, Loss: 1.26565, Train Acc: 0.92857, Val Acc: 0.84317
# Epoch: 018, Loss: 1.27123, Train Acc: 0.92857, Val Acc: 0.84317
# Epoch: 019, Loss: 1.26309, Train Acc: 0.93473, Val Acc: 0.84317
# Epoch: 020, Loss: 1.26338, Train Acc: 0.93473, Val Acc: 0.83764
# Epoch: 021, Loss: 1.26719, Train Acc: 0.93103, Val Acc: 0.83579
# Epoch: 022, Loss: 1.26123, Train Acc: 0.93473, Val Acc: 0.83395
# Epoch: 023, Loss: 1.26659, Train Acc: 0.93473, Val Acc: 0.83026
# Epoch: 024, Loss: 1.25953, Train Acc: 0.93596, Val Acc: 0.83026
# Epoch: 025, Loss: 1.26777, Train Acc: 0.93227, Val Acc: 0.82657
# Epoch: 026, Loss: 1.25831, Train Acc: 0.93842, Val Acc: 0.82288
# Epoch: 027, Loss: 1.25968, Train Acc: 0.94089, Val Acc: 0.82288
# Epoch: 028, Loss: 1.26067, Train Acc: 0.93781, Val Acc: 0.82288
# Epoch: 029, Loss: 1.26538, Train Acc: 0.93596, Val Acc: 0.82288
# Epoch: 030, Loss: 1.26427, Train Acc: 0.93719, Val Acc: 0.82841
# Epoch: 031, Loss: 1.25878, Train Acc: 0.94397, Val Acc: 0.82841
# Epoch: 032, Loss: 1.26308, Train Acc: 0.93904, Val Acc: 0.81919
# Epoch: 033, Loss: 1.26374, Train Acc: 0.93288, Val Acc: 0.82103
# Epoch: 034, Loss: 1.26251, Train Acc: 0.94273, Val Acc: 0.81734
# Epoch: 035, Loss: 1.26427, Train Acc: 0.93966, Val Acc: 0.81919
# Epoch: 036, Loss: 1.26409, Train Acc: 0.93904, Val Acc: 0.81365
# Epoch: 037, Loss: 1.26427, Train Acc: 0.93966, Val Acc: 0.81550
# Epoch: 038, Loss: 1.26439, Train Acc: 0.93719, Val Acc: 0.82103
# Epoch: 039, Loss: 1.26057, Train Acc: 0.94520, Val Acc: 0.81181
# Epoch: 040, Loss: 1.26176, Train Acc: 0.94704, Val Acc: 0.80996
# Epoch: 041, Loss: 1.26159, Train Acc: 0.94335, Val Acc: 0.81181
# Epoch: 042, Loss: 1.26047, Train Acc: 0.93966, Val Acc: 0.81550
# Epoch: 043, Loss: 1.26305, Train Acc: 0.93534, Val Acc: 0.81550
# Epoch: 044, Loss: 1.26772, Train Acc: 0.93842, Val Acc: 0.81365
# Epoch: 045, Loss: 1.25880, Train Acc: 0.94335, Val Acc: 0.81181
# Epoch: 046, Loss: 1.26332, Train Acc: 0.94089, Val Acc: 0.81365
# Epoch: 047, Loss: 1.26208, Train Acc: 0.94150, Val Acc: 0.81365
# Epoch: 048, Loss: 1.25875, Train Acc: 0.94581, Val Acc: 0.80627
# Epoch: 049, Loss: 1.25914, Train Acc: 0.94335, Val Acc: 0.80443
# Epoch: 050, Loss: 1.25811, Train Acc: 0.94335, Val Acc: 0.80258
# Epoch: 051, Loss: 1.26370, Train Acc: 0.93658, Val Acc: 0.80443
# Epoch: 052, Loss: 1.25879, Train Acc: 0.94335, Val Acc: 0.80627
# Epoch: 053, Loss: 1.25801, Train Acc: 0.94027, Val Acc: 0.80996
# Epoch: 054, Loss: 1.25523, Train Acc: 0.94089, Val Acc: 0.80812
# Epoch: 055, Loss: 1.26042, Train Acc: 0.94212, Val Acc: 0.80996
# Epoch: 056, Loss: 1.25983, Train Acc: 0.94335, Val Acc: 0.81181
# Epoch: 057, Loss: 1.25310, Train Acc: 0.94828, Val Acc: 0.80627
# Epoch: 058, Loss: 1.25810, Train Acc: 0.94520, Val Acc: 0.80627
# Epoch: 059, Loss: 1.26060, Train Acc: 0.93966, Val Acc: 0.80443
# Epoch: 060, Loss: 1.26111, Train Acc: 0.94027, Val Acc: 0.79705
# Epoch: 061, Loss: 1.25953, Train Acc: 0.94335, Val Acc: 0.80258
# Epoch: 062, Loss: 1.26040, Train Acc: 0.93904, Val Acc: 0.80443
# Epoch: 063, Loss: 1.25726, Train Acc: 0.93966, Val Acc: 0.80627
# Epoch: 064, Loss: 1.26012, Train Acc: 0.94458, Val Acc: 0.80627
# Epoch: 065, Loss: 1.25916, Train Acc: 0.94520, Val Acc: 0.80996
# Epoch: 066, Loss: 1.26157, Train Acc: 0.93719, Val Acc: 0.80996
# Epoch: 067, Loss: 1.26272, Train Acc: 0.94212, Val Acc: 0.80996
# Epoch: 068, Loss: 1.25860, Train Acc: 0.94212, Val Acc: 0.80812
# Epoch: 069, Loss: 1.26325, Train Acc: 0.94027, Val Acc: 0.81365
# Epoch: 070, Loss: 1.25810, Train Acc: 0.93966, Val Acc: 0.81181
# Epoch: 071, Loss: 1.25901, Train Acc: 0.93966, Val Acc: 0.80996
# Epoch: 072, Loss: 1.25277, Train Acc: 0.94828, Val Acc: 0.80443
# Epoch: 073, Loss: 1.25798, Train Acc: 0.94458, Val Acc: 0.80074
# Epoch: 074, Loss: 1.26349, Train Acc: 0.94027, Val Acc: 0.80074
# Epoch: 075, Loss: 1.25612, Train Acc: 0.94581, Val Acc: 0.79705
# Epoch: 076, Loss: 1.25795, Train Acc: 0.94458, Val Acc: 0.80258
# Epoch: 077, Loss: 1.25736, Train Acc: 0.94150, Val Acc: 0.80258
# Epoch: 078, Loss: 1.25871, Train Acc: 0.93842, Val Acc: 0.80074
# Epoch: 079, Loss: 1.26149, Train Acc: 0.93719, Val Acc: 0.80812
# Epoch: 080, Loss: 1.25837, Train Acc: 0.94458, Val Acc: 0.80812
# Epoch: 081, Loss: 1.25370, Train Acc: 0.94397, Val Acc: 0.80996
# Epoch: 082, Loss: 1.25240, Train Acc: 0.94889, Val Acc: 0.80258
# Epoch: 083, Loss: 1.26073, Train Acc: 0.93781, Val Acc: 0.80258
# Epoch: 084, Loss: 1.25741, Train Acc: 0.94581, Val Acc: 0.79889
# Epoch: 085, Loss: 1.25775, Train Acc: 0.94643, Val Acc: 0.79705
# Epoch: 086, Loss: 1.26138, Train Acc: 0.94273, Val Acc: 0.79520
# Epoch: 087, Loss: 1.25636, Train Acc: 0.94335, Val Acc: 0.80074
# Epoch: 088, Loss: 1.25799, Train Acc: 0.94027, Val Acc: 0.80258
# Epoch: 089, Loss: 1.25613, Train Acc: 0.94273, Val Acc: 0.80258
# Epoch: 090, Loss: 1.25915, Train Acc: 0.94273, Val Acc: 0.80258
# Epoch: 091, Loss: 1.25513, Train Acc: 0.94458, Val Acc: 0.79889
# Epoch: 092, Loss: 1.26063, Train Acc: 0.94643, Val Acc: 0.79520
# Epoch: 093, Loss: 1.25240, Train Acc: 0.94458, Val Acc: 0.78967
# Epoch: 094, Loss: 1.26138, Train Acc: 0.93904, Val Acc: 0.78967
# Epoch: 095, Loss: 1.25587, Train Acc: 0.94150, Val Acc: 0.78967
# Epoch: 096, Loss: 1.25205, Train Acc: 0.95259, Val Acc: 0.78782
# Epoch: 097, Loss: 1.25512, Train Acc: 0.94643, Val Acc: 0.79336
# Epoch: 098, Loss: 1.25900, Train Acc: 0.94212, Val Acc: 0.79520
# Epoch: 099, Loss: 1.25877, Train Acc: 0.94212, Val Acc: 0.79889
# Epoch: 100, Loss: 1.25691, Train Acc: 0.94458, Val Acc: 0.80074
# Test Accuracy: 0.76199
# Random State 543452  in the iteration 3
# Epoch: 001, Loss: 1.31347, Train Acc: 0.89409, Val Acc: 0.88007
# Epoch: 002, Loss: 1.31580, Train Acc: 0.89347, Val Acc: 0.88376
# Epoch: 003, Loss: 1.30976, Train Acc: 0.89224, Val Acc: 0.88007
# Epoch: 004, Loss: 1.29407, Train Acc: 0.90640, Val Acc: 0.87823
# Epoch: 005, Loss: 1.29829, Train Acc: 0.90702, Val Acc: 0.88007
# Epoch: 006, Loss: 1.29033, Train Acc: 0.91379, Val Acc: 0.88930
# Epoch: 007, Loss: 1.29004, Train Acc: 0.90394, Val Acc: 0.88561
# Epoch: 008, Loss: 1.27893, Train Acc: 0.91318, Val Acc: 0.88561
# Epoch: 009, Loss: 1.27843, Train Acc: 0.92241, Val Acc: 0.88192
# Epoch: 010, Loss: 1.27740, Train Acc: 0.92426, Val Acc: 0.87823
# Epoch: 011, Loss: 1.26952, Train Acc: 0.92549, Val Acc: 0.87269
# Epoch: 012, Loss: 1.27044, Train Acc: 0.92857, Val Acc: 0.86716
# Epoch: 013, Loss: 1.26434, Train Acc: 0.93719, Val Acc: 0.86716
# Epoch: 014, Loss: 1.27145, Train Acc: 0.92426, Val Acc: 0.86716
# Epoch: 015, Loss: 1.26758, Train Acc: 0.92734, Val Acc: 0.86162
# Epoch: 016, Loss: 1.26909, Train Acc: 0.93165, Val Acc: 0.86531
# Epoch: 017, Loss: 1.26152, Train Acc: 0.92734, Val Acc: 0.86162
# Epoch: 018, Loss: 1.26448, Train Acc: 0.92796, Val Acc: 0.85609
# Epoch: 019, Loss: 1.26206, Train Acc: 0.93411, Val Acc: 0.85424
# Epoch: 020, Loss: 1.26738, Train Acc: 0.93227, Val Acc: 0.84871
# Epoch: 021, Loss: 1.26506, Train Acc: 0.93165, Val Acc: 0.84502
# Epoch: 022, Loss: 1.26489, Train Acc: 0.93534, Val Acc: 0.84317
# Epoch: 023, Loss: 1.25887, Train Acc: 0.93473, Val Acc: 0.83948
# Epoch: 024, Loss: 1.26469, Train Acc: 0.93411, Val Acc: 0.83764
# Epoch: 025, Loss: 1.26255, Train Acc: 0.93227, Val Acc: 0.83395
# Epoch: 026, Loss: 1.26862, Train Acc: 0.93534, Val Acc: 0.83395
# Epoch: 027, Loss: 1.26858, Train Acc: 0.93411, Val Acc: 0.83395
# Epoch: 028, Loss: 1.26641, Train Acc: 0.93596, Val Acc: 0.83210
# Epoch: 029, Loss: 1.26242, Train Acc: 0.93350, Val Acc: 0.82657
# Epoch: 030, Loss: 1.26215, Train Acc: 0.93658, Val Acc: 0.82288
# Epoch: 031, Loss: 1.26126, Train Acc: 0.94643, Val Acc: 0.81919
# Epoch: 032, Loss: 1.26416, Train Acc: 0.94027, Val Acc: 0.82103
# Epoch: 033, Loss: 1.26235, Train Acc: 0.94335, Val Acc: 0.82103
# Epoch: 034, Loss: 1.26695, Train Acc: 0.93350, Val Acc: 0.82288
# Epoch: 035, Loss: 1.26074, Train Acc: 0.93658, Val Acc: 0.82288
# Epoch: 036, Loss: 1.26726, Train Acc: 0.93473, Val Acc: 0.81919
# Epoch: 037, Loss: 1.26354, Train Acc: 0.93350, Val Acc: 0.82288
# Epoch: 038, Loss: 1.26961, Train Acc: 0.93288, Val Acc: 0.82103
# Epoch: 039, Loss: 1.25546, Train Acc: 0.94273, Val Acc: 0.81550
# Epoch: 040, Loss: 1.26370, Train Acc: 0.94458, Val Acc: 0.81365
# Epoch: 041, Loss: 1.26180, Train Acc: 0.93966, Val Acc: 0.81734
# Epoch: 042, Loss: 1.25851, Train Acc: 0.94150, Val Acc: 0.81365
# Epoch: 043, Loss: 1.25822, Train Acc: 0.93966, Val Acc: 0.81365
# Epoch: 044, Loss: 1.25894, Train Acc: 0.93781, Val Acc: 0.81365
# Epoch: 045, Loss: 1.26553, Train Acc: 0.93534, Val Acc: 0.81181
# Epoch: 046, Loss: 1.26445, Train Acc: 0.94335, Val Acc: 0.80996
# Epoch: 047, Loss: 1.25895, Train Acc: 0.94027, Val Acc: 0.80996
# Epoch: 048, Loss: 1.25935, Train Acc: 0.93719, Val Acc: 0.80812
# Epoch: 049, Loss: 1.25884, Train Acc: 0.93842, Val Acc: 0.80812
# Epoch: 050, Loss: 1.26122, Train Acc: 0.93411, Val Acc: 0.81181
# Epoch: 051, Loss: 1.25898, Train Acc: 0.94397, Val Acc: 0.80996
# Epoch: 052, Loss: 1.26451, Train Acc: 0.93904, Val Acc: 0.82288
# Epoch: 053, Loss: 1.26473, Train Acc: 0.93904, Val Acc: 0.81919
# Epoch: 054, Loss: 1.26395, Train Acc: 0.94643, Val Acc: 0.81550
# Epoch: 055, Loss: 1.25965, Train Acc: 0.94397, Val Acc: 0.81365
# Epoch: 056, Loss: 1.26371, Train Acc: 0.93781, Val Acc: 0.81550
# Epoch: 057, Loss: 1.26053, Train Acc: 0.94273, Val Acc: 0.80627
# Epoch: 058, Loss: 1.26252, Train Acc: 0.93904, Val Acc: 0.79705
# Epoch: 059, Loss: 1.25826, Train Acc: 0.94397, Val Acc: 0.79520
# Epoch: 060, Loss: 1.26051, Train Acc: 0.94089, Val Acc: 0.80258
# Epoch: 061, Loss: 1.26277, Train Acc: 0.94027, Val Acc: 0.80258
# Epoch: 062, Loss: 1.25716, Train Acc: 0.94520, Val Acc: 0.80258
# Epoch: 063, Loss: 1.25839, Train Acc: 0.94212, Val Acc: 0.80074
# Epoch: 064, Loss: 1.26108, Train Acc: 0.94089, Val Acc: 0.80443
# Epoch: 065, Loss: 1.26112, Train Acc: 0.93411, Val Acc: 0.80443
# Epoch: 066, Loss: 1.25993, Train Acc: 0.94150, Val Acc: 0.80443
# Epoch: 067, Loss: 1.26501, Train Acc: 0.93596, Val Acc: 0.80443
# Epoch: 068, Loss: 1.26051, Train Acc: 0.93781, Val Acc: 0.80258
# Epoch: 069, Loss: 1.26261, Train Acc: 0.93842, Val Acc: 0.80443
# Epoch: 070, Loss: 1.25932, Train Acc: 0.93904, Val Acc: 0.80258
# Epoch: 071, Loss: 1.25942, Train Acc: 0.94212, Val Acc: 0.80627
# Epoch: 072, Loss: 1.26424, Train Acc: 0.94212, Val Acc: 0.80258
# Epoch: 073, Loss: 1.26036, Train Acc: 0.94273, Val Acc: 0.79889
# Epoch: 074, Loss: 1.25967, Train Acc: 0.93904, Val Acc: 0.80258
# Epoch: 075, Loss: 1.25588, Train Acc: 0.94089, Val Acc: 0.80258
# Epoch: 076, Loss: 1.26182, Train Acc: 0.93966, Val Acc: 0.80812
# Epoch: 077, Loss: 1.25865, Train Acc: 0.94520, Val Acc: 0.80812
# Epoch: 078, Loss: 1.26099, Train Acc: 0.94150, Val Acc: 0.80627
# Epoch: 079, Loss: 1.26017, Train Acc: 0.93966, Val Acc: 0.79336
# Epoch: 080, Loss: 1.25888, Train Acc: 0.93904, Val Acc: 0.80074
# Epoch: 081, Loss: 1.26006, Train Acc: 0.94273, Val Acc: 0.80258
# Epoch: 082, Loss: 1.25762, Train Acc: 0.94335, Val Acc: 0.80443
# Epoch: 083, Loss: 1.25495, Train Acc: 0.94951, Val Acc: 0.80443
# Epoch: 084, Loss: 1.26091, Train Acc: 0.93596, Val Acc: 0.80627
# Epoch: 085, Loss: 1.26390, Train Acc: 0.94273, Val Acc: 0.80258
# Epoch: 086, Loss: 1.25582, Train Acc: 0.94643, Val Acc: 0.79889
# Epoch: 087, Loss: 1.26543, Train Acc: 0.93781, Val Acc: 0.79336
# Epoch: 088, Loss: 1.25997, Train Acc: 0.93904, Val Acc: 0.79151
# Epoch: 089, Loss: 1.26253, Train Acc: 0.93781, Val Acc: 0.79151
# Epoch: 090, Loss: 1.25572, Train Acc: 0.94273, Val Acc: 0.79705
# Epoch: 091, Loss: 1.26271, Train Acc: 0.94089, Val Acc: 0.80258
# Epoch: 092, Loss: 1.25652, Train Acc: 0.94520, Val Acc: 0.80074
# Epoch: 093, Loss: 1.26106, Train Acc: 0.93966, Val Acc: 0.80258
# Epoch: 094, Loss: 1.26697, Train Acc: 0.94089, Val Acc: 0.80627
# Epoch: 095, Loss: 1.26320, Train Acc: 0.93842, Val Acc: 0.79889
# Epoch: 096, Loss: 1.26676, Train Acc: 0.93473, Val Acc: 0.80443
# Epoch: 097, Loss: 1.25693, Train Acc: 0.94089, Val Acc: 0.80074
# Epoch: 098, Loss: 1.25870, Train Acc: 0.94828, Val Acc: 0.80443
# Epoch: 099, Loss: 1.26064, Train Acc: 0.93781, Val Acc: 0.80074
# Epoch: 100, Loss: 1.26135, Train Acc: 0.94458, Val Acc: 0.79889
# Test Accuracy: 0.83395
# Random State 743456  in the iteration 4
# Epoch: 001, Loss: 1.29425, Train Acc: 0.90948, Val Acc: 0.87085
# Epoch: 002, Loss: 1.28726, Train Acc: 0.91502, Val Acc: 0.86162
# Epoch: 003, Loss: 1.27618, Train Acc: 0.91749, Val Acc: 0.87638
# Epoch: 004, Loss: 1.27982, Train Acc: 0.91872, Val Acc: 0.87269
# Epoch: 005, Loss: 1.27306, Train Acc: 0.92118, Val Acc: 0.87638
# Epoch: 006, Loss: 1.27105, Train Acc: 0.92919, Val Acc: 0.87638
# Epoch: 007, Loss: 1.26914, Train Acc: 0.93042, Val Acc: 0.86716
# Epoch: 008, Loss: 1.26559, Train Acc: 0.93227, Val Acc: 0.86716
# Epoch: 009, Loss: 1.26402, Train Acc: 0.93350, Val Acc: 0.86347
# Epoch: 010, Loss: 1.26276, Train Acc: 0.93719, Val Acc: 0.85978
# Epoch: 011, Loss: 1.26173, Train Acc: 0.93966, Val Acc: 0.85609
# Epoch: 012, Loss: 1.25673, Train Acc: 0.93966, Val Acc: 0.85793
# Epoch: 013, Loss: 1.25636, Train Acc: 0.94273, Val Acc: 0.85793
# Epoch: 014, Loss: 1.25223, Train Acc: 0.94581, Val Acc: 0.85424
# Epoch: 015, Loss: 1.25975, Train Acc: 0.93966, Val Acc: 0.84871
# Epoch: 016, Loss: 1.25262, Train Acc: 0.94212, Val Acc: 0.84686
# Epoch: 017, Loss: 1.25513, Train Acc: 0.94089, Val Acc: 0.84133
# Epoch: 018, Loss: 1.25205, Train Acc: 0.94089, Val Acc: 0.83948
# Epoch: 019, Loss: 1.25284, Train Acc: 0.94581, Val Acc: 0.83210
# Epoch: 020, Loss: 1.25379, Train Acc: 0.93966, Val Acc: 0.83579
# Epoch: 021, Loss: 1.25309, Train Acc: 0.94520, Val Acc: 0.83579
# Epoch: 022, Loss: 1.25055, Train Acc: 0.94889, Val Acc: 0.83579
# Epoch: 023, Loss: 1.25023, Train Acc: 0.94458, Val Acc: 0.83395
# Epoch: 024, Loss: 1.24910, Train Acc: 0.94766, Val Acc: 0.82657
# Epoch: 025, Loss: 1.25368, Train Acc: 0.94089, Val Acc: 0.82657
# Epoch: 026, Loss: 1.24870, Train Acc: 0.94335, Val Acc: 0.82472
# Epoch: 027, Loss: 1.24982, Train Acc: 0.94766, Val Acc: 0.82472
# Epoch: 028, Loss: 1.25328, Train Acc: 0.94581, Val Acc: 0.82472
# Epoch: 029, Loss: 1.24936, Train Acc: 0.94951, Val Acc: 0.82472
# Epoch: 030, Loss: 1.25195, Train Acc: 0.94273, Val Acc: 0.82288
# Epoch: 031, Loss: 1.25625, Train Acc: 0.94273, Val Acc: 0.82103
# Epoch: 032, Loss: 1.25293, Train Acc: 0.94643, Val Acc: 0.81919
# Epoch: 033, Loss: 1.24982, Train Acc: 0.94889, Val Acc: 0.81550
# Epoch: 034, Loss: 1.25376, Train Acc: 0.94335, Val Acc: 0.81550
# Epoch: 035, Loss: 1.25513, Train Acc: 0.94581, Val Acc: 0.81181
# Epoch: 036, Loss: 1.24794, Train Acc: 0.94889, Val Acc: 0.80996
# Epoch: 037, Loss: 1.25565, Train Acc: 0.94335, Val Acc: 0.80812
# Epoch: 038, Loss: 1.25578, Train Acc: 0.94458, Val Acc: 0.80074
# Epoch: 039, Loss: 1.25032, Train Acc: 0.95074, Val Acc: 0.80258
# Epoch: 040, Loss: 1.25562, Train Acc: 0.94520, Val Acc: 0.80443
# Epoch: 041, Loss: 1.25471, Train Acc: 0.94089, Val Acc: 0.80812
# Epoch: 042, Loss: 1.25299, Train Acc: 0.94397, Val Acc: 0.81365
# Epoch: 043, Loss: 1.25342, Train Acc: 0.94458, Val Acc: 0.81734
# Epoch: 044, Loss: 1.25372, Train Acc: 0.94520, Val Acc: 0.81181
# Epoch: 045, Loss: 1.25132, Train Acc: 0.94766, Val Acc: 0.80443
# Epoch: 046, Loss: 1.25582, Train Acc: 0.94520, Val Acc: 0.80627
# Epoch: 047, Loss: 1.25404, Train Acc: 0.94766, Val Acc: 0.80443
# Epoch: 048, Loss: 1.24728, Train Acc: 0.94889, Val Acc: 0.79336
# Epoch: 049, Loss: 1.25088, Train Acc: 0.95320, Val Acc: 0.79520
# Epoch: 050, Loss: 1.25239, Train Acc: 0.94273, Val Acc: 0.80443
# Epoch: 051, Loss: 1.25500, Train Acc: 0.94520, Val Acc: 0.80812
# Epoch: 052, Loss: 1.25351, Train Acc: 0.94397, Val Acc: 0.80812
# Epoch: 053, Loss: 1.24736, Train Acc: 0.95197, Val Acc: 0.80443
# Epoch: 054, Loss: 1.25470, Train Acc: 0.94458, Val Acc: 0.80443
# Epoch: 055, Loss: 1.26053, Train Acc: 0.94212, Val Acc: 0.80074
# Epoch: 056, Loss: 1.25182, Train Acc: 0.95197, Val Acc: 0.79151
# Epoch: 057, Loss: 1.25296, Train Acc: 0.94581, Val Acc: 0.78967
# Epoch: 058, Loss: 1.24997, Train Acc: 0.94889, Val Acc: 0.78598
# Epoch: 059, Loss: 1.25221, Train Acc: 0.94828, Val Acc: 0.78413
# Epoch: 060, Loss: 1.25147, Train Acc: 0.94828, Val Acc: 0.79151
# Epoch: 061, Loss: 1.25228, Train Acc: 0.94581, Val Acc: 0.79520
# Epoch: 062, Loss: 1.25440, Train Acc: 0.94828, Val Acc: 0.79520
# Epoch: 063, Loss: 1.25301, Train Acc: 0.94397, Val Acc: 0.79520
# Epoch: 064, Loss: 1.25375, Train Acc: 0.94951, Val Acc: 0.79705
# Epoch: 065, Loss: 1.25278, Train Acc: 0.94889, Val Acc: 0.79151
# Epoch: 066, Loss: 1.24764, Train Acc: 0.95012, Val Acc: 0.79151
# Epoch: 067, Loss: 1.24999, Train Acc: 0.94643, Val Acc: 0.78782
# Epoch: 068, Loss: 1.24793, Train Acc: 0.94951, Val Acc: 0.78598
# Epoch: 069, Loss: 1.24687, Train Acc: 0.94889, Val Acc: 0.78598
# Epoch: 070, Loss: 1.24702, Train Acc: 0.94828, Val Acc: 0.78598
# Epoch: 071, Loss: 1.25348, Train Acc: 0.94520, Val Acc: 0.78782
# Epoch: 072, Loss: 1.25191, Train Acc: 0.94828, Val Acc: 0.78782
# Epoch: 073, Loss: 1.25221, Train Acc: 0.94520, Val Acc: 0.78967
# Epoch: 074, Loss: 1.25124, Train Acc: 0.94704, Val Acc: 0.79336
# Epoch: 075, Loss: 1.25016, Train Acc: 0.94889, Val Acc: 0.79336
# Epoch: 076, Loss: 1.25336, Train Acc: 0.95012, Val Acc: 0.79520
# Epoch: 077, Loss: 1.24941, Train Acc: 0.95135, Val Acc: 0.79889
# Epoch: 078, Loss: 1.25029, Train Acc: 0.94889, Val Acc: 0.79705
# Epoch: 079, Loss: 1.25213, Train Acc: 0.94643, Val Acc: 0.79889
# Epoch: 080, Loss: 1.25203, Train Acc: 0.94828, Val Acc: 0.79889
# Epoch: 081, Loss: 1.24772, Train Acc: 0.94828, Val Acc: 0.79520
# Epoch: 082, Loss: 1.24719, Train Acc: 0.94889, Val Acc: 0.79336
# Epoch: 083, Loss: 1.25010, Train Acc: 0.94889, Val Acc: 0.78967
# Epoch: 084, Loss: 1.25124, Train Acc: 0.95012, Val Acc: 0.79336
# Epoch: 085, Loss: 1.24946, Train Acc: 0.94520, Val Acc: 0.79889
# Epoch: 086, Loss: 1.25259, Train Acc: 0.94889, Val Acc: 0.80074
# Epoch: 087, Loss: 1.25619, Train Acc: 0.94458, Val Acc: 0.80074
# Epoch: 088, Loss: 1.24740, Train Acc: 0.95012, Val Acc: 0.80258
# Epoch: 089, Loss: 1.25069, Train Acc: 0.95197, Val Acc: 0.80627
# Epoch: 090, Loss: 1.24844, Train Acc: 0.94766, Val Acc: 0.80258
# Epoch: 091, Loss: 1.25102, Train Acc: 0.94581, Val Acc: 0.79336
# Epoch: 092, Loss: 1.25099, Train Acc: 0.95259, Val Acc: 0.79151
# Epoch: 093, Loss: 1.25270, Train Acc: 0.95074, Val Acc: 0.79151
# Epoch: 094, Loss: 1.25423, Train Acc: 0.94889, Val Acc: 0.79151
# Epoch: 095, Loss: 1.25443, Train Acc: 0.94581, Val Acc: 0.79705
# Epoch: 096, Loss: 1.24853, Train Acc: 0.95074, Val Acc: 0.79705
# Epoch: 097, Loss: 1.25095, Train Acc: 0.94828, Val Acc: 0.79705
# Epoch: 098, Loss: 1.24908, Train Acc: 0.94581, Val Acc: 0.79151
# Epoch: 099, Loss: 1.25637, Train Acc: 0.94828, Val Acc: 0.78967
# Epoch: 100, Loss: 1.25447, Train Acc: 0.94273, Val Acc: 0.78229
# Test Accuracy: 0.77491
# Random State 4734510  in the iteration 5
# Epoch: 001, Loss: 1.32142, Train Acc: 0.87869, Val Acc: 0.87454
# Epoch: 002, Loss: 1.31170, Train Acc: 0.89778, Val Acc: 0.87823
# Epoch: 003, Loss: 1.29705, Train Acc: 0.90702, Val Acc: 0.86900
# Epoch: 004, Loss: 1.29064, Train Acc: 0.91195, Val Acc: 0.86347
# Epoch: 005, Loss: 1.28863, Train Acc: 0.91133, Val Acc: 0.86162
# Epoch: 006, Loss: 1.29048, Train Acc: 0.90825, Val Acc: 0.85793
# Epoch: 007, Loss: 1.27913, Train Acc: 0.91995, Val Acc: 0.85978
# Epoch: 008, Loss: 1.27766, Train Acc: 0.91933, Val Acc: 0.85424
# Epoch: 009, Loss: 1.27836, Train Acc: 0.92365, Val Acc: 0.85424
# Epoch: 010, Loss: 1.27202, Train Acc: 0.92611, Val Acc: 0.85055
# Epoch: 011, Loss: 1.27383, Train Acc: 0.92303, Val Acc: 0.84502
# Epoch: 012, Loss: 1.27397, Train Acc: 0.92488, Val Acc: 0.84502
# Epoch: 013, Loss: 1.27368, Train Acc: 0.92180, Val Acc: 0.84317
# Epoch: 014, Loss: 1.27266, Train Acc: 0.92180, Val Acc: 0.83948
# Epoch: 015, Loss: 1.26734, Train Acc: 0.92857, Val Acc: 0.83395
# Epoch: 016, Loss: 1.27433, Train Acc: 0.92241, Val Acc: 0.83210
# Epoch: 017, Loss: 1.26919, Train Acc: 0.92672, Val Acc: 0.83210
# Epoch: 018, Loss: 1.26887, Train Acc: 0.92857, Val Acc: 0.83210
# Epoch: 019, Loss: 1.26262, Train Acc: 0.93350, Val Acc: 0.83026
# Epoch: 020, Loss: 1.26693, Train Acc: 0.93350, Val Acc: 0.82657
# Epoch: 021, Loss: 1.25780, Train Acc: 0.94027, Val Acc: 0.82841
# Epoch: 022, Loss: 1.26547, Train Acc: 0.93473, Val Acc: 0.82657
# Epoch: 023, Loss: 1.27002, Train Acc: 0.93227, Val Acc: 0.82288
# Epoch: 024, Loss: 1.27018, Train Acc: 0.92919, Val Acc: 0.81919
# Epoch: 025, Loss: 1.26644, Train Acc: 0.93473, Val Acc: 0.81734
# Epoch: 026, Loss: 1.26822, Train Acc: 0.93534, Val Acc: 0.82103
# Epoch: 027, Loss: 1.26902, Train Acc: 0.92796, Val Acc: 0.81550
# Epoch: 028, Loss: 1.26813, Train Acc: 0.93288, Val Acc: 0.81181
# Epoch: 029, Loss: 1.26755, Train Acc: 0.93288, Val Acc: 0.81181
# Epoch: 030, Loss: 1.26424, Train Acc: 0.93658, Val Acc: 0.80996
# Epoch: 031, Loss: 1.26430, Train Acc: 0.93411, Val Acc: 0.80812
# Epoch: 032, Loss: 1.26260, Train Acc: 0.93904, Val Acc: 0.80627
# Epoch: 033, Loss: 1.26706, Train Acc: 0.92919, Val Acc: 0.80443
# Epoch: 034, Loss: 1.27139, Train Acc: 0.93227, Val Acc: 0.80443
# Epoch: 035, Loss: 1.26764, Train Acc: 0.92919, Val Acc: 0.80443
# Epoch: 036, Loss: 1.26183, Train Acc: 0.93658, Val Acc: 0.80443
# Epoch: 037, Loss: 1.26307, Train Acc: 0.93719, Val Acc: 0.79705
# Epoch: 038, Loss: 1.26977, Train Acc: 0.92919, Val Acc: 0.80258
# Epoch: 039, Loss: 1.26332, Train Acc: 0.93842, Val Acc: 0.80443
# Epoch: 040, Loss: 1.26235, Train Acc: 0.94273, Val Acc: 0.80258
# Epoch: 041, Loss: 1.26189, Train Acc: 0.93904, Val Acc: 0.80443
# Epoch: 042, Loss: 1.26638, Train Acc: 0.92980, Val Acc: 0.79889
# Epoch: 043, Loss: 1.26466, Train Acc: 0.94089, Val Acc: 0.79889
# Epoch: 044, Loss: 1.26062, Train Acc: 0.93842, Val Acc: 0.79889
# Epoch: 045, Loss: 1.26382, Train Acc: 0.93350, Val Acc: 0.80258
# Epoch: 046, Loss: 1.26561, Train Acc: 0.93596, Val Acc: 0.80074
# Epoch: 047, Loss: 1.26645, Train Acc: 0.93781, Val Acc: 0.79889
# Epoch: 048, Loss: 1.26296, Train Acc: 0.93534, Val Acc: 0.79889
# Epoch: 049, Loss: 1.26476, Train Acc: 0.94089, Val Acc: 0.79705
# Epoch: 050, Loss: 1.26140, Train Acc: 0.93966, Val Acc: 0.79705
# Epoch: 051, Loss: 1.26583, Train Acc: 0.93350, Val Acc: 0.79705
# Epoch: 052, Loss: 1.26638, Train Acc: 0.92919, Val Acc: 0.80258
# Epoch: 053, Loss: 1.26556, Train Acc: 0.93719, Val Acc: 0.80074
# Epoch: 054, Loss: 1.26602, Train Acc: 0.93596, Val Acc: 0.80443
# Epoch: 055, Loss: 1.26702, Train Acc: 0.93288, Val Acc: 0.80627
# Epoch: 056, Loss: 1.26027, Train Acc: 0.94273, Val Acc: 0.80443
# Epoch: 057, Loss: 1.25990, Train Acc: 0.94150, Val Acc: 0.80258
# Epoch: 058, Loss: 1.26273, Train Acc: 0.94027, Val Acc: 0.80258
# Epoch: 059, Loss: 1.25989, Train Acc: 0.94335, Val Acc: 0.80627
# Epoch: 060, Loss: 1.26517, Train Acc: 0.93288, Val Acc: 0.80258
# Epoch: 061, Loss: 1.25764, Train Acc: 0.94089, Val Acc: 0.80074
# Epoch: 062, Loss: 1.26495, Train Acc: 0.93781, Val Acc: 0.80443
# Epoch: 063, Loss: 1.26026, Train Acc: 0.93658, Val Acc: 0.80812
# Epoch: 064, Loss: 1.26502, Train Acc: 0.93966, Val Acc: 0.80443
# Epoch: 065, Loss: 1.26476, Train Acc: 0.93658, Val Acc: 0.80074
# Epoch: 066, Loss: 1.26446, Train Acc: 0.94273, Val Acc: 0.79889
# Epoch: 067, Loss: 1.26273, Train Acc: 0.93719, Val Acc: 0.79889
# Epoch: 068, Loss: 1.25961, Train Acc: 0.94212, Val Acc: 0.79520
# Epoch: 069, Loss: 1.26558, Train Acc: 0.93781, Val Acc: 0.79520
# Epoch: 070, Loss: 1.26367, Train Acc: 0.93904, Val Acc: 0.79336
# Epoch: 071, Loss: 1.26577, Train Acc: 0.93411, Val Acc: 0.79336
# Epoch: 072, Loss: 1.26419, Train Acc: 0.94273, Val Acc: 0.79705
# Epoch: 073, Loss: 1.26198, Train Acc: 0.94643, Val Acc: 0.79520
# Epoch: 074, Loss: 1.25552, Train Acc: 0.94273, Val Acc: 0.79336
# Epoch: 075, Loss: 1.25693, Train Acc: 0.94089, Val Acc: 0.79520
# Epoch: 076, Loss: 1.26462, Train Acc: 0.93411, Val Acc: 0.79889
# Epoch: 077, Loss: 1.26521, Train Acc: 0.93473, Val Acc: 0.79705
# Epoch: 078, Loss: 1.26078, Train Acc: 0.93473, Val Acc: 0.79705
# Epoch: 079, Loss: 1.26009, Train Acc: 0.94273, Val Acc: 0.79520
# Epoch: 080, Loss: 1.26383, Train Acc: 0.93658, Val Acc: 0.79705
# Epoch: 081, Loss: 1.26469, Train Acc: 0.93165, Val Acc: 0.79705
# Epoch: 082, Loss: 1.26015, Train Acc: 0.93966, Val Acc: 0.79705
# Epoch: 083, Loss: 1.26445, Train Acc: 0.93227, Val Acc: 0.79889
# Epoch: 084, Loss: 1.26254, Train Acc: 0.93411, Val Acc: 0.79705
# Epoch: 085, Loss: 1.26367, Train Acc: 0.93904, Val Acc: 0.79705
# Epoch: 086, Loss: 1.25839, Train Acc: 0.94212, Val Acc: 0.80258
# Epoch: 087, Loss: 1.26243, Train Acc: 0.93719, Val Acc: 0.80258
# Epoch: 088, Loss: 1.25995, Train Acc: 0.93781, Val Acc: 0.80258
# Epoch: 089, Loss: 1.26331, Train Acc: 0.93658, Val Acc: 0.80074
# Epoch: 090, Loss: 1.26268, Train Acc: 0.93904, Val Acc: 0.80258
# Epoch: 091, Loss: 1.26360, Train Acc: 0.94335, Val Acc: 0.80258
# Epoch: 092, Loss: 1.26218, Train Acc: 0.93781, Val Acc: 0.80074
# Epoch: 093, Loss: 1.26350, Train Acc: 0.93350, Val Acc: 0.79336
# Epoch: 094, Loss: 1.26579, Train Acc: 0.93473, Val Acc: 0.79520
# Epoch: 095, Loss: 1.26281, Train Acc: 0.93781, Val Acc: 0.79151
# Epoch: 096, Loss: 1.25919, Train Acc: 0.94520, Val Acc: 0.79889
# Epoch: 097, Loss: 1.26082, Train Acc: 0.93781, Val Acc: 0.79889
# Epoch: 098, Loss: 1.26887, Train Acc: 0.93473, Val Acc: 0.79705
# Epoch: 099, Loss: 1.26309, Train Acc: 0.94027, Val Acc: 0.80074
# Epoch: 100, Loss: 1.26122, Train Acc: 0.93596, Val Acc: 0.79889
# Test Accuracy: 0.83764
# Random State 654321  in the iteration 6
# Epoch: 001, Loss: 1.30349, Train Acc: 0.90271, Val Acc: 0.87454
# Epoch: 002, Loss: 1.29981, Train Acc: 0.90086, Val Acc: 0.87638
# Epoch: 003, Loss: 1.28421, Train Acc: 0.91995, Val Acc: 0.88745
# Epoch: 004, Loss: 1.28204, Train Acc: 0.91441, Val Acc: 0.88007
# Epoch: 005, Loss: 1.27570, Train Acc: 0.92118, Val Acc: 0.87638
# Epoch: 006, Loss: 1.27760, Train Acc: 0.92057, Val Acc: 0.87638
# Epoch: 007, Loss: 1.26971, Train Acc: 0.92980, Val Acc: 0.86900
# Epoch: 008, Loss: 1.27317, Train Acc: 0.92488, Val Acc: 0.86347
# Epoch: 009, Loss: 1.27492, Train Acc: 0.92241, Val Acc: 0.86531
# Epoch: 010, Loss: 1.27411, Train Acc: 0.92365, Val Acc: 0.85424
# Epoch: 011, Loss: 1.27060, Train Acc: 0.93042, Val Acc: 0.85240
# Epoch: 012, Loss: 1.26510, Train Acc: 0.92980, Val Acc: 0.85240
# Epoch: 013, Loss: 1.26585, Train Acc: 0.92980, Val Acc: 0.85240
# Epoch: 014, Loss: 1.26288, Train Acc: 0.93534, Val Acc: 0.84502
# Epoch: 015, Loss: 1.26434, Train Acc: 0.92919, Val Acc: 0.83764
# Epoch: 016, Loss: 1.26680, Train Acc: 0.92857, Val Acc: 0.83764
# Epoch: 017, Loss: 1.26294, Train Acc: 0.93350, Val Acc: 0.83210
# Epoch: 018, Loss: 1.26289, Train Acc: 0.92980, Val Acc: 0.82103
# Epoch: 019, Loss: 1.26068, Train Acc: 0.93473, Val Acc: 0.82103
# Epoch: 020, Loss: 1.26153, Train Acc: 0.93411, Val Acc: 0.81919
# Epoch: 021, Loss: 1.25660, Train Acc: 0.93596, Val Acc: 0.82103
# Epoch: 022, Loss: 1.25968, Train Acc: 0.93904, Val Acc: 0.82288
# Epoch: 023, Loss: 1.26099, Train Acc: 0.93596, Val Acc: 0.83210
# Epoch: 024, Loss: 1.25436, Train Acc: 0.94273, Val Acc: 0.82841
# Epoch: 025, Loss: 1.26050, Train Acc: 0.93658, Val Acc: 0.82288
# Epoch: 026, Loss: 1.26126, Train Acc: 0.93103, Val Acc: 0.81734
# Epoch: 027, Loss: 1.25967, Train Acc: 0.93534, Val Acc: 0.81550
# Epoch: 028, Loss: 1.26161, Train Acc: 0.93658, Val Acc: 0.81734
# Epoch: 029, Loss: 1.25737, Train Acc: 0.93658, Val Acc: 0.81734
# Epoch: 030, Loss: 1.26107, Train Acc: 0.93658, Val Acc: 0.81550
# Epoch: 031, Loss: 1.26098, Train Acc: 0.93596, Val Acc: 0.81919
# Epoch: 032, Loss: 1.25841, Train Acc: 0.93719, Val Acc: 0.81734
# Epoch: 033, Loss: 1.26037, Train Acc: 0.93842, Val Acc: 0.81919
# Epoch: 034, Loss: 1.25948, Train Acc: 0.93473, Val Acc: 0.81734
# Epoch: 035, Loss: 1.25491, Train Acc: 0.94212, Val Acc: 0.81365
# Epoch: 036, Loss: 1.26111, Train Acc: 0.93842, Val Acc: 0.81181
# Epoch: 037, Loss: 1.26313, Train Acc: 0.93288, Val Acc: 0.80996
# Epoch: 038, Loss: 1.26099, Train Acc: 0.93534, Val Acc: 0.80812
# Epoch: 039, Loss: 1.25836, Train Acc: 0.93904, Val Acc: 0.80996
# Epoch: 040, Loss: 1.26255, Train Acc: 0.93596, Val Acc: 0.81181
# Epoch: 041, Loss: 1.26019, Train Acc: 0.93904, Val Acc: 0.81365
# Epoch: 042, Loss: 1.26219, Train Acc: 0.93719, Val Acc: 0.81365
# Epoch: 043, Loss: 1.25644, Train Acc: 0.95074, Val Acc: 0.81181
# Epoch: 044, Loss: 1.25686, Train Acc: 0.94458, Val Acc: 0.81181
# Epoch: 045, Loss: 1.25726, Train Acc: 0.94335, Val Acc: 0.81550
# Epoch: 046, Loss: 1.26444, Train Acc: 0.93534, Val Acc: 0.80996
# Epoch: 047, Loss: 1.26077, Train Acc: 0.93781, Val Acc: 0.80443
# Epoch: 048, Loss: 1.25913, Train Acc: 0.94273, Val Acc: 0.80443
# Epoch: 049, Loss: 1.26208, Train Acc: 0.93658, Val Acc: 0.80443
# Epoch: 050, Loss: 1.26101, Train Acc: 0.93719, Val Acc: 0.79705
# Epoch: 051, Loss: 1.25872, Train Acc: 0.94212, Val Acc: 0.79520
# Epoch: 052, Loss: 1.26165, Train Acc: 0.93904, Val Acc: 0.79520
# Epoch: 053, Loss: 1.25880, Train Acc: 0.93966, Val Acc: 0.79151
# Epoch: 054, Loss: 1.26267, Train Acc: 0.93966, Val Acc: 0.78782
# Epoch: 055, Loss: 1.25756, Train Acc: 0.94397, Val Acc: 0.78967
# Epoch: 056, Loss: 1.26075, Train Acc: 0.93596, Val Acc: 0.79151
# Epoch: 057, Loss: 1.25936, Train Acc: 0.93904, Val Acc: 0.78967
# Epoch: 058, Loss: 1.26322, Train Acc: 0.93781, Val Acc: 0.79336
# Epoch: 059, Loss: 1.25443, Train Acc: 0.94273, Val Acc: 0.79151
# Epoch: 060, Loss: 1.25715, Train Acc: 0.94397, Val Acc: 0.79889
# Epoch: 061, Loss: 1.25383, Train Acc: 0.94150, Val Acc: 0.78967
# Epoch: 062, Loss: 1.25171, Train Acc: 0.94704, Val Acc: 0.78229
# Epoch: 063, Loss: 1.25514, Train Acc: 0.94212, Val Acc: 0.78044
# Epoch: 064, Loss: 1.25787, Train Acc: 0.94089, Val Acc: 0.78229
# Epoch: 065, Loss: 1.26400, Train Acc: 0.94027, Val Acc: 0.78967
# Epoch: 066, Loss: 1.26143, Train Acc: 0.93534, Val Acc: 0.78413
# Epoch: 067, Loss: 1.25698, Train Acc: 0.94397, Val Acc: 0.78782
# Epoch: 068, Loss: 1.26040, Train Acc: 0.93842, Val Acc: 0.78967
# Epoch: 069, Loss: 1.26099, Train Acc: 0.93842, Val Acc: 0.78967
# Epoch: 070, Loss: 1.25793, Train Acc: 0.94150, Val Acc: 0.79151
# Epoch: 071, Loss: 1.25975, Train Acc: 0.93904, Val Acc: 0.78967
# Epoch: 072, Loss: 1.25697, Train Acc: 0.94212, Val Acc: 0.78782
# Epoch: 073, Loss: 1.25908, Train Acc: 0.94212, Val Acc: 0.78598
# Epoch: 074, Loss: 1.26319, Train Acc: 0.93411, Val Acc: 0.78598
# Epoch: 075, Loss: 1.25693, Train Acc: 0.93966, Val Acc: 0.78413
# Epoch: 076, Loss: 1.25610, Train Acc: 0.94089, Val Acc: 0.78967
# Epoch: 077, Loss: 1.25832, Train Acc: 0.93904, Val Acc: 0.78967
# Epoch: 078, Loss: 1.25389, Train Acc: 0.94335, Val Acc: 0.78967
# Epoch: 079, Loss: 1.25312, Train Acc: 0.94335, Val Acc: 0.78413
# Epoch: 080, Loss: 1.25706, Train Acc: 0.94150, Val Acc: 0.78413
# Epoch: 081, Loss: 1.25439, Train Acc: 0.94704, Val Acc: 0.78967
# Epoch: 082, Loss: 1.25959, Train Acc: 0.94027, Val Acc: 0.79336
# Epoch: 083, Loss: 1.25704, Train Acc: 0.94581, Val Acc: 0.78782
# Epoch: 084, Loss: 1.25727, Train Acc: 0.94704, Val Acc: 0.78967
# Epoch: 085, Loss: 1.25943, Train Acc: 0.94458, Val Acc: 0.78598
# Epoch: 086, Loss: 1.26267, Train Acc: 0.93781, Val Acc: 0.78229
# Epoch: 087, Loss: 1.26136, Train Acc: 0.93842, Val Acc: 0.78413
# Epoch: 088, Loss: 1.25727, Train Acc: 0.93966, Val Acc: 0.78782
# Epoch: 089, Loss: 1.25704, Train Acc: 0.93719, Val Acc: 0.78598
# Epoch: 090, Loss: 1.26085, Train Acc: 0.93781, Val Acc: 0.79151
# Epoch: 091, Loss: 1.25853, Train Acc: 0.94150, Val Acc: 0.79520
# Epoch: 092, Loss: 1.25742, Train Acc: 0.94766, Val Acc: 0.79151
# Epoch: 093, Loss: 1.26114, Train Acc: 0.94027, Val Acc: 0.79520
# Epoch: 094, Loss: 1.25711, Train Acc: 0.94212, Val Acc: 0.79151
# Epoch: 095, Loss: 1.26006, Train Acc: 0.94273, Val Acc: 0.79520
# Epoch: 096, Loss: 1.25810, Train Acc: 0.94889, Val Acc: 0.79705
# Epoch: 097, Loss: 1.26103, Train Acc: 0.93596, Val Acc: 0.79889
# Epoch: 098, Loss: 1.26028, Train Acc: 0.93227, Val Acc: 0.79336
# Epoch: 099, Loss: 1.25815, Train Acc: 0.94150, Val Acc: 0.79336
# Epoch: 100, Loss: 1.25582, Train Acc: 0.94520, Val Acc: 0.79705
# Test Accuracy: 0.79151
# Random State 124321  in the iteration 7
# Epoch: 001, Loss: 1.32466, Train Acc: 0.87746, Val Acc: 0.88192
# Epoch: 002, Loss: 1.30470, Train Acc: 0.89963, Val Acc: 0.88376
# Epoch: 003, Loss: 1.30458, Train Acc: 0.89778, Val Acc: 0.88192
# Epoch: 004, Loss: 1.29968, Train Acc: 0.90333, Val Acc: 0.88007
# Epoch: 005, Loss: 1.29344, Train Acc: 0.90579, Val Acc: 0.88007
# Epoch: 006, Loss: 1.28081, Train Acc: 0.91626, Val Acc: 0.87085
# Epoch: 007, Loss: 1.28467, Train Acc: 0.91379, Val Acc: 0.86716
# Epoch: 008, Loss: 1.27851, Train Acc: 0.91626, Val Acc: 0.86531
# Epoch: 009, Loss: 1.27753, Train Acc: 0.92118, Val Acc: 0.86716
# Epoch: 010, Loss: 1.27422, Train Acc: 0.92426, Val Acc: 0.85978
# Epoch: 011, Loss: 1.27998, Train Acc: 0.91133, Val Acc: 0.86347
# Epoch: 012, Loss: 1.26732, Train Acc: 0.92734, Val Acc: 0.85793
# Epoch: 013, Loss: 1.26289, Train Acc: 0.92734, Val Acc: 0.85793
# Epoch: 014, Loss: 1.27150, Train Acc: 0.91995, Val Acc: 0.85055
# Epoch: 015, Loss: 1.27305, Train Acc: 0.92241, Val Acc: 0.85055
# Epoch: 016, Loss: 1.27219, Train Acc: 0.92734, Val Acc: 0.84133
# Epoch: 017, Loss: 1.26568, Train Acc: 0.93042, Val Acc: 0.83579
# Epoch: 018, Loss: 1.26401, Train Acc: 0.93103, Val Acc: 0.83026
# Epoch: 019, Loss: 1.26562, Train Acc: 0.93534, Val Acc: 0.82657
# Epoch: 020, Loss: 1.26382, Train Acc: 0.93596, Val Acc: 0.83026
# Epoch: 021, Loss: 1.26228, Train Acc: 0.93596, Val Acc: 0.82841
# Epoch: 022, Loss: 1.26938, Train Acc: 0.93350, Val Acc: 0.82288
# Epoch: 023, Loss: 1.26127, Train Acc: 0.93596, Val Acc: 0.82103
# Epoch: 024, Loss: 1.26872, Train Acc: 0.92857, Val Acc: 0.82103
# Epoch: 025, Loss: 1.26697, Train Acc: 0.93165, Val Acc: 0.81919
# Epoch: 026, Loss: 1.26763, Train Acc: 0.93411, Val Acc: 0.82103
# Epoch: 027, Loss: 1.26031, Train Acc: 0.94397, Val Acc: 0.81181
# Epoch: 028, Loss: 1.26562, Train Acc: 0.93473, Val Acc: 0.81365
# Epoch: 029, Loss: 1.26107, Train Acc: 0.93904, Val Acc: 0.80812
# Epoch: 030, Loss: 1.26011, Train Acc: 0.94027, Val Acc: 0.80443
# Epoch: 031, Loss: 1.26152, Train Acc: 0.93288, Val Acc: 0.80258
# Epoch: 032, Loss: 1.26264, Train Acc: 0.93350, Val Acc: 0.80258
# Epoch: 033, Loss: 1.26212, Train Acc: 0.93658, Val Acc: 0.80074
# Epoch: 034, Loss: 1.26545, Train Acc: 0.93534, Val Acc: 0.79520
# Epoch: 035, Loss: 1.26073, Train Acc: 0.93904, Val Acc: 0.80074
# Epoch: 036, Loss: 1.26195, Train Acc: 0.93966, Val Acc: 0.80258
# Epoch: 037, Loss: 1.26175, Train Acc: 0.94273, Val Acc: 0.80074
# Epoch: 038, Loss: 1.26484, Train Acc: 0.92919, Val Acc: 0.80258
# Epoch: 039, Loss: 1.26407, Train Acc: 0.93473, Val Acc: 0.80443
# Epoch: 040, Loss: 1.25811, Train Acc: 0.93966, Val Acc: 0.80443
# Epoch: 041, Loss: 1.26303, Train Acc: 0.93719, Val Acc: 0.80258
# Epoch: 042, Loss: 1.26123, Train Acc: 0.94458, Val Acc: 0.79705
# Epoch: 043, Loss: 1.26544, Train Acc: 0.93658, Val Acc: 0.79889
# Epoch: 044, Loss: 1.26635, Train Acc: 0.93350, Val Acc: 0.80258
# Epoch: 045, Loss: 1.25833, Train Acc: 0.93596, Val Acc: 0.79705
# Epoch: 046, Loss: 1.26060, Train Acc: 0.93904, Val Acc: 0.79889
# Epoch: 047, Loss: 1.26200, Train Acc: 0.93781, Val Acc: 0.80443
# Epoch: 048, Loss: 1.26248, Train Acc: 0.93966, Val Acc: 0.80258
# Epoch: 049, Loss: 1.25994, Train Acc: 0.94581, Val Acc: 0.79705
# Epoch: 050, Loss: 1.26447, Train Acc: 0.93534, Val Acc: 0.80074
# Epoch: 051, Loss: 1.26364, Train Acc: 0.93842, Val Acc: 0.80074
# Epoch: 052, Loss: 1.25646, Train Acc: 0.94212, Val Acc: 0.79705
# Epoch: 053, Loss: 1.25778, Train Acc: 0.94520, Val Acc: 0.79705
# Epoch: 054, Loss: 1.26186, Train Acc: 0.94212, Val Acc: 0.79889
# Epoch: 055, Loss: 1.25670, Train Acc: 0.94027, Val Acc: 0.80074
# Epoch: 056, Loss: 1.26387, Train Acc: 0.94027, Val Acc: 0.79889
# Epoch: 057, Loss: 1.25262, Train Acc: 0.94335, Val Acc: 0.80258
# Epoch: 058, Loss: 1.25889, Train Acc: 0.94520, Val Acc: 0.80074
# Epoch: 059, Loss: 1.25858, Train Acc: 0.94150, Val Acc: 0.80074
# Epoch: 060, Loss: 1.26101, Train Acc: 0.94027, Val Acc: 0.79889
# Epoch: 061, Loss: 1.25518, Train Acc: 0.94027, Val Acc: 0.79889
# Epoch: 062, Loss: 1.25874, Train Acc: 0.94027, Val Acc: 0.79889
# Epoch: 063, Loss: 1.25986, Train Acc: 0.93966, Val Acc: 0.80074
# Epoch: 064, Loss: 1.26100, Train Acc: 0.94150, Val Acc: 0.79889
# Epoch: 065, Loss: 1.25674, Train Acc: 0.94273, Val Acc: 0.80074
# Epoch: 066, Loss: 1.25917, Train Acc: 0.93842, Val Acc: 0.80258
# Epoch: 067, Loss: 1.25593, Train Acc: 0.93719, Val Acc: 0.80258
# Epoch: 068, Loss: 1.25626, Train Acc: 0.94027, Val Acc: 0.79520
# Epoch: 069, Loss: 1.25901, Train Acc: 0.94027, Val Acc: 0.79705
# Epoch: 070, Loss: 1.25833, Train Acc: 0.94273, Val Acc: 0.79705
# Epoch: 071, Loss: 1.26402, Train Acc: 0.93842, Val Acc: 0.79705
# Epoch: 072, Loss: 1.25974, Train Acc: 0.94704, Val Acc: 0.79520
# Epoch: 073, Loss: 1.25953, Train Acc: 0.94397, Val Acc: 0.79520
# Epoch: 074, Loss: 1.25870, Train Acc: 0.94335, Val Acc: 0.79705
# Epoch: 075, Loss: 1.25915, Train Acc: 0.93904, Val Acc: 0.79705
# Epoch: 076, Loss: 1.26063, Train Acc: 0.93904, Val Acc: 0.79889
# Epoch: 077, Loss: 1.25849, Train Acc: 0.94643, Val Acc: 0.79889
# Epoch: 078, Loss: 1.26008, Train Acc: 0.94027, Val Acc: 0.79705
# Epoch: 079, Loss: 1.26087, Train Acc: 0.94643, Val Acc: 0.79336
# Epoch: 080, Loss: 1.26022, Train Acc: 0.94089, Val Acc: 0.79520
# Epoch: 081, Loss: 1.26076, Train Acc: 0.94397, Val Acc: 0.80074
# Epoch: 082, Loss: 1.25896, Train Acc: 0.94766, Val Acc: 0.79705
# Epoch: 083, Loss: 1.25930, Train Acc: 0.94089, Val Acc: 0.79889
# Epoch: 084, Loss: 1.26038, Train Acc: 0.93842, Val Acc: 0.79520
# Epoch: 085, Loss: 1.26057, Train Acc: 0.93842, Val Acc: 0.79151
# Epoch: 086, Loss: 1.25770, Train Acc: 0.93966, Val Acc: 0.79705
# Epoch: 087, Loss: 1.25999, Train Acc: 0.93719, Val Acc: 0.79520
# Epoch: 088, Loss: 1.26019, Train Acc: 0.94581, Val Acc: 0.79705
# Epoch: 089, Loss: 1.26178, Train Acc: 0.94335, Val Acc: 0.79889
# Epoch: 090, Loss: 1.25979, Train Acc: 0.94397, Val Acc: 0.79705
# Epoch: 091, Loss: 1.25947, Train Acc: 0.93719, Val Acc: 0.79705
# Epoch: 092, Loss: 1.25413, Train Acc: 0.94397, Val Acc: 0.80258
# Epoch: 093, Loss: 1.25796, Train Acc: 0.93781, Val Acc: 0.80258
# Epoch: 094, Loss: 1.25806, Train Acc: 0.94027, Val Acc: 0.79705
# Epoch: 095, Loss: 1.26296, Train Acc: 0.92857, Val Acc: 0.79889
# Epoch: 096, Loss: 1.25971, Train Acc: 0.94089, Val Acc: 0.79705
# Epoch: 097, Loss: 1.25647, Train Acc: 0.93966, Val Acc: 0.79520
# Epoch: 098, Loss: 1.26034, Train Acc: 0.94150, Val Acc: 0.79520
# Epoch: 099, Loss: 1.25930, Train Acc: 0.94089, Val Acc: 0.79336
# Epoch: 100, Loss: 1.25568, Train Acc: 0.94520, Val Acc: 0.79520
# Test Accuracy: 0.80443
# Random State 945321  in the iteration 8
# Epoch: 001, Loss: 1.30532, Train Acc: 0.89409, Val Acc: 0.88561
# Epoch: 002, Loss: 1.29837, Train Acc: 0.90702, Val Acc: 0.88561
# Epoch: 003, Loss: 1.29065, Train Acc: 0.91133, Val Acc: 0.88376
# Epoch: 004, Loss: 1.28608, Train Acc: 0.91687, Val Acc: 0.88192
# Epoch: 005, Loss: 1.28105, Train Acc: 0.91564, Val Acc: 0.88376
# Epoch: 006, Loss: 1.27183, Train Acc: 0.92426, Val Acc: 0.88192
# Epoch: 007, Loss: 1.27454, Train Acc: 0.92672, Val Acc: 0.88376
# Epoch: 008, Loss: 1.27247, Train Acc: 0.92734, Val Acc: 0.88007
# Epoch: 009, Loss: 1.27087, Train Acc: 0.92118, Val Acc: 0.87638
# Epoch: 010, Loss: 1.26635, Train Acc: 0.92980, Val Acc: 0.87454
# Epoch: 011, Loss: 1.27127, Train Acc: 0.92241, Val Acc: 0.86716
# Epoch: 012, Loss: 1.26808, Train Acc: 0.93165, Val Acc: 0.86531
# Epoch: 013, Loss: 1.26274, Train Acc: 0.93350, Val Acc: 0.85609
# Epoch: 014, Loss: 1.26360, Train Acc: 0.93165, Val Acc: 0.85424
# Epoch: 015, Loss: 1.26404, Train Acc: 0.93288, Val Acc: 0.84502
# Epoch: 016, Loss: 1.26273, Train Acc: 0.93227, Val Acc: 0.84871
# Epoch: 017, Loss: 1.26282, Train Acc: 0.92980, Val Acc: 0.84871
# Epoch: 018, Loss: 1.26446, Train Acc: 0.94027, Val Acc: 0.84502
# Epoch: 019, Loss: 1.26442, Train Acc: 0.92919, Val Acc: 0.84871
# Epoch: 020, Loss: 1.25524, Train Acc: 0.94273, Val Acc: 0.84317
# Epoch: 021, Loss: 1.25945, Train Acc: 0.93904, Val Acc: 0.83764
# Epoch: 022, Loss: 1.25976, Train Acc: 0.93842, Val Acc: 0.83210
# Epoch: 023, Loss: 1.26172, Train Acc: 0.93658, Val Acc: 0.83210
# Epoch: 024, Loss: 1.25275, Train Acc: 0.94150, Val Acc: 0.82657
# Epoch: 025, Loss: 1.25510, Train Acc: 0.93904, Val Acc: 0.82103
# Epoch: 026, Loss: 1.25716, Train Acc: 0.93781, Val Acc: 0.82288
# Epoch: 027, Loss: 1.26089, Train Acc: 0.93473, Val Acc: 0.82472
# Epoch: 028, Loss: 1.26127, Train Acc: 0.93534, Val Acc: 0.81919
# Epoch: 029, Loss: 1.25391, Train Acc: 0.94643, Val Acc: 0.82103
# Epoch: 030, Loss: 1.25802, Train Acc: 0.94335, Val Acc: 0.81919
# Epoch: 031, Loss: 1.26275, Train Acc: 0.93904, Val Acc: 0.82103
# Epoch: 032, Loss: 1.26506, Train Acc: 0.93719, Val Acc: 0.81734
# Epoch: 033, Loss: 1.26109, Train Acc: 0.93904, Val Acc: 0.81365
# Epoch: 034, Loss: 1.26010, Train Acc: 0.94704, Val Acc: 0.81365
# Epoch: 035, Loss: 1.25665, Train Acc: 0.94458, Val Acc: 0.80996
# Epoch: 036, Loss: 1.25653, Train Acc: 0.94458, Val Acc: 0.80627
# Epoch: 037, Loss: 1.25826, Train Acc: 0.94089, Val Acc: 0.80812
# Epoch: 038, Loss: 1.25496, Train Acc: 0.94212, Val Acc: 0.80812
# Epoch: 039, Loss: 1.26284, Train Acc: 0.94520, Val Acc: 0.80812
# Epoch: 040, Loss: 1.25475, Train Acc: 0.94581, Val Acc: 0.80996
# Epoch: 041, Loss: 1.25606, Train Acc: 0.94520, Val Acc: 0.80258
# Epoch: 042, Loss: 1.25813, Train Acc: 0.94273, Val Acc: 0.80627
# Epoch: 043, Loss: 1.25448, Train Acc: 0.94951, Val Acc: 0.80627
# Epoch: 044, Loss: 1.26040, Train Acc: 0.93411, Val Acc: 0.80627
# Epoch: 045, Loss: 1.25528, Train Acc: 0.94027, Val Acc: 0.80812
# Epoch: 046, Loss: 1.25236, Train Acc: 0.95074, Val Acc: 0.80443
# Epoch: 047, Loss: 1.25858, Train Acc: 0.94273, Val Acc: 0.80258
# Epoch: 048, Loss: 1.25718, Train Acc: 0.94273, Val Acc: 0.80443
# Epoch: 049, Loss: 1.25350, Train Acc: 0.94766, Val Acc: 0.80443
# Epoch: 050, Loss: 1.25760, Train Acc: 0.94212, Val Acc: 0.80443
# Epoch: 051, Loss: 1.25167, Train Acc: 0.95320, Val Acc: 0.80074
# Epoch: 052, Loss: 1.25451, Train Acc: 0.94889, Val Acc: 0.80258
# Epoch: 053, Loss: 1.25525, Train Acc: 0.94027, Val Acc: 0.80258
# ...
# Epoch: 055, Loss: 1.24016, Train Acc: 0.94150, Val Acc: 0.82841
# Epoch: 056, Loss: 1.23579, Train Acc: 0.94766, Val Acc: 0.82472
# Epoch: 057, Loss: 1.24286, Train Acc: 0.94150, Val Acc: 0.82472
# Epoch: 058, Loss: 1.23337, Train Acc: 0.94889, Val Acc: 0.82103
# Epoch: 059, Loss: 1.23787, Train Acc: 0.94520, Val Acc: 0.81365
# Epoch: 060, Loss: 1.23781, Train Acc: 0.94212, Val Acc: 0.81734
# Epoch: 061, Loss: 1.23876, Train Acc: 0.94150, Val Acc: 0.81365
# Epoch: 062, Loss: 1.24338, Train Acc: 0.94335, Val Acc: 0.81365
# Epoch: 063, Loss: 1.24143, Train Acc: 0.94273, Val Acc: 0.81734
# Epoch: 064, Loss: 1.24106, Train Acc: 0.94027, Val Acc: 0.81919
# Epoch: 065, Loss: 1.23814, Train Acc: 0.94089, Val Acc: 0.81550
# Epoch: 066, Loss: 1.24349, Train Acc: 0.94089, Val Acc: 0.80812
# Epoch: 067, Loss: 1.24218, Train Acc: 0.94150, Val Acc: 0.80812
# Epoch: 068, Loss: 1.23980, Train Acc: 0.94520, Val Acc: 0.80443
# Epoch: 069, Loss: 1.24613, Train Acc: 0.93411, Val Acc: 0.80443
# Epoch: 070, Loss: 1.24294, Train Acc: 0.93842, Val Acc: 0.80258
# Epoch: 071, Loss: 1.23923, Train Acc: 0.94027, Val Acc: 0.79889
# Epoch: 072, Loss: 1.24391, Train Acc: 0.93473, Val Acc: 0.80074
# Epoch: 073, Loss: 1.23794, Train Acc: 0.94704, Val Acc: 0.80258
# Epoch: 074, Loss: 1.23735, Train Acc: 0.94828, Val Acc: 0.80074
# Epoch: 075, Loss: 1.23834, Train Acc: 0.94397, Val Acc: 0.79520
# Epoch: 076, Loss: 1.24094, Train Acc: 0.93966, Val Acc: 0.79520
# Epoch: 077, Loss: 1.23820, Train Acc: 0.94273, Val Acc: 0.79705
# Epoch: 078, Loss: 1.23517, Train Acc: 0.94766, Val Acc: 0.80074
# Epoch: 079, Loss: 1.24614, Train Acc: 0.93904, Val Acc: 0.80443
# Epoch: 080, Loss: 1.23892, Train Acc: 0.94458, Val Acc: 0.80812
# Epoch: 081, Loss: 1.23971, Train Acc: 0.94581, Val Acc: 0.80627
# Epoch: 082, Loss: 1.23726, Train Acc: 0.94273, Val Acc: 0.80812
# Epoch: 083, Loss: 1.23588, Train Acc: 0.94212, Val Acc: 0.80258
# Epoch: 084, Loss: 1.23601, Train Acc: 0.94766, Val Acc: 0.79889
# Epoch: 085, Loss: 1.23362, Train Acc: 0.95012, Val Acc: 0.78967
# Epoch: 086, Loss: 1.23764, Train Acc: 0.94397, Val Acc: 0.78967
# Epoch: 087, Loss: 1.23963, Train Acc: 0.94643, Val Acc: 0.78967
# Epoch: 088, Loss: 1.23646, Train Acc: 0.94212, Val Acc: 0.79520
# Epoch: 089, Loss: 1.23791, Train Acc: 0.94212, Val Acc: 0.79336
# Epoch: 090, Loss: 1.23712, Train Acc: 0.94150, Val Acc: 0.80258
# Epoch: 091, Loss: 1.23576, Train Acc: 0.94520, Val Acc: 0.80258
# Epoch: 092, Loss: 1.23598, Train Acc: 0.94335, Val Acc: 0.80258
# Epoch: 093, Loss: 1.23579, Train Acc: 0.94643, Val Acc: 0.80074
# Epoch: 094, Loss: 1.23534, Train Acc: 0.94520, Val Acc: 0.79889
# Epoch: 095, Loss: 1.24142, Train Acc: 0.93719, Val Acc: 0.79151
# Epoch: 096, Loss: 1.23767, Train Acc: 0.94335, Val Acc: 0.78967
# Epoch: 097, Loss: 1.24010, Train Acc: 0.94212, Val Acc: 0.78044
# Epoch: 098, Loss: 1.23998, Train Acc: 0.94704, Val Acc: 0.78044
# Epoch: 099, Loss: 1.23888, Train Acc: 0.94643, Val Acc: 0.78782
# Epoch: 100, Loss: 1.23815, Train Acc: 0.94212, Val Acc: 0.78782
# Test Accuracy: 0.80443
# Random State 945321  in the iteration 8
# Epoch: 001, Loss: 1.32287, Train Acc: 0.86145, Val Acc: 0.86347
# Epoch: 002, Loss: 1.29810, Train Acc: 0.89163, Val Acc: 0.85609
# Epoch: 003, Loss: 1.29341, Train Acc: 0.88855, Val Acc: 0.85793
# Epoch: 004, Loss: 1.28043, Train Acc: 0.90025, Val Acc: 0.86347
# Epoch: 005, Loss: 1.26923, Train Acc: 0.91749, Val Acc: 0.85978
# Epoch: 006, Loss: 1.26483, Train Acc: 0.92241, Val Acc: 0.85978
# Epoch: 007, Loss: 1.25954, Train Acc: 0.93165, Val Acc: 0.85978
# Epoch: 008, Loss: 1.26500, Train Acc: 0.92057, Val Acc: 0.84871
# Epoch: 009, Loss: 1.25822, Train Acc: 0.92796, Val Acc: 0.84686
# Epoch: 010, Loss: 1.26149, Train Acc: 0.92180, Val Acc: 0.83948
# Epoch: 011, Loss: 1.26124, Train Acc: 0.92365, Val Acc: 0.83764
# Epoch: 012, Loss: 1.25669, Train Acc: 0.92611, Val Acc: 0.83210
# Epoch: 013, Loss: 1.25883, Train Acc: 0.92303, Val Acc: 0.82841
# Epoch: 014, Loss: 1.24890, Train Acc: 0.93042, Val Acc: 0.82841
# Epoch: 015, Loss: 1.25355, Train Acc: 0.92611, Val Acc: 0.82472
# Epoch: 016, Loss: 1.24692, Train Acc: 0.93596, Val Acc: 0.82472
# Epoch: 017, Loss: 1.25005, Train Acc: 0.93350, Val Acc: 0.82472
# Epoch: 018, Loss: 1.24965, Train Acc: 0.93042, Val Acc: 0.82472
# Epoch: 019, Loss: 1.24612, Train Acc: 0.93227, Val Acc: 0.82657
# Epoch: 020, Loss: 1.24724, Train Acc: 0.93411, Val Acc: 0.82657
# Epoch: 021, Loss: 1.24726, Train Acc: 0.93042, Val Acc: 0.82841
# Epoch: 022, Loss: 1.24173, Train Acc: 0.94027, Val Acc: 0.82841
# Epoch: 023, Loss: 1.24030, Train Acc: 0.93966, Val Acc: 0.82288
# Epoch: 024, Loss: 1.24262, Train Acc: 0.93658, Val Acc: 0.82657
# Epoch: 025, Loss: 1.24069, Train Acc: 0.93842, Val Acc: 0.82103
# Epoch: 026, Loss: 1.24647, Train Acc: 0.93042, Val Acc: 0.82103
# Epoch: 027, Loss: 1.24108, Train Acc: 0.93596, Val Acc: 0.82288
# Epoch: 028, Loss: 1.24094, Train Acc: 0.94150, Val Acc: 0.82472
# Epoch: 029, Loss: 1.24048, Train Acc: 0.94027, Val Acc: 0.82288
# Epoch: 030, Loss: 1.24211, Train Acc: 0.93596, Val Acc: 0.81550
# Epoch: 031, Loss: 1.23926, Train Acc: 0.94273, Val Acc: 0.81365
# Epoch: 032, Loss: 1.24208, Train Acc: 0.94212, Val Acc: 0.81365
# Epoch: 033, Loss: 1.24581, Train Acc: 0.93781, Val Acc: 0.81550
# Epoch: 034, Loss: 1.24193, Train Acc: 0.94212, Val Acc: 0.80812
# Epoch: 035, Loss: 1.23713, Train Acc: 0.94766, Val Acc: 0.80627
# Epoch: 036, Loss: 1.23630, Train Acc: 0.94397, Val Acc: 0.80258
# Epoch: 037, Loss: 1.24496, Train Acc: 0.94089, Val Acc: 0.80443
# Epoch: 038, Loss: 1.24542, Train Acc: 0.93473, Val Acc: 0.80258
# Epoch: 039, Loss: 1.24155, Train Acc: 0.93904, Val Acc: 0.80812
# Epoch: 040, Loss: 1.23404, Train Acc: 0.94643, Val Acc: 0.80443
# Epoch: 041, Loss: 1.23586, Train Acc: 0.94766, Val Acc: 0.80812
# Epoch: 042, Loss: 1.24046, Train Acc: 0.94273, Val Acc: 0.80627
# Epoch: 043, Loss: 1.23856, Train Acc: 0.94704, Val Acc: 0.81550
# Epoch: 044, Loss: 1.24206, Train Acc: 0.93904, Val Acc: 0.81181
# Epoch: 045, Loss: 1.23541, Train Acc: 0.94951, Val Acc: 0.81181
# Epoch: 046, Loss: 1.24246, Train Acc: 0.94027, Val Acc: 0.80812
# Epoch: 047, Loss: 1.24059, Train Acc: 0.94150, Val Acc: 0.80627
# Epoch: 048, Loss: 1.23848, Train Acc: 0.94458, Val Acc: 0.80258
# Epoch: 049, Loss: 1.23481, Train Acc: 0.94335, Val Acc: 0.80074
# Epoch: 050, Loss: 1.23655, Train Acc: 0.94581, Val Acc: 0.79889
# Epoch: 051, Loss: 1.23242, Train Acc: 0.94889, Val Acc: 0.80443
# Epoch: 052, Loss: 1.23307, Train Acc: 0.94889, Val Acc: 0.80443
# Epoch: 053, Loss: 1.23385, Train Acc: 0.95012, Val Acc: 0.80812
# Epoch: 054, Loss: 1.23888, Train Acc: 0.94397, Val Acc: 0.81365
# Epoch: 055, Loss: 1.23416, Train Acc: 0.94828, Val Acc: 0.81919
# Epoch: 056, Loss: 1.23000, Train Acc: 0.95074, Val Acc: 0.81734
# Epoch: 057, Loss: 1.23380, Train Acc: 0.94828, Val Acc: 0.81550
# Epoch: 058, Loss: 1.23074, Train Acc: 0.95012, Val Acc: 0.81919
# Epoch: 059, Loss: 1.23165, Train Acc: 0.95135, Val Acc: 0.81365
# Epoch: 060, Loss: 1.23455, Train Acc: 0.94889, Val Acc: 0.81365
# Epoch: 061, Loss: 1.22886, Train Acc: 0.95197, Val Acc: 0.80074
# Epoch: 062, Loss: 1.23080, Train Acc: 0.95320, Val Acc: 0.80074
# Epoch: 063, Loss: 1.23326, Train Acc: 0.94766, Val Acc: 0.79889
# Epoch: 064, Loss: 1.23178, Train Acc: 0.95074, Val Acc: 0.80443
# Epoch: 065, Loss: 1.22928, Train Acc: 0.95197, Val Acc: 0.80443
# Epoch: 066, Loss: 1.23174, Train Acc: 0.95135, Val Acc: 0.80627
# Epoch: 067, Loss: 1.23420, Train Acc: 0.94704, Val Acc: 0.81365
# Epoch: 068, Loss: 1.23352, Train Acc: 0.95012, Val Acc: 0.80812
# Epoch: 069, Loss: 1.22924, Train Acc: 0.95443, Val Acc: 0.80812
# Epoch: 070, Loss: 1.23240, Train Acc: 0.94828, Val Acc: 0.80627
# Epoch: 071, Loss: 1.23058, Train Acc: 0.95197, Val Acc: 0.80074
# Epoch: 072, Loss: 1.23250, Train Acc: 0.94766, Val Acc: 0.79520
# Epoch: 073, Loss: 1.23061, Train Acc: 0.95259, Val Acc: 0.79336
# Epoch: 074, Loss: 1.22981, Train Acc: 0.95259, Val Acc: 0.79520
# Epoch: 075, Loss: 1.23200, Train Acc: 0.95074, Val Acc: 0.79520
# Epoch: 076, Loss: 1.23183, Train Acc: 0.94889, Val Acc: 0.79336
# Epoch: 077, Loss: 1.23309, Train Acc: 0.95135, Val Acc: 0.78598
# Epoch: 078, Loss: 1.23077, Train Acc: 0.95382, Val Acc: 0.78413
# Epoch: 079, Loss: 1.22921, Train Acc: 0.94951, Val Acc: 0.78782
# Epoch: 080, Loss: 1.23006, Train Acc: 0.95320, Val Acc: 0.78967
# Epoch: 081, Loss: 1.22911, Train Acc: 0.94889, Val Acc: 0.78782
# Epoch: 082, Loss: 1.23148, Train Acc: 0.94951, Val Acc: 0.78782
# Epoch: 083, Loss: 1.23770, Train Acc: 0.94335, Val Acc: 0.79889
# Epoch: 084, Loss: 1.23420, Train Acc: 0.95074, Val Acc: 0.80443
# Epoch: 085, Loss: 1.23547, Train Acc: 0.94766, Val Acc: 0.80443
# Epoch: 086, Loss: 1.23372, Train Acc: 0.94704, Val Acc: 0.79705
# Epoch: 087, Loss: 1.23583, Train Acc: 0.94458, Val Acc: 0.79336
# Epoch: 088, Loss: 1.23898, Train Acc: 0.94335, Val Acc: 0.79520
# Epoch: 089, Loss: 1.23556, Train Acc: 0.95012, Val Acc: 0.79705
# Epoch: 090, Loss: 1.23464, Train Acc: 0.95135, Val Acc: 0.79336
# Epoch: 091, Loss: 1.23430, Train Acc: 0.95259, Val Acc: 0.79889
# Epoch: 092, Loss: 1.23168, Train Acc: 0.95135, Val Acc: 0.80258
# Epoch: 093, Loss: 1.22857, Train Acc: 0.95382, Val Acc: 0.80258
# Epoch: 094, Loss: 1.23021, Train Acc: 0.95320, Val Acc: 0.80074
# Epoch: 095, Loss: 1.23139, Train Acc: 0.95320, Val Acc: 0.79889
# Epoch: 096, Loss: 1.23024, Train Acc: 0.95074, Val Acc: 0.79889
# Epoch: 097, Loss: 1.23711, Train Acc: 0.94335, Val Acc: 0.79889
# Epoch: 098, Loss: 1.23024, Train Acc: 0.95074, Val Acc: 0.80074
# Epoch: 099, Loss: 1.23081, Train Acc: 0.95074, Val Acc: 0.79889
# Epoch: 100, Loss: 1.23270, Train Acc: 0.94828, Val Acc: 0.80443
# Test Accuracy: 0.80627
# Random State 784328  in the iteration 9
# Epoch: 001, Loss: 1.32001, Train Acc: 0.86330, Val Acc: 0.85055
# Epoch: 002, Loss: 1.30091, Train Acc: 0.88054, Val Acc: 0.85609
# Epoch: 003, Loss: 1.29222, Train Acc: 0.88424, Val Acc: 0.86162
# Epoch: 004, Loss: 1.28071, Train Acc: 0.89594, Val Acc: 0.85609
# Epoch: 005, Loss: 1.27575, Train Acc: 0.90702, Val Acc: 0.85424
# Epoch: 006, Loss: 1.27125, Train Acc: 0.91318, Val Acc: 0.85055
# Epoch: 007, Loss: 1.27193, Train Acc: 0.91133, Val Acc: 0.85240
# Epoch: 008, Loss: 1.26055, Train Acc: 0.91872, Val Acc: 0.85240
# Epoch: 009, Loss: 1.26221, Train Acc: 0.92426, Val Acc: 0.84871
# Epoch: 010, Loss: 1.26199, Train Acc: 0.92426, Val Acc: 0.84502
# Epoch: 011, Loss: 1.25119, Train Acc: 0.92611, Val Acc: 0.84871
# Epoch: 012, Loss: 1.25309, Train Acc: 0.92796, Val Acc: 0.84317
# Epoch: 013, Loss: 1.25375, Train Acc: 0.92611, Val Acc: 0.84317
# Epoch: 014, Loss: 1.25142, Train Acc: 0.92919, Val Acc: 0.84502
# Epoch: 015, Loss: 1.24863, Train Acc: 0.93165, Val Acc: 0.83579
# Epoch: 016, Loss: 1.25066, Train Acc: 0.92919, Val Acc: 0.84317
# Epoch: 017, Loss: 1.25040, Train Acc: 0.92919, Val Acc: 0.83764
# Epoch: 018, Loss: 1.24763, Train Acc: 0.93288, Val Acc: 0.84133
# Epoch: 019, Loss: 1.25140, Train Acc: 0.92857, Val Acc: 0.83948
# Epoch: 020, Loss: 1.24726, Train Acc: 0.93658, Val Acc: 0.83395
# Epoch: 021, Loss: 1.24770, Train Acc: 0.93165, Val Acc: 0.83395
# Epoch: 022, Loss: 1.24024, Train Acc: 0.93966, Val Acc: 0.83395
# Epoch: 023, Loss: 1.24315, Train Acc: 0.93966, Val Acc: 0.83764
# Epoch: 024, Loss: 1.24310, Train Acc: 0.93658, Val Acc: 0.83948
# Epoch: 025, Loss: 1.24349, Train Acc: 0.93719, Val Acc: 0.84133
# Epoch: 026, Loss: 1.24291, Train Acc: 0.93719, Val Acc: 0.83948
# Epoch: 027, Loss: 1.24204, Train Acc: 0.93966, Val Acc: 0.83395
# Epoch: 028, Loss: 1.24211, Train Acc: 0.93411, Val Acc: 0.83210
# Epoch: 029, Loss: 1.24125, Train Acc: 0.93842, Val Acc: 0.83210
# Epoch: 030, Loss: 1.24128, Train Acc: 0.94027, Val Acc: 0.82841
# Epoch: 031, Loss: 1.24367, Train Acc: 0.93842, Val Acc: 0.82472
# Epoch: 032, Loss: 1.24449, Train Acc: 0.93658, Val Acc: 0.82472
# Epoch: 033, Loss: 1.23880, Train Acc: 0.93842, Val Acc: 0.82657
# Epoch: 034, Loss: 1.24116, Train Acc: 0.93904, Val Acc: 0.83026
# Epoch: 035, Loss: 1.23352, Train Acc: 0.94704, Val Acc: 0.83210
# Epoch: 036, Loss: 1.23703, Train Acc: 0.94458, Val Acc: 0.83210
# Epoch: 037, Loss: 1.23912, Train Acc: 0.94273, Val Acc: 0.83210
# Epoch: 038, Loss: 1.24089, Train Acc: 0.94273, Val Acc: 0.82841
# Epoch: 039, Loss: 1.24491, Train Acc: 0.93966, Val Acc: 0.83026
# Epoch: 040, Loss: 1.24384, Train Acc: 0.93658, Val Acc: 0.82657
# Epoch: 041, Loss: 1.23801, Train Acc: 0.94212, Val Acc: 0.82288
# Epoch: 042, Loss: 1.24200, Train Acc: 0.93842, Val Acc: 0.81734
# Epoch: 043, Loss: 1.24470, Train Acc: 0.93411, Val Acc: 0.81734
# Epoch: 044, Loss: 1.24055, Train Acc: 0.94889, Val Acc: 0.81734
# Epoch: 045, Loss: 1.24481, Train Acc: 0.93658, Val Acc: 0.81365
# Epoch: 046, Loss: 1.24057, Train Acc: 0.94027, Val Acc: 0.80996
# Epoch: 047, Loss: 1.23516, Train Acc: 0.94889, Val Acc: 0.80996
# Epoch: 048, Loss: 1.23856, Train Acc: 0.94397, Val Acc: 0.80996
# Epoch: 049, Loss: 1.23441, Train Acc: 0.94828, Val Acc: 0.80996
# Epoch: 050, Loss: 1.23269, Train Acc: 0.94581, Val Acc: 0.81734
# Epoch: 051, Loss: 1.24350, Train Acc: 0.94150, Val Acc: 0.81181
# Epoch: 052, Loss: 1.23615, Train Acc: 0.94951, Val Acc: 0.81181
# Epoch: 053, Loss: 1.23403, Train Acc: 0.94951, Val Acc: 0.80812
# Epoch: 054, Loss: 1.23443, Train Acc: 0.94643, Val Acc: 0.80812
# Epoch: 055, Loss: 1.23627, Train Acc: 0.94397, Val Acc: 0.80812
# Epoch: 056, Loss: 1.23849, Train Acc: 0.94150, Val Acc: 0.81181
# Epoch: 057, Loss: 1.23628, Train Acc: 0.94520, Val Acc: 0.80996
# Epoch: 058, Loss: 1.23521, Train Acc: 0.94643, Val Acc: 0.80812
# Epoch: 059, Loss: 1.23432, Train Acc: 0.94951, Val Acc: 0.81181
# Epoch: 060, Loss: 1.23851, Train Acc: 0.94520, Val Acc: 0.81181
# Epoch: 061, Loss: 1.23573, Train Acc: 0.95012, Val Acc: 0.80443
# Epoch: 062, Loss: 1.23581, Train Acc: 0.94581, Val Acc: 0.80627
# Epoch: 063, Loss: 1.23437, Train Acc: 0.95135, Val Acc: 0.80996
# Epoch: 064, Loss: 1.24006, Train Acc: 0.94458, Val Acc: 0.80812
# Epoch: 065, Loss: 1.23412, Train Acc: 0.95012, Val Acc: 0.80812
# Epoch: 066, Loss: 1.23614, Train Acc: 0.94828, Val Acc: 0.81365
# Epoch: 067, Loss: 1.23276, Train Acc: 0.94889, Val Acc: 0.81181
# Epoch: 068, Loss: 1.24042, Train Acc: 0.94027, Val Acc: 0.80812
# Epoch: 069, Loss: 1.23012, Train Acc: 0.95012, Val Acc: 0.80812
# Epoch: 070, Loss: 1.23480, Train Acc: 0.94889, Val Acc: 0.80996
# Epoch: 071, Loss: 1.23531, Train Acc: 0.94828, Val Acc: 0.81181
# Epoch: 072, Loss: 1.23338, Train Acc: 0.94951, Val Acc: 0.80812
# Epoch: 073, Loss: 1.23596, Train Acc: 0.94889, Val Acc: 0.80996
# Epoch: 074, Loss: 1.23342, Train Acc: 0.94643, Val Acc: 0.81181
# Epoch: 075, Loss: 1.23212, Train Acc: 0.95135, Val Acc: 0.81181
# Epoch: 076, Loss: 1.23576, Train Acc: 0.94704, Val Acc: 0.80996
# Epoch: 077, Loss: 1.23381, Train Acc: 0.94889, Val Acc: 0.80812
# Epoch: 078, Loss: 1.23572, Train Acc: 0.94643, Val Acc: 0.81365
# Epoch: 079, Loss: 1.23306, Train Acc: 0.95012, Val Acc: 0.80258
# Epoch: 080, Loss: 1.23400, Train Acc: 0.94704, Val Acc: 0.79151
# Epoch: 081, Loss: 1.23030, Train Acc: 0.95074, Val Acc: 0.79151
# Epoch: 082, Loss: 1.23581, Train Acc: 0.94581, Val Acc: 0.78967
# Epoch: 083, Loss: 1.23540, Train Acc: 0.94581, Val Acc: 0.78782
# Epoch: 084, Loss: 1.23965, Train Acc: 0.94458, Val Acc: 0.78598
# Epoch: 085, Loss: 1.23580, Train Acc: 0.94889, Val Acc: 0.78782
# Epoch: 086, Loss: 1.23888, Train Acc: 0.94335, Val Acc: 0.79151
# Epoch: 087, Loss: 1.23372, Train Acc: 0.94951, Val Acc: 0.79520
# Epoch: 088, Loss: 1.23502, Train Acc: 0.94581, Val Acc: 0.79705
# Epoch: 089, Loss: 1.23819, Train Acc: 0.94581, Val Acc: 0.79520
# Epoch: 090, Loss: 1.23140, Train Acc: 0.95197, Val Acc: 0.79151
# Epoch: 091, Loss: 1.23637, Train Acc: 0.94704, Val Acc: 0.79520
# Epoch: 092, Loss: 1.23304, Train Acc: 0.94766, Val Acc: 0.80812
# Epoch: 093, Loss: 1.23392, Train Acc: 0.94704, Val Acc: 0.80627
# Epoch: 094, Loss: 1.23527, Train Acc: 0.94520, Val Acc: 0.80074
# Epoch: 095, Loss: 1.23828, Train Acc: 0.94273, Val Acc: 0.79336
# Epoch: 096, Loss: 1.23322, Train Acc: 0.94889, Val Acc: 0.79151
# Epoch: 097, Loss: 1.23471, Train Acc: 0.94643, Val Acc: 0.78782
# Epoch: 098, Loss: 1.23053, Train Acc: 0.95012, Val Acc: 0.78967
# Epoch: 099, Loss: 1.23161, Train Acc: 0.94951, Val Acc: 0.79705
# Epoch: 100, Loss: 1.23334, Train Acc: 0.95320, Val Acc: 0.79889
# Test Accuracy: 0.81181
# GAT
# 79.98154981549814 +- 1.5062629381465555

# %% [markdown]
# Apenas diferencia entre train semi supervised y el supervised para la GCN
#
# Mejor SAGE con primera capa aggr=max y las segunda defalt con aggr=mean
#
# Cheb mejora con aumenta K, nos quedamos con K=10

# %% [markdown]
# #### Visualize the results and the embedding

# %%
fig,axs = plt.subplots(1,2,figsize=(20,8))
axs[0].set_title('GCN boxplot of 10 runs')
axs[0].boxplot(global_results,labels=['GCN','MLP', 'SAGE', 'Cheb', 'GAT'])
axs[0].set_xlabel('Run')
axs[0].set_ylabel('Accuracy')

axs[1].set_title('Models lineplot of 10 runs')
axs[1].plot(range(1,11),global_results[0],'ro',color='red')
axs[1].plot(range(1,11),global_results[0],color='red',label='GCN')

axs[1].plot(range(1,11),global_results[1],'ro',color='blue')
axs[1].plot(range(1,11),global_results[1],color='blue',label='MLP')

axs[1].plot(range(1,11),global_results[2],'ro',color='green')
axs[1].plot(range(1,11),global_results[2],color='green',label='SAGE')

axs[1].plot(range(1,11),global_results[3],'ro',color='k')
axs[1].plot(range(1,11),global_results[3],color='k',label='Cheb')

axs[1].plot(range(1,11),global_results[4],'ro',color='violet')
axs[1].plot(range(1,11),global_results[4],color='violet',label='GAT')

axs[1].set_xticks(range(1,11))
axs[1].set_xlabel('Run')
axs[1].set_ylabel('Accuracy')
axs[1].legend()
fig.show()

# %%
from sklearn.manifold import TSNE
# Let's see the embedding of the best model over the 10 runs

'''
    Arguments of TSNE:
        * n_components: The dimension of the embedded space.
        * random_state: The seed to use for the t-SNE algorithm.
    Returns:
        * tsne_obj: The t-SNE embedding of the nodes.
'''

# GCN
out_gcn = global_best_models[0][0](data.x, data.edge_index) # Get the output of the model with the entire dataset
tsne = TSNE(n_components=2, random_state=12345)
tsne_gcn_results = tsne.fit_transform(out_gcn.detach().cpu().numpy())
# SAGE
out_sage = global_best_models[2][0](data.x, data.edge_index) # Get the output of the model with the entire dataset
tsne = TSNE(n_components=2, random_state=12345)
tsne_sage_results = tsne.fit_transform(out_sage.detach().cpu().numpy())
# Cheb
out_cheb = global_best_models[3][0](data.x, data.edge_index) # Get the output of the model with the entire dataset
tsne = TSNE(n_components=2, random_state=12345)
tsne_cheb_results = tsne.fit_transform(out_cheb.detach().cpu().numpy())
# GAT
out_gat = global_best_models[4][0](data.x, data.edge_index) # Get the output of the model with the entire dataset
tsne = TSNE(n_components=2, random_state=12345)
tsne_gat_results = tsne.fit_transform(out_gat.detach().cpu().numpy())
# MLP
out_mlp = global_best_models[1][0](data.x, data.edge_index) # Get the output of the model with the entire dataset
tsne = TSNE(n_components=2, random_state=12345)
tsne_mlp_results = tsne.fit_transform(out_mlp.detach().cpu().numpy())
# Plot the results
fig,axs = plt.subplots(3,2,figsize=(20,10))
axs[0,0].set_title('GCN t-SNE')
axs[0,0].scatter(tsne_gcn_results[:,0],tsne_gcn_results[:,1],c=data.y.cpu(),cmap='viridis',s=60,alpha=0.85,edgecolors='black',linewidths=0.5)

axs[0,1].set_title('MLP t-SNE')
axs[0,1].scatter(tsne_mlp_results[:,0],tsne_mlp_results[:,1],c=data.y.cpu(),cmap='viridis',s=60,alpha=0.85,edgecolors='black',linewidths=0.5)

axs[1,0].set_title('SAGE t-SNE')
axs[1,0].scatter(tsne_sage_results[:,0],tsne_sage_results[:,1],c=data.y.cpu(),cmap='viridis',s=60,alpha=0.85,edgecolors='black',linewidths=0.5)

axs[1,1].set_title('Cheb t-SNE')
axs[1,1].scatter(tsne_cheb_results[:,0],tsne_cheb_results[:,1],c=data.y.cpu(),cmap='viridis',s=60,alpha=0.85,edgecolors='black',linewidths=0.5)

axs[2,0].set_title('GAT t-SNE')
axs[2,0].scatter(tsne_gat_results[:,0],tsne_gat_results[:,1],c=data.y.cpu(),cmap='viridis',s=60,alpha=0.85,edgecolors='black',linewidths=0.5)

fig.suptitle('t-SNE of the best model over the 10 runs',fontsize=20)
fig.show()

# %% [markdown]
# ### 3.1 Report

# %% [markdown]
# In this section we will report the results of the model. We will report the accuracy, precision, recall and F1 score for the model. We will also visualize the confusion matrix for the model using the scikit-learn library to report the results. After all, we will put the results in a markdown cell.

# %% [markdown]
# #### Report the results

# %%
# Report the best model over the 10 runs using the test set and sklearn classification report
from sklearn.metrics import classification_report
print('GCN')
print(classification_report(data.y[test_mask].cpu(), global_best_models[0][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy()))
print('========================================================================')
print('MLP')
print(classification_report(data.y[test_mask].cpu(), global_best_models[1][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy()))
print('SAGE')
print(classification_report(data.y[test_mask].cpu(), global_best_models[2][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy()))
print('========================================================================')
print('Cheb')
print(classification_report(data.y[test_mask].cpu(), global_best_models[3][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy()))
print('========================================================================')
print('GAT')
print(classification_report(data.y[test_mask].cpu(), global_best_models[4][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy()))
print('========================================================================')
# Out:
# GCN
#               precision    recall  f1-score   support
#
#            0       0.68      0.81      0.74        57
#            1       0.93      0.93      0.93        44
#            2       0.94      0.97      0.95        75
#            3       0.95      0.92      0.93       174
#            4       0.89      0.88      0.89        92
#            5       0.90      0.86      0.88        64
#            6       0.97      0.83      0.90        36
#
#     accuracy                           0.90       542
#    macro avg       0.89      0.89      0.89       542
# weighted avg       0.90      0.90      0.90       542
#
# ========================================================================
# MLP
#               precision    recall  f1-score   support
#
#            0       0.57      0.60      0.58        57
#            1       0.83      0.77      0.80        44
#            2       0.88      0.87      0.87        75
#            3       0.83      0.78      0.81       174
#            4       0.71      0.91      0.80        92
#            5       0.84      0.73      0.78        64
#            6       0.69      0.56      0.62        36
#
#     accuracy                           0.77       542
#    macro avg       0.76      0.75      0.75       542
# weighted avg       0.78      0.77      0.77       542
#
# SAGE
#               precision    recall  f1-score   support
#
#            0       0.71      0.79      0.75        57
#            1       0.87      0.91      0.89        44
#            2       0.91      0.97      0.94        75
#            3       0.96      0.87      0.91       174
#            4       0.85      0.93      0.89        92
#            5       0.92      0.86      0.89        64
#            6       0.88      0.83      0.86        36
#
#     accuracy                           0.89       542
#    macro avg       0.87      0.88      0.88       542
# weighted avg       0.89      0.89      0.89       542
#
# ========================================================================
# Cheb
#               precision    recall  f1-score   support
#
#            0       0.72      0.72      0.72        57
#            1       0.86      0.86      0.86        44
#            2       0.90      0.95      0.92        75
#            3       0.92      0.89      0.90       174
#            4       0.91      0.91      0.91        92
#            5       0.90      0.86      0.88        64
#            6       0.79      0.92      0.85        36
#
#     accuracy                           0.88       542
#    macro avg       0.86      0.87      0.86       542
# weighted avg       0.88      0.88      0.88       542
#
# ========================================================================
# GAT
#               precision    recall  f1-score   support
#
#            0       0.74      0.84      0.79        57
#            1       0.86      0.84      0.85        44
#            2       0.93      0.92      0.93        75
#            3       0.89      0.92      0.91       174
#            4       0.92      0.88      0.90        92
#            5       0.85      0.83      0.84        64
#            6       0.97      0.83      0.90        36
#
#     accuracy                           0.88       542
#    macro avg       0.88      0.87      0.87       542
# weighted avg       0.88      0.88      0.88       542
#
# ========================================================================

# %% [markdown]
# #### Confusion matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Crear las matrices de confusión
conf_matrix_gcn = confusion_matrix(data.y[test_mask].cpu(), global_best_models[0][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy())
conf_matrix_mlp = confusion_matrix(data.y[test_mask].cpu(), global_best_models[1][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy())
conf_matrix_sage = confusion_matrix(data.y[test_mask].cpu(), global_best_models[2][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy())
conf_matrix_cheb = confusion_matrix(data.y[test_mask].cpu(), global_best_models[3][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy())
conf_matrix_gat = confusion_matrix(data.y[test_mask].cpu(), global_best_models[4][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy())

# Crear los displays de las matrices de confusión
disp_gcn = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_gcn, display_labels=data.y.unique().cpu().numpy())
disp_mlp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_mlp, display_labels=data.y.unique().cpu().numpy())
disp_sage = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_sage, display_labels=data.y.unique().cpu().numpy())
disp_cheb = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_cheb, display_labels=data.y.unique().cpu().numpy())
disp_gat = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_gat, display_labels=data.y.unique().cpu().numpy())

# Crear la figura y los ejes
fig, axs = plt.subplots(3, 2, figsize=(20, 15))

# Plotear las matrices de confusión
disp_gcn.plot(ax=axs[0][0])
disp_gcn.ax_.set_title('GCN Confusion Matrix')
disp_gcn.im_.colorbar.remove()

disp_mlp.plot(ax=axs[0][1])
disp_mlp.ax_.set_title('MLP Confusion Matrix')
disp_mlp.im_.colorbar.remove()

disp_sage.plot(ax=axs[1][0])
disp_sage.ax_.set_title('SAGE Confusion Matrix')
disp_sage.im_.colorbar.remove()

disp_cheb.plot(ax=axs[1][1])
disp_cheb.ax_.set_title('Cheb Confusion Matrix')
disp_cheb.im_.colorbar.remove()

# Colocar la última matriz en la posición central de la tercera fila
disp_gat.plot(ax=axs[2][0])
disp_gat.ax_.set_title('GAT Confusion Matrix')
disp_gat.im_.colorbar.remove()

# Eliminar el subplot vacío
fig.delaxes(axs[2][1])

# Ajustar el diseño
fig.tight_layout(rect=[0, 0, 1, 0.95])
fig.suptitle('Confusion Matrix of the best model over the 10 runs', fontsize=20)

# Mostrar la figura
plt.show()
