# %% [markdown]
# # Node classification practice

# %%
#Libraries we are going to use
# Install required packages.
import os
import torch #Library for deep learning
os.environ['TORCH'] = torch.__version__
print(torch.__version__)

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git
COLLAB_ENV = True
if COLLAB_ENV:
    # !pip install 'scipy>=1.8'
    # !pip install mycolorpy
import numpy as np #Library for linear algebra
import matplotlib.pyplot as plt #Library for plotting
import networkx as nx #Library for graph
from torch_geometric.datasets import Planetoid,WebKB, Actor #Library for graph dataset and deep learning on graphs
from torch_geometric.utils import to_dense_adj
import warnings
warnings.filterwarnings("ignore") # Get rid of warnings
# Out:
# 2.2.1+cu121
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 21.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 16.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for torch-geometric (pyproject.toml) ... done
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.10/dist-packages (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy>=1.8) (1.25.2)
# Collecting mycolorpy
#   Downloading mycolorpy-1.5.1.tar.gz (2.5 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mycolorpy) (1.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mycolorpy) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mycolorpy) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mycolorpy) (1.16.0)
# Building wheels for collected packages: mycolorpy
#   Building wheel for mycolorpy (setup.py) ... done
#   Created wheel for mycolorpy: filename=mycolorpy-1.5.1-py3-none-any.whl size=3851 sha256=2f0b08f5a80130999a35fdb5df2c3a33e3d09dc7abd67e900df7ab2e8e428cdf
#   Stored in directory: /root/.cache/pip/wheels/d6/1d/04/f8bfb8b04e3daba330b3f377c041b89304271ff98fb6704946
# Successfully built mycolorpy
# Installing collected packages: mycolorpy
# Successfully installed mycolorpy-1.5.1

# %% [markdown]
# ### 1. Load data and visualize it

# %%
'''
    Load the dataset:
        * root: The root directory where the dataset should be saved.
        * name: The name of the dataset (cora, citeseer or pubmed).
        * transform: A function/transform that takes in an Data object of the dataset and returns a transformed version. The data object will be transformed before every access.
    Returns:
        * Dataset object
'''

data_Cornell = WebKB(root='/tmp/Cornell', name='Cornell') # Load the Cornell dataset (homogeneous)
dataset = data_Cornell
data = dataset[0] # Get the first graph object (in this case is only one graph, while in Graph classification there are multiple graphs)
print()
print(f'Dataset: {dataset}:')
print('======================')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.num_classes}')
print()
print(data) # Note that the adjacency matrix is not stored explicitly but in the edge_index attribute.
            # The edge_index attribute is a 2 x E tensor, with each column denoting an edge.
            # The first row denotes the source nodes and the second row the destination nodes of the edges.
            # The nodes are numbered consecutively starting from zero.
            # The features are stored in the x attribute, which is a N x F tensor, with N being the number of nodes and F the number of features per node.
            # The labels are stored in the y attribute, which is a vector of length N, with each entry denoting the class of the corresponding node.
print('===========================================================================================================')
adj = to_dense_adj(data.edge_index)[0] # Convert the sparse adjacency matrix to a dense adjacency matrix
print("Shape of the new adjacency matrix: ",adj.shape)
#Let's get statistics about the graph adjacency matrix
print("Number of nodes: ",adj.shape[0])
print("Number of edges: ",round(adj.sum().item()))
print("Density: ",round((adj.sum()/(adj.shape[0]*adj.shape[0])).item(),4))
print("Maximum node degree: ",round(adj.sum(axis=1).max().item()))
print("Minimum node degree: ",round(adj.sum(axis=1).min().item()))
print("Average node degree: ",round(adj.sum(axis=1).mean().item()))
print(f'Has isolated nodes: {data.has_isolated_nodes()}')
print(f'Has self-loops: {data.has_self_loops()}')
print(f'Is undirected: {data.is_undirected()}')
print('===========================================================================================================')
# Out:
# Downloading https://raw.githubusercontent.com/graphdml-uiuc-jlu/geom-gcn/master/new_data/cornell/out1_node_feature_label.txt
# Downloading https://raw.githubusercontent.com/graphdml-uiuc-jlu/geom-gcn/master/new_data/cornell/out1_graph_edges.txt
# Downloading https://raw.githubusercontent.com/graphdml-uiuc-jlu/geom-gcn/master/splits/cornell_split_0.6_0.2_0.npz
# Downloading https://raw.githubusercontent.com/graphdml-uiuc-jlu/geom-gcn/master/splits/cornell_split_0.6_0.2_1.npz
# Downloading https://raw.githubusercontent.com/graphdml-uiuc-jlu/geom-gcn/master/splits/cornell_split_0.6_0.2_2.npz
# Downloading https://raw.githubusercontent.com/graphdml-uiuc-jlu/geom-gcn/master/splits/cornell_split_0.6_0.2_3.npz
# Downloading https://raw.githubusercontent.com/graphdml-uiuc-jlu/geom-gcn/master/splits/cornell_split_0.6_0.2_4.npz
# Downloading https://raw.githubusercontent.com/graphdml-uiuc-jlu/geom-gcn/master/splits/cornell_split_0.6_0.2_5.npz
# Downloading https://raw.githubusercontent.com/graphdml-uiuc-jlu/geom-gcn/master/splits/cornell_split_0.6_0.2_6.npz
# Downloading https://raw.githubusercontent.com/graphdml-uiuc-jlu/geom-gcn/master/splits/cornell_split_0.6_0.2_7.npz
# Downloading https://raw.githubusercontent.com/graphdml-uiuc-jlu/geom-gcn/master/splits/cornell_split_0.6_0.2_8.npz
# Downloading https://raw.githubusercontent.com/graphdml-uiuc-jlu/geom-gcn/master/splits/cornell_split_0.6_0.2_9.npz
# Processing...
# Dataset: cornell():
# ======================
# Number of graphs: 1
# Number of features: 1703
# Number of classes: 5
#
# Data(x=[183, 1703], edge_index=[2, 298], y=[183], train_mask=[183, 10], val_mask=[183, 10], test_mask=[183, 10])
# ===========================================================================================================
# Shape of the new adjacency matrix:  torch.Size([183, 183])
# Number of nodes:  183
# Number of edges:  298
# Density:  0.0089
# Maximum node degree:  93
# Minimum node degree:  0
# Average node degree:  2
# Has isolated nodes: False
# Has self-loops: True
# Is undirected: False
# ===========================================================================================================
# Done!

# %%
def calculate_homophily(edge_index, labels):
    num_edges = edge_index.size(1)
    same_label_edges = 0

    for i in range(num_edges):
        src, dst = edge_index[:, i]
        if labels[src] == labels[dst]:
            same_label_edges += 1

    homophily = same_label_edges / num_edges
    return homophily

homophily = calculate_homophily(data.edge_index, data.y)
print(f'Grado de homofilia: {homophily:.4f}')
# Out:
# Grado de homofilia: 0.1309

# %% [markdown]
# ### 1.1 Visualize the graph

# %%
# To visualize the graph we are going to use networkx library, but first we need to convert the graph to networkx format
from torch_geometric.utils import to_networkx
A = to_networkx(data, to_undirected=True) # Convert the graph to networkx format
# Now we are going to get the largest connected component of the graph, because the graph is not connected!
Gcc = sorted(nx.connected_components(A), key=len, reverse=True) # Get the sorted list of connected components
A = A.subgraph(Gcc[0]) # Get the largest connected component
G = nx.adjacency_matrix(A)
# All the following code is just for plotting the graph, so you can ignore it
# This how we can get the edge_index attribute for the largest connected component
g_tensor = torch.tensor(G.todense())
new_edge_index = g_tensor.nonzero().t().contiguous()
# This is how we create the new data object for the largest connected component
data.x = data.x[list(A.nodes())]
data.y = data.y[list(A.nodes())]
data.edge_index = new_edge_index
data.num_nodes = len(A.nodes())
data.num_edges = len(A.edges())
print(data)
# Now we can plot the graph
A = to_networkx(data, to_undirected=True) # Convert the graph to networkx format
plt.figure(figsize=(20,15))
plt.title('Largest connected component',fontsize=20)
pos = nx.spring_layout(A,seed=12)
#Let's drow the graph, adding borders to the nodes
'''
    Arguments of nx.draw:
        * G: The graph to draw.
        * node_color: The color of the nodes.
        * pos: A dictionary with nodes as keys and positions as values.
        * cmap: A colormap or registered colormap name.
        * node_size: The size of the nodes.
        * edge_color: The color of the edges.
        * width: The width of the edges.
        * with_labels: Whether to draw the node labels.
        * node_shape: The shape of the nodes.
        * alpha: The node transparency.
    Returns:
        * None
'''
nx.draw(A,node_color=data.y,pos= pos, cmap=plt.cm.viridis, node_size=100, edge_color='black',width=1,with_labels=False,node_shape='o',alpha=0.8)
plt.show()
# Out:
# Data(x=[183, 1703], edge_index=[2, 557], y=[183], train_mask=[183, 10], val_mask=[183, 10], test_mask=[183, 10], num_nodes=183, num_edges=280)

# %% [markdown]
# ### 1.3 Visualize full graph [Optional]

# %%
# The same as above but with the whole graph
data = dataset[0]
G = to_networkx(data, to_undirected=True)
plt.figure(figsize=(20,15))
plt.title('Whole graph',fontsize=20)
color = data.y
pos = nx.spring_layout(G,seed=12)
nx.draw(G,node_color=color,pos= pos, cmap=plt.cm.viridis, node_size=100, edge_color='black',width=1,with_labels=False,node_shape='o',alpha=0.8)
plt.show()

# %% [markdown]
# ### 2. Train a GCN model

# %% [markdown]
# #### Utility functions

# %%
'''
    Arguments of train:
        * model: The model to train.
        * data: The data object.
        * optimizer: The optimizer to use.
        * train_mask: The mask of the training nodes.
        * criterion: The loss function to use.
    Returns:
        * loss: The loss of the model.
        * acc: The accuracy of the model.
'''
def train(model, data, optimizer,train_mask,device,criterion = torch.nn.CrossEntropyLoss()):
    model.train()
    optimizer.zero_grad() # Clear gradients.
    #Make sure that we only use the features of the training nodes
    features = torch.zeros(data.x.shape[0],data.x.shape[1]).to(device)
    features[train_mask] = data.x[train_mask]
    # Put the features in the same device as the model
    features = features.to(device)
    # al modelo se le pasan las características y las conexiones
    out = model(features, data.edge_index) # Perform a single forward pass.
    # Lo que me equivoco, solo en entrenamiento
    loss = criterion(out[train_mask], data.y[train_mask]) # Compute the loss solely based on the training nodes.
    pred = out.argmax(dim=1) # Use the class with highest probability.
    acc = pred[train_mask].eq(data.y[train_mask]).sum().item() / train_mask.sum().item() # Derive ratio of correct predictions.
    # Actualizar la loss, cambiar las matrices W de cada neurona
    loss.backward() # Derive gradients.
    optimizer.step() # Update parameters based on gradients.
    return loss,acc
'''
    Arguments of validation:
        * model: The model to train.
        * data: The data object.
        * val_mask: The mask of the validation nodes.
    Returns:
        * acc: The accuracy of the model.
'''
@torch.no_grad()
def validation(model,data,val_mask,device):
    model.eval() # Set model to evaluation mode (e.g. disable dropout)
    #Make sure that we only use the features of the validation nodes
    features = torch.zeros(data.x.shape[0],data.x.shape[1]).to(device)
    features[val_mask] = data.x[val_mask]
    # Put the features in the same device as the model
    features = features.to(device)
    out = model(features, data.edge_index)
    pred = out.argmax(dim=1) # Use the class with highest probability.
    acc = pred[val_mask].eq(data.y[val_mask]).sum().item() / val_mask.sum().item() # Derive ratio of correct predictions.
    return acc
'''
    Arguments of test:
        * model: The model to train.
        * data: The data object.
        * test_mask: The mask of the test nodes.
    Returns:
        * acc: The accuracy of the model.
'''
@torch.no_grad()
def test(model,data,test_mask,device):
    model.eval() # Set model to evaluation mode (e.g. disable dropout)
    #Make sure that we only use the features of the testing nodes
    features = torch.zeros(data.x.shape[0],data.x.shape[1]).to(device)
    features[test_mask] = data.x[test_mask]
    # Put the features in the same device as the model
    features = features.to(device)
    out = model(features, data.edge_index)
    pred = out.argmax(dim=1) # Use the class with highest probability.
    acc = pred[test_mask].eq(data.y[test_mask]).sum().item() / test_mask.sum().item() # Derive ratio of correct predictions.
    return acc

# %% [markdown]
# #### Split dataset

# %% [markdown]
# In this section we will split the dataset into training, validation and test sets. We will use the training set to train the model, the validation set to tune the hyperparameters and the test set to evaluate the model. We will use two functions for the splits. One function will give as a semi-supervised split where we will have a small number of labeled nodes in the training set and the rest of the nodes will be unlabeled. The other function will give us a fully supervised split where all the nodes in the training set will be labeled.

# %%
from sklearn.model_selection import train_test_split
'''
    Arguments of get_semi_supervised_split:
        * data: The data object.
        * seed: The seed to use for the random split.
    Returns: the train, test and validation masks with an 48%/32%/20%.
        * train_mask: The mask of the training nodes.
        * test_mask: The mask of the test nodes.
        * val_mask: The mask of the validation nodes.
'''
def get_semi_supervised_split(data,seed):
    #We are going to use 48% of the nodes for training, 32% for testing and 20% for validation
    #First we split the nodes in 80% for training and 20% for testing
    #Then we split the training nodes in 48% for training and 32% for validation over the 80% of the nodes
    train_split, test_split = train_test_split(list(range(len(data.y))), test_size=0.20,random_state=seed, shuffle=True)
    train_split, val_split = train_test_split(train_split, test_size=0.40,random_state=seed, shuffle=True)

    train_mask = torch.full_like(data.y, False, dtype=bool)
    train_mask[train_split] = True

    test_mask = torch.full_like(data.y, False, dtype=bool)
    test_mask[test_split] = True

    val_mask = torch.full_like(data.y, False, dtype=bool)
    val_mask[val_split] = True

    return train_mask,test_mask,val_mask
'''
    Arguments of get_supervised_split:
        * data: The data object.
        * seed: The seed to use for the random split.
    Returns: the train, test and validation masks with an 60%/20%/20%.
        * train_mask: The mask of the training nodes.
        * test_mask: The mask of the test nodes.
        * val_mask: The mask of the validation nodes.
'''
def get_supervised_split(data,seed):
    train_split, test_split = train_test_split(list(range(len(data.y))), test_size=0.40,random_state=seed, shuffle=True)
    test_split, val_split = train_test_split(test_split, test_size=0.50,random_state=seed, shuffle=True)

    train_mask = torch.full_like(data.y, False, dtype=bool)
    train_mask[train_split] = True

    test_mask = torch.full_like(data.y, False, dtype=bool)
    test_mask[test_split] = True

    val_mask = torch.full_like(data.y, False, dtype=bool)
    val_mask[val_split] = True

    return train_mask, test_mask, val_mask

# %% [markdown]
# #### Create the model

# %% [markdown]
# In this section we will create our model for node classification. We will use a GCN model with 2 hidden layers. The input to the model will be the node features and the output will be the logits for each node in the graph. We will use the cross entropy loss function and the Adam optimizer.

# %% [markdown]
# Using the above models as templates, **create as many cells as models**.

# %% [markdown]
# ##### GCN

# %%
from torch_geometric.nn import GCNConv
from torch.functional import F
'''
    In PyTorch, you define a model by subclassing torch.nn.Module and defining a forward() method which receives input data and returns output data.
    The forward() method can use other modules defined in the constructor as submodules, and it can use arbitrary operators on Tensors, including loops and conditional statements.
    This approach is very flexible, and you can use it to define models of arbitrary complexity.
'''
class GCN(torch.nn.Module):
    '''
        Arguments of __init__:
            * hidden_channels: The number of hidden units.
            * dataset.num_features: The number of input features.
            * dataset.num_classes: The number of output classes.
        Returns:
            * self.conv1: The first GCN layer.
            * self.conv2: The second GCN layer.
    '''
    # hidden channels: capa intermedia
    def __init__(self,hidden_channels = 16):
        super(GCN, self).__init__()
        # 2-layer GCN
        # GCConv(tamaño entrada, tamaño salida)
        self.conv1 = GCNConv(dataset.num_features, hidden_channels) # 16 hidden units
        self.conv2 = GCNConv(hidden_channels, dataset.num_classes) # dataset.num_classes output units
    '''
        Arguments of forward:
            * x: The input features.
            * edge_index: The edge indices.
        Returns:
            * F.softmax(x, dim=1): The output of the model.
    '''
    # lo que aplica el modelo
    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index)) # ReLU activation
        x = F.dropout(x,p=0.5, training=self.training) # Dropout: 50% of the nodes are randomly dropped out during training
        x = self.conv2(x, edge_index)
        return x.softmax(dim=1) # Log softmax activation
print(GCN())
# Out:
# GCN(
#   (conv1): GCNConv(1703, 16)
#   (conv2): GCNConv(16, 5)
# )

# %% [markdown]
# ##### SAGE

# %%
from torch_geometric.nn import SAGEConv
from torch.functional import F
'''
    In PyTorch, you define a model by subclassing torch.nn.Module and defining a forward() method which receives input data and returns output data.
    The forward() method can use other modules defined in the constructor as submodules, and it can use arbitrary operators on Tensors, including loops and conditional statements.
    This approach is very flexible, and you can use it to define models of arbitrary complexity.
'''
class SAGE(torch.nn.Module):
    '''
        Arguments of __init__:
            * hidden_channels: The number of hidden units.
            * dataset.num_features: The number of input features.
            * dataset.num_classes: The number of output classes.
        Returns:
            * self.conv1: The first GCN layer.
            * self.conv2: The second GCN layer.
    '''
    # hidden channels: capa intermedia
    def __init__(self,hidden_channels = 16):
        super(SAGE, self).__init__()
        # 2-layer GCN
        # GCConv(tamaño entrada, tamaño salida)
        self.conv1 = SAGEConv(dataset.num_features, hidden_channels, aggr='max') # 16 hidden units
        self.conv2 = SAGEConv(hidden_channels, dataset.num_classes) # dataset.num_classes output units
    '''
        Arguments of forward:
            * x: The input features.
            * edge_index: The edge indices.
        Returns:
            * F.softmax(x, dim=1): The output of the model.
    '''
    # lo que aplica el modelo
    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index)) # ReLU activation
        x = F.dropout(x,p=0.5, training=self.training) # Dropout: 50% of the nodes are randomly dropped out during training
        x = self.conv2(x, edge_index)
        return x.softmax(dim=1) # Log softmax activation
print(SAGE())
# Out:
# SAGE(
#   (conv1): SAGEConv(1703, 16, aggr=max)
#   (conv2): SAGEConv(16, 5, aggr=mean)
# )

# %% [markdown]
# ##### Cheb

# %%
from torch_geometric.nn import ChebConv
from torch.functional import F
'''
    In PyTorch, you define a model by subclassing torch.nn.Module and defining a forward() method which receives input data and returns output data.
    The forward() method can use other modules defined in the constructor as submodules, and it can use arbitrary operators on Tensors, including loops and conditional statements.
    This approach is very flexible, and you can use it to define models of arbitrary complexity.
'''
class Cheb(torch.nn.Module):
    '''
        Arguments of __init__:
            * hidden_channels: The number of hidden units.
            * dataset.num_features: The number of input features.
            * dataset.num_classes: The number of output classes.
        Returns:
            * self.conv1: The first GCN layer.
            * self.conv2: The second GCN layer.
    '''
    # hidden channels: capa intermedia
    def __init__(self,hidden_channels = 16):
        super(Cheb, self).__init__()
        # 2-layer GCN
        # GCConv(tamaño entrada, tamaño salida)
        self.conv1 = ChebConv(dataset.num_features, hidden_channels, K=10, normalization='sym') # 16 hidden units
        self.conv2 = ChebConv(hidden_channels, dataset.num_classes, K=10, normalization='sym') # dataset.num_classes output units
    '''
        Arguments of forward:
            * x: The input features.
            * edge_index: The edge indices.
        Returns:
            * F.softmax(x, dim=1): The output of the model.
    '''
    # lo que aplica el modelo
    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index)) # ReLU activation
        x = F.dropout(x,p=0.5, training=self.training) # Dropout: 50% of the nodes are randomly dropped out during training
        x = self.conv2(x, edge_index)
        return x.softmax(dim=1) # Log softmax activation
print(Cheb())
# Out:
# Cheb(
#   (conv1): ChebConv(1703, 16, K=10, normalization=sym)
#   (conv2): ChebConv(16, 5, K=10, normalization=sym)
# )

# %% [markdown]
# ##### GAT

# %%
from torch_geometric.nn import GATConv
from torch.functional import F
'''
    In PyTorch, you define a model by subclassing torch.nn.Module and defining a forward() method which receives input data and returns output data.
    The forward() method can use other modules defined in the constructor as submodules, and it can use arbitrary operators on Tensors, including loops and conditional statements.
    This approach is very flexible, and you can use it to define models of arbitrary complexity.
'''
class GAT(torch.nn.Module):
    '''
        Arguments of __init__:
            * hidden_channels: The number of hidden units.
            * dataset.num_features: The number of input features.
            * dataset.num_classes: The number of output classes.
        Returns:
            * self.conv1: The first GCN layer.
            * self.conv2: The second GCN layer.
    '''
    # hidden channels: capa intermedia
    def __init__(self,hidden_channels = 16):
        super(GAT, self).__init__()
        # 2-layer GCN
        # GCConv(tamaño entrada, tamaño salida)
        self.conv1 = GATConv(dataset.num_features, hidden_channels, heads=1) # 16 hidden units
        self.conv2 = GATConv(hidden_channels, dataset.num_classes, heads=1) # dataset.num_classes output units
    '''
        Arguments of forward:
            * x: The input features.
            * edge_index: The edge indices.
        Returns:
            * F.softmax(x, dim=1): The output of the model.
    '''
    # lo que aplica el modelo
    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index)) # ReLU activation
        x = F.dropout(x,p=0.5, training=self.training) # Dropout: 50% of the nodes are randomly dropped out during training
        x = self.conv2(x, edge_index)
        return x.softmax(dim=1) # Log softmax activation
print(GAT())
# Out:
# GAT(
#   (conv1): GATConv(1703, 16, heads=1)
#   (conv2): GATConv(16, 5, heads=1)
# )

# %% [markdown]
# ##### MLP

# %%
from torch.nn import Linear
# Same as GCN but with Linear layers instead of GCNConv layers. If we use MLP as a model, we can't take into account the graph STRUCTURE.
class MLP(torch.nn.Module):
    def __init__(self,hidden_channels = 16):
        super(MLP, self).__init__()
        # 2-layer GCN
        self.lin1 = Linear(dataset.num_features, hidden_channels)
        self.lin2 = Linear(hidden_channels, dataset.num_classes)

    def forward(self, x, edge_index):
        # edge_index is not used
        x = self.lin1(x)
        x = x.relu()
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin2(x)
        return x.softmax(dim=1)
print(MLP())
# Out:
# MLP(
#   (lin1): Linear(in_features=1703, out_features=16, bias=True)
#   (lin2): Linear(in_features=16, out_features=5, bias=True)
# )

# %% [markdown]
# #### Train the models

# %%
# Seeds for the random split. This allows us to reproduce the results.
RandList = [12345, 423456, 643451, 543452, 743456, 4734510, 654321, 124321, 945321, 784328]
# This allows us to run the code on the GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Here you can add models to train and test (include your own models)
models = [GCN(), MLP(), SAGE(), Cheb(), GAT()]
global_results = []
global_best_models = []
for j in range(len(models)):
    ExperimentResult = []
    best_model = None
    print(data)
    for i in range(10):
        print("Random State", RandList[i]," in the iteration",i)
        train_mask,test_mask,val_mask = get_semi_supervised_split(data.cpu(), RandList[i])
        #train_mask,test_mask,val_mask = get_supervised_split(data.cpu(), RandList[i])
        data = data.to(device)
        model = models[j].to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
        for epoch in range(1, 101):
            loss, acc_train = train(model,data,optimizer,train_mask.to(device),device=device)
            acc_validation = validation(model,data,val_mask.to(device),device=device)
            print('Epoch: {:03d}, Loss: {:.5f}, Train Acc: {:.5f}, Val Acc: {:.5f}'.format(epoch, loss, acc_train, acc_validation))
        acc = test(model,data,test_mask.to(device),device=device)
        print('Test Accuracy: {:.5f}'.format(acc))
        # Save the best model over the 10 runs
        if best_model is None or acc > best_model[1]:
            best_model = [model, acc]
        ExperimentResult.append(acc)
        del model
    print(models[j].__class__.__name__) # Name of the model
    print('{} +- {}'.format(np.mean(ExperimentResult)*100, np.std(ExperimentResult)*100))
    global_results.append(ExperimentResult.copy())
    global_best_models.append(best_model.copy())
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Epoch: 012, Loss: 1.25843, Train Acc: 0.66667, Val Acc: 0.64407
# Epoch: 013, Loss: 1.22348, Train Acc: 0.70115, Val Acc: 0.64407
# Epoch: 014, Loss: 1.21435, Train Acc: 0.72414, Val Acc: 0.64407
# Epoch: 015, Loss: 1.28175, Train Acc: 0.66667, Val Acc: 0.62712
# Epoch: 016, Loss: 1.21094, Train Acc: 0.71264, Val Acc: 0.62712
# Epoch: 017, Loss: 1.23162, Train Acc: 0.66667, Val Acc: 0.64407
# Epoch: 018, Loss: 1.17738, Train Acc: 0.75862, Val Acc: 0.61017
# Epoch: 019, Loss: 1.18722, Train Acc: 0.74713, Val Acc: 0.59322
# Epoch: 020, Loss: 1.20881, Train Acc: 0.70115, Val Acc: 0.59322
# Epoch: 021, Loss: 1.20256, Train Acc: 0.70115, Val Acc: 0.59322
# Epoch: 022, Loss: 1.22505, Train Acc: 0.72414, Val Acc: 0.59322
# Epoch: 023, Loss: 1.18629, Train Acc: 0.75862, Val Acc: 0.57627
# Epoch: 024, Loss: 1.21389, Train Acc: 0.68966, Val Acc: 0.55932
# Epoch: 025, Loss: 1.18313, Train Acc: 0.72414, Val Acc: 0.55932
# Epoch: 026, Loss: 1.20899, Train Acc: 0.70115, Val Acc: 0.57627
# Epoch: 027, Loss: 1.16953, Train Acc: 0.73563, Val Acc: 0.57627
# Epoch: 028, Loss: 1.21808, Train Acc: 0.71264, Val Acc: 0.57627
# Epoch: 029, Loss: 1.17126, Train Acc: 0.77011, Val Acc: 0.55932
# Epoch: 030, Loss: 1.18637, Train Acc: 0.72414, Val Acc: 0.55932
# Epoch: 031, Loss: 1.17189, Train Acc: 0.73563, Val Acc: 0.54237
# Epoch: 032, Loss: 1.21139, Train Acc: 0.68966, Val Acc: 0.54237
# Epoch: 033, Loss: 1.18613, Train Acc: 0.72414, Val Acc: 0.55932
# Epoch: 034, Loss: 1.18348, Train Acc: 0.68966, Val Acc: 0.55932
# Epoch: 035, Loss: 1.16959, Train Acc: 0.72414, Val Acc: 0.55932
# Epoch: 036, Loss: 1.17940, Train Acc: 0.73563, Val Acc: 0.55932
# Epoch: 037, Loss: 1.16492, Train Acc: 0.75862, Val Acc: 0.54237
# Epoch: 038, Loss: 1.13994, Train Acc: 0.77011, Val Acc: 0.54237
# Epoch: 039, Loss: 1.15801, Train Acc: 0.75862, Val Acc: 0.54237
# Epoch: 040, Loss: 1.18135, Train Acc: 0.74713, Val Acc: 0.54237
# Epoch: 041, Loss: 1.18846, Train Acc: 0.72414, Val Acc: 0.54237
# Epoch: 042, Loss: 1.19615, Train Acc: 0.70115, Val Acc: 0.54237
# Epoch: 043, Loss: 1.15866, Train Acc: 0.75862, Val Acc: 0.52542
# Epoch: 044, Loss: 1.16486, Train Acc: 0.75862, Val Acc: 0.52542
# Epoch: 045, Loss: 1.15755, Train Acc: 0.74713, Val Acc: 0.52542
# Epoch: 046, Loss: 1.16183, Train Acc: 0.77011, Val Acc: 0.50847
# Epoch: 047, Loss: 1.16101, Train Acc: 0.74713, Val Acc: 0.50847
# Epoch: 048, Loss: 1.18222, Train Acc: 0.73563, Val Acc: 0.50847
# Epoch: 049, Loss: 1.16651, Train Acc: 0.72414, Val Acc: 0.50847
# Epoch: 050, Loss: 1.15244, Train Acc: 0.75862, Val Acc: 0.50847
# Epoch: 051, Loss: 1.17213, Train Acc: 0.75862, Val Acc: 0.50847
# Epoch: 052, Loss: 1.14057, Train Acc: 0.78161, Val Acc: 0.52542
# Epoch: 053, Loss: 1.15710, Train Acc: 0.73563, Val Acc: 0.52542
# Epoch: 054, Loss: 1.20610, Train Acc: 0.70115, Val Acc: 0.50847
# Epoch: 055, Loss: 1.15555, Train Acc: 0.78161, Val Acc: 0.50847
# Epoch: 056, Loss: 1.14839, Train Acc: 0.75862, Val Acc: 0.52542
# Epoch: 057, Loss: 1.16131, Train Acc: 0.74713, Val Acc: 0.52542
# Epoch: 058, Loss: 1.16352, Train Acc: 0.73563, Val Acc: 0.52542
# Epoch: 059, Loss: 1.15980, Train Acc: 0.73563, Val Acc: 0.54237
# Epoch: 060, Loss: 1.13958, Train Acc: 0.74713, Val Acc: 0.55932
# Epoch: 061, Loss: 1.14769, Train Acc: 0.74713, Val Acc: 0.57627
# Epoch: 062, Loss: 1.13395, Train Acc: 0.79310, Val Acc: 0.55932
# Epoch: 063, Loss: 1.13203, Train Acc: 0.78161, Val Acc: 0.59322
# Epoch: 064, Loss: 1.14889, Train Acc: 0.79310, Val Acc: 0.59322
# Epoch: 065, Loss: 1.20034, Train Acc: 0.70115, Val Acc: 0.59322
# Epoch: 066, Loss: 1.14891, Train Acc: 0.77011, Val Acc: 0.59322
# Epoch: 067, Loss: 1.17275, Train Acc: 0.75862, Val Acc: 0.57627
# Epoch: 068, Loss: 1.15448, Train Acc: 0.75862, Val Acc: 0.57627
# Epoch: 069, Loss: 1.13219, Train Acc: 0.79310, Val Acc: 0.55932
# Epoch: 070, Loss: 1.15179, Train Acc: 0.77011, Val Acc: 0.55932
# Epoch: 071, Loss: 1.13586, Train Acc: 0.78161, Val Acc: 0.55932
# Epoch: 072, Loss: 1.13353, Train Acc: 0.79310, Val Acc: 0.55932
# Epoch: 073, Loss: 1.13027, Train Acc: 0.79310, Val Acc: 0.55932
# Epoch: 074, Loss: 1.14260, Train Acc: 0.78161, Val Acc: 0.57627
# Epoch: 075, Loss: 1.10495, Train Acc: 0.82759, Val Acc: 0.57627
# Epoch: 076, Loss: 1.13508, Train Acc: 0.78161, Val Acc: 0.57627
# Epoch: 077, Loss: 1.09633, Train Acc: 0.81609, Val Acc: 0.54237
# Epoch: 078, Loss: 1.10742, Train Acc: 0.78161, Val Acc: 0.54237
# Epoch: 079, Loss: 1.12831, Train Acc: 0.78161, Val Acc: 0.54237
# Epoch: 080, Loss: 1.13465, Train Acc: 0.77011, Val Acc: 0.50847
# Epoch: 081, Loss: 1.14457, Train Acc: 0.75862, Val Acc: 0.52542
# Epoch: 082, Loss: 1.10900, Train Acc: 0.81609, Val Acc: 0.52542
# Epoch: 083, Loss: 1.11339, Train Acc: 0.80460, Val Acc: 0.55932
# Epoch: 084, Loss: 1.11066, Train Acc: 0.81609, Val Acc: 0.55932
# Epoch: 085, Loss: 1.14708, Train Acc: 0.77011, Val Acc: 0.57627
# Epoch: 086, Loss: 1.12649, Train Acc: 0.79310, Val Acc: 0.57627
# Epoch: 087, Loss: 1.16160, Train Acc: 0.74713, Val Acc: 0.61017
# Epoch: 088, Loss: 1.13010, Train Acc: 0.80460, Val Acc: 0.61017
# Epoch: 089, Loss: 1.12654, Train Acc: 0.77011, Val Acc: 0.61017
# Epoch: 090, Loss: 1.08475, Train Acc: 0.82759, Val Acc: 0.61017
# Epoch: 091, Loss: 1.11262, Train Acc: 0.80460, Val Acc: 0.59322
# Epoch: 092, Loss: 1.10518, Train Acc: 0.80460, Val Acc: 0.59322
# Epoch: 093, Loss: 1.13776, Train Acc: 0.78161, Val Acc: 0.57627
# Epoch: 094, Loss: 1.16062, Train Acc: 0.74713, Val Acc: 0.57627
# Epoch: 095, Loss: 1.15358, Train Acc: 0.78161, Val Acc: 0.57627
# Epoch: 096, Loss: 1.10508, Train Acc: 0.81609, Val Acc: 0.57627
# Epoch: 097, Loss: 1.15479, Train Acc: 0.79310, Val Acc: 0.57627
# Epoch: 098, Loss: 1.11210, Train Acc: 0.82759, Val Acc: 0.55932
# Epoch: 099, Loss: 1.14165, Train Acc: 0.77011, Val Acc: 0.55932
# Epoch: 100, Loss: 1.13243, Train Acc: 0.77011, Val Acc: 0.54237
# Test Accuracy: 0.54054
# Random State 643451  in the iteration 2
# Epoch: 001, Loss: 1.28305, Train Acc: 0.63218, Val Acc: 0.57627
# Epoch: 002, Loss: 1.28151, Train Acc: 0.65517, Val Acc: 0.59322
# Epoch: 003, Loss: 1.22124, Train Acc: 0.68966, Val Acc: 0.59322
# Epoch: 004, Loss: 1.21092, Train Acc: 0.68966, Val Acc: 0.61017
# Epoch: 005, Loss: 1.21122, Train Acc: 0.72414, Val Acc: 0.61017
# Epoch: 006, Loss: 1.25354, Train Acc: 0.63218, Val Acc: 0.61017
# Epoch: 007, Loss: 1.19124, Train Acc: 0.73563, Val Acc: 0.61017
# Epoch: 008, Loss: 1.18804, Train Acc: 0.71264, Val Acc: 0.59322
# Epoch: 009, Loss: 1.15107, Train Acc: 0.77011, Val Acc: 0.59322
# Epoch: 010, Loss: 1.19044, Train Acc: 0.71264, Val Acc: 0.61017
# Epoch: 011, Loss: 1.23482, Train Acc: 0.67816, Val Acc: 0.61017
# Epoch: 012, Loss: 1.18805, Train Acc: 0.73563, Val Acc: 0.61017
# Epoch: 013, Loss: 1.17155, Train Acc: 0.75862, Val Acc: 0.62712
# Epoch: 014, Loss: 1.20205, Train Acc: 0.70115, Val Acc: 0.62712
# Epoch: 015, Loss: 1.20845, Train Acc: 0.72414, Val Acc: 0.62712
# Epoch: 016, Loss: 1.19776, Train Acc: 0.70115, Val Acc: 0.62712
# Epoch: 017, Loss: 1.15349, Train Acc: 0.78161, Val Acc: 0.64407
# Epoch: 018, Loss: 1.16881, Train Acc: 0.75862, Val Acc: 0.64407
# Epoch: 019, Loss: 1.14108, Train Acc: 0.77011, Val Acc: 0.66102
# Epoch: 020, Loss: 1.12130, Train Acc: 0.78161, Val Acc: 0.66102
# Epoch: 021, Loss: 1.13526, Train Acc: 0.80460, Val Acc: 0.66102
# Epoch: 022, Loss: 1.13849, Train Acc: 0.80460, Val Acc: 0.66102
# Epoch: 023, Loss: 1.14374, Train Acc: 0.79310, Val Acc: 0.64407
# Epoch: 024, Loss: 1.14880, Train Acc: 0.77011, Val Acc: 0.64407
# Epoch: 025, Loss: 1.12728, Train Acc: 0.79310, Val Acc: 0.66102
# Epoch: 026, Loss: 1.11863, Train Acc: 0.79310, Val Acc: 0.64407
# Epoch: 027, Loss: 1.11070, Train Acc: 0.82759, Val Acc: 0.62712
# Epoch: 028, Loss: 1.10426, Train Acc: 0.80460, Val Acc: 0.62712
# Epoch: 029, Loss: 1.13070, Train Acc: 0.78161, Val Acc: 0.61017
# Epoch: 030, Loss: 1.15201, Train Acc: 0.77011, Val Acc: 0.61017
# Epoch: 031, Loss: 1.12131, Train Acc: 0.79310, Val Acc: 0.62712
# Epoch: 032, Loss: 1.11438, Train Acc: 0.81609, Val Acc: 0.64407
# Epoch: 033, Loss: 1.14514, Train Acc: 0.77011, Val Acc: 0.64407
# Epoch: 034, Loss: 1.08790, Train Acc: 0.83908, Val Acc: 0.64407
# Epoch: 035, Loss: 1.11930, Train Acc: 0.79310, Val Acc: 0.64407
# Epoch: 036, Loss: 1.11202, Train Acc: 0.81609, Val Acc: 0.64407
# Epoch: 037, Loss: 1.12635, Train Acc: 0.80460, Val Acc: 0.66102
# Epoch: 038, Loss: 1.11565, Train Acc: 0.79310, Val Acc: 0.64407
# Epoch: 039, Loss: 1.11760, Train Acc: 0.80460, Val Acc: 0.64407
# Epoch: 040, Loss: 1.10197, Train Acc: 0.81609, Val Acc: 0.64407
# Epoch: 041, Loss: 1.11685, Train Acc: 0.80460, Val Acc: 0.64407
# Epoch: 042, Loss: 1.11362, Train Acc: 0.81609, Val Acc: 0.64407
# Epoch: 043, Loss: 1.07629, Train Acc: 0.83908, Val Acc: 0.62712
# Epoch: 044, Loss: 1.13848, Train Acc: 0.78161, Val Acc: 0.62712
# Epoch: 045, Loss: 1.10619, Train Acc: 0.80460, Val Acc: 0.62712
# Epoch: 046, Loss: 1.13983, Train Acc: 0.79310, Val Acc: 0.64407
# Epoch: 047, Loss: 1.11390, Train Acc: 0.80460, Val Acc: 0.62712
# Epoch: 048, Loss: 1.11027, Train Acc: 0.82759, Val Acc: 0.62712
# Epoch: 049, Loss: 1.10739, Train Acc: 0.81609, Val Acc: 0.62712
# Epoch: 050, Loss: 1.08715, Train Acc: 0.83908, Val Acc: 0.64407
# Epoch: 051, Loss: 1.10477, Train Acc: 0.81609, Val Acc: 0.62712
# Epoch: 052, Loss: 1.12314, Train Acc: 0.78161, Val Acc: 0.62712
# Epoch: 053, Loss: 1.09160, Train Acc: 0.80460, Val Acc: 0.61017
# Epoch: 054, Loss: 1.10652, Train Acc: 0.80460, Val Acc: 0.61017
# Epoch: 055, Loss: 1.09358, Train Acc: 0.81609, Val Acc: 0.61017
# Epoch: 056, Loss: 1.09724, Train Acc: 0.79310, Val Acc: 0.64407
# Epoch: 057, Loss: 1.08095, Train Acc: 0.83908, Val Acc: 0.64407
# Epoch: 058, Loss: 1.12548, Train Acc: 0.80460, Val Acc: 0.64407
# Epoch: 059, Loss: 1.13016, Train Acc: 0.79310, Val Acc: 0.66102
# Epoch: 060, Loss: 1.10864, Train Acc: 0.78161, Val Acc: 0.66102
# Epoch: 061, Loss: 1.11537, Train Acc: 0.78161, Val Acc: 0.66102
# Epoch: 062, Loss: 1.08473, Train Acc: 0.81609, Val Acc: 0.66102
# Epoch: 063, Loss: 1.06683, Train Acc: 0.86207, Val Acc: 0.64407
# Epoch: 064, Loss: 1.14993, Train Acc: 0.75862, Val Acc: 0.64407
# Epoch: 065, Loss: 1.10936, Train Acc: 0.78161, Val Acc: 0.64407
# Epoch: 066, Loss: 1.08549, Train Acc: 0.82759, Val Acc: 0.64407
# Epoch: 067, Loss: 1.11011, Train Acc: 0.78161, Val Acc: 0.62712
# Epoch: 068, Loss: 1.12177, Train Acc: 0.78161, Val Acc: 0.62712
# Epoch: 069, Loss: 1.12723, Train Acc: 0.79310, Val Acc: 0.64407
# Epoch: 070, Loss: 1.09565, Train Acc: 0.81609, Val Acc: 0.64407
# Epoch: 071, Loss: 1.08447, Train Acc: 0.87356, Val Acc: 0.64407
# Epoch: 072, Loss: 1.12809, Train Acc: 0.77011, Val Acc: 0.66102
# Epoch: 073, Loss: 1.09183, Train Acc: 0.85057, Val Acc: 0.66102
# Epoch: 074, Loss: 1.07209, Train Acc: 0.85057, Val Acc: 0.64407
# Epoch: 075, Loss: 1.08730, Train Acc: 0.85057, Val Acc: 0.64407
# Epoch: 076, Loss: 1.08689, Train Acc: 0.82759, Val Acc: 0.62712
# Epoch: 077, Loss: 1.07507, Train Acc: 0.82759, Val Acc: 0.62712
# Epoch: 078, Loss: 1.06539, Train Acc: 0.86207, Val Acc: 0.61017
# Epoch: 079, Loss: 1.08848, Train Acc: 0.83908, Val Acc: 0.61017
# Epoch: 080, Loss: 1.11880, Train Acc: 0.79310, Val Acc: 0.61017
# Epoch: 081, Loss: 1.07666, Train Acc: 0.85057, Val Acc: 0.61017
# Epoch: 082, Loss: 1.13674, Train Acc: 0.80460, Val Acc: 0.61017
# Epoch: 083, Loss: 1.08495, Train Acc: 0.83908, Val Acc: 0.64407
# Epoch: 084, Loss: 1.10577, Train Acc: 0.80460, Val Acc: 0.64407
# Epoch: 085, Loss: 1.09199, Train Acc: 0.85057, Val Acc: 0.64407
# Epoch: 086, Loss: 1.09915, Train Acc: 0.80460, Val Acc: 0.62712
# Epoch: 087, Loss: 1.07930, Train Acc: 0.82759, Val Acc: 0.62712
# Epoch: 088, Loss: 1.10688, Train Acc: 0.79310, Val Acc: 0.62712
# Epoch: 089, Loss: 1.10591, Train Acc: 0.81609, Val Acc: 0.62712
# Epoch: 090, Loss: 1.06646, Train Acc: 0.83908, Val Acc: 0.64407
# Epoch: 091, Loss: 1.08479, Train Acc: 0.83908, Val Acc: 0.64407
# Epoch: 092, Loss: 1.07487, Train Acc: 0.82759, Val Acc: 0.66102
# Epoch: 093, Loss: 1.08473, Train Acc: 0.85057, Val Acc: 0.66102
# Epoch: 094, Loss: 1.06865, Train Acc: 0.88506, Val Acc: 0.66102
# Epoch: 095, Loss: 1.09770, Train Acc: 0.82759, Val Acc: 0.67797
# Epoch: 096, Loss: 1.10955, Train Acc: 0.80460, Val Acc: 0.67797
# Epoch: 097, Loss: 1.07572, Train Acc: 0.83908, Val Acc: 0.67797
# Epoch: 098, Loss: 1.12734, Train Acc: 0.77011, Val Acc: 0.66102
# Epoch: 099, Loss: 1.07184, Train Acc: 0.86207, Val Acc: 0.66102
# Epoch: 100, Loss: 1.08420, Train Acc: 0.82759, Val Acc: 0.66102
# Test Accuracy: 0.67568
# Random State 543452  in the iteration 3
# Epoch: 001, Loss: 1.26301, Train Acc: 0.66667, Val Acc: 0.71186
# Epoch: 002, Loss: 1.24726, Train Acc: 0.65517, Val Acc: 0.69492
# Epoch: 003, Loss: 1.23264, Train Acc: 0.68966, Val Acc: 0.69492
# Epoch: 004, Loss: 1.26249, Train Acc: 0.62069, Val Acc: 0.71186
# Epoch: 005, Loss: 1.26071, Train Acc: 0.63218, Val Acc: 0.72881
# Epoch: 006, Loss: 1.21489, Train Acc: 0.68966, Val Acc: 0.74576
# Epoch: 007, Loss: 1.15692, Train Acc: 0.77011, Val Acc: 0.74576
# Epoch: 008, Loss: 1.16813, Train Acc: 0.73563, Val Acc: 0.74576
# Epoch: 009, Loss: 1.16627, Train Acc: 0.74713, Val Acc: 0.74576
# Epoch: 010, Loss: 1.17886, Train Acc: 0.73563, Val Acc: 0.74576
# Epoch: 011, Loss: 1.17882, Train Acc: 0.73563, Val Acc: 0.74576
# Epoch: 012, Loss: 1.12962, Train Acc: 0.79310, Val Acc: 0.74576
# Epoch: 013, Loss: 1.16200, Train Acc: 0.77011, Val Acc: 0.74576
# Epoch: 014, Loss: 1.12159, Train Acc: 0.79310, Val Acc: 0.74576
# Epoch: 015, Loss: 1.15033, Train Acc: 0.74713, Val Acc: 0.76271
# Epoch: 016, Loss: 1.14183, Train Acc: 0.78161, Val Acc: 0.76271
# Epoch: 017, Loss: 1.13076, Train Acc: 0.80460, Val Acc: 0.74576
# Epoch: 018, Loss: 1.14746, Train Acc: 0.77011, Val Acc: 0.74576
# Epoch: 019, Loss: 1.10395, Train Acc: 0.82759, Val Acc: 0.74576
# Epoch: 020, Loss: 1.12676, Train Acc: 0.78161, Val Acc: 0.74576
# Epoch: 021, Loss: 1.11606, Train Acc: 0.81609, Val Acc: 0.74576
# Epoch: 022, Loss: 1.12888, Train Acc: 0.78161, Val Acc: 0.74576
# Epoch: 023, Loss: 1.14059, Train Acc: 0.77011, Val Acc: 0.74576
# Epoch: 024, Loss: 1.11925, Train Acc: 0.81609, Val Acc: 0.72881
# Epoch: 025, Loss: 1.12713, Train Acc: 0.78161, Val Acc: 0.74576
# Epoch: 026, Loss: 1.13075, Train Acc: 0.78161, Val Acc: 0.74576
# Epoch: 027, Loss: 1.15172, Train Acc: 0.75862, Val Acc: 0.74576
# Epoch: 028, Loss: 1.12571, Train Acc: 0.79310, Val Acc: 0.74576
# Epoch: 029, Loss: 1.11085, Train Acc: 0.80460, Val Acc: 0.74576
# Epoch: 030, Loss: 1.10177, Train Acc: 0.82759, Val Acc: 0.74576
# Epoch: 031, Loss: 1.11098, Train Acc: 0.79310, Val Acc: 0.76271
# Epoch: 032, Loss: 1.09497, Train Acc: 0.81609, Val Acc: 0.76271
# Epoch: 033, Loss: 1.12136, Train Acc: 0.80460, Val Acc: 0.76271
# Epoch: 034, Loss: 1.10903, Train Acc: 0.81609, Val Acc: 0.77966
# Epoch: 035, Loss: 1.14876, Train Acc: 0.77011, Val Acc: 0.79661
# Epoch: 036, Loss: 1.15553, Train Acc: 0.75862, Val Acc: 0.79661
# Epoch: 037, Loss: 1.11041, Train Acc: 0.79310, Val Acc: 0.79661
# Epoch: 038, Loss: 1.13776, Train Acc: 0.79310, Val Acc: 0.77966
# Epoch: 039, Loss: 1.10159, Train Acc: 0.81609, Val Acc: 0.77966
# Epoch: 040, Loss: 1.11083, Train Acc: 0.79310, Val Acc: 0.77966
# Epoch: 041, Loss: 1.10123, Train Acc: 0.83908, Val Acc: 0.77966
# Epoch: 042, Loss: 1.10344, Train Acc: 0.81609, Val Acc: 0.77966
# Epoch: 043, Loss: 1.11924, Train Acc: 0.78161, Val Acc: 0.79661
# Epoch: 044, Loss: 1.11469, Train Acc: 0.80460, Val Acc: 0.79661
# Epoch: 045, Loss: 1.09239, Train Acc: 0.82759, Val Acc: 0.79661
# Epoch: 046, Loss: 1.09612, Train Acc: 0.80460, Val Acc: 0.79661
# Epoch: 047, Loss: 1.11348, Train Acc: 0.80460, Val Acc: 0.79661
# Epoch: 048, Loss: 1.11777, Train Acc: 0.78161, Val Acc: 0.79661
# Epoch: 049, Loss: 1.09327, Train Acc: 0.82759, Val Acc: 0.77966
# Epoch: 050, Loss: 1.12666, Train Acc: 0.77011, Val Acc: 0.77966
# Epoch: 051, Loss: 1.07401, Train Acc: 0.82759, Val Acc: 0.77966
# Epoch: 052, Loss: 1.09591, Train Acc: 0.82759, Val Acc: 0.77966
# Epoch: 053, Loss: 1.08322, Train Acc: 0.83908, Val Acc: 0.77966
# Epoch: 054, Loss: 1.09223, Train Acc: 0.82759, Val Acc: 0.77966
# Epoch: 055, Loss: 1.09376, Train Acc: 0.82759, Val Acc: 0.77966
# Epoch: 056, Loss: 1.11107, Train Acc: 0.79310, Val Acc: 0.77966
# Epoch: 057, Loss: 1.09919, Train Acc: 0.79310, Val Acc: 0.77966
# Epoch: 058, Loss: 1.11297, Train Acc: 0.79310, Val Acc: 0.77966
# Epoch: 059, Loss: 1.07964, Train Acc: 0.85057, Val Acc: 0.79661
# Epoch: 060, Loss: 1.08266, Train Acc: 0.85057, Val Acc: 0.79661
# Epoch: 061, Loss: 1.10486, Train Acc: 0.81609, Val Acc: 0.79661
# Epoch: 062, Loss: 1.08069, Train Acc: 0.82759, Val Acc: 0.79661
# Epoch: 063, Loss: 1.09971, Train Acc: 0.80460, Val Acc: 0.79661
# Epoch: 064, Loss: 1.10645, Train Acc: 0.81609, Val Acc: 0.79661
# Epoch: 065, Loss: 1.13914, Train Acc: 0.78161, Val Acc: 0.79661
# Epoch: 066, Loss: 1.10661, Train Acc: 0.80460, Val Acc: 0.79661
# Epoch: 067, Loss: 1.10107, Train Acc: 0.81609, Val Acc: 0.77966
# Epoch: 068, Loss: 1.10035, Train Acc: 0.80460, Val Acc: 0.74576
# Epoch: 069, Loss: 1.11460, Train Acc: 0.79310, Val Acc: 0.74576
# Epoch: 070, Loss: 1.08340, Train Acc: 0.82759, Val Acc: 0.74576
# Epoch: 071, Loss: 1.12268, Train Acc: 0.77011, Val Acc: 0.77966
# Epoch: 072, Loss: 1.09258, Train Acc: 0.82759, Val Acc: 0.79661
# Epoch: 073, Loss: 1.10371, Train Acc: 0.81609, Val Acc: 0.77966
# Epoch: 074, Loss: 1.08991, Train Acc: 0.82759, Val Acc: 0.77966
# Epoch: 075, Loss: 1.14333, Train Acc: 0.78161, Val Acc: 0.79661
# Epoch: 076, Loss: 1.08741, Train Acc: 0.82759, Val Acc: 0.77966
# Epoch: 077, Loss: 1.09532, Train Acc: 0.81609, Val Acc: 0.74576
# Epoch: 078, Loss: 1.09487, Train Acc: 0.80460, Val Acc: 0.74576
# Epoch: 079, Loss: 1.10624, Train Acc: 0.80460, Val Acc: 0.77966
# Epoch: 080, Loss: 1.09638, Train Acc: 0.81609, Val Acc: 0.79661
# Epoch: 081, Loss: 1.12935, Train Acc: 0.79310, Val Acc: 0.79661
# Epoch: 082, Loss: 1.08353, Train Acc: 0.82759, Val Acc: 0.79661
# Epoch: 083, Loss: 1.11912, Train Acc: 0.79310, Val Acc: 0.79661
# Epoch: 084, Loss: 1.10547, Train Acc: 0.81609, Val Acc: 0.79661
# Epoch: 085, Loss: 1.11410, Train Acc: 0.80460, Val Acc: 0.77966
# Epoch: 086, Loss: 1.11718, Train Acc: 0.82759, Val Acc: 0.77966
# Epoch: 087, Loss: 1.11429, Train Acc: 0.79310, Val Acc: 0.76271
# Epoch: 088, Loss: 1.08430, Train Acc: 0.83908, Val Acc: 0.76271
# Epoch: 089, Loss: 1.09158, Train Acc: 0.82759, Val Acc: 0.76271
# Epoch: 090, Loss: 1.08658, Train Acc: 0.85057, Val Acc: 0.77966
# Epoch: 091, Loss: 1.08933, Train Acc: 0.82759, Val Acc: 0.79661
# Epoch: 092, Loss: 1.09759, Train Acc: 0.79310, Val Acc: 0.79661
# Epoch: 093, Loss: 1.10554, Train Acc: 0.80460, Val Acc: 0.81356
# Epoch: 094, Loss: 1.07522, Train Acc: 0.83908, Val Acc: 0.81356
# Epoch: 095, Loss: 1.06699, Train Acc: 0.86207, Val Acc: 0.81356
# Epoch: 096, Loss: 1.08404, Train Acc: 0.86207, Val Acc: 0.81356
# Epoch: 097, Loss: 1.07684, Train Acc: 0.83908, Val Acc: 0.79661
# Epoch: 098, Loss: 1.08863, Train Acc: 0.86207, Val Acc: 0.79661
# Epoch: 099, Loss: 1.08614, Train Acc: 0.82759, Val Acc: 0.79661
# Epoch: 100, Loss: 1.11428, Train Acc: 0.79310, Val Acc: 0.79661
# Test Accuracy: 0.56757
# Random State 743456  in the iteration 4
# Epoch: 001, Loss: 1.27414, Train Acc: 0.60920, Val Acc: 0.71186
# Epoch: 002, Loss: 1.14938, Train Acc: 0.74713, Val Acc: 0.71186
# Epoch: 003, Loss: 1.13709, Train Acc: 0.78161, Val Acc: 0.72881
# Epoch: 004, Loss: 1.17064, Train Acc: 0.71264, Val Acc: 0.74576
# Epoch: 005, Loss: 1.18017, Train Acc: 0.71264, Val Acc: 0.74576
# Epoch: 006, Loss: 1.13458, Train Acc: 0.78161, Val Acc: 0.72881
# Epoch: 007, Loss: 1.10427, Train Acc: 0.82759, Val Acc: 0.72881
# Epoch: 008, Loss: 1.16349, Train Acc: 0.75862, Val Acc: 0.72881
# Epoch: 009, Loss: 1.12643, Train Acc: 0.78161, Val Acc: 0.74576
# Epoch: 010, Loss: 1.08558, Train Acc: 0.81609, Val Acc: 0.74576
# Epoch: 011, Loss: 1.08972, Train Acc: 0.83908, Val Acc: 0.72881
# Epoch: 012, Loss: 1.06771, Train Acc: 0.85057, Val Acc: 0.72881
# Epoch: 013, Loss: 1.07932, Train Acc: 0.82759, Val Acc: 0.72881
# Epoch: 014, Loss: 1.10345, Train Acc: 0.81609, Val Acc: 0.74576
# Epoch: 015, Loss: 1.06735, Train Acc: 0.86207, Val Acc: 0.74576
# Epoch: 016, Loss: 1.08129, Train Acc: 0.81609, Val Acc: 0.74576
# Epoch: 017, Loss: 1.10408, Train Acc: 0.78161, Val Acc: 0.72881
# Epoch: 018, Loss: 1.07737, Train Acc: 0.85057, Val Acc: 0.74576
# Epoch: 019, Loss: 1.11107, Train Acc: 0.81609, Val Acc: 0.76271
# Epoch: 020, Loss: 1.07493, Train Acc: 0.86207, Val Acc: 0.76271
# Epoch: 021, Loss: 1.04954, Train Acc: 0.88506, Val Acc: 0.74576
# Epoch: 022, Loss: 1.06104, Train Acc: 0.87356, Val Acc: 0.74576
# Epoch: 023, Loss: 1.03583, Train Acc: 0.86207, Val Acc: 0.74576
# Epoch: 024, Loss: 1.06826, Train Acc: 0.81609, Val Acc: 0.74576
# Epoch: 025, Loss: 1.05907, Train Acc: 0.86207, Val Acc: 0.72881
# Epoch: 026, Loss: 1.04198, Train Acc: 0.87356, Val Acc: 0.72881
# Epoch: 027, Loss: 1.08964, Train Acc: 0.83908, Val Acc: 0.72881
# Epoch: 028, Loss: 1.07852, Train Acc: 0.82759, Val Acc: 0.72881
# Epoch: 029, Loss: 1.09772, Train Acc: 0.80460, Val Acc: 0.71186
# Epoch: 030, Loss: 1.08469, Train Acc: 0.81609, Val Acc: 0.66102
# Epoch: 031, Loss: 1.06061, Train Acc: 0.86207, Val Acc: 0.64407
# Epoch: 032, Loss: 1.05694, Train Acc: 0.89655, Val Acc: 0.66102
# Epoch: 033, Loss: 1.04407, Train Acc: 0.86207, Val Acc: 0.64407
# Epoch: 034, Loss: 1.09375, Train Acc: 0.79310, Val Acc: 0.62712
# Epoch: 035, Loss: 1.06393, Train Acc: 0.83908, Val Acc: 0.66102
# Epoch: 036, Loss: 1.06529, Train Acc: 0.83908, Val Acc: 0.67797
# Epoch: 037, Loss: 1.03708, Train Acc: 0.88506, Val Acc: 0.67797
# Epoch: 038, Loss: 1.07344, Train Acc: 0.81609, Val Acc: 0.69492
# Epoch: 039, Loss: 1.02987, Train Acc: 0.87356, Val Acc: 0.69492
# Epoch: 040, Loss: 1.05368, Train Acc: 0.87356, Val Acc: 0.69492
# Epoch: 041, Loss: 1.04736, Train Acc: 0.85057, Val Acc: 0.67797
# Epoch: 042, Loss: 1.07639, Train Acc: 0.86207, Val Acc: 0.67797
# Epoch: 043, Loss: 1.04654, Train Acc: 0.86207, Val Acc: 0.67797
# Epoch: 044, Loss: 1.00407, Train Acc: 0.90805, Val Acc: 0.67797
# Epoch: 045, Loss: 1.03039, Train Acc: 0.89655, Val Acc: 0.69492
# Epoch: 046, Loss: 1.03128, Train Acc: 0.88506, Val Acc: 0.71186
# Epoch: 047, Loss: 1.05696, Train Acc: 0.87356, Val Acc: 0.69492
# Epoch: 048, Loss: 1.03143, Train Acc: 0.88506, Val Acc: 0.67797
# Epoch: 049, Loss: 1.04687, Train Acc: 0.86207, Val Acc: 0.67797
# Epoch: 050, Loss: 1.03350, Train Acc: 0.89655, Val Acc: 0.69492
# Epoch: 051, Loss: 1.04088, Train Acc: 0.89655, Val Acc: 0.69492
# Epoch: 052, Loss: 1.03248, Train Acc: 0.89655, Val Acc: 0.71186
# Epoch: 053, Loss: 1.07289, Train Acc: 0.83908, Val Acc: 0.71186
# Epoch: 054, Loss: 1.04412, Train Acc: 0.89655, Val Acc: 0.71186
# Epoch: 055, Loss: 1.06943, Train Acc: 0.86207, Val Acc: 0.71186
# Epoch: 056, Loss: 1.05713, Train Acc: 0.86207, Val Acc: 0.71186
# Epoch: 057, Loss: 1.06990, Train Acc: 0.83908, Val Acc: 0.71186
# Epoch: 058, Loss: 1.02000, Train Acc: 0.89655, Val Acc: 0.71186
# Epoch: 059, Loss: 1.01971, Train Acc: 0.90805, Val Acc: 0.69492
# Epoch: 060, Loss: 1.04026, Train Acc: 0.88506, Val Acc: 0.69492
# Epoch: 061, Loss: 1.03456, Train Acc: 0.88506, Val Acc: 0.69492
# Epoch: 062, Loss: 1.03523, Train Acc: 0.89655, Val Acc: 0.69492
# Epoch: 063, Loss: 1.03793, Train Acc: 0.87356, Val Acc: 0.69492
# Epoch: 064, Loss: 1.01682, Train Acc: 0.88506, Val Acc: 0.69492
# Epoch: 065, Loss: 1.03552, Train Acc: 0.88506, Val Acc: 0.67797
# Epoch: 066, Loss: 1.06931, Train Acc: 0.85057, Val Acc: 0.69492
# Epoch: 067, Loss: 1.04645, Train Acc: 0.86207, Val Acc: 0.71186
# Epoch: 068, Loss: 1.02863, Train Acc: 0.89655, Val Acc: 0.67797
# Epoch: 069, Loss: 1.02278, Train Acc: 0.89655, Val Acc: 0.69492
# Epoch: 070, Loss: 1.00451, Train Acc: 0.90805, Val Acc: 0.72881
# Epoch: 071, Loss: 1.02798, Train Acc: 0.88506, Val Acc: 0.71186
# Epoch: 072, Loss: 1.02441, Train Acc: 0.88506, Val Acc: 0.69492
# Epoch: 073, Loss: 1.05493, Train Acc: 0.87356, Val Acc: 0.66102
# Epoch: 074, Loss: 1.03900, Train Acc: 0.87356, Val Acc: 0.66102
# Epoch: 075, Loss: 1.03346, Train Acc: 0.87356, Val Acc: 0.67797
# Epoch: 076, Loss: 1.02202, Train Acc: 0.89655, Val Acc: 0.69492
# Epoch: 077, Loss: 1.03309, Train Acc: 0.89655, Val Acc: 0.69492
# Epoch: 078, Loss: 1.03442, Train Acc: 0.88506, Val Acc: 0.69492
# Epoch: 079, Loss: 1.07458, Train Acc: 0.88506, Val Acc: 0.69492
# Epoch: 080, Loss: 1.06770, Train Acc: 0.86207, Val Acc: 0.69492
# Epoch: 081, Loss: 1.03863, Train Acc: 0.86207, Val Acc: 0.69492
# Epoch: 082, Loss: 1.03412, Train Acc: 0.88506, Val Acc: 0.69492
# Epoch: 083, Loss: 1.03683, Train Acc: 0.89655, Val Acc: 0.69492
# Epoch: 084, Loss: 1.08667, Train Acc: 0.81609, Val Acc: 0.69492
# Epoch: 085, Loss: 1.02423, Train Acc: 0.90805, Val Acc: 0.67797
# Epoch: 086, Loss: 1.09399, Train Acc: 0.81609, Val Acc: 0.67797
# Epoch: 087, Loss: 1.03880, Train Acc: 0.88506, Val Acc: 0.67797
# Epoch: 088, Loss: 1.02810, Train Acc: 0.90805, Val Acc: 0.66102
# Epoch: 089, Loss: 1.06831, Train Acc: 0.83908, Val Acc: 0.66102
# Epoch: 090, Loss: 0.99553, Train Acc: 0.91954, Val Acc: 0.66102
# Epoch: 091, Loss: 1.04167, Train Acc: 0.86207, Val Acc: 0.69492
# Epoch: 092, Loss: 1.04556, Train Acc: 0.89655, Val Acc: 0.67797
# Epoch: 093, Loss: 1.02614, Train Acc: 0.90805, Val Acc: 0.67797
# Epoch: 094, Loss: 1.01827, Train Acc: 0.89655, Val Acc: 0.67797
# Epoch: 095, Loss: 1.05674, Train Acc: 0.86207, Val Acc: 0.64407
# Epoch: 096, Loss: 1.00915, Train Acc: 0.91954, Val Acc: 0.64407
# Epoch: 097, Loss: 1.02574, Train Acc: 0.87356, Val Acc: 0.64407
# Epoch: 098, Loss: 1.04936, Train Acc: 0.87356, Val Acc: 0.64407
# Epoch: 099, Loss: 1.00677, Train Acc: 0.90805, Val Acc: 0.67797
# Epoch: 100, Loss: 1.02764, Train Acc: 0.89655, Val Acc: 0.66102
# Test Accuracy: 0.59459
# Random State 4734510  in the iteration 5
# Epoch: 001, Loss: 1.26673, Train Acc: 0.63218, Val Acc: 0.86441
# Epoch: 002, Loss: 1.21293, Train Acc: 0.71264, Val Acc: 0.72881
# Epoch: 003, Loss: 1.23492, Train Acc: 0.67816, Val Acc: 0.69492
# Epoch: 004, Loss: 1.19801, Train Acc: 0.73563, Val Acc: 0.62712
# Epoch: 005, Loss: 1.23461, Train Acc: 0.66667, Val Acc: 0.62712
# Epoch: 006, Loss: 1.19051, Train Acc: 0.73563, Val Acc: 0.66102
# Epoch: 007, Loss: 1.15998, Train Acc: 0.75862, Val Acc: 0.71186
# Epoch: 008, Loss: 1.19376, Train Acc: 0.70115, Val Acc: 0.74576
# Epoch: 009, Loss: 1.17312, Train Acc: 0.74713, Val Acc: 0.81356
# Epoch: 010, Loss: 1.16519, Train Acc: 0.75862, Val Acc: 0.77966
# Epoch: 011, Loss: 1.14297, Train Acc: 0.77011, Val Acc: 0.76271
# Epoch: 012, Loss: 1.13545, Train Acc: 0.80460, Val Acc: 0.76271
# Epoch: 013, Loss: 1.16370, Train Acc: 0.73563, Val Acc: 0.77966
# Epoch: 014, Loss: 1.16467, Train Acc: 0.75862, Val Acc: 0.76271
# Epoch: 015, Loss: 1.11866, Train Acc: 0.79310, Val Acc: 0.74576
# Epoch: 016, Loss: 1.15083, Train Acc: 0.74713, Val Acc: 0.74576
# Epoch: 017, Loss: 1.12724, Train Acc: 0.77011, Val Acc: 0.72881
# Epoch: 018, Loss: 1.10283, Train Acc: 0.82759, Val Acc: 0.72881
# Epoch: 019, Loss: 1.12931, Train Acc: 0.77011, Val Acc: 0.72881
# Epoch: 020, Loss: 1.13676, Train Acc: 0.78161, Val Acc: 0.74576
# Epoch: 021, Loss: 1.14011, Train Acc: 0.77011, Val Acc: 0.71186
# Epoch: 022, Loss: 1.11043, Train Acc: 0.80460, Val Acc: 0.74576
# Epoch: 023, Loss: 1.10398, Train Acc: 0.83908, Val Acc: 0.71186
# Epoch: 024, Loss: 1.12876, Train Acc: 0.77011, Val Acc: 0.71186
# Epoch: 025, Loss: 1.09104, Train Acc: 0.81609, Val Acc: 0.72881
# Epoch: 026, Loss: 1.10814, Train Acc: 0.80460, Val Acc: 0.71186
# Epoch: 027, Loss: 1.11183, Train Acc: 0.81609, Val Acc: 0.72881
# Epoch: 028, Loss: 1.08277, Train Acc: 0.85057, Val Acc: 0.77966
# Epoch: 029, Loss: 1.13031, Train Acc: 0.78161, Val Acc: 0.79661
# Epoch: 030, Loss: 1.09609, Train Acc: 0.81609, Val Acc: 0.79661
# Epoch: 031, Loss: 1.06604, Train Acc: 0.85057, Val Acc: 0.77966
# Epoch: 032, Loss: 1.08524, Train Acc: 0.83908, Val Acc: 0.77966
# Epoch: 033, Loss: 1.11850, Train Acc: 0.79310, Val Acc: 0.77966
# Epoch: 034, Loss: 1.07634, Train Acc: 0.86207, Val Acc: 0.77966
# Epoch: 035, Loss: 1.10449, Train Acc: 0.81609, Val Acc: 0.76271
# Epoch: 036, Loss: 1.11216, Train Acc: 0.78161, Val Acc: 0.76271
# Epoch: 037, Loss: 1.08553, Train Acc: 0.82759, Val Acc: 0.79661
# Epoch: 038, Loss: 1.12212, Train Acc: 0.79310, Val Acc: 0.77966
# Epoch: 039, Loss: 1.05883, Train Acc: 0.87356, Val Acc: 0.76271
# Epoch: 040, Loss: 1.08952, Train Acc: 0.83908, Val Acc: 0.76271
# Epoch: 041, Loss: 1.11319, Train Acc: 0.75862, Val Acc: 0.74576
# Epoch: 042, Loss: 1.10728, Train Acc: 0.81609, Val Acc: 0.74576
# Epoch: 043, Loss: 1.06842, Train Acc: 0.85057, Val Acc: 0.74576
# Epoch: 044, Loss: 1.06923, Train Acc: 0.83908, Val Acc: 0.72881
# Epoch: 045, Loss: 1.05690, Train Acc: 0.86207, Val Acc: 0.72881
# Epoch: 046, Loss: 1.08303, Train Acc: 0.81609, Val Acc: 0.72881
# Epoch: 047, Loss: 1.07432, Train Acc: 0.82759, Val Acc: 0.74576
# Epoch: 048, Loss: 1.06623, Train Acc: 0.86207, Val Acc: 0.72881
# Epoch: 049, Loss: 1.06513, Train Acc: 0.85057, Val Acc: 0.71186
# Epoch: 050, Loss: 1.06174, Train Acc: 0.87356, Val Acc: 0.72881
# Epoch: 051, Loss: 1.06599, Train Acc: 0.85057, Val Acc: 0.71186
# Epoch: 052, Loss: 1.08680, Train Acc: 0.82759, Val Acc: 0.71186
# Epoch: 053, Loss: 1.08482, Train Acc: 0.82759, Val Acc: 0.72881
# Epoch: 054, Loss: 1.06321, Train Acc: 0.85057, Val Acc: 0.72881
# Epoch: 055, Loss: 1.07093, Train Acc: 0.86207, Val Acc: 0.72881
# Epoch: 056, Loss: 1.09827, Train Acc: 0.83908, Val Acc: 0.71186
# Epoch: 057, Loss: 1.08493, Train Acc: 0.82759, Val Acc: 0.71186
# Epoch: 058, Loss: 1.07883, Train Acc: 0.82759, Val Acc: 0.69492
# Epoch: 059, Loss: 1.07349, Train Acc: 0.83908, Val Acc: 0.67797
# Epoch: 060, Loss: 1.03912, Train Acc: 0.88506, Val Acc: 0.66102
# Epoch: 061, Loss: 1.05940, Train Acc: 0.87356, Val Acc: 0.66102
# Epoch: 062, Loss: 1.07583, Train Acc: 0.85057, Val Acc: 0.62712
# Epoch: 063, Loss: 1.05137, Train Acc: 0.87356, Val Acc: 0.57627
# Epoch: 064, Loss: 1.07149, Train Acc: 0.86207, Val Acc: 0.59322
# Epoch: 065, Loss: 1.05405, Train Acc: 0.86207, Val Acc: 0.61017
# Epoch: 066, Loss: 1.04758, Train Acc: 0.86207, Val Acc: 0.64407
# Epoch: 067, Loss: 1.10938, Train Acc: 0.80460, Val Acc: 0.67797
# Epoch: 068, Loss: 1.05729, Train Acc: 0.87356, Val Acc: 0.69492
# Epoch: 069, Loss: 1.05369, Train Acc: 0.88506, Val Acc: 0.71186
# Epoch: 070, Loss: 1.08613, Train Acc: 0.82759, Val Acc: 0.71186
# Epoch: 071, Loss: 1.07453, Train Acc: 0.82759, Val Acc: 0.71186
# Epoch: 072, Loss: 1.06735, Train Acc: 0.86207, Val Acc: 0.74576
# Epoch: 073, Loss: 1.05926, Train Acc: 0.86207, Val Acc: 0.74576
# Epoch: 074, Loss: 1.09495, Train Acc: 0.82759, Val Acc: 0.72881
# Epoch: 075, Loss: 1.08646, Train Acc: 0.83908, Val Acc: 0.72881
# Epoch: 076, Loss: 1.04914, Train Acc: 0.87356, Val Acc: 0.76271
# Epoch: 077, Loss: 1.05402, Train Acc: 0.86207, Val Acc: 0.77966
# Epoch: 078, Loss: 1.07292, Train Acc: 0.83908, Val Acc: 0.77966
# Epoch: 079, Loss: 1.03806, Train Acc: 0.88506, Val Acc: 0.76271
# Epoch: 080, Loss: 1.07575, Train Acc: 0.86207, Val Acc: 0.76271
# Epoch: 081, Loss: 1.07601, Train Acc: 0.85057, Val Acc: 0.71186
# Epoch: 082, Loss: 1.08655, Train Acc: 0.85057, Val Acc: 0.66102
# Epoch: 083, Loss: 1.09405, Train Acc: 0.79310, Val Acc: 0.59322
# Epoch: 084, Loss: 1.07052, Train Acc: 0.86207, Val Acc: 0.61017
# Epoch: 085, Loss: 1.06794, Train Acc: 0.86207, Val Acc: 0.67797
# Epoch: 086, Loss: 1.06428, Train Acc: 0.86207, Val Acc: 0.67797
# Epoch: 087, Loss: 1.05990, Train Acc: 0.88506, Val Acc: 0.62712
# Epoch: 088, Loss: 1.09833, Train Acc: 0.82759, Val Acc: 0.62712
# Epoch: 089, Loss: 1.04212, Train Acc: 0.87356, Val Acc: 0.61017
# Epoch: 090, Loss: 1.07194, Train Acc: 0.86207, Val Acc: 0.61017
# Epoch: 091, Loss: 1.04973, Train Acc: 0.88506, Val Acc: 0.66102
# Epoch: 092, Loss: 1.05840, Train Acc: 0.85057, Val Acc: 0.67797
# Epoch: 093, Loss: 1.04542, Train Acc: 0.89655, Val Acc: 0.69492
# Epoch: 094, Loss: 1.06489, Train Acc: 0.85057, Val Acc: 0.67797
# Epoch: 095, Loss: 1.05401, Train Acc: 0.86207, Val Acc: 0.67797
# Epoch: 096, Loss: 1.04567, Train Acc: 0.86207, Val Acc: 0.66102
# Epoch: 097, Loss: 1.03737, Train Acc: 0.87356, Val Acc: 0.67797
# Epoch: 098, Loss: 1.06169, Train Acc: 0.87356, Val Acc: 0.69492
# Epoch: 099, Loss: 1.06592, Train Acc: 0.86207, Val Acc: 0.69492
# Epoch: 100, Loss: 1.06804, Train Acc: 0.86207, Val Acc: 0.66102
# Test Accuracy: 0.75676
# Random State 654321  in the iteration 6
# Epoch: 001, Loss: 1.22007, Train Acc: 0.72414, Val Acc: 0.76271
# Epoch: 002, Loss: 1.19467, Train Acc: 0.72414, Val Acc: 0.76271
# Epoch: 003, Loss: 1.24841, Train Acc: 0.62069, Val Acc: 0.81356
# Epoch: 004, Loss: 1.19620, Train Acc: 0.72414, Val Acc: 0.83051
# Epoch: 005, Loss: 1.20310, Train Acc: 0.71264, Val Acc: 0.81356
# Epoch: 006, Loss: 1.19100, Train Acc: 0.72414, Val Acc: 0.84746
# Epoch: 007, Loss: 1.14743, Train Acc: 0.78161, Val Acc: 0.86441
# Epoch: 008, Loss: 1.12476, Train Acc: 0.82759, Val Acc: 0.84746
# Epoch: 009, Loss: 1.13264, Train Acc: 0.77011, Val Acc: 0.86441
# Epoch: 010, Loss: 1.17688, Train Acc: 0.72414, Val Acc: 0.84746
# Epoch: 011, Loss: 1.14014, Train Acc: 0.80460, Val Acc: 0.81356
# Epoch: 012, Loss: 1.11928, Train Acc: 0.79310, Val Acc: 0.79661
# Epoch: 013, Loss: 1.13378, Train Acc: 0.81609, Val Acc: 0.79661
# Epoch: 014, Loss: 1.11724, Train Acc: 0.80460, Val Acc: 0.77966
# Epoch: 015, Loss: 1.12668, Train Acc: 0.81609, Val Acc: 0.76271
# Epoch: 016, Loss: 1.11103, Train Acc: 0.81609, Val Acc: 0.76271
# Epoch: 017, Loss: 1.07801, Train Acc: 0.85057, Val Acc: 0.77966
# Epoch: 018, Loss: 1.14734, Train Acc: 0.73563, Val Acc: 0.77966
# Epoch: 019, Loss: 1.08878, Train Acc: 0.83908, Val Acc: 0.76271
# Epoch: 020, Loss: 1.14501, Train Acc: 0.74713, Val Acc: 0.72881
# Epoch: 021, Loss: 1.12192, Train Acc: 0.77011, Val Acc: 0.72881
# Epoch: 022, Loss: 1.15124, Train Acc: 0.74713, Val Acc: 0.72881
# Epoch: 023, Loss: 1.15136, Train Acc: 0.74713, Val Acc: 0.69492
# Epoch: 024, Loss: 1.07801, Train Acc: 0.82759, Val Acc: 0.71186
# Epoch: 025, Loss: 1.08419, Train Acc: 0.83908, Val Acc: 0.71186
# Epoch: 026, Loss: 1.10982, Train Acc: 0.79310, Val Acc: 0.71186
# Epoch: 027, Loss: 1.12101, Train Acc: 0.81609, Val Acc: 0.72881
# Epoch: 028, Loss: 1.11035, Train Acc: 0.81609, Val Acc: 0.79661
# Epoch: 029, Loss: 1.14643, Train Acc: 0.78161, Val Acc: 0.79661
# Epoch: 030, Loss: 1.11303, Train Acc: 0.79310, Val Acc: 0.79661
# Epoch: 031, Loss: 1.11591, Train Acc: 0.81609, Val Acc: 0.77966
# Epoch: 032, Loss: 1.07649, Train Acc: 0.83908, Val Acc: 0.76271
# Epoch: 033, Loss: 1.09772, Train Acc: 0.81609, Val Acc: 0.76271
# Epoch: 034, Loss: 1.10315, Train Acc: 0.82759, Val Acc: 0.76271
# Epoch: 035, Loss: 1.10601, Train Acc: 0.81609, Val Acc: 0.77966
# Epoch: 036, Loss: 1.08073, Train Acc: 0.83908, Val Acc: 0.77966
# Epoch: 037, Loss: 1.08546, Train Acc: 0.81609, Val Acc: 0.77966
# Epoch: 038, Loss: 1.07350, Train Acc: 0.85057, Val Acc: 0.77966
# Epoch: 039, Loss: 1.11191, Train Acc: 0.80460, Val Acc: 0.76271
# Epoch: 040, Loss: 1.07396, Train Acc: 0.83908, Val Acc: 0.77966
# Epoch: 041, Loss: 1.09911, Train Acc: 0.82759, Val Acc: 0.77966
# Epoch: 042, Loss: 1.08386, Train Acc: 0.83908, Val Acc: 0.79661
# Epoch: 043, Loss: 1.11830, Train Acc: 0.79310, Val Acc: 0.77966
# Epoch: 044, Loss: 1.09329, Train Acc: 0.83908, Val Acc: 0.79661
# Epoch: 045, Loss: 1.07467, Train Acc: 0.85057, Val Acc: 0.81356
# Epoch: 046, Loss: 1.09961, Train Acc: 0.81609, Val Acc: 0.81356
# Epoch: 047, Loss: 1.06617, Train Acc: 0.83908, Val Acc: 0.81356
# Epoch: 048, Loss: 1.07820, Train Acc: 0.83908, Val Acc: 0.81356
# Epoch: 049, Loss: 1.04873, Train Acc: 0.86207, Val Acc: 0.81356
# Epoch: 050, Loss: 1.14516, Train Acc: 0.75862, Val Acc: 0.81356
# Epoch: 051, Loss: 1.07751, Train Acc: 0.85057, Val Acc: 0.79661
# Epoch: 052, Loss: 1.10970, Train Acc: 0.80460, Val Acc: 0.77966
# Epoch: 053, Loss: 1.07607, Train Acc: 0.85057, Val Acc: 0.77966
# Epoch: 054, Loss: 1.09082, Train Acc: 0.82759, Val Acc: 0.76271
# Epoch: 055, Loss: 1.10158, Train Acc: 0.82759, Val Acc: 0.76271
# Epoch: 056, Loss: 1.08684, Train Acc: 0.81609, Val Acc: 0.76271
# Epoch: 057, Loss: 1.07675, Train Acc: 0.83908, Val Acc: 0.74576
# Epoch: 058, Loss: 1.08808, Train Acc: 0.80460, Val Acc: 0.76271
# Epoch: 059, Loss: 1.08937, Train Acc: 0.85057, Val Acc: 0.72881
# Epoch: 060, Loss: 1.08141, Train Acc: 0.83908, Val Acc: 0.72881
# Epoch: 061, Loss: 1.10282, Train Acc: 0.80460, Val Acc: 0.74576
# Epoch: 062, Loss: 1.06834, Train Acc: 0.87356, Val Acc: 0.76271
# Epoch: 063, Loss: 1.07370, Train Acc: 0.83908, Val Acc: 0.76271
# Epoch: 064, Loss: 1.05639, Train Acc: 0.87356, Val Acc: 0.76271
# Epoch: 065, Loss: 1.07176, Train Acc: 0.88506, Val Acc: 0.76271
# Epoch: 066, Loss: 1.05335, Train Acc: 0.86207, Val Acc: 0.76271
# Epoch: 067, Loss: 1.08756, Train Acc: 0.85057, Val Acc: 0.76271
# Epoch: 068, Loss: 1.06917, Train Acc: 0.86207, Val Acc: 0.76271
# Epoch: 069, Loss: 1.08845, Train Acc: 0.81609, Val Acc: 0.77966
# Epoch: 070, Loss: 1.06972, Train Acc: 0.85057, Val Acc: 0.81356
# Epoch: 071, Loss: 1.08988, Train Acc: 0.83908, Val Acc: 0.83051
# Epoch: 072, Loss: 1.05541, Train Acc: 0.86207, Val Acc: 0.83051
# Epoch: 073, Loss: 1.05651, Train Acc: 0.87356, Val Acc: 0.83051
# Epoch: 074, Loss: 1.08865, Train Acc: 0.82759, Val Acc: 0.83051
# Epoch: 075, Loss: 1.10046, Train Acc: 0.80460, Val Acc: 0.81356
# Epoch: 076, Loss: 1.09138, Train Acc: 0.81609, Val Acc: 0.81356
# Epoch: 077, Loss: 1.06778, Train Acc: 0.82759, Val Acc: 0.81356
# Epoch: 078, Loss: 1.06657, Train Acc: 0.86207, Val Acc: 0.83051
# Epoch: 079, Loss: 1.06481, Train Acc: 0.85057, Val Acc: 0.84746
# Epoch: 080, Loss: 1.09152, Train Acc: 0.81609, Val Acc: 0.84746
# Epoch: 081, Loss: 1.11158, Train Acc: 0.78161, Val Acc: 0.84746
# Epoch: 082, Loss: 1.08254, Train Acc: 0.82759, Val Acc: 0.83051
# Epoch: 083, Loss: 1.07060, Train Acc: 0.83908, Val Acc: 0.83051
# Epoch: 084, Loss: 1.07996, Train Acc: 0.85057, Val Acc: 0.83051
# Epoch: 085, Loss: 1.10939, Train Acc: 0.79310, Val Acc: 0.83051
# Epoch: 086, Loss: 1.09164, Train Acc: 0.83908, Val Acc: 0.83051
# Epoch: 087, Loss: 1.04941, Train Acc: 0.88506, Val Acc: 0.81356
# Epoch: 088, Loss: 1.12633, Train Acc: 0.79310, Val Acc: 0.79661
# Epoch: 089, Loss: 1.08073, Train Acc: 0.82759, Val Acc: 0.79661
# Epoch: 090, Loss: 1.06938, Train Acc: 0.82759, Val Acc: 0.79661
# Epoch: 091, Loss: 1.06966, Train Acc: 0.85057, Val Acc: 0.79661
# Epoch: 092, Loss: 1.08465, Train Acc: 0.83908, Val Acc: 0.79661
# Epoch: 093, Loss: 1.09007, Train Acc: 0.82759, Val Acc: 0.77966
# Epoch: 094, Loss: 1.05239, Train Acc: 0.86207, Val Acc: 0.77966
# Epoch: 095, Loss: 1.08950, Train Acc: 0.83908, Val Acc: 0.76271
# Epoch: 096, Loss: 1.07138, Train Acc: 0.83908, Val Acc: 0.74576
# Epoch: 097, Loss: 1.08958, Train Acc: 0.83908, Val Acc: 0.76271
# Epoch: 098, Loss: 1.07613, Train Acc: 0.85057, Val Acc: 0.76271
# Epoch: 099, Loss: 1.09398, Train Acc: 0.81609, Val Acc: 0.76271
# Epoch: 100, Loss: 1.05321, Train Acc: 0.88506, Val Acc: 0.76271
# Test Accuracy: 0.78378
# Random State 124321  in the iteration 7
# Epoch: 001, Loss: 1.21608, Train Acc: 0.68966, Val Acc: 0.76271
# Epoch: 002, Loss: 1.21501, Train Acc: 0.68966, Val Acc: 0.74576
# Epoch: 003, Loss: 1.20553, Train Acc: 0.67816, Val Acc: 0.72881
# Epoch: 004, Loss: 1.21011, Train Acc: 0.67816, Val Acc: 0.69492
# Epoch: 005, Loss: 1.21163, Train Acc: 0.66667, Val Acc: 0.71186
# Epoch: 006, Loss: 1.16085, Train Acc: 0.74713, Val Acc: 0.71186
# Epoch: 007, Loss: 1.21111, Train Acc: 0.67816, Val Acc: 0.71186
# Epoch: 008, Loss: 1.19840, Train Acc: 0.68966, Val Acc: 0.71186
# Epoch: 009, Loss: 1.16378, Train Acc: 0.72414, Val Acc: 0.72881
# Epoch: 010, Loss: 1.15977, Train Acc: 0.75862, Val Acc: 0.72881
# Epoch: 011, Loss: 1.15668, Train Acc: 0.75862, Val Acc: 0.72881
# Epoch: 012, Loss: 1.17782, Train Acc: 0.72414, Val Acc: 0.71186
# Epoch: 013, Loss: 1.15861, Train Acc: 0.73563, Val Acc: 0.71186
# Epoch: 014, Loss: 1.14486, Train Acc: 0.78161, Val Acc: 0.71186
# Epoch: 015, Loss: 1.13511, Train Acc: 0.77011, Val Acc: 0.71186
# Epoch: 016, Loss: 1.11972, Train Acc: 0.80460, Val Acc: 0.71186
# Epoch: 017, Loss: 1.14399, Train Acc: 0.78161, Val Acc: 0.71186
# Epoch: 018, Loss: 1.14044, Train Acc: 0.78161, Val Acc: 0.69492
# Epoch: 019, Loss: 1.16729, Train Acc: 0.74713, Val Acc: 0.67797
# Epoch: 020, Loss: 1.14933, Train Acc: 0.77011, Val Acc: 0.66102
# Epoch: 021, Loss: 1.13193, Train Acc: 0.79310, Val Acc: 0.66102
# Epoch: 022, Loss: 1.10748, Train Acc: 0.80460, Val Acc: 0.64407
# Epoch: 023, Loss: 1.11833, Train Acc: 0.81609, Val Acc: 0.64407
# Epoch: 024, Loss: 1.10926, Train Acc: 0.79310, Val Acc: 0.62712
# Epoch: 025, Loss: 1.17184, Train Acc: 0.75862, Val Acc: 0.59322
# Epoch: 026, Loss: 1.12931, Train Acc: 0.75862, Val Acc: 0.57627
# Epoch: 027, Loss: 1.12683, Train Acc: 0.78161, Val Acc: 0.57627
# Epoch: 028, Loss: 1.11112, Train Acc: 0.79310, Val Acc: 0.57627
# Epoch: 029, Loss: 1.11783, Train Acc: 0.79310, Val Acc: 0.59322
# Epoch: 030, Loss: 1.11376, Train Acc: 0.75862, Val Acc: 0.61017
# Epoch: 031, Loss: 1.12000, Train Acc: 0.79310, Val Acc: 0.61017
# Epoch: 032, Loss: 1.11076, Train Acc: 0.78161, Val Acc: 0.61017
# Epoch: 033, Loss: 1.10559, Train Acc: 0.78161, Val Acc: 0.61017
# Epoch: 034, Loss: 1.06855, Train Acc: 0.88506, Val Acc: 0.62712
# Epoch: 035, Loss: 1.09118, Train Acc: 0.83908, Val Acc: 0.64407
# Epoch: 036, Loss: 1.09442, Train Acc: 0.83908, Val Acc: 0.67797
# Epoch: 037, Loss: 1.10191, Train Acc: 0.80460, Val Acc: 0.67797
# Epoch: 038, Loss: 1.11355, Train Acc: 0.77011, Val Acc: 0.67797
# Epoch: 039, Loss: 1.09696, Train Acc: 0.82759, Val Acc: 0.67797
# Epoch: 040, Loss: 1.09308, Train Acc: 0.81609, Val Acc: 0.67797
# Epoch: 041, Loss: 1.10557, Train Acc: 0.80460, Val Acc: 0.69492
# Epoch: 042, Loss: 1.10374, Train Acc: 0.78161, Val Acc: 0.69492
# Epoch: 043, Loss: 1.07810, Train Acc: 0.82759, Val Acc: 0.69492
# Epoch: 044, Loss: 1.11187, Train Acc: 0.79310, Val Acc: 0.69492
# Epoch: 045, Loss: 1.09278, Train Acc: 0.81609, Val Acc: 0.71186
# Epoch: 046, Loss: 1.09193, Train Acc: 0.81609, Val Acc: 0.71186
# Epoch: 047, Loss: 1.08182, Train Acc: 0.83908, Val Acc: 0.71186
# Epoch: 048, Loss: 1.09579, Train Acc: 0.81609, Val Acc: 0.71186
# Epoch: 049, Loss: 1.09534, Train Acc: 0.83908, Val Acc: 0.69492
# Epoch: 050, Loss: 1.08929, Train Acc: 0.81609, Val Acc: 0.69492
# Epoch: 051, Loss: 1.09611, Train Acc: 0.82759, Val Acc: 0.69492
# Epoch: 052, Loss: 1.08853, Train Acc: 0.81609, Val Acc: 0.69492
# Epoch: 053, Loss: 1.08445, Train Acc: 0.82759, Val Acc: 0.66102
# Epoch: 054, Loss: 1.10737, Train Acc: 0.81609, Val Acc: 0.62712
# Epoch: 055, Loss: 1.09465, Train Acc: 0.80460, Val Acc: 0.62712
# Epoch: 056, Loss: 1.10153, Train Acc: 0.82759, Val Acc: 0.62712
# Epoch: 057, Loss: 1.07865, Train Acc: 0.82759, Val Acc: 0.62712
# Epoch: 058, Loss: 1.09742, Train Acc: 0.80460, Val Acc: 0.62712
# Epoch: 059, Loss: 1.08866, Train Acc: 0.82759, Val Acc: 0.62712
# Epoch: 060, Loss: 1.08526, Train Acc: 0.85057, Val Acc: 0.62712
# Epoch: 061, Loss: 1.08397, Train Acc: 0.81609, Val Acc: 0.64407
# Epoch: 062, Loss: 1.07718, Train Acc: 0.86207, Val Acc: 0.64407
# Epoch: 063, Loss: 1.08704, Train Acc: 0.79310, Val Acc: 0.64407
# Epoch: 064, Loss: 1.10591, Train Acc: 0.80460, Val Acc: 0.66102
# Epoch: 065, Loss: 1.08296, Train Acc: 0.83908, Val Acc: 0.66102
# Epoch: 066, Loss: 1.07172, Train Acc: 0.82759, Val Acc: 0.66102
# Epoch: 067, Loss: 1.08196, Train Acc: 0.83908, Val Acc: 0.66102
# Epoch: 068, Loss: 1.09867, Train Acc: 0.81609, Val Acc: 0.66102
# Epoch: 069, Loss: 1.06923, Train Acc: 0.85057, Val Acc: 0.64407
# Epoch: 070, Loss: 1.08552, Train Acc: 0.83908, Val Acc: 0.62712
# Epoch: 071, Loss: 1.08681, Train Acc: 0.83908, Val Acc: 0.62712
# Epoch: 072, Loss: 1.05084, Train Acc: 0.87356, Val Acc: 0.61017
# Epoch: 073, Loss: 1.10787, Train Acc: 0.80460, Val Acc: 0.61017
# Epoch: 074, Loss: 1.06957, Train Acc: 0.86207, Val Acc: 0.62712
# Epoch: 075, Loss: 1.09530, Train Acc: 0.81609, Val Acc: 0.62712
# Epoch: 076, Loss: 1.06378, Train Acc: 0.83908, Val Acc: 0.59322
# Epoch: 077, Loss: 1.07371, Train Acc: 0.83908, Val Acc: 0.59322
# Epoch: 078, Loss: 1.06688, Train Acc: 0.83908, Val Acc: 0.57627
# Epoch: 079, Loss: 1.08915, Train Acc: 0.83908, Val Acc: 0.57627
# Epoch: 080, Loss: 1.07564, Train Acc: 0.83908, Val Acc: 0.57627
# Epoch: 081, Loss: 1.08406, Train Acc: 0.82759, Val Acc: 0.57627
# Epoch: 082, Loss: 1.06362, Train Acc: 0.83908, Val Acc: 0.59322
# Epoch: 083, Loss: 1.09604, Train Acc: 0.80460, Val Acc: 0.57627
# Epoch: 084, Loss: 1.10280, Train Acc: 0.81609, Val Acc: 0.57627
# Epoch: 085, Loss: 1.07473, Train Acc: 0.83908, Val Acc: 0.57627
# Epoch: 086, Loss: 1.07829, Train Acc: 0.81609, Val Acc: 0.54237
# Epoch: 087, Loss: 1.05875, Train Acc: 0.85057, Val Acc: 0.54237
# Epoch: 088, Loss: 1.08145, Train Acc: 0.83908, Val Acc: 0.54237
# Epoch: 089, Loss: 1.06932, Train Acc: 0.83908, Val Acc: 0.54237
# Epoch: 090, Loss: 1.08218, Train Acc: 0.82759, Val Acc: 0.54237
# Epoch: 091, Loss: 1.06423, Train Acc: 0.86207, Val Acc: 0.54237
# Epoch: 092, Loss: 1.06557, Train Acc: 0.83908, Val Acc: 0.57627
# Epoch: 093, Loss: 1.07665, Train Acc: 0.82759, Val Acc: 0.57627
# Epoch: 094, Loss: 1.11946, Train Acc: 0.77011, Val Acc: 0.57627
# Epoch: 095, Loss: 1.06557, Train Acc: 0.86207, Val Acc: 0.57627
# Epoch: 096, Loss: 1.05745, Train Acc: 0.86207, Val Acc: 0.57627
# Epoch: 097, Loss: 1.06633, Train Acc: 0.83908, Val Acc: 0.55932
# Epoch: 098, Loss: 1.08695, Train Acc: 0.82759, Val Acc: 0.55932
# Epoch: 099, Loss: 1.08725, Train Acc: 0.83908, Val Acc: 0.57627
# Epoch: 100, Loss: 1.07998, Train Acc: 0.83908, Val Acc: 0.57627
# Test Accuracy: 0.64865
# Random State 945321  in the iteration 8
# Epoch: 001, Loss: 1.22317, Train Acc: 0.68966, Val Acc: 0.66102
# Epoch: 002, Loss: 1.20144, Train Acc: 0.71264, Val Acc: 0.67797
# Epoch: 003, Loss: 1.19198, Train Acc: 0.71264, Val Acc: 0.67797
# Epoch: 004, Loss: 1.21044, Train Acc: 0.70115, Val Acc: 0.67797
# Epoch: 005, Loss: 1.19335, Train Acc: 0.71264, Val Acc: 0.71186
# Epoch: 006, Loss: 1.20272, Train Acc: 0.70115, Val Acc: 0.69492
# Epoch: 007, Loss: 1.17940, Train Acc: 0.73563, Val Acc: 0.69492
# Epoch: 008, Loss: 1.16188, Train Acc: 0.75862, Val Acc: 0.69492
# Epoch: 009, Loss: 1.19900, Train Acc: 0.70115, Val Acc: 0.67797
# Epoch: 010, Loss: 1.15297, Train Acc: 0.75862, Val Acc: 0.67797
# Epoch: 011, Loss: 1.18615, Train Acc: 0.72414, Val Acc: 0.67797
# Epoch: 012, Loss: 1.13423, Train Acc: 0.78161, Val Acc: 0.67797
# Epoch: 013, Loss: 1.17926, Train Acc: 0.73563, Val Acc: 0.67797
# Epoch: 014, Loss: 1.17230, Train Acc: 0.74713, Val Acc: 0.72881
# Epoch: 015, Loss: 1.16126, Train Acc: 0.75862, Val Acc: 0.72881
# Epoch: 016, Loss: 1.13944, Train Acc: 0.78161, Val Acc: 0.71186
# Epoch: 017, Loss: 1.14562, Train Acc: 0.75862, Val Acc: 0.71186
# Epoch: 018, Loss: 1.12739, Train Acc: 0.78161, Val Acc: 0.71186
# Epoch: 019, Loss: 1.12083, Train Acc: 0.80460, Val Acc: 0.69492
# Epoch: 020, Loss: 1.13825, Train Acc: 0.75862, Val Acc: 0.67797
# Epoch: 021, Loss: 1.12038, Train Acc: 0.78161, Val Acc: 0.69492
# Epoch: 022, Loss: 1.13884, Train Acc: 0.75862, Val Acc: 0.66102
# Epoch: 023, Loss: 1.11581, Train Acc: 0.79310, Val Acc: 0.61017
# Epoch: 024, Loss: 1.13149, Train Acc: 0.78161, Val Acc: 0.62712
# Epoch: 025, Loss: 1.14111, Train Acc: 0.75862, Val Acc: 0.62712
# Epoch: 026, Loss: 1.07288, Train Acc: 0.83908, Val Acc: 0.64407
# Epoch: 027, Loss: 1.13780, Train Acc: 0.77011, Val Acc: 0.64407
# Epoch: 028, Loss: 1.11512, Train Acc: 0.82759, Val Acc: 0.62712
# Epoch: 029, Loss: 1.10965, Train Acc: 0.80460, Val Acc: 0.62712
# Epoch: 030, Loss: 1.08661, Train Acc: 0.82759, Val Acc: 0.62712
# Epoch: 031, Loss: 1.10925, Train Acc: 0.82759, Val Acc: 0.62712
# Epoch: 032, Loss: 1.10541, Train Acc: 0.79310, Val Acc: 0.62712
# Epoch: 033, Loss: 1.09688, Train Acc: 0.81609, Val Acc: 0.64407
# Epoch: 034, Loss: 1.08350, Train Acc: 0.83908, Val Acc: 0.66102
# Epoch: 035, Loss: 1.10332, Train Acc: 0.81609, Val Acc: 0.66102
# Epoch: 036, Loss: 1.09718, Train Acc: 0.79310, Val Acc: 0.66102
# Epoch: 037, Loss: 1.08636, Train Acc: 0.82759, Val Acc: 0.66102
# Epoch: 038, Loss: 1.14972, Train Acc: 0.75862, Val Acc: 0.66102
# Epoch: 039, Loss: 1.12609, Train Acc: 0.77011, Val Acc: 0.66102
# Epoch: 040, Loss: 1.10294, Train Acc: 0.80460, Val Acc: 0.69492
# Epoch: 041, Loss: 1.11018, Train Acc: 0.79310, Val Acc: 0.69492
# Epoch: 042, Loss: 1.09859, Train Acc: 0.81609, Val Acc: 0.69492
# Epoch: 043, Loss: 1.06103, Train Acc: 0.85057, Val Acc: 0.69492
# Epoch: 044, Loss: 1.10760, Train Acc: 0.82759, Val Acc: 0.71186
# Epoch: 045, Loss: 1.11552, Train Acc: 0.78161, Val Acc: 0.71186
# Epoch: 046, Loss: 1.08839, Train Acc: 0.82759, Val Acc: 0.71186
# Epoch: 047, Loss: 1.10727, Train Acc: 0.81609, Val Acc: 0.69492
# Epoch: 048, Loss: 1.08697, Train Acc: 0.83908, Val Acc: 0.67797
# Epoch: 049, Loss: 1.09232, Train Acc: 0.82759, Val Acc: 0.64407
# Epoch: 050, Loss: 1.09751, Train Acc: 0.82759, Val Acc: 0.64407
# Epoch: 051, Loss: 1.05796, Train Acc: 0.87356, Val Acc: 0.64407
# Epoch: 052, Loss: 1.11213, Train Acc: 0.80460, Val Acc: 0.64407
# Epoch: 053, Loss: 1.13320, Train Acc: 0.78161, Val Acc: 0.64407
# ...
# Epoch: 054, Loss: 1.03598, Train Acc: 0.88506, Val Acc: 0.72881
# Epoch: 055, Loss: 1.04434, Train Acc: 0.86207, Val Acc: 0.72881
# Epoch: 056, Loss: 1.05693, Train Acc: 0.86207, Val Acc: 0.72881
# Epoch: 057, Loss: 1.05978, Train Acc: 0.85057, Val Acc: 0.74576
# Epoch: 058, Loss: 1.02752, Train Acc: 0.88506, Val Acc: 0.74576
# Epoch: 059, Loss: 1.02321, Train Acc: 0.89655, Val Acc: 0.74576
# Epoch: 060, Loss: 1.01727, Train Acc: 0.88506, Val Acc: 0.76271
# Epoch: 061, Loss: 1.03959, Train Acc: 0.87356, Val Acc: 0.76271
# Epoch: 062, Loss: 1.00843, Train Acc: 0.90805, Val Acc: 0.77966
# Epoch: 063, Loss: 1.03205, Train Acc: 0.88506, Val Acc: 0.77966
# Epoch: 064, Loss: 1.04481, Train Acc: 0.86207, Val Acc: 0.74576
# Epoch: 065, Loss: 1.00424, Train Acc: 0.90805, Val Acc: 0.72881
# Epoch: 066, Loss: 1.02411, Train Acc: 0.88506, Val Acc: 0.71186
# Epoch: 067, Loss: 1.03539, Train Acc: 0.87356, Val Acc: 0.71186
# Epoch: 068, Loss: 1.04208, Train Acc: 0.85057, Val Acc: 0.71186
# Epoch: 069, Loss: 1.06603, Train Acc: 0.82759, Val Acc: 0.71186
# Epoch: 070, Loss: 1.04581, Train Acc: 0.86207, Val Acc: 0.71186
# Epoch: 071, Loss: 1.05950, Train Acc: 0.86207, Val Acc: 0.69492
# Epoch: 072, Loss: 1.09401, Train Acc: 0.82759, Val Acc: 0.66102
# Epoch: 073, Loss: 1.05255, Train Acc: 0.82759, Val Acc: 0.66102
# Epoch: 074, Loss: 1.00413, Train Acc: 0.89655, Val Acc: 0.66102
# Epoch: 075, Loss: 1.04521, Train Acc: 0.86207, Val Acc: 0.67797
# Epoch: 076, Loss: 1.05816, Train Acc: 0.85057, Val Acc: 0.66102
# Epoch: 077, Loss: 1.01403, Train Acc: 0.88506, Val Acc: 0.67797
# Epoch: 078, Loss: 1.02467, Train Acc: 0.88506, Val Acc: 0.67797
# Epoch: 079, Loss: 1.04927, Train Acc: 0.85057, Val Acc: 0.67797
# Epoch: 080, Loss: 1.03166, Train Acc: 0.87356, Val Acc: 0.66102
# Epoch: 081, Loss: 1.02196, Train Acc: 0.90805, Val Acc: 0.66102
# Epoch: 082, Loss: 1.06261, Train Acc: 0.83908, Val Acc: 0.66102
# Epoch: 083, Loss: 1.03579, Train Acc: 0.87356, Val Acc: 0.66102
# Epoch: 084, Loss: 1.04647, Train Acc: 0.86207, Val Acc: 0.66102
# Epoch: 085, Loss: 1.02885, Train Acc: 0.88506, Val Acc: 0.64407
# Epoch: 086, Loss: 1.03126, Train Acc: 0.88506, Val Acc: 0.64407
# Epoch: 087, Loss: 1.02779, Train Acc: 0.87356, Val Acc: 0.66102
# Epoch: 088, Loss: 1.01482, Train Acc: 0.89655, Val Acc: 0.64407
# Epoch: 089, Loss: 1.00056, Train Acc: 0.90805, Val Acc: 0.64407
# Epoch: 090, Loss: 1.03005, Train Acc: 0.89655, Val Acc: 0.64407
# Epoch: 091, Loss: 1.00373, Train Acc: 0.90805, Val Acc: 0.67797
# Epoch: 092, Loss: 1.06428, Train Acc: 0.83908, Val Acc: 0.67797
# Epoch: 093, Loss: 1.00645, Train Acc: 0.90805, Val Acc: 0.67797
# Epoch: 094, Loss: 1.01566, Train Acc: 0.89655, Val Acc: 0.69492
# Epoch: 095, Loss: 0.99385, Train Acc: 0.91954, Val Acc: 0.72881
# Epoch: 096, Loss: 1.00296, Train Acc: 0.91954, Val Acc: 0.74576
# Epoch: 097, Loss: 1.05992, Train Acc: 0.83908, Val Acc: 0.74576
# Epoch: 098, Loss: 0.99702, Train Acc: 0.90805, Val Acc: 0.74576
# Epoch: 099, Loss: 1.06045, Train Acc: 0.83908, Val Acc: 0.74576
# Epoch: 100, Loss: 1.04081, Train Acc: 0.86207, Val Acc: 0.74576
# Test Accuracy: 0.75676
# Random State 945321  in the iteration 8
# Epoch: 001, Loss: 1.15208, Train Acc: 0.74713, Val Acc: 0.88136
# Epoch: 002, Loss: 1.09865, Train Acc: 0.80460, Val Acc: 0.84746
# Epoch: 003, Loss: 1.11840, Train Acc: 0.79310, Val Acc: 0.84746
# Epoch: 004, Loss: 1.12705, Train Acc: 0.77011, Val Acc: 0.84746
# Epoch: 005, Loss: 1.10888, Train Acc: 0.80460, Val Acc: 0.83051
# Epoch: 006, Loss: 1.08126, Train Acc: 0.81609, Val Acc: 0.84746
# Epoch: 007, Loss: 1.09255, Train Acc: 0.80460, Val Acc: 0.86441
# Epoch: 008, Loss: 1.03935, Train Acc: 0.87356, Val Acc: 0.84746
# Epoch: 009, Loss: 1.04710, Train Acc: 0.88506, Val Acc: 0.86441
# Epoch: 010, Loss: 1.07166, Train Acc: 0.85057, Val Acc: 0.86441
# Epoch: 011, Loss: 1.06218, Train Acc: 0.86207, Val Acc: 0.86441
# Epoch: 012, Loss: 1.03620, Train Acc: 0.87356, Val Acc: 0.84746
# Epoch: 013, Loss: 1.05307, Train Acc: 0.83908, Val Acc: 0.86441
# Epoch: 014, Loss: 1.05790, Train Acc: 0.83908, Val Acc: 0.84746
# Epoch: 015, Loss: 1.02967, Train Acc: 0.88506, Val Acc: 0.84746
# Epoch: 016, Loss: 1.05025, Train Acc: 0.87356, Val Acc: 0.83051
# Epoch: 017, Loss: 1.02075, Train Acc: 0.88506, Val Acc: 0.83051
# Epoch: 018, Loss: 1.04446, Train Acc: 0.87356, Val Acc: 0.83051
# Epoch: 019, Loss: 1.01054, Train Acc: 0.90805, Val Acc: 0.83051
# Epoch: 020, Loss: 1.03858, Train Acc: 0.86207, Val Acc: 0.83051
# Epoch: 021, Loss: 1.03157, Train Acc: 0.89655, Val Acc: 0.83051
# Epoch: 022, Loss: 1.03909, Train Acc: 0.86207, Val Acc: 0.83051
# Epoch: 023, Loss: 1.03404, Train Acc: 0.88506, Val Acc: 0.83051
# Epoch: 024, Loss: 1.02790, Train Acc: 0.88506, Val Acc: 0.83051
# Epoch: 025, Loss: 1.03633, Train Acc: 0.86207, Val Acc: 0.83051
# Epoch: 026, Loss: 1.00277, Train Acc: 0.90805, Val Acc: 0.83051
# Epoch: 027, Loss: 1.02381, Train Acc: 0.88506, Val Acc: 0.83051
# Epoch: 028, Loss: 1.03944, Train Acc: 0.87356, Val Acc: 0.83051
# Epoch: 029, Loss: 1.03969, Train Acc: 0.86207, Val Acc: 0.84746
# Epoch: 030, Loss: 1.01552, Train Acc: 0.88506, Val Acc: 0.84746
# Epoch: 031, Loss: 1.04608, Train Acc: 0.87356, Val Acc: 0.84746
# Epoch: 032, Loss: 1.03084, Train Acc: 0.88506, Val Acc: 0.84746
# Epoch: 033, Loss: 1.00102, Train Acc: 0.90805, Val Acc: 0.83051
# Epoch: 034, Loss: 1.00570, Train Acc: 0.89655, Val Acc: 0.83051
# Epoch: 035, Loss: 1.03798, Train Acc: 0.87356, Val Acc: 0.83051
# Epoch: 036, Loss: 1.06779, Train Acc: 0.81609, Val Acc: 0.83051
# Epoch: 037, Loss: 1.05318, Train Acc: 0.85057, Val Acc: 0.83051
# Epoch: 038, Loss: 1.03420, Train Acc: 0.86207, Val Acc: 0.81356
# Epoch: 039, Loss: 1.01706, Train Acc: 0.88506, Val Acc: 0.81356
# Epoch: 040, Loss: 1.05525, Train Acc: 0.86207, Val Acc: 0.81356
# Epoch: 041, Loss: 1.01353, Train Acc: 0.88506, Val Acc: 0.81356
# Epoch: 042, Loss: 1.00693, Train Acc: 0.89655, Val Acc: 0.81356
# Epoch: 043, Loss: 0.97710, Train Acc: 0.93103, Val Acc: 0.81356
# Epoch: 044, Loss: 1.00093, Train Acc: 0.90805, Val Acc: 0.81356
# Epoch: 045, Loss: 1.01111, Train Acc: 0.89655, Val Acc: 0.81356
# Epoch: 046, Loss: 1.00197, Train Acc: 0.90805, Val Acc: 0.81356
# Epoch: 047, Loss: 1.00835, Train Acc: 0.90805, Val Acc: 0.81356
# Epoch: 048, Loss: 1.01562, Train Acc: 0.89655, Val Acc: 0.81356
# Epoch: 049, Loss: 1.04099, Train Acc: 0.87356, Val Acc: 0.81356
# Epoch: 050, Loss: 1.01400, Train Acc: 0.89655, Val Acc: 0.81356
# Epoch: 051, Loss: 1.03845, Train Acc: 0.86207, Val Acc: 0.81356
# Epoch: 052, Loss: 1.02039, Train Acc: 0.90805, Val Acc: 0.79661
# Epoch: 053, Loss: 1.02062, Train Acc: 0.88506, Val Acc: 0.79661
# Epoch: 054, Loss: 1.01835, Train Acc: 0.88506, Val Acc: 0.79661
# Epoch: 055, Loss: 1.02609, Train Acc: 0.88506, Val Acc: 0.79661
# Epoch: 056, Loss: 1.01934, Train Acc: 0.88506, Val Acc: 0.79661
# Epoch: 057, Loss: 1.02190, Train Acc: 0.90805, Val Acc: 0.79661
# Epoch: 058, Loss: 1.04975, Train Acc: 0.85057, Val Acc: 0.79661
# Epoch: 059, Loss: 1.03825, Train Acc: 0.87356, Val Acc: 0.79661
# Epoch: 060, Loss: 1.00026, Train Acc: 0.90805, Val Acc: 0.79661
# Epoch: 061, Loss: 1.02429, Train Acc: 0.87356, Val Acc: 0.79661
# Epoch: 062, Loss: 1.02894, Train Acc: 0.86207, Val Acc: 0.79661
# Epoch: 063, Loss: 0.99945, Train Acc: 0.91954, Val Acc: 0.79661
# Epoch: 064, Loss: 1.01167, Train Acc: 0.88506, Val Acc: 0.79661
# Epoch: 065, Loss: 0.97666, Train Acc: 0.93103, Val Acc: 0.79661
# Epoch: 066, Loss: 1.06562, Train Acc: 0.85057, Val Acc: 0.79661
# Epoch: 067, Loss: 1.00995, Train Acc: 0.89655, Val Acc: 0.79661
# Epoch: 068, Loss: 1.00437, Train Acc: 0.91954, Val Acc: 0.79661
# Epoch: 069, Loss: 1.01084, Train Acc: 0.89655, Val Acc: 0.79661
# Epoch: 070, Loss: 1.01337, Train Acc: 0.88506, Val Acc: 0.79661
# Epoch: 071, Loss: 1.00949, Train Acc: 0.88506, Val Acc: 0.79661
# Epoch: 072, Loss: 1.01983, Train Acc: 0.90805, Val Acc: 0.79661
# Epoch: 073, Loss: 1.00683, Train Acc: 0.90805, Val Acc: 0.77966
# Epoch: 074, Loss: 1.01588, Train Acc: 0.89655, Val Acc: 0.77966
# Epoch: 075, Loss: 1.04000, Train Acc: 0.88506, Val Acc: 0.77966
# Epoch: 076, Loss: 1.03483, Train Acc: 0.88506, Val Acc: 0.77966
# Epoch: 077, Loss: 0.99301, Train Acc: 0.91954, Val Acc: 0.77966
# Epoch: 078, Loss: 1.04559, Train Acc: 0.88506, Val Acc: 0.77966
# Epoch: 079, Loss: 1.03300, Train Acc: 0.89655, Val Acc: 0.76271
# Epoch: 080, Loss: 1.00249, Train Acc: 0.89655, Val Acc: 0.76271
# Epoch: 081, Loss: 0.99071, Train Acc: 0.93103, Val Acc: 0.76271
# Epoch: 082, Loss: 1.01616, Train Acc: 0.90805, Val Acc: 0.74576
# Epoch: 083, Loss: 1.03506, Train Acc: 0.87356, Val Acc: 0.74576
# Epoch: 084, Loss: 1.02606, Train Acc: 0.89655, Val Acc: 0.74576
# Epoch: 085, Loss: 1.03494, Train Acc: 0.87356, Val Acc: 0.74576
# Epoch: 086, Loss: 1.00645, Train Acc: 0.89655, Val Acc: 0.76271
# Epoch: 087, Loss: 1.04393, Train Acc: 0.87356, Val Acc: 0.76271
# Epoch: 088, Loss: 1.01643, Train Acc: 0.89655, Val Acc: 0.76271
# Epoch: 089, Loss: 0.99958, Train Acc: 0.90805, Val Acc: 0.76271
# Epoch: 090, Loss: 1.03372, Train Acc: 0.87356, Val Acc: 0.76271
# Epoch: 091, Loss: 1.01286, Train Acc: 0.88506, Val Acc: 0.76271
# Epoch: 092, Loss: 1.03144, Train Acc: 0.87356, Val Acc: 0.76271
# Epoch: 093, Loss: 0.99226, Train Acc: 0.91954, Val Acc: 0.76271
# Epoch: 094, Loss: 0.98905, Train Acc: 0.91954, Val Acc: 0.76271
# Epoch: 095, Loss: 1.02849, Train Acc: 0.89655, Val Acc: 0.76271
# Epoch: 096, Loss: 1.01078, Train Acc: 0.89655, Val Acc: 0.77966
# Epoch: 097, Loss: 1.01121, Train Acc: 0.89655, Val Acc: 0.77966
# Epoch: 098, Loss: 1.03406, Train Acc: 0.88506, Val Acc: 0.77966
# Epoch: 099, Loss: 0.99567, Train Acc: 0.90805, Val Acc: 0.77966
# Epoch: 100, Loss: 1.03049, Train Acc: 0.89655, Val Acc: 0.77966
# Test Accuracy: 0.83784
# Random State 784328  in the iteration 9
# Epoch: 001, Loss: 1.17355, Train Acc: 0.73563, Val Acc: 0.88136
# Epoch: 002, Loss: 1.17961, Train Acc: 0.73563, Val Acc: 0.88136
# Epoch: 003, Loss: 1.15813, Train Acc: 0.74713, Val Acc: 0.89831
# Epoch: 004, Loss: 1.11453, Train Acc: 0.79310, Val Acc: 0.89831
# Epoch: 005, Loss: 1.14223, Train Acc: 0.75862, Val Acc: 0.91525
# Epoch: 006, Loss: 1.10851, Train Acc: 0.80460, Val Acc: 0.89831
# Epoch: 007, Loss: 1.10639, Train Acc: 0.79310, Val Acc: 0.89831
# Epoch: 008, Loss: 1.12649, Train Acc: 0.79310, Val Acc: 0.89831
# Epoch: 009, Loss: 1.09572, Train Acc: 0.82759, Val Acc: 0.89831
# Epoch: 010, Loss: 1.06771, Train Acc: 0.85057, Val Acc: 0.89831
# Epoch: 011, Loss: 1.06729, Train Acc: 0.85057, Val Acc: 0.86441
# Epoch: 012, Loss: 1.05871, Train Acc: 0.86207, Val Acc: 0.86441
# Epoch: 013, Loss: 1.04391, Train Acc: 0.87356, Val Acc: 0.86441
# Epoch: 014, Loss: 1.10355, Train Acc: 0.80460, Val Acc: 0.88136
# Epoch: 015, Loss: 1.10310, Train Acc: 0.81609, Val Acc: 0.88136
# Epoch: 016, Loss: 1.06643, Train Acc: 0.82759, Val Acc: 0.88136
# Epoch: 017, Loss: 1.07899, Train Acc: 0.85057, Val Acc: 0.88136
# Epoch: 018, Loss: 1.10213, Train Acc: 0.79310, Val Acc: 0.88136
# Epoch: 019, Loss: 1.06787, Train Acc: 0.83908, Val Acc: 0.88136
# Epoch: 020, Loss: 1.09666, Train Acc: 0.82759, Val Acc: 0.88136
# Epoch: 021, Loss: 1.03529, Train Acc: 0.88506, Val Acc: 0.88136
# Epoch: 022, Loss: 1.06404, Train Acc: 0.86207, Val Acc: 0.88136
# Epoch: 023, Loss: 1.06926, Train Acc: 0.88506, Val Acc: 0.88136
# Epoch: 024, Loss: 1.03943, Train Acc: 0.88506, Val Acc: 0.88136
# Epoch: 025, Loss: 1.03008, Train Acc: 0.88506, Val Acc: 0.88136
# Epoch: 026, Loss: 1.06314, Train Acc: 0.86207, Val Acc: 0.88136
# Epoch: 027, Loss: 1.04966, Train Acc: 0.86207, Val Acc: 0.88136
# Epoch: 028, Loss: 1.03132, Train Acc: 0.88506, Val Acc: 0.88136
# Epoch: 029, Loss: 1.00117, Train Acc: 0.91954, Val Acc: 0.86441
# Epoch: 030, Loss: 1.02301, Train Acc: 0.90805, Val Acc: 0.86441
# Epoch: 031, Loss: 1.05722, Train Acc: 0.83908, Val Acc: 0.86441
# Epoch: 032, Loss: 1.05073, Train Acc: 0.83908, Val Acc: 0.86441
# Epoch: 033, Loss: 1.03544, Train Acc: 0.87356, Val Acc: 0.86441
# Epoch: 034, Loss: 1.04848, Train Acc: 0.86207, Val Acc: 0.86441
# Epoch: 035, Loss: 1.05445, Train Acc: 0.87356, Val Acc: 0.86441
# Epoch: 036, Loss: 1.07592, Train Acc: 0.82759, Val Acc: 0.86441
# Epoch: 037, Loss: 1.06139, Train Acc: 0.85057, Val Acc: 0.86441
# Epoch: 038, Loss: 1.02790, Train Acc: 0.88506, Val Acc: 0.84746
# Epoch: 039, Loss: 1.01878, Train Acc: 0.89655, Val Acc: 0.84746
# Epoch: 040, Loss: 1.03835, Train Acc: 0.86207, Val Acc: 0.84746
# Epoch: 041, Loss: 1.02554, Train Acc: 0.89655, Val Acc: 0.84746
# Epoch: 042, Loss: 1.13249, Train Acc: 0.77011, Val Acc: 0.84746
# Epoch: 043, Loss: 1.01255, Train Acc: 0.91954, Val Acc: 0.84746
# Epoch: 044, Loss: 1.03521, Train Acc: 0.86207, Val Acc: 0.84746
# Epoch: 045, Loss: 1.02499, Train Acc: 0.89655, Val Acc: 0.86441
# Epoch: 046, Loss: 1.01673, Train Acc: 0.88506, Val Acc: 0.84746
# Epoch: 047, Loss: 1.01977, Train Acc: 0.88506, Val Acc: 0.84746
# Epoch: 048, Loss: 1.01036, Train Acc: 0.88506, Val Acc: 0.84746
# Epoch: 049, Loss: 1.03635, Train Acc: 0.87356, Val Acc: 0.84746
# Epoch: 050, Loss: 1.06707, Train Acc: 0.85057, Val Acc: 0.83051
# Epoch: 051, Loss: 1.08492, Train Acc: 0.81609, Val Acc: 0.84746
# Epoch: 052, Loss: 1.05911, Train Acc: 0.83908, Val Acc: 0.84746
# Epoch: 053, Loss: 1.08430, Train Acc: 0.81609, Val Acc: 0.84746
# Epoch: 054, Loss: 1.05216, Train Acc: 0.86207, Val Acc: 0.84746
# Epoch: 055, Loss: 1.03150, Train Acc: 0.88506, Val Acc: 0.86441
# Epoch: 056, Loss: 1.05879, Train Acc: 0.85057, Val Acc: 0.88136
# Epoch: 057, Loss: 1.04911, Train Acc: 0.85057, Val Acc: 0.88136
# Epoch: 058, Loss: 1.05289, Train Acc: 0.83908, Val Acc: 0.88136
# Epoch: 059, Loss: 1.03106, Train Acc: 0.87356, Val Acc: 0.88136
# Epoch: 060, Loss: 1.01992, Train Acc: 0.89655, Val Acc: 0.88136
# Epoch: 061, Loss: 1.06632, Train Acc: 0.85057, Val Acc: 0.88136
# Epoch: 062, Loss: 1.03501, Train Acc: 0.87356, Val Acc: 0.88136
# Epoch: 063, Loss: 1.05488, Train Acc: 0.86207, Val Acc: 0.88136
# Epoch: 064, Loss: 1.05250, Train Acc: 0.86207, Val Acc: 0.88136
# Epoch: 065, Loss: 1.00708, Train Acc: 0.90805, Val Acc: 0.88136
# Epoch: 066, Loss: 1.02533, Train Acc: 0.87356, Val Acc: 0.88136
# Epoch: 067, Loss: 0.99391, Train Acc: 0.93103, Val Acc: 0.86441
# Epoch: 068, Loss: 1.07220, Train Acc: 0.82759, Val Acc: 0.86441
# Epoch: 069, Loss: 1.00592, Train Acc: 0.90805, Val Acc: 0.88136
# Epoch: 070, Loss: 1.03870, Train Acc: 0.86207, Val Acc: 0.88136
# Epoch: 071, Loss: 1.04065, Train Acc: 0.87356, Val Acc: 0.88136
# Epoch: 072, Loss: 1.03499, Train Acc: 0.87356, Val Acc: 0.88136
# Epoch: 073, Loss: 1.01750, Train Acc: 0.89655, Val Acc: 0.88136
# Epoch: 074, Loss: 1.01048, Train Acc: 0.89655, Val Acc: 0.88136
# Epoch: 075, Loss: 1.01400, Train Acc: 0.90805, Val Acc: 0.88136
# Epoch: 076, Loss: 1.06119, Train Acc: 0.86207, Val Acc: 0.88136
# Epoch: 077, Loss: 0.99788, Train Acc: 0.91954, Val Acc: 0.88136
# Epoch: 078, Loss: 1.03651, Train Acc: 0.89655, Val Acc: 0.86441
# Epoch: 079, Loss: 1.00971, Train Acc: 0.91954, Val Acc: 0.84746
# Epoch: 080, Loss: 0.99420, Train Acc: 0.90805, Val Acc: 0.83051
# Epoch: 081, Loss: 1.03381, Train Acc: 0.86207, Val Acc: 0.83051
# Epoch: 082, Loss: 0.98153, Train Acc: 0.93103, Val Acc: 0.83051
# Epoch: 083, Loss: 1.06610, Train Acc: 0.85057, Val Acc: 0.83051
# Epoch: 084, Loss: 0.97392, Train Acc: 0.94253, Val Acc: 0.83051
# Epoch: 085, Loss: 1.02005, Train Acc: 0.88506, Val Acc: 0.83051
# Epoch: 086, Loss: 0.99685, Train Acc: 0.90805, Val Acc: 0.83051
# Epoch: 087, Loss: 1.00434, Train Acc: 0.90805, Val Acc: 0.83051
# Epoch: 088, Loss: 0.99545, Train Acc: 0.91954, Val Acc: 0.84746
# Epoch: 089, Loss: 1.07504, Train Acc: 0.83908, Val Acc: 0.84746
# Epoch: 090, Loss: 1.03024, Train Acc: 0.88506, Val Acc: 0.84746
# Epoch: 091, Loss: 1.04906, Train Acc: 0.85057, Val Acc: 0.84746
# Epoch: 092, Loss: 1.01925, Train Acc: 0.89655, Val Acc: 0.84746
# Epoch: 093, Loss: 1.00104, Train Acc: 0.90805, Val Acc: 0.86441
# Epoch: 094, Loss: 0.99254, Train Acc: 0.91954, Val Acc: 0.84746
# Epoch: 095, Loss: 1.04324, Train Acc: 0.86207, Val Acc: 0.84746
# Epoch: 096, Loss: 1.01334, Train Acc: 0.89655, Val Acc: 0.83051
# Epoch: 097, Loss: 1.04464, Train Acc: 0.85057, Val Acc: 0.83051
# Epoch: 098, Loss: 1.05630, Train Acc: 0.83908, Val Acc: 0.83051
# Epoch: 099, Loss: 1.00469, Train Acc: 0.90805, Val Acc: 0.83051
# Epoch: 100, Loss: 1.00162, Train Acc: 0.90805, Val Acc: 0.83051
# Test Accuracy: 0.81081
# GAT
# 75.13513513513513 +- 7.907426399096106

# %% [markdown]
# #### Visualize the results and the embedding

# %%
fig,axs = plt.subplots(1,2,figsize=(20,8))
axs[0].set_title('GCN boxplot of 10 runs')
axs[0].boxplot(global_results,labels=['GCN','MLP', 'SAGE', 'Cheb', 'GAT'])
axs[0].set_xlabel('Run')
axs[0].set_ylabel('Accuracy')

axs[1].set_title('Models lineplot of 10 runs')
axs[1].plot(range(1,11),global_results[0],'ro',color='red')
axs[1].plot(range(1,11),global_results[0],color='red',label='GCN')

axs[1].plot(range(1,11),global_results[1],'ro',color='blue')
axs[1].plot(range(1,11),global_results[1],color='blue',label='MLP')

axs[1].plot(range(1,11),global_results[2],'ro',color='green')
axs[1].plot(range(1,11),global_results[2],color='green',label='SAGE')

axs[1].plot(range(1,11),global_results[3],'ro',color='k')
axs[1].plot(range(1,11),global_results[3],color='k',label='Cheb')

axs[1].plot(range(1,11),global_results[4],'ro',color='violet')
axs[1].plot(range(1,11),global_results[4],color='violet',label='GAT')

axs[1].set_xticks(range(1,11))
axs[1].set_xlabel('Run')
axs[1].set_ylabel('Accuracy')
axs[1].legend()
fig.show()

# %%
from sklearn.manifold import TSNE
# Let's see the embedding of the best model over the 10 runs

'''
    Arguments of TSNE:
        * n_components: The dimension of the embedded space.
        * random_state: The seed to use for the t-SNE algorithm.
    Returns:
        * tsne_obj: The t-SNE embedding of the nodes.
'''

# GCN
out_gcn = global_best_models[0][0](data.x, data.edge_index) # Get the output of the model with the entire dataset
tsne = TSNE(n_components=2, random_state=12345)
tsne_gcn_results = tsne.fit_transform(out_gcn.detach().cpu().numpy())
# SAGE
out_sage = global_best_models[2][0](data.x, data.edge_index) # Get the output of the model with the entire dataset
tsne = TSNE(n_components=2, random_state=12345)
tsne_sage_results = tsne.fit_transform(out_sage.detach().cpu().numpy())
# Cheb
out_cheb = global_best_models[3][0](data.x, data.edge_index) # Get the output of the model with the entire dataset
tsne = TSNE(n_components=2, random_state=12345)
tsne_cheb_results = tsne.fit_transform(out_cheb.detach().cpu().numpy())
# GAT
out_gat = global_best_models[4][0](data.x, data.edge_index) # Get the output of the model with the entire dataset
tsne = TSNE(n_components=2, random_state=12345)
tsne_gat_results = tsne.fit_transform(out_gat.detach().cpu().numpy())
# MLP
out_mlp = global_best_models[1][0](data.x, data.edge_index) # Get the output of the model with the entire dataset
tsne = TSNE(n_components=2, random_state=12345)
tsne_mlp_results = tsne.fit_transform(out_mlp.detach().cpu().numpy())
# Plot the results
fig,axs = plt.subplots(3,2,figsize=(20,10))
axs[0,0].set_title('GCN t-SNE')
axs[0,0].scatter(tsne_gcn_results[:,0],tsne_gcn_results[:,1],c=data.y.cpu(),cmap='viridis',s=60,alpha=0.85,edgecolors='black',linewidths=0.5)

axs[0,1].set_title('MLP t-SNE')
axs[0,1].scatter(tsne_mlp_results[:,0],tsne_mlp_results[:,1],c=data.y.cpu(),cmap='viridis',s=60,alpha=0.85,edgecolors='black',linewidths=0.5)

axs[1,0].set_title('SAGE t-SNE')
axs[1,0].scatter(tsne_sage_results[:,0],tsne_sage_results[:,1],c=data.y.cpu(),cmap='viridis',s=60,alpha=0.85,edgecolors='black',linewidths=0.5)

axs[1,1].set_title('Cheb t-SNE')
axs[1,1].scatter(tsne_cheb_results[:,0],tsne_cheb_results[:,1],c=data.y.cpu(),cmap='viridis',s=60,alpha=0.85,edgecolors='black',linewidths=0.5)

axs[2,0].set_title('GAT t-SNE')
axs[2,0].scatter(tsne_gat_results[:,0],tsne_gat_results[:,1],c=data.y.cpu(),cmap='viridis',s=60,alpha=0.85,edgecolors='black',linewidths=0.5)

fig.suptitle('t-SNE of the best model over the 10 runs',fontsize=20)
fig.show()

# %% [markdown]
# ### 3.1 Report

# %% [markdown]
# In this section we will report the results of the model. We will report the accuracy, precision, recall and F1 score for the model. We will also visualize the confusion matrix for the model using the scikit-learn library to report the results. After all, we will put the results in a markdown cell.

# %% [markdown]
# #### Report the results

# %%
# Report the best model over the 10 runs using the test set and sklearn classification report
from sklearn.metrics import classification_report
print('GCN')
print(classification_report(data.y[test_mask].cpu(), global_best_models[0][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy()))
print('========================================================================')
print('MLP')
print(classification_report(data.y[test_mask].cpu(), global_best_models[1][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy()))
print('SAGE')
print(classification_report(data.y[test_mask].cpu(), global_best_models[2][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy()))
print('========================================================================')
print('Cheb')
print(classification_report(data.y[test_mask].cpu(), global_best_models[3][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy()))
print('========================================================================')
print('GAT')
print(classification_report(data.y[test_mask].cpu(), global_best_models[4][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy()))
print('========================================================================')
# Out:
# GCN
#               precision    recall  f1-score   support
#
#            0       1.00      0.78      0.88         9
#            1       0.29      0.67      0.40         3
#            2       0.00      0.00      0.00         5
#            3       0.80      0.50      0.62        16
#            4       0.44      1.00      0.62         4
#
#     accuracy                           0.57        37
#    macro avg       0.51      0.59      0.50        37
# weighted avg       0.66      0.57      0.58        37
#
# ========================================================================
# MLP
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       0.33      0.33      0.33         3
#            2       0.62      1.00      0.77         5
#            3       0.93      0.81      0.87        16
#            4       1.00      0.75      0.86         4
#
#     accuracy                           0.84        37
#    macro avg       0.78      0.78      0.77        37
# weighted avg       0.86      0.84      0.84        37
#
# SAGE
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       0.00      0.00      0.00         3
#            2       1.00      1.00      1.00         5
#            3       0.80      1.00      0.89        16
#            4       1.00      0.75      0.86         4
#
#     accuracy                           0.89        37
#    macro avg       0.76      0.75      0.75        37
# weighted avg       0.83      0.89      0.86        37
#
# ========================================================================
# Cheb
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89         9
#            1       0.00      0.00      0.00         3
#            2       0.67      0.40      0.50         5
#            3       0.64      0.88      0.74        16
#            4       1.00      0.25      0.40         4
#
#     accuracy                           0.68        37
#    macro avg       0.64      0.48      0.51        37
# weighted avg       0.69      0.68      0.65        37
#
# ========================================================================
# GAT
#               precision    recall  f1-score   support
#
#            0       0.86      0.67      0.75         9
#            1       0.00      0.00      0.00         3
#            2       0.43      0.60      0.50         5
#            3       0.83      0.94      0.88        16
#            4       1.00      1.00      1.00         4
#
#     accuracy                           0.76        37
#    macro avg       0.62      0.64      0.63        37
# weighted avg       0.73      0.76      0.74        37
#
# ========================================================================

# %% [markdown]
# #### Confusion matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Crear las matrices de confusión
conf_matrix_gcn = confusion_matrix(data.y[test_mask].cpu(), global_best_models[0][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy())
conf_matrix_mlp = confusion_matrix(data.y[test_mask].cpu(), global_best_models[1][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy())
conf_matrix_sage = confusion_matrix(data.y[test_mask].cpu(), global_best_models[2][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy())
conf_matrix_cheb = confusion_matrix(data.y[test_mask].cpu(), global_best_models[3][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy())
conf_matrix_gat = confusion_matrix(data.y[test_mask].cpu(), global_best_models[4][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy())

# Crear los displays de las matrices de confusión
disp_gcn = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_gcn, display_labels=data.y.unique().cpu().numpy())
disp_mlp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_mlp, display_labels=data.y.unique().cpu().numpy())
disp_sage = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_sage, display_labels=data.y.unique().cpu().numpy())
disp_cheb = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_cheb, display_labels=data.y.unique().cpu().numpy())
disp_gat = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_gat, display_labels=data.y.unique().cpu().numpy())

# Crear la figura y los ejes
fig, axs = plt.subplots(3, 2, figsize=(20, 15))

# Plotear las matrices de confusión
disp_gcn.plot(ax=axs[0][0])
disp_gcn.ax_.set_title('GCN Confusion Matrix')
disp_gcn.im_.colorbar.remove()

disp_mlp.plot(ax=axs[0][1])
disp_mlp.ax_.set_title('MLP Confusion Matrix')
disp_mlp.im_.colorbar.remove()

disp_sage.plot(ax=axs[1][0])
disp_sage.ax_.set_title('SAGE Confusion Matrix')
disp_sage.im_.colorbar.remove()

disp_cheb.plot(ax=axs[1][1])
disp_cheb.ax_.set_title('Cheb Confusion Matrix')
disp_cheb.im_.colorbar.remove()

# Colocar la última matriz en la posición central de la tercera fila
disp_gat.plot(ax=axs[2][0])
disp_gat.ax_.set_title('GAT Confusion Matrix')
disp_gat.im_.colorbar.remove()

# Eliminar el subplot vacío
fig.delaxes(axs[2][1])

# Ajustar el diseño
fig.tight_layout(rect=[0, 0, 1, 0.95])
fig.suptitle('Confusion Matrix of the best model over the 10 runs', fontsize=20)

# Mostrar la figura
plt.show()
